# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/B0-Pro-V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# Configuración del modelo
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-4

# Paths
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')
TEST_IMAGES_PATH = os.path.join(BASE_PATH, 'test/images')
TEST_MASKS_PATH = os.path.join(BASE_PATH, 'test/masks')

# Definición de clases y funciones del modelo
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True
    layer_names = [
        'block1a_project_activation',
        'block2b_add',
        'block3b_add',
        'block5c_add',
        'top_activation'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)
    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_B0')
    return model

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

def load_and_preprocess_data(image_paths, mask_paths, augment=False):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5:
            image, mask = tf.image.flip_left_right(image), tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5:
            image, mask = tf.image.flip_up_down(image), tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5:
            k = tf.random.uniform([], 1, 4, dtype=tf.int32)
            image, mask = tf.image.rot90(image, k), tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = tf.data.Dataset.zip((image_ds, mask_ds))
    if augment:
        dataset = dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_B0.keras'):
    model = create_weed_detection_model()
    model.summary()
    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-5)

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_iou_metric', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_iou_metric', patience=50, mode='max', restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1),
    ]

    print(f"Iniciando entrenamiento por {EPOCHS} épocas...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history

def plot_sample_masks(images, masks, predictions, num_samples=4):
    plt.figure(figsize=(15, 5 * num_samples))
    for i in range(num_samples):
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(images[i].astype("uint8"))
        plt.title("Imagen")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(tf.argmax(masks[i], axis=-1))
        plt.title("Máscara Real")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(tf.argmax(predictions[i], axis=-1))
        plt.title("Máscara Predicha")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(TRAIN_MASKS_PATH, '*.png')))
    val_image_paths = sorted(glob(os.path.join(VAL_IMAGES_PATH, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(VAL_MASKS_PATH, '*.png')))

    print("Creando datasets de entrenamiento y validación...")
    train_ds = load_and_preprocess_data(train_image_paths, train_mask_paths, augment=True)
    val_ds = load_and_preprocess_data(val_image_paths, val_mask_paths, augment=False)

    model_save_path = 'efficient_weed_model_B0_best.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("\n--- Entrenamiento Finalizado ---")
    print(f"El mejor modelo se ha guardado en: {model_save_path}")

    print("\nCargando el mejor modelo guardado para la evaluación en el conjunto de test...")
    best_model = tf.keras.models.load_model(
        model_save_path,
        custom_objects={
            'ASPPModule': ASPPModule,
            'DeformableAttention': DeformableAttention,
            'combined_loss': combined_loss,
            'dice_coefficient': dice_coefficient,
            'iou_metric': iou_metric,
            'dice_loss': dice_loss
        }
    )

    test_image_paths = sorted(glob(os.path.join(TEST_IMAGES_PATH, '*.jpg')))
    test_mask_paths = sorted(glob(os.path.join(TEST_MASKS_PATH, '*.png')))

    if not test_image_paths:
        print("\nADVERTENCIA: No se encontraron imágenes en el directorio de test. Saltando la evaluación de test.")
    else:
        print(f"Se encontraron {len(test_image_paths)} imágenes de test.")
        print("Creando dataset de test...")
        test_ds = load_and_preprocess_data(test_image_paths, test_mask_paths, augment=False)

        print("\n--- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---")
        test_metrics = best_model.evaluate(test_ds)

        print("\n## MÉTRICAS DE TEST - MODELO 'B0' ##")
        print(f"Test Loss: {test_metrics[0]:.4f}")
        print(f"Test Dice Coefficient: {test_metrics[1]:.4f}")
        print(f"Test mIoU: {test_metrics[2]:.4f}")
        print(f"Test Global Accuracy: {test_metrics[3]:.4f}")

        print("\nCalculando IoU por clase en el conjunto de test...")
        iou_per_class_values = []
        for images_batch, masks_batch in test_ds:
            predictions_batch = best_model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()
        class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
        print("\n## IoU por Clase (Test) ##")
        for i, iou in enumerate(iou_per_class_values):
            print(f"IoU for {class_names[i]}: {iou:.4f}")

        print(f"\nPromedio de IoU por clase: {np.mean(iou_per_class_values):.4f}")

        # Mostrar ejemplos de máscaras reales y predichas
        for images_batch, masks_batch in test_ds.take(1):
            predictions_batch = best_model.predict(images_batch)
            plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)

        # Gráficas de Dice Coefficient y Loss durante el entrenamiento
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['dice_coefficient'], label='Dice Coefficient (Train)')
        plt.plot(history.history['val_dice_coefficient'], label='Dice Coefficient (Validation)')
        plt.title('Dice Coefficient over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Dice Coefficient')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Loss (Train)')
        plt.plot(history.history['val_loss'], label='Loss (Validation)')
        plt.title('Loss over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
# Out:
# Creando datasets de entrenamiento y validación...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientWeedDetectionModel_B0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer[0][0] │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 32), (None,   │            │                   │
# │                     │ 16, 16, 48),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 112), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 96)  │     10,752 │ EfficientNetV2B0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 192) │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 8, 8, 96)  │     20,160 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     36,864 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      4,608 │ EfficientNetV2B0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_10[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │     20,160 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_12[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     18,432 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      1,536 │ EfficientNetV2B0… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │ 96)               │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      5,472 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      4,608 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │        384 │ EfficientNetV2B0… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_16[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │ 48)               │            │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │      1,584 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_18[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        576 │ dropout_8[0][0]   │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,514,346 (51.55 MB)
#  Trainable params: 13,449,082 (51.30 MB)
#  Non-trainable params: 65,264 (254.94 KB)
# Iniciando entrenamiento por 150 épocas...
# Epoch 1/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2084 - dice_coefficient: 0.0880 - iou_metric: 0.1170 - loss: 2.3129
# Epoch 1: val_iou_metric improved from -inf to 0.13122, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 156s 227ms/step - accuracy: 0.2090 - dice_coefficient: 0.0881 - iou_metric: 0.1174 - loss: 2.3121 - val_accuracy: 0.2315 - val_dice_coefficient: 0.0865 - val_iou_metric: 0.1312 - val_loss: 2.1931 - learning_rate: 1.0000e-04
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3590 - dice_coefficient: 0.1047 - iou_metric: 0.2252 - loss: 2.1315
# Epoch 2: val_iou_metric improved from 0.13122 to 0.22337, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.3595 - dice_coefficient: 0.1048 - iou_metric: 0.2256 - loss: 2.1307 - val_accuracy: 0.3636 - val_dice_coefficient: 0.0931 - val_iou_metric: 0.2234 - val_loss: 2.0786 - learning_rate: 1.0000e-04
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5622 - dice_coefficient: 0.1334 - iou_metric: 0.4074 - loss: 1.8860
# Epoch 3: val_iou_metric improved from 0.22337 to 0.31329, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.5625 - dice_coefficient: 0.1334 - iou_metric: 0.4077 - loss: 1.8857 - val_accuracy: 0.4732 - val_dice_coefficient: 0.1080 - val_iou_metric: 0.3133 - val_loss: 1.9148 - learning_rate: 1.0000e-04
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6930 - dice_coefficient: 0.1610 - iou_metric: 0.5500 - loss: 1.7467
# Epoch 4: val_iou_metric improved from 0.31329 to 0.50267, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.6932 - dice_coefficient: 0.1611 - iou_metric: 0.5502 - loss: 1.7465 - val_accuracy: 0.6604 - val_dice_coefficient: 0.1348 - val_iou_metric: 0.5027 - val_loss: 1.7867 - learning_rate: 1.0000e-04
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7775 - dice_coefficient: 0.1884 - iou_metric: 0.6562 - loss: 1.6387
# Epoch 5: val_iou_metric improved from 0.50267 to 0.63175, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.7775 - dice_coefficient: 0.1884 - iou_metric: 0.6563 - loss: 1.6387 - val_accuracy: 0.7656 - val_dice_coefficient: 0.1681 - val_iou_metric: 0.6318 - val_loss: 1.6615 - learning_rate: 1.0000e-04
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8167 - dice_coefficient: 0.2039 - iou_metric: 0.7106 - loss: 1.5798
# Epoch 6: val_iou_metric improved from 0.63175 to 0.72975, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.8168 - dice_coefficient: 0.2040 - iou_metric: 0.7107 - loss: 1.5798 - val_accuracy: 0.8381 - val_dice_coefficient: 0.2075 - val_iou_metric: 0.7297 - val_loss: 1.5083 - learning_rate: 1.0000e-04
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8439 - dice_coefficient: 0.2257 - iou_metric: 0.7473 - loss: 1.5247
# Epoch 7: val_iou_metric improved from 0.72975 to 0.76185, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8440 - dice_coefficient: 0.2257 - iou_metric: 0.7473 - loss: 1.5246 - val_accuracy: 0.8605 - val_dice_coefficient: 0.2327 - val_iou_metric: 0.7618 - val_loss: 1.4284 - learning_rate: 1.0000e-04
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8677 - dice_coefficient: 0.2442 - iou_metric: 0.7814 - loss: 1.4625
# Epoch 8: val_iou_metric improved from 0.76185 to 0.78012, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8677 - dice_coefficient: 0.2443 - iou_metric: 0.7814 - loss: 1.4625 - val_accuracy: 0.8728 - val_dice_coefficient: 0.2481 - val_iou_metric: 0.7801 - val_loss: 1.3859 - learning_rate: 1.0000e-04
# Epoch 9/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8719 - dice_coefficient: 0.2521 - iou_metric: 0.7879 - loss: 1.4498
# Epoch 9: val_iou_metric improved from 0.78012 to 0.78889, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8719 - dice_coefficient: 0.2522 - iou_metric: 0.7879 - loss: 1.4497 - val_accuracy: 0.8788 - val_dice_coefficient: 0.2644 - val_iou_metric: 0.7889 - val_loss: 1.3474 - learning_rate: 1.0000e-04
# Epoch 10/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8810 - dice_coefficient: 0.2676 - iou_metric: 0.8002 - loss: 1.4000
# Epoch 10: val_iou_metric improved from 0.78889 to 0.79257, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8810 - dice_coefficient: 0.2676 - iou_metric: 0.8002 - loss: 1.4001 - val_accuracy: 0.8818 - val_dice_coefficient: 0.2776 - val_iou_metric: 0.7926 - val_loss: 1.3181 - learning_rate: 1.0000e-04
# Epoch 11/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8886 - dice_coefficient: 0.2828 - iou_metric: 0.8115 - loss: 1.3689
# Epoch 11: val_iou_metric improved from 0.79257 to 0.79949, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8885 - dice_coefficient: 0.2828 - iou_metric: 0.8114 - loss: 1.3688 - val_accuracy: 0.8854 - val_dice_coefficient: 0.2889 - val_iou_metric: 0.7995 - val_loss: 1.2931 - learning_rate: 1.0000e-04
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8862 - dice_coefficient: 0.2939 - iou_metric: 0.8082 - loss: 1.3631
# Epoch 12: val_iou_metric did not improve from 0.79949
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8862 - dice_coefficient: 0.2938 - iou_metric: 0.8082 - loss: 1.3629 - val_accuracy: 0.8839 - val_dice_coefficient: 0.2964 - val_iou_metric: 0.7976 - val_loss: 1.2671 - learning_rate: 1.0000e-04
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8916 - dice_coefficient: 0.3030 - iou_metric: 0.8152 - loss: 1.3255
# Epoch 13: val_iou_metric did not improve from 0.79949
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8915 - dice_coefficient: 0.3030 - iou_metric: 0.8151 - loss: 1.3255 - val_accuracy: 0.8854 - val_dice_coefficient: 0.3095 - val_iou_metric: 0.7990 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 14/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8916 - dice_coefficient: 0.3167 - iou_metric: 0.8153 - loss: 1.2903
# Epoch 14: val_iou_metric did not improve from 0.79949
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8916 - dice_coefficient: 0.3167 - iou_metric: 0.8153 - loss: 1.2902 - val_accuracy: 0.8798 - val_dice_coefficient: 0.3196 - val_iou_metric: 0.7910 - val_loss: 1.2096 - learning_rate: 1.0000e-04
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8987 - dice_coefficient: 0.3282 - iou_metric: 0.8257 - loss: 1.2522
# Epoch 15: val_iou_metric improved from 0.79949 to 0.80522, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.8987 - dice_coefficient: 0.3282 - iou_metric: 0.8256 - loss: 1.2522 - val_accuracy: 0.8917 - val_dice_coefficient: 0.3319 - val_iou_metric: 0.8052 - val_loss: 1.1811 - learning_rate: 1.0000e-04
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8959 - dice_coefficient: 0.3367 - iou_metric: 0.8232 - loss: 1.2532
# Epoch 16: val_iou_metric improved from 0.80522 to 0.80720, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8959 - dice_coefficient: 0.3367 - iou_metric: 0.8232 - loss: 1.2531 - val_accuracy: 0.8930 - val_dice_coefficient: 0.3375 - val_iou_metric: 0.8072 - val_loss: 1.1604 - learning_rate: 1.0000e-04
# Epoch 17/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9028 - dice_coefficient: 0.3495 - iou_metric: 0.8319 - loss: 1.2038
# Epoch 17: val_iou_metric improved from 0.80720 to 0.82183, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9028 - dice_coefficient: 0.3495 - iou_metric: 0.8319 - loss: 1.2038 - val_accuracy: 0.9018 - val_dice_coefficient: 0.3540 - val_iou_metric: 0.8218 - val_loss: 1.1286 - learning_rate: 1.0000e-04
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9026 - dice_coefficient: 0.3555 - iou_metric: 0.8324 - loss: 1.1917
# Epoch 18: val_iou_metric did not improve from 0.82183
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9026 - dice_coefficient: 0.3555 - iou_metric: 0.8325 - loss: 1.1917 - val_accuracy: 0.8869 - val_dice_coefficient: 0.3495 - val_iou_metric: 0.7973 - val_loss: 1.1298 - learning_rate: 1.0000e-04
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9076 - dice_coefficient: 0.3698 - iou_metric: 0.8402 - loss: 1.1501
# Epoch 19: val_iou_metric did not improve from 0.82183
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9076 - dice_coefficient: 0.3698 - iou_metric: 0.8402 - loss: 1.1502 - val_accuracy: 0.9009 - val_dice_coefficient: 0.3654 - val_iou_metric: 0.8202 - val_loss: 1.1018 - learning_rate: 1.0000e-04
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9094 - dice_coefficient: 0.3824 - iou_metric: 0.8421 - loss: 1.1297
# Epoch 20: val_iou_metric did not improve from 0.82183
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9094 - dice_coefficient: 0.3824 - iou_metric: 0.8421 - loss: 1.1297 - val_accuracy: 0.8975 - val_dice_coefficient: 0.3664 - val_iou_metric: 0.8150 - val_loss: 1.1010 - learning_rate: 1.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9107 - dice_coefficient: 0.3846 - iou_metric: 0.8442 - loss: 1.1336
# Epoch 21: val_iou_metric improved from 0.82183 to 0.82578, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.9107 - dice_coefficient: 0.3846 - iou_metric: 0.8442 - loss: 1.1337 - val_accuracy: 0.9041 - val_dice_coefficient: 0.3719 - val_iou_metric: 0.8258 - val_loss: 1.0893 - learning_rate: 1.0000e-04
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9116 - dice_coefficient: 0.3916 - iou_metric: 0.8453 - loss: 1.1119
# Epoch 22: val_iou_metric improved from 0.82578 to 0.83593, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9116 - dice_coefficient: 0.3915 - iou_metric: 0.8453 - loss: 1.1120 - val_accuracy: 0.9104 - val_dice_coefficient: 0.3857 - val_iou_metric: 0.8359 - val_loss: 1.0588 - learning_rate: 1.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9092 - dice_coefficient: 0.3963 - iou_metric: 0.8417 - loss: 1.1098
# Epoch 23: val_iou_metric did not improve from 0.83593
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9092 - dice_coefficient: 0.3963 - iou_metric: 0.8417 - loss: 1.1099 - val_accuracy: 0.9082 - val_dice_coefficient: 0.3877 - val_iou_metric: 0.8327 - val_loss: 1.0500 - learning_rate: 1.0000e-04
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9140 - dice_coefficient: 0.4070 - iou_metric: 0.8506 - loss: 1.0784
# Epoch 24: val_iou_metric did not improve from 0.83593
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9140 - dice_coefficient: 0.4070 - iou_metric: 0.8506 - loss: 1.0783 - val_accuracy: 0.9045 - val_dice_coefficient: 0.3943 - val_iou_metric: 0.8268 - val_loss: 1.0328 - learning_rate: 1.0000e-04
# Epoch 25/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9177 - dice_coefficient: 0.4231 - iou_metric: 0.8556 - loss: 1.0436
# Epoch 25: val_iou_metric did not improve from 0.83593
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9177 - dice_coefficient: 0.4231 - iou_metric: 0.8556 - loss: 1.0437 - val_accuracy: 0.9006 - val_dice_coefficient: 0.4040 - val_iou_metric: 0.8204 - val_loss: 1.0152 - learning_rate: 1.0000e-04
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9161 - dice_coefficient: 0.4280 - iou_metric: 0.8539 - loss: 1.0290
# Epoch 26: val_iou_metric improved from 0.83593 to 0.84053, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9161 - dice_coefficient: 0.4280 - iou_metric: 0.8539 - loss: 1.0289 - val_accuracy: 0.9133 - val_dice_coefficient: 0.4245 - val_iou_metric: 0.8405 - val_loss: 0.9844 - learning_rate: 1.0000e-04
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9111 - dice_coefficient: 0.4401 - iou_metric: 0.8466 - loss: 1.0208
# Epoch 27: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9111 - dice_coefficient: 0.4401 - iou_metric: 0.8467 - loss: 1.0207 - val_accuracy: 0.9097 - val_dice_coefficient: 0.4269 - val_iou_metric: 0.8339 - val_loss: 0.9755 - learning_rate: 1.0000e-04
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9188 - dice_coefficient: 0.4509 - iou_metric: 0.8584 - loss: 0.9853
# Epoch 28: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9188 - dice_coefficient: 0.4509 - iou_metric: 0.8583 - loss: 0.9854 - val_accuracy: 0.9050 - val_dice_coefficient: 0.4284 - val_iou_metric: 0.8272 - val_loss: 0.9702 - learning_rate: 1.0000e-04
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9179 - dice_coefficient: 0.4493 - iou_metric: 0.8566 - loss: 1.0036
# Epoch 29: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9179 - dice_coefficient: 0.4494 - iou_metric: 0.8565 - loss: 1.0035 - val_accuracy: 0.8967 - val_dice_coefficient: 0.4277 - val_iou_metric: 0.8145 - val_loss: 0.9691 - learning_rate: 1.0000e-04
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9199 - dice_coefficient: 0.4658 - iou_metric: 0.8596 - loss: 0.9670
# Epoch 30: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9199 - dice_coefficient: 0.4658 - iou_metric: 0.8596 - loss: 0.9670 - val_accuracy: 0.9067 - val_dice_coefficient: 0.4353 - val_iou_metric: 0.8310 - val_loss: 0.9580 - learning_rate: 1.0000e-04
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9184 - dice_coefficient: 0.4677 - iou_metric: 0.8578 - loss: 0.9597
# Epoch 31: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9184 - dice_coefficient: 0.4678 - iou_metric: 0.8578 - loss: 0.9596 - val_accuracy: 0.9060 - val_dice_coefficient: 0.4401 - val_iou_metric: 0.8293 - val_loss: 0.9451 - learning_rate: 1.0000e-04
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9190 - dice_coefficient: 0.4738 - iou_metric: 0.8584 - loss: 0.9625
# Epoch 32: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9190 - dice_coefficient: 0.4737 - iou_metric: 0.8584 - loss: 0.9625 - val_accuracy: 0.9029 - val_dice_coefficient: 0.4367 - val_iou_metric: 0.8245 - val_loss: 0.9493 - learning_rate: 1.0000e-04
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9171 - dice_coefficient: 0.4729 - iou_metric: 0.8564 - loss: 0.9745
# Epoch 33: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9171 - dice_coefficient: 0.4729 - iou_metric: 0.8564 - loss: 0.9744 - val_accuracy: 0.9093 - val_dice_coefficient: 0.4478 - val_iou_metric: 0.8346 - val_loss: 0.9335 - learning_rate: 1.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9180 - dice_coefficient: 0.4731 - iou_metric: 0.8568 - loss: 0.9624
# Epoch 34: val_iou_metric did not improve from 0.84053
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9180 - dice_coefficient: 0.4731 - iou_metric: 0.8568 - loss: 0.9624 - val_accuracy: 0.9092 - val_dice_coefficient: 0.4480 - val_iou_metric: 0.8343 - val_loss: 0.9332 - learning_rate: 1.0000e-04
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9213 - dice_coefficient: 0.4853 - iou_metric: 0.8622 - loss: 0.9337
# Epoch 35: val_iou_metric improved from 0.84053 to 0.84061, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9213 - dice_coefficient: 0.4853 - iou_metric: 0.8622 - loss: 0.9337 - val_accuracy: 0.9132 - val_dice_coefficient: 0.4555 - val_iou_metric: 0.8406 - val_loss: 0.9255 - learning_rate: 1.0000e-04
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9185 - dice_coefficient: 0.4804 - iou_metric: 0.8586 - loss: 0.9486
# Epoch 36: val_iou_metric did not improve from 0.84061
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9185 - dice_coefficient: 0.4805 - iou_metric: 0.8586 - loss: 0.9485 - val_accuracy: 0.9122 - val_dice_coefficient: 0.4543 - val_iou_metric: 0.8398 - val_loss: 0.9237 - learning_rate: 1.0000e-04
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9203 - dice_coefficient: 0.4834 - iou_metric: 0.8606 - loss: 0.9424
# Epoch 37: val_iou_metric improved from 0.84061 to 0.84369, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9203 - dice_coefficient: 0.4834 - iou_metric: 0.8607 - loss: 0.9423 - val_accuracy: 0.9150 - val_dice_coefficient: 0.4606 - val_iou_metric: 0.8437 - val_loss: 0.9093 - learning_rate: 1.0000e-04
# Epoch 38/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9259 - dice_coefficient: 0.4973 - iou_metric: 0.8693 - loss: 0.9012
# Epoch 38: val_iou_metric did not improve from 0.84369
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9259 - dice_coefficient: 0.4973 - iou_metric: 0.8693 - loss: 0.9013 - val_accuracy: 0.9132 - val_dice_coefficient: 0.4578 - val_iou_metric: 0.8407 - val_loss: 0.9118 - learning_rate: 1.0000e-04
# Epoch 39/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9249 - dice_coefficient: 0.5009 - iou_metric: 0.8683 - loss: 0.9085
# Epoch 39: val_iou_metric did not improve from 0.84369
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9249 - dice_coefficient: 0.5008 - iou_metric: 0.8682 - loss: 0.9085 - val_accuracy: 0.9111 - val_dice_coefficient: 0.4589 - val_iou_metric: 0.8381 - val_loss: 0.9102 - learning_rate: 1.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9236 - dice_coefficient: 0.5005 - iou_metric: 0.8656 - loss: 0.9147
# Epoch 40: val_iou_metric did not improve from 0.84369
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9236 - dice_coefficient: 0.5005 - iou_metric: 0.8657 - loss: 0.9146 - val_accuracy: 0.9139 - val_dice_coefficient: 0.4643 - val_iou_metric: 0.8418 - val_loss: 0.8998 - learning_rate: 1.0000e-04
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9248 - dice_coefficient: 0.4964 - iou_metric: 0.8675 - loss: 0.9096
# Epoch 41: val_iou_metric improved from 0.84369 to 0.84476, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9248 - dice_coefficient: 0.4964 - iou_metric: 0.8675 - loss: 0.9095 - val_accuracy: 0.9158 - val_dice_coefficient: 0.4681 - val_iou_metric: 0.8448 - val_loss: 0.8967 - learning_rate: 1.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9223 - dice_coefficient: 0.4999 - iou_metric: 0.8645 - loss: 0.9092
# Epoch 42: val_iou_metric did not improve from 0.84476
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9223 - dice_coefficient: 0.4999 - iou_metric: 0.8645 - loss: 0.9092 - val_accuracy: 0.9134 - val_dice_coefficient: 0.4660 - val_iou_metric: 0.8403 - val_loss: 0.8959 - learning_rate: 1.0000e-04
# Epoch 43/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9244 - dice_coefficient: 0.5042 - iou_metric: 0.8674 - loss: 0.9038
# Epoch 43: val_iou_metric did not improve from 0.84476
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9244 - dice_coefficient: 0.5042 - iou_metric: 0.8674 - loss: 0.9037 - val_accuracy: 0.9124 - val_dice_coefficient: 0.4663 - val_iou_metric: 0.8392 - val_loss: 0.8925 - learning_rate: 1.0000e-04
# Epoch 44/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9266 - dice_coefficient: 0.5074 - iou_metric: 0.8704 - loss: 0.8850
# Epoch 44: val_iou_metric improved from 0.84476 to 0.85011, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9266 - dice_coefficient: 0.5074 - iou_metric: 0.8705 - loss: 0.8850 - val_accuracy: 0.9192 - val_dice_coefficient: 0.4723 - val_iou_metric: 0.8501 - val_loss: 0.8874 - learning_rate: 1.0000e-04
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9274 - dice_coefficient: 0.5123 - iou_metric: 0.8718 - loss: 0.8843
# Epoch 45: val_iou_metric did not improve from 0.85011
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9274 - dice_coefficient: 0.5123 - iou_metric: 0.8718 - loss: 0.8843 - val_accuracy: 0.9157 - val_dice_coefficient: 0.4708 - val_iou_metric: 0.8458 - val_loss: 0.8868 - learning_rate: 1.0000e-04
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9301 - dice_coefficient: 0.5215 - iou_metric: 0.8763 - loss: 0.8568
# Epoch 46: val_iou_metric did not improve from 0.85011
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9301 - dice_coefficient: 0.5215 - iou_metric: 0.8763 - loss: 0.8569 - val_accuracy: 0.9150 - val_dice_coefficient: 0.4748 - val_iou_metric: 0.8440 - val_loss: 0.8825 - learning_rate: 1.0000e-04
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9294 - dice_coefficient: 0.5115 - iou_metric: 0.8750 - loss: 0.8830
# Epoch 47: val_iou_metric improved from 0.85011 to 0.85181, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9294 - dice_coefficient: 0.5115 - iou_metric: 0.8750 - loss: 0.8829 - val_accuracy: 0.9202 - val_dice_coefficient: 0.4769 - val_iou_metric: 0.8518 - val_loss: 0.8820 - learning_rate: 1.0000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9301 - dice_coefficient: 0.5219 - iou_metric: 0.8760 - loss: 0.8629
# Epoch 48: val_iou_metric did not improve from 0.85181
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9301 - dice_coefficient: 0.5219 - iou_metric: 0.8760 - loss: 0.8630 - val_accuracy: 0.9189 - val_dice_coefficient: 0.4802 - val_iou_metric: 0.8496 - val_loss: 0.8727 - learning_rate: 1.0000e-04
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9286 - dice_coefficient: 0.5185 - iou_metric: 0.8738 - loss: 0.8672
# Epoch 49: val_iou_metric improved from 0.85181 to 0.85533, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9286 - dice_coefficient: 0.5185 - iou_metric: 0.8738 - loss: 0.8672 - val_accuracy: 0.9225 - val_dice_coefficient: 0.4864 - val_iou_metric: 0.8553 - val_loss: 0.8645 - learning_rate: 1.0000e-04
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9291 - dice_coefficient: 0.5117 - iou_metric: 0.8748 - loss: 0.8806
# Epoch 50: val_iou_metric did not improve from 0.85533
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9291 - dice_coefficient: 0.5117 - iou_metric: 0.8748 - loss: 0.8805 - val_accuracy: 0.9225 - val_dice_coefficient: 0.4815 - val_iou_metric: 0.8546 - val_loss: 0.8702 - learning_rate: 1.0000e-04
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9286 - dice_coefficient: 0.5128 - iou_metric: 0.8734 - loss: 0.8836
# Epoch 51: val_iou_metric improved from 0.85533 to 0.86068, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9286 - dice_coefficient: 0.5129 - iou_metric: 0.8734 - loss: 0.8834 - val_accuracy: 0.9267 - val_dice_coefficient: 0.4853 - val_iou_metric: 0.8607 - val_loss: 0.8668 - learning_rate: 1.0000e-04
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9273 - dice_coefficient: 0.5204 - iou_metric: 0.8719 - loss: 0.8677
# Epoch 52: val_iou_metric improved from 0.86068 to 0.86949, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9274 - dice_coefficient: 0.5204 - iou_metric: 0.8720 - loss: 0.8676 - val_accuracy: 0.9318 - val_dice_coefficient: 0.4839 - val_iou_metric: 0.8695 - val_loss: 0.8641 - learning_rate: 1.0000e-04
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9306 - dice_coefficient: 0.5259 - iou_metric: 0.8771 - loss: 0.8596
# Epoch 53: val_iou_metric did not improve from 0.86949
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9306 - dice_coefficient: 0.5259 - iou_metric: 0.8771 - loss: 0.8596 - val_accuracy: 0.9295 - val_dice_coefficient: 0.4838 - val_iou_metric: 0.8660 - val_loss: 0.8609 - learning_rate: 1.0000e-04
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9316 - dice_coefficient: 0.5353 - iou_metric: 0.8786 - loss: 0.8393
# Epoch 54: val_iou_metric improved from 0.86949 to 0.87661, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9317 - dice_coefficient: 0.5352 - iou_metric: 0.8787 - loss: 0.8395 - val_accuracy: 0.9351 - val_dice_coefficient: 0.4869 - val_iou_metric: 0.8766 - val_loss: 0.8621 - learning_rate: 1.0000e-04
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9342 - dice_coefficient: 0.5238 - iou_metric: 0.8822 - loss: 0.8589
# Epoch 55: val_iou_metric improved from 0.87661 to 0.89129, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9341 - dice_coefficient: 0.5238 - iou_metric: 0.8822 - loss: 0.8588 - val_accuracy: 0.9422 - val_dice_coefficient: 0.4848 - val_iou_metric: 0.8913 - val_loss: 0.8595 - learning_rate: 1.0000e-04
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9330 - dice_coefficient: 0.5336 - iou_metric: 0.8800 - loss: 0.8450
# Epoch 56: val_iou_metric did not improve from 0.89129
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9330 - dice_coefficient: 0.5336 - iou_metric: 0.8800 - loss: 0.8449 - val_accuracy: 0.9405 - val_dice_coefficient: 0.4920 - val_iou_metric: 0.8873 - val_loss: 0.8484 - learning_rate: 1.0000e-04
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9366 - dice_coefficient: 0.5394 - iou_metric: 0.8860 - loss: 0.8248
# Epoch 57: val_iou_metric improved from 0.89129 to 0.89718, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9366 - dice_coefficient: 0.5393 - iou_metric: 0.8860 - loss: 0.8249 - val_accuracy: 0.9457 - val_dice_coefficient: 0.4963 - val_iou_metric: 0.8972 - val_loss: 0.8418 - learning_rate: 1.0000e-04
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9367 - dice_coefficient: 0.5303 - iou_metric: 0.8857 - loss: 0.8458
# Epoch 58: val_iou_metric did not improve from 0.89718
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9367 - dice_coefficient: 0.5303 - iou_metric: 0.8857 - loss: 0.8457 - val_accuracy: 0.9443 - val_dice_coefficient: 0.4964 - val_iou_metric: 0.8961 - val_loss: 0.8414 - learning_rate: 1.0000e-04
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9377 - dice_coefficient: 0.5381 - iou_metric: 0.8872 - loss: 0.8302
# Epoch 59: val_iou_metric improved from 0.89718 to 0.89723, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9377 - dice_coefficient: 0.5380 - iou_metric: 0.8871 - loss: 0.8303 - val_accuracy: 0.9448 - val_dice_coefficient: 0.4984 - val_iou_metric: 0.8972 - val_loss: 0.8375 - learning_rate: 1.0000e-04
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9400 - dice_coefficient: 0.5377 - iou_metric: 0.8909 - loss: 0.8226
# Epoch 60: val_iou_metric improved from 0.89723 to 0.90172, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9399 - dice_coefficient: 0.5377 - iou_metric: 0.8909 - loss: 0.8226 - val_accuracy: 0.9476 - val_dice_coefficient: 0.5081 - val_iou_metric: 0.9017 - val_loss: 0.8223 - learning_rate: 1.0000e-04
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9406 - dice_coefficient: 0.5532 - iou_metric: 0.8918 - loss: 0.8052
# Epoch 61: val_iou_metric improved from 0.90172 to 0.90185, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9406 - dice_coefficient: 0.5532 - iou_metric: 0.8918 - loss: 0.8052 - val_accuracy: 0.9476 - val_dice_coefficient: 0.5125 - val_iou_metric: 0.9019 - val_loss: 0.8132 - learning_rate: 1.0000e-04
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9400 - dice_coefficient: 0.5613 - iou_metric: 0.8908 - loss: 0.7870
# Epoch 62: val_iou_metric did not improve from 0.90185
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9400 - dice_coefficient: 0.5612 - iou_metric: 0.8908 - loss: 0.7871 - val_accuracy: 0.9448 - val_dice_coefficient: 0.5209 - val_iou_metric: 0.8969 - val_loss: 0.8022 - learning_rate: 1.0000e-04
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9415 - dice_coefficient: 0.5587 - iou_metric: 0.8932 - loss: 0.7930
# Epoch 63: val_iou_metric did not improve from 0.90185
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9415 - dice_coefficient: 0.5586 - iou_metric: 0.8932 - loss: 0.7931 - val_accuracy: 0.9474 - val_dice_coefficient: 0.5311 - val_iou_metric: 0.9016 - val_loss: 0.7864 - learning_rate: 1.0000e-04
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9400 - dice_coefficient: 0.5724 - iou_metric: 0.8908 - loss: 0.7767
# Epoch 64: val_iou_metric did not improve from 0.90185
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9401 - dice_coefficient: 0.5724 - iou_metric: 0.8908 - loss: 0.7768 - val_accuracy: 0.9468 - val_dice_coefficient: 0.5440 - val_iou_metric: 0.9005 - val_loss: 0.7672 - learning_rate: 1.0000e-04
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9412 - dice_coefficient: 0.5757 - iou_metric: 0.8930 - loss: 0.7717
# Epoch 65: val_iou_metric did not improve from 0.90185
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9412 - dice_coefficient: 0.5757 - iou_metric: 0.8930 - loss: 0.7717 - val_accuracy: 0.9446 - val_dice_coefficient: 0.5518 - val_iou_metric: 0.8973 - val_loss: 0.7570 - learning_rate: 1.0000e-04
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9446 - dice_coefficient: 0.5912 - iou_metric: 0.8984 - loss: 0.7314
# Epoch 66: val_iou_metric improved from 0.90185 to 0.90203, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9446 - dice_coefficient: 0.5911 - iou_metric: 0.8984 - loss: 0.7315 - val_accuracy: 0.9478 - val_dice_coefficient: 0.5672 - val_iou_metric: 0.9020 - val_loss: 0.7338 - learning_rate: 1.0000e-04
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9461 - dice_coefficient: 0.5927 - iou_metric: 0.9008 - loss: 0.7292
# Epoch 67: val_iou_metric did not improve from 0.90203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9461 - dice_coefficient: 0.5927 - iou_metric: 0.9008 - loss: 0.7293 - val_accuracy: 0.9442 - val_dice_coefficient: 0.5709 - val_iou_metric: 0.8964 - val_loss: 0.7282 - learning_rate: 1.0000e-04
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9441 - dice_coefficient: 0.5984 - iou_metric: 0.8976 - loss: 0.7291
# Epoch 68: val_iou_metric did not improve from 0.90203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9441 - dice_coefficient: 0.5983 - iou_metric: 0.8976 - loss: 0.7291 - val_accuracy: 0.9425 - val_dice_coefficient: 0.5736 - val_iou_metric: 0.8931 - val_loss: 0.7215 - learning_rate: 1.0000e-04
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9455 - dice_coefficient: 0.6104 - iou_metric: 0.8998 - loss: 0.7079
# Epoch 69: val_iou_metric did not improve from 0.90203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9455 - dice_coefficient: 0.6104 - iou_metric: 0.8998 - loss: 0.7079 - val_accuracy: 0.9467 - val_dice_coefficient: 0.5852 - val_iou_metric: 0.9009 - val_loss: 0.7017 - learning_rate: 1.0000e-04
# Epoch 70/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9469 - dice_coefficient: 0.6178 - iou_metric: 0.9023 - loss: 0.6937
# Epoch 70: val_iou_metric improved from 0.90203 to 0.90544, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9469 - dice_coefficient: 0.6177 - iou_metric: 0.9023 - loss: 0.6938 - val_accuracy: 0.9493 - val_dice_coefficient: 0.5947 - val_iou_metric: 0.9054 - val_loss: 0.6931 - learning_rate: 1.0000e-04
# Epoch 71/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9441 - dice_coefficient: 0.6116 - iou_metric: 0.8985 - loss: 0.7295
# Epoch 71: val_iou_metric improved from 0.90544 to 0.90822, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9441 - dice_coefficient: 0.6116 - iou_metric: 0.8985 - loss: 0.7294 - val_accuracy: 0.9510 - val_dice_coefficient: 0.6031 - val_iou_metric: 0.9082 - val_loss: 0.6872 - learning_rate: 1.0000e-04
# Epoch 72/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9422 - dice_coefficient: 0.6115 - iou_metric: 0.8952 - loss: 0.7112
# Epoch 72: val_iou_metric did not improve from 0.90822
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9422 - dice_coefficient: 0.6115 - iou_metric: 0.8952 - loss: 0.7112 - val_accuracy: 0.9483 - val_dice_coefficient: 0.5990 - val_iou_metric: 0.9033 - val_loss: 0.6835 - learning_rate: 1.0000e-04
# Epoch 73/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9451 - dice_coefficient: 0.6199 - iou_metric: 0.8990 - loss: 0.6906
# Epoch 73: val_iou_metric did not improve from 0.90822
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9451 - dice_coefficient: 0.6199 - iou_metric: 0.8991 - loss: 0.6906 - val_accuracy: 0.9460 - val_dice_coefficient: 0.5959 - val_iou_metric: 0.8988 - val_loss: 0.6849 - learning_rate: 1.0000e-04
# Epoch 74/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9475 - dice_coefficient: 0.6288 - iou_metric: 0.9033 - loss: 0.6799
# Epoch 74: val_iou_metric did not improve from 0.90822
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9475 - dice_coefficient: 0.6289 - iou_metric: 0.9033 - loss: 0.6798 - val_accuracy: 0.9481 - val_dice_coefficient: 0.6015 - val_iou_metric: 0.9034 - val_loss: 0.6768 - learning_rate: 1.0000e-04
# Epoch 75/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9468 - dice_coefficient: 0.6289 - iou_metric: 0.9026 - loss: 0.6820
# Epoch 75: val_iou_metric did not improve from 0.90822
# ...
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9551 - dice_coefficient: 0.7369 - iou_metric: 0.9174 - loss: 0.5185 - val_accuracy: 0.9561 - val_dice_coefficient: 0.6920 - val_iou_metric: 0.9180 - val_loss: 0.5575 - learning_rate: 1.0000e-04
# Epoch 119/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9563 - dice_coefficient: 0.7534 - iou_metric: 0.9185 - loss: 0.4777
# Epoch 119: val_iou_metric did not improve from 0.91890
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9563 - dice_coefficient: 0.7534 - iou_metric: 0.9185 - loss: 0.4777 - val_accuracy: 0.9534 - val_dice_coefficient: 0.6836 - val_iou_metric: 0.9135 - val_loss: 0.5703 - learning_rate: 1.0000e-04
# Epoch 120/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9582 - dice_coefficient: 0.7585 - iou_metric: 0.9216 - loss: 0.4633
# Epoch 120: val_iou_metric improved from 0.91890 to 0.92004, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9582 - dice_coefficient: 0.7585 - iou_metric: 0.9216 - loss: 0.4633 - val_accuracy: 0.9573 - val_dice_coefficient: 0.6908 - val_iou_metric: 0.9200 - val_loss: 0.5580 - learning_rate: 1.0000e-04
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9574 - dice_coefficient: 0.7434 - iou_metric: 0.9203 - loss: 0.4958
# Epoch 121: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9574 - dice_coefficient: 0.7434 - iou_metric: 0.9203 - loss: 0.4957 - val_accuracy: 0.9556 - val_dice_coefficient: 0.6897 - val_iou_metric: 0.9175 - val_loss: 0.5590 - learning_rate: 1.0000e-04
# Epoch 122/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9569 - dice_coefficient: 0.7609 - iou_metric: 0.9194 - loss: 0.4659
# Epoch 122: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9569 - dice_coefficient: 0.7608 - iou_metric: 0.9194 - loss: 0.4660 - val_accuracy: 0.9568 - val_dice_coefficient: 0.6909 - val_iou_metric: 0.9190 - val_loss: 0.5556 - learning_rate: 1.0000e-04
# Epoch 123/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9563 - dice_coefficient: 0.7569 - iou_metric: 0.9183 - loss: 0.4629
# Epoch 123: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9563 - dice_coefficient: 0.7569 - iou_metric: 0.9184 - loss: 0.4629 - val_accuracy: 0.9553 - val_dice_coefficient: 0.6914 - val_iou_metric: 0.9167 - val_loss: 0.5558 - learning_rate: 1.0000e-04
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9583 - dice_coefficient: 0.7634 - iou_metric: 0.9219 - loss: 0.4579
# Epoch 124: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9583 - dice_coefficient: 0.7634 - iou_metric: 0.9219 - loss: 0.4579 - val_accuracy: 0.9540 - val_dice_coefficient: 0.6885 - val_iou_metric: 0.9143 - val_loss: 0.5613 - learning_rate: 1.0000e-04
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9563 - dice_coefficient: 0.7483 - iou_metric: 0.9184 - loss: 0.4861
# Epoch 125: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9563 - dice_coefficient: 0.7483 - iou_metric: 0.9184 - loss: 0.4861 - val_accuracy: 0.9553 - val_dice_coefficient: 0.6904 - val_iou_metric: 0.9169 - val_loss: 0.5619 - learning_rate: 1.0000e-04
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9563 - dice_coefficient: 0.7535 - iou_metric: 0.9184 - loss: 0.4796
# Epoch 126: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9563 - dice_coefficient: 0.7535 - iou_metric: 0.9184 - loss: 0.4795 - val_accuracy: 0.9559 - val_dice_coefficient: 0.6892 - val_iou_metric: 0.9171 - val_loss: 0.5647 - learning_rate: 1.0000e-04
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9561 - dice_coefficient: 0.7646 - iou_metric: 0.9181 - loss: 0.4611
# Epoch 127: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9562 - dice_coefficient: 0.7646 - iou_metric: 0.9181 - loss: 0.4612 - val_accuracy: 0.9533 - val_dice_coefficient: 0.6830 - val_iou_metric: 0.9131 - val_loss: 0.5748 - learning_rate: 1.0000e-04
# Epoch 128/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9594 - dice_coefficient: 0.7638 - iou_metric: 0.9238 - loss: 0.4516
# Epoch 128: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9594 - dice_coefficient: 0.7638 - iou_metric: 0.9238 - loss: 0.4517 - val_accuracy: 0.9562 - val_dice_coefficient: 0.6929 - val_iou_metric: 0.9181 - val_loss: 0.5570 - learning_rate: 1.0000e-04
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9582 - dice_coefficient: 0.7565 - iou_metric: 0.9216 - loss: 0.4691
# Epoch 129: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9582 - dice_coefficient: 0.7565 - iou_metric: 0.9216 - loss: 0.4690 - val_accuracy: 0.9557 - val_dice_coefficient: 0.6917 - val_iou_metric: 0.9179 - val_loss: 0.5648 - learning_rate: 1.0000e-04
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9580 - dice_coefficient: 0.7561 - iou_metric: 0.9214 - loss: 0.4690
# Epoch 130: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9580 - dice_coefficient: 0.7562 - iou_metric: 0.9214 - loss: 0.4689 - val_accuracy: 0.9552 - val_dice_coefficient: 0.6918 - val_iou_metric: 0.9167 - val_loss: 0.5632 - learning_rate: 1.0000e-04
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9575 - dice_coefficient: 0.7559 - iou_metric: 0.9204 - loss: 0.4731
# Epoch 131: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9575 - dice_coefficient: 0.7559 - iou_metric: 0.9204 - loss: 0.4732 - val_accuracy: 0.9549 - val_dice_coefficient: 0.6921 - val_iou_metric: 0.9155 - val_loss: 0.5631 - learning_rate: 1.0000e-04
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9577 - dice_coefficient: 0.7611 - iou_metric: 0.9210 - loss: 0.4546
# Epoch 132: val_iou_metric did not improve from 0.92004
#
# Epoch 132: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9577 - dice_coefficient: 0.7611 - iou_metric: 0.9210 - loss: 0.4546 - val_accuracy: 0.9549 - val_dice_coefficient: 0.6907 - val_iou_metric: 0.9154 - val_loss: 0.5594 - learning_rate: 1.0000e-04
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9580 - dice_coefficient: 0.7707 - iou_metric: 0.9213 - loss: 0.4438
# Epoch 133: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9580 - dice_coefficient: 0.7706 - iou_metric: 0.9213 - loss: 0.4439 - val_accuracy: 0.9549 - val_dice_coefficient: 0.6927 - val_iou_metric: 0.9157 - val_loss: 0.5577 - learning_rate: 3.0000e-05
# Epoch 134/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9595 - dice_coefficient: 0.7716 - iou_metric: 0.9242 - loss: 0.4428
# Epoch 134: val_iou_metric did not improve from 0.92004
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9595 - dice_coefficient: 0.7715 - iou_metric: 0.9242 - loss: 0.4429 - val_accuracy: 0.9551 - val_dice_coefficient: 0.6923 - val_iou_metric: 0.9162 - val_loss: 0.5582 - learning_rate: 3.0000e-05
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9604 - dice_coefficient: 0.7583 - iou_metric: 0.9255 - loss: 0.4573
# Epoch 135: val_iou_metric improved from 0.92004 to 0.92141, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9604 - dice_coefficient: 0.7583 - iou_metric: 0.9255 - loss: 0.4573 - val_accuracy: 0.9581 - val_dice_coefficient: 0.6969 - val_iou_metric: 0.9214 - val_loss: 0.5555 - learning_rate: 3.0000e-05
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9588 - dice_coefficient: 0.7732 - iou_metric: 0.9226 - loss: 0.4362
# Epoch 136: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9588 - dice_coefficient: 0.7731 - iou_metric: 0.9226 - loss: 0.4363 - val_accuracy: 0.9550 - val_dice_coefficient: 0.6933 - val_iou_metric: 0.9163 - val_loss: 0.5567 - learning_rate: 3.0000e-05
# Epoch 137/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9599 - dice_coefficient: 0.7685 - iou_metric: 0.9247 - loss: 0.4412
# Epoch 137: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9599 - dice_coefficient: 0.7685 - iou_metric: 0.9247 - loss: 0.4412 - val_accuracy: 0.9574 - val_dice_coefficient: 0.6968 - val_iou_metric: 0.9204 - val_loss: 0.5539 - learning_rate: 3.0000e-05
# Epoch 138/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9584 - dice_coefficient: 0.7759 - iou_metric: 0.9221 - loss: 0.4325
# Epoch 138: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9584 - dice_coefficient: 0.7759 - iou_metric: 0.9221 - loss: 0.4325 - val_accuracy: 0.9563 - val_dice_coefficient: 0.6955 - val_iou_metric: 0.9187 - val_loss: 0.5513 - learning_rate: 3.0000e-05
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9587 - dice_coefficient: 0.7663 - iou_metric: 0.9225 - loss: 0.4453
# Epoch 139: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9587 - dice_coefficient: 0.7663 - iou_metric: 0.9225 - loss: 0.4453 - val_accuracy: 0.9565 - val_dice_coefficient: 0.6963 - val_iou_metric: 0.9189 - val_loss: 0.5526 - learning_rate: 3.0000e-05
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9611 - dice_coefficient: 0.7656 - iou_metric: 0.9268 - loss: 0.4410
# Epoch 140: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9611 - dice_coefficient: 0.7657 - iou_metric: 0.9268 - loss: 0.4409 - val_accuracy: 0.9561 - val_dice_coefficient: 0.6953 - val_iou_metric: 0.9184 - val_loss: 0.5521 - learning_rate: 3.0000e-05
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9601 - dice_coefficient: 0.7774 - iou_metric: 0.9249 - loss: 0.4291
# Epoch 141: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9601 - dice_coefficient: 0.7773 - iou_metric: 0.9249 - loss: 0.4291 - val_accuracy: 0.9564 - val_dice_coefficient: 0.6958 - val_iou_metric: 0.9189 - val_loss: 0.5528 - learning_rate: 3.0000e-05
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9603 - dice_coefficient: 0.7781 - iou_metric: 0.9253 - loss: 0.4265
# Epoch 142: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9603 - dice_coefficient: 0.7781 - iou_metric: 0.9253 - loss: 0.4265 - val_accuracy: 0.9560 - val_dice_coefficient: 0.6949 - val_iou_metric: 0.9183 - val_loss: 0.5541 - learning_rate: 3.0000e-05
# Epoch 143/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9608 - dice_coefficient: 0.7713 - iou_metric: 0.9263 - loss: 0.4331
# Epoch 143: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9608 - dice_coefficient: 0.7713 - iou_metric: 0.9263 - loss: 0.4330 - val_accuracy: 0.9567 - val_dice_coefficient: 0.6964 - val_iou_metric: 0.9194 - val_loss: 0.5543 - learning_rate: 3.0000e-05
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9601 - dice_coefficient: 0.7783 - iou_metric: 0.9250 - loss: 0.4252
# Epoch 144: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9601 - dice_coefficient: 0.7783 - iou_metric: 0.9250 - loss: 0.4253 - val_accuracy: 0.9559 - val_dice_coefficient: 0.6944 - val_iou_metric: 0.9185 - val_loss: 0.5565 - learning_rate: 3.0000e-05
# Epoch 145/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9590 - dice_coefficient: 0.7744 - iou_metric: 0.9232 - loss: 0.4349
# Epoch 145: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9590 - dice_coefficient: 0.7744 - iou_metric: 0.9232 - loss: 0.4348 - val_accuracy: 0.9565 - val_dice_coefficient: 0.6950 - val_iou_metric: 0.9193 - val_loss: 0.5555 - learning_rate: 3.0000e-05
# Epoch 146/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9607 - dice_coefficient: 0.7704 - iou_metric: 0.9261 - loss: 0.4366
# Epoch 146: val_iou_metric did not improve from 0.92141
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9607 - dice_coefficient: 0.7704 - iou_metric: 0.9261 - loss: 0.4366 - val_accuracy: 0.9569 - val_dice_coefficient: 0.6976 - val_iou_metric: 0.9197 - val_loss: 0.5516 - learning_rate: 3.0000e-05
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9600 - dice_coefficient: 0.7844 - iou_metric: 0.9248 - loss: 0.4178
# Epoch 147: val_iou_metric improved from 0.92141 to 0.92198, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9599 - dice_coefficient: 0.7844 - iou_metric: 0.9248 - loss: 0.4179 - val_accuracy: 0.9580 - val_dice_coefficient: 0.6992 - val_iou_metric: 0.9220 - val_loss: 0.5496 - learning_rate: 3.0000e-05
# Epoch 148/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9578 - dice_coefficient: 0.7689 - iou_metric: 0.9213 - loss: 0.4482
# Epoch 148: val_iou_metric did not improve from 0.92198
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9578 - dice_coefficient: 0.7690 - iou_metric: 0.9213 - loss: 0.4481 - val_accuracy: 0.9563 - val_dice_coefficient: 0.6983 - val_iou_metric: 0.9192 - val_loss: 0.5498 - learning_rate: 3.0000e-05
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9618 - dice_coefficient: 0.7753 - iou_metric: 0.9282 - loss: 0.4255
# Epoch 149: val_iou_metric did not improve from 0.92198
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9618 - dice_coefficient: 0.7753 - iou_metric: 0.9282 - loss: 0.4255 - val_accuracy: 0.9574 - val_dice_coefficient: 0.6977 - val_iou_metric: 0.9212 - val_loss: 0.5522 - learning_rate: 3.0000e-05
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9598 - dice_coefficient: 0.7777 - iou_metric: 0.9246 - loss: 0.4258
# Epoch 150: val_iou_metric did not improve from 0.92198
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9598 - dice_coefficient: 0.7776 - iou_metric: 0.9246 - loss: 0.4259 - val_accuracy: 0.9576 - val_dice_coefficient: 0.6985 - val_iou_metric: 0.9213 - val_loss: 0.5509 - learning_rate: 3.0000e-05
#
# --- Entrenamiento Finalizado ---
# El mejor modelo se ha guardado en: efficient_weed_model_B0_best.keras
#
# Cargando el mejor modelo guardado para la evaluación en el conjunto de test...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'aspp_module', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Se encontraron 210 imágenes de test.
# Creando dataset de test...
#
# --- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 379ms/step - accuracy: 0.9608 - dice_coefficient: 0.6471 - iou_metric: 0.9261 - loss: 0.6713
#
# ## MÉTRICAS DE TEST - MODELO 'B0' ##
# Test Loss: 0.5715
# Test Dice Coefficient: 0.6719
# Test mIoU: 0.9314
# Test Global Accuracy: 0.9645
#
# Calculando IoU por clase en el conjunto de test...
#
# ## IoU por Clase (Test) ##
# IoU for Background: 0.9501
# IoU for Cow-tongue: 0.8966
# IoU for Dandelion: 0.8899
# IoU for Kikuyo: 0.9071
# IoU for Other: 0.6307
# IoU for Potato: 0.8759
#
# Promedio de IoU por clase: 0.8584
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
