# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/B0-Pro-V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# Configuración del modelo
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6
BATCH_SIZE = 32 #cambiooo
EPOCHS = 150
LEARNING_RATE = 1e-4

# Paths
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')
TEST_IMAGES_PATH = os.path.join(BASE_PATH, 'test/images')
TEST_MASKS_PATH = os.path.join(BASE_PATH, 'test/masks')

# Definición de clases y funciones del modelo
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True
    layer_names = [
        'block1a_project_activation',
        'block2b_add',
        'block3b_add',
        'block5c_add',
        'top_activation'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)
    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_B0')
    return model

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

def load_and_preprocess_data(image_paths, mask_paths, augment=False):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5:
            image, mask = tf.image.flip_left_right(image), tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5:
            image, mask = tf.image.flip_up_down(image), tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5:
            k = tf.random.uniform([], 1, 4, dtype=tf.int32)
            image, mask = tf.image.rot90(image, k), tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = tf.data.Dataset.zip((image_ds, mask_ds))
    if augment:
        dataset = dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_B0.keras'):
    model = create_weed_detection_model()
    model.summary()

    # Cálculo de pasos para el scheduler
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    total_steps = (len(train_image_paths) // BATCH_SIZE) * EPOCHS
    warmup_steps = int(total_steps * 0.1)
    initial_learning_rate = 1e-4

    # Definición del scheduler
    lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=initial_learning_rate,
        decay_steps=total_steps - warmup_steps,
        alpha=0.0
    )

    warmup_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
        initial_learning_rate=0.0,
        decay_steps=warmup_steps,
        end_learning_rate=initial_learning_rate,
        power=1.0
    )

    # Función para obtener el learning rate actual
    def get_lr(epoch, step):
        # Convertir el paso actual a un valor de punto flotante
        step = tf.cast(step, tf.float32)
        if step < warmup_steps:
            return float(warmup_schedule(step))
        else:
            return float(lr_schedule(step - warmup_steps))

    # Crear un callback para actualizar el learning rate
    lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: get_lr(None, step))

    optimizer = tf.keras.optimizers.AdamW(
        learning_rate=initial_learning_rate,  # Comenzar con la tasa de aprendizaje inicial
        weight_decay=1e-5
    )

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_iou_metric', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_iou_metric', patience=25, mode='max', restore_best_weights=True),
        lr_callback  # Añadir el callback del learning rate scheduler
    ]

    print(f"Iniciando entrenamiento con BATCH_SIZE={BATCH_SIZE} y scheduler CosineDecay...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )

    return model, history

def plot_sample_masks(images, masks, predictions, num_samples=4):
    plt.figure(figsize=(15, 5 * num_samples))
    for i in range(num_samples):
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(images[i].astype("uint8"))
        plt.title("Imagen")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(tf.argmax(masks[i], axis=-1))
        plt.title("Máscara Real")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(tf.argmax(predictions[i], axis=-1))
        plt.title("Máscara Predicha")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(TRAIN_MASKS_PATH, '*.png')))
    val_image_paths = sorted(glob(os.path.join(VAL_IMAGES_PATH, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(VAL_MASKS_PATH, '*.png')))

    print("Creando datasets de entrenamiento y validación...")
    train_ds = load_and_preprocess_data(train_image_paths, train_mask_paths, augment=True)
    val_ds = load_and_preprocess_data(val_image_paths, val_mask_paths, augment=False)

    model_save_path = 'efficient_weed_model_B0_best.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("\n--- Entrenamiento Finalizado ---")
    print(f"El mejor modelo se ha guardado en: {model_save_path}")

    print("\nCargando el mejor modelo guardado para la evaluación en el conjunto de test...")
    best_model = tf.keras.models.load_model(
        model_save_path,
        custom_objects={
            'ASPPModule': ASPPModule,
            'DeformableAttention': DeformableAttention,
            'combined_loss': combined_loss,
            'dice_coefficient': dice_coefficient,
            'iou_metric': iou_metric,
            'dice_loss': dice_loss
        }
    )

    test_image_paths = sorted(glob(os.path.join(TEST_IMAGES_PATH, '*.jpg')))
    test_mask_paths = sorted(glob(os.path.join(TEST_MASKS_PATH, '*.png')))

    if not test_image_paths:
        print("\nADVERTENCIA: No se encontraron imágenes en el directorio de test. Saltando la evaluación de test.")
    else:
        print(f"Se encontraron {len(test_image_paths)} imágenes de test.")
        print("Creando dataset de test...")
        test_ds = load_and_preprocess_data(test_image_paths, test_mask_paths, augment=False)

        print("\n--- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---")
        test_metrics = best_model.evaluate(test_ds)

        print("\n## MÉTRICAS DE TEST - MODELO 'B0' ##")
        print(f"Test Loss: {test_metrics[0]:.4f}")
        print(f"Test Dice Coefficient: {test_metrics[1]:.4f}")
        print(f"Test mIoU: {test_metrics[2]:.4f}")
        print(f"Test Global Accuracy: {test_metrics[3]:.4f}")

        print("\nCalculando IoU por clase en el conjunto de test...")
        iou_per_class_values = []
        for images_batch, masks_batch in test_ds:
            predictions_batch = best_model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()
        class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
        print("\n## IoU por Clase (Test) ##")
        for i, iou in enumerate(iou_per_class_values):
            print(f"IoU for {class_names[i]}: {iou:.4f}")

        print(f"\nPromedio de IoU por clase: {np.mean(iou_per_class_values):.4f}")

        # Mostrar ejemplos de máscaras reales y predichas
        for images_batch, masks_batch in test_ds.take(1):
            predictions_batch = best_model.predict(images_batch)
            plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)

        # Gráficas de Dice Coefficient y Loss durante el entrenamiento
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['dice_coefficient'], label='Dice Coefficient (Train)')
        plt.plot(history.history['val_dice_coefficient'], label='Dice Coefficient (Validation)')
        plt.title('Dice Coefficient over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Dice Coefficient')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Loss (Train)')
        plt.plot(history.history['val_loss'], label='Loss (Validation)')
        plt.title('Loss over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
# Out:
# Creando datasets de entrenamiento y validación...
# Model: "EfficientWeedDetectionModel_B0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer_6[0]… │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 32), (None,   │            │                   │
# │                     │ 16, 16, 48),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 112), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module_3       │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module_3[0]… │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 8, 8, 96)  │     10,752 │ EfficientNetV2B0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_71 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 8, 8, 96)  │          0 │ re_lu_71[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_72 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, 8, 8, 192) │          0 │ dropout_29[0][0], │
# │ (Concatenate)       │                   │            │ re_lu_72[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_12 │ (None, 8, 8, 96)  │     20,160 │ concatenate_29[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_73 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 8, 8, 96)  │          0 │ re_lu_73[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 16, 16,    │     36,864 │ dropout_30[0][0]  │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 16, 16,    │      4,608 │ EfficientNetV2B0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_74 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 16, 16,    │          0 │ re_lu_74[0][0]    │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_75 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, 16, 16,    │          0 │ dropout_31[0][0], │
# │ (Concatenate)       │ 192)              │            │ re_lu_75[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_13 │ (None, 16, 16,    │     20,160 │ concatenate_30[0… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_76 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 16, 16,    │          0 │ re_lu_76[0][0]    │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 32, 32,    │     18,432 │ dropout_32[0][0]  │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 32, 32,    │      1,536 │ EfficientNetV2B0… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_77 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 32, 32,    │          0 │ re_lu_77[0][0]    │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_78 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, 32, 32,    │          0 │ dropout_33[0][0], │
# │ (Concatenate)       │ 96)               │            │ re_lu_78[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_14 │ (None, 32, 32,    │      5,472 │ concatenate_31[0… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_79 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 32, 32,    │          0 │ re_lu_79[0][0]    │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_18 │ (None, 64, 64,    │      4,608 │ dropout_34[0][0]  │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 64, 64,    │        384 │ EfficientNetV2B0… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_80 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 64, 64,    │          0 │ re_lu_80[0][0]    │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_81 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, 64, 64,    │          0 │ dropout_35[0][0], │
# │ (Concatenate)       │ 48)               │            │ re_lu_81[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_15 │ (None, 64, 64,    │      1,584 │ concatenate_32[0… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_82 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_36          │ (None, 64, 64,    │          0 │ re_lu_82[0][0]    │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_19 │ (None, 128, 128,  │        576 │ dropout_36[0][0]  │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,514,346 (51.55 MB)
#  Trainable params: 13,449,082 (51.30 MB)
#  Non-trainable params: 65,264 (254.94 KB)
# Iniciando entrenamiento con BATCH_SIZE=32 y scheduler CosineDecay...
# Epoch 1/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2040 - dice_coefficient: 0.0861 - iou_metric: 0.1138 - loss: 2.4359
# Epoch 1: val_iou_metric improved from -inf to 0.09738, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 206s 1s/step - accuracy: 0.2040 - dice_coefficient: 0.0861 - iou_metric: 0.1138 - loss: 2.4354 - val_accuracy: 0.1761 - val_dice_coefficient: 0.0883 - val_iou_metric: 0.0974 - val_loss: 2.2384 - learning_rate: 0.0000e+00
# Epoch 2/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2037 - dice_coefficient: 0.0865 - iou_metric: 0.1137 - loss: 2.4370
# Epoch 2: val_iou_metric improved from 0.09738 to 0.10058, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2037 - dice_coefficient: 0.0865 - iou_metric: 0.1137 - loss: 2.4365 - val_accuracy: 0.1817 - val_dice_coefficient: 0.0883 - val_iou_metric: 0.1006 - val_loss: 2.2375 - learning_rate: 1.2820e-07
# Epoch 3/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2040 - dice_coefficient: 0.0860 - iou_metric: 0.1138 - loss: 2.4264
# Epoch 3: val_iou_metric improved from 0.10058 to 0.11021, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2040 - dice_coefficient: 0.0860 - iou_metric: 0.1138 - loss: 2.4261 - val_accuracy: 0.1976 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1102 - val_loss: 2.2400 - learning_rate: 2.5641e-07
# Epoch 4/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2037 - dice_coefficient: 0.0860 - iou_metric: 0.1136 - loss: 2.4191
# Epoch 4: val_iou_metric improved from 0.11021 to 0.11520, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2037 - dice_coefficient: 0.0860 - iou_metric: 0.1136 - loss: 2.4189 - val_accuracy: 0.2057 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1152 - val_loss: 2.2450 - learning_rate: 3.8461e-07
# Epoch 5/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2049 - dice_coefficient: 0.0857 - iou_metric: 0.1144 - loss: 2.3932
# Epoch 5: val_iou_metric improved from 0.11520 to 0.11845, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2049 - dice_coefficient: 0.0857 - iou_metric: 0.1144 - loss: 2.3935 - val_accuracy: 0.2110 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1185 - val_loss: 2.2512 - learning_rate: 5.1282e-07
# Epoch 6/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2048 - dice_coefficient: 0.0860 - iou_metric: 0.1143 - loss: 2.4018
# Epoch 6: val_iou_metric improved from 0.11845 to 0.12068, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.2048 - dice_coefficient: 0.0860 - iou_metric: 0.1143 - loss: 2.4019 - val_accuracy: 0.2146 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1207 - val_loss: 2.2584 - learning_rate: 6.4103e-07
# Epoch 7/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2048 - dice_coefficient: 0.0857 - iou_metric: 0.1143 - loss: 2.4008
# Epoch 7: val_iou_metric improved from 0.12068 to 0.12203, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2048 - dice_coefficient: 0.0857 - iou_metric: 0.1143 - loss: 2.4011 - val_accuracy: 0.2169 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1220 - val_loss: 2.2665 - learning_rate: 7.6924e-07
# Epoch 8/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2042 - dice_coefficient: 0.0869 - iou_metric: 0.1139 - loss: 2.4208
# Epoch 8: val_iou_metric improved from 0.12203 to 0.12369, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2042 - dice_coefficient: 0.0869 - iou_metric: 0.1139 - loss: 2.4206 - val_accuracy: 0.2196 - val_dice_coefficient: 0.0883 - val_iou_metric: 0.1237 - val_loss: 2.2743 - learning_rate: 8.9744e-07
# Epoch 9/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2053 - dice_coefficient: 0.0864 - iou_metric: 0.1146 - loss: 2.4272
# Epoch 9: val_iou_metric improved from 0.12369 to 0.12429, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2053 - dice_coefficient: 0.0864 - iou_metric: 0.1146 - loss: 2.4264 - val_accuracy: 0.2206 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1243 - val_loss: 2.2805 - learning_rate: 1.0256e-06
# Epoch 10/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2044 - dice_coefficient: 0.0866 - iou_metric: 0.1141 - loss: 2.4298
# Epoch 10: val_iou_metric improved from 0.12429 to 0.12460, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2044 - dice_coefficient: 0.0865 - iou_metric: 0.1141 - loss: 2.4289 - val_accuracy: 0.2212 - val_dice_coefficient: 0.0883 - val_iou_metric: 0.1246 - val_loss: 2.2871 - learning_rate: 1.1538e-06
# Epoch 11/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2063 - dice_coefficient: 0.0854 - iou_metric: 0.1152 - loss: 2.3956
# Epoch 11: val_iou_metric improved from 0.12460 to 0.12553, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2063 - dice_coefficient: 0.0854 - iou_metric: 0.1152 - loss: 2.3959 - val_accuracy: 0.2227 - val_dice_coefficient: 0.0883 - val_iou_metric: 0.1255 - val_loss: 2.2903 - learning_rate: 1.2821e-06
# Epoch 12/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2062 - dice_coefficient: 0.0862 - iou_metric: 0.1152 - loss: 2.4106
# Epoch 12: val_iou_metric did not improve from 0.12553
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.2062 - dice_coefficient: 0.0862 - iou_metric: 0.1152 - loss: 2.4102 - val_accuracy: 0.2213 - val_dice_coefficient: 0.0883 - val_iou_metric: 0.1247 - val_loss: 2.2951 - learning_rate: 1.4103e-06
# Epoch 13/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2067 - dice_coefficient: 0.0868 - iou_metric: 0.1155 - loss: 2.4132
# Epoch 13: val_iou_metric did not improve from 0.12553
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.2067 - dice_coefficient: 0.0868 - iou_metric: 0.1155 - loss: 2.4130 - val_accuracy: 0.2222 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1252 - val_loss: 2.2963 - learning_rate: 1.5385e-06
# Epoch 14/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2066 - dice_coefficient: 0.0871 - iou_metric: 0.1154 - loss: 2.4256
# Epoch 14: val_iou_metric improved from 0.12553 to 0.12568, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.2066 - dice_coefficient: 0.0871 - iou_metric: 0.1154 - loss: 2.4251 - val_accuracy: 0.2229 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1257 - val_loss: 2.2960 - learning_rate: 1.6667e-06
# Epoch 15/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2067 - dice_coefficient: 0.0872 - iou_metric: 0.1155 - loss: 2.4271
# Epoch 15: val_iou_metric improved from 0.12568 to 0.12581, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2068 - dice_coefficient: 0.0872 - iou_metric: 0.1156 - loss: 2.4260 - val_accuracy: 0.2232 - val_dice_coefficient: 0.0884 - val_iou_metric: 0.1258 - val_loss: 2.2962 - learning_rate: 1.7949e-06
# Epoch 16/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2077 - dice_coefficient: 0.0872 - iou_metric: 0.1161 - loss: 2.4130
# Epoch 16: val_iou_metric improved from 0.12581 to 0.12649, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2077 - dice_coefficient: 0.0872 - iou_metric: 0.1161 - loss: 2.4127 - val_accuracy: 0.2243 - val_dice_coefficient: 0.0885 - val_iou_metric: 0.1265 - val_loss: 2.2945 - learning_rate: 1.9231e-06
# Epoch 17/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2087 - dice_coefficient: 0.0870 - iou_metric: 0.1167 - loss: 2.3945
# Epoch 17: val_iou_metric improved from 0.12649 to 0.12682, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2087 - dice_coefficient: 0.0870 - iou_metric: 0.1167 - loss: 2.3944 - val_accuracy: 0.2248 - val_dice_coefficient: 0.0886 - val_iou_metric: 0.1268 - val_loss: 2.2945 - learning_rate: 2.0513e-06
# Epoch 18/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2093 - dice_coefficient: 0.0872 - iou_metric: 0.1171 - loss: 2.4049
# Epoch 18: val_iou_metric improved from 0.12682 to 0.12767, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.2094 - dice_coefficient: 0.0872 - iou_metric: 0.1171 - loss: 2.4043 - val_accuracy: 0.2261 - val_dice_coefficient: 0.0887 - val_iou_metric: 0.1277 - val_loss: 2.2916 - learning_rate: 2.1795e-06
# Epoch 19/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2098 - dice_coefficient: 0.0868 - iou_metric: 0.1174 - loss: 2.3975
# Epoch 19: val_iou_metric improved from 0.12767 to 0.12841, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.2098 - dice_coefficient: 0.0868 - iou_metric: 0.1174 - loss: 2.3971 - val_accuracy: 0.2273 - val_dice_coefficient: 0.0888 - val_iou_metric: 0.1284 - val_loss: 2.2900 - learning_rate: 2.3077e-06
# Epoch 20/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2110 - dice_coefficient: 0.0872 - iou_metric: 0.1181 - loss: 2.3899
# Epoch 20: val_iou_metric did not improve from 0.12841
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.2110 - dice_coefficient: 0.0872 - iou_metric: 0.1181 - loss: 2.3896 - val_accuracy: 0.2269 - val_dice_coefficient: 0.0888 - val_iou_metric: 0.1282 - val_loss: 2.2910 - learning_rate: 2.4359e-06
# Epoch 21/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2111 - dice_coefficient: 0.0874 - iou_metric: 0.1182 - loss: 2.3999
# Epoch 21: val_iou_metric improved from 0.12841 to 0.12959, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2111 - dice_coefficient: 0.0874 - iou_metric: 0.1182 - loss: 2.3995 - val_accuracy: 0.2292 - val_dice_coefficient: 0.0890 - val_iou_metric: 0.1296 - val_loss: 2.2865 - learning_rate: 2.5641e-06
# Epoch 22/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2125 - dice_coefficient: 0.0873 - iou_metric: 0.1191 - loss: 2.3721
# Epoch 22: val_iou_metric improved from 0.12959 to 0.13076, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2126 - dice_coefficient: 0.0873 - iou_metric: 0.1191 - loss: 2.3722 - val_accuracy: 0.2311 - val_dice_coefficient: 0.0891 - val_iou_metric: 0.1308 - val_loss: 2.2837 - learning_rate: 2.6923e-06
# Epoch 23/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2125 - dice_coefficient: 0.0877 - iou_metric: 0.1191 - loss: 2.4108
# Epoch 23: val_iou_metric improved from 0.13076 to 0.13177, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2125 - dice_coefficient: 0.0877 - iou_metric: 0.1191 - loss: 2.4094 - val_accuracy: 0.2327 - val_dice_coefficient: 0.0892 - val_iou_metric: 0.1318 - val_loss: 2.2817 - learning_rate: 2.8205e-06
# Epoch 24/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2141 - dice_coefficient: 0.0875 - iou_metric: 0.1201 - loss: 2.3821
# Epoch 24: val_iou_metric improved from 0.13177 to 0.13200, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2141 - dice_coefficient: 0.0875 - iou_metric: 0.1201 - loss: 2.3817 - val_accuracy: 0.2330 - val_dice_coefficient: 0.0893 - val_iou_metric: 0.1320 - val_loss: 2.2795 - learning_rate: 2.9487e-06
# Epoch 25/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2153 - dice_coefficient: 0.0870 - iou_metric: 0.1209 - loss: 2.3628
# Epoch 25: val_iou_metric improved from 0.13200 to 0.13298, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.2153 - dice_coefficient: 0.0870 - iou_metric: 0.1209 - loss: 2.3628 - val_accuracy: 0.2346 - val_dice_coefficient: 0.0895 - val_iou_metric: 0.1330 - val_loss: 2.2775 - learning_rate: 3.0769e-06
# Epoch 26/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2159 - dice_coefficient: 0.0874 - iou_metric: 0.1212 - loss: 2.3794
# Epoch 26: val_iou_metric improved from 0.13298 to 0.13366, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2159 - dice_coefficient: 0.0874 - iou_metric: 0.1212 - loss: 2.3790 - val_accuracy: 0.2356 - val_dice_coefficient: 0.0896 - val_iou_metric: 0.1337 - val_loss: 2.2759 - learning_rate: 3.2051e-06
# Epoch 27/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2177 - dice_coefficient: 0.0874 - iou_metric: 0.1223 - loss: 2.3612
# Epoch 27: val_iou_metric improved from 0.13366 to 0.13542, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.2177 - dice_coefficient: 0.0874 - iou_metric: 0.1223 - loss: 2.3612 - val_accuracy: 0.2384 - val_dice_coefficient: 0.0897 - val_iou_metric: 0.1354 - val_loss: 2.2729 - learning_rate: 3.3333e-06
# Epoch 28/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2186 - dice_coefficient: 0.0885 - iou_metric: 0.1229 - loss: 2.3736
# Epoch 28: val_iou_metric improved from 0.13542 to 0.13581, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2186 - dice_coefficient: 0.0885 - iou_metric: 0.1229 - loss: 2.3732 - val_accuracy: 0.2390 - val_dice_coefficient: 0.0899 - val_iou_metric: 0.1358 - val_loss: 2.2697 - learning_rate: 3.4615e-06
# Epoch 29/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2195 - dice_coefficient: 0.0883 - iou_metric: 0.1235 - loss: 2.3596
# Epoch 29: val_iou_metric improved from 0.13581 to 0.13718, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.2195 - dice_coefficient: 0.0883 - iou_metric: 0.1235 - loss: 2.3595 - val_accuracy: 0.2411 - val_dice_coefficient: 0.0900 - val_iou_metric: 0.1372 - val_loss: 2.2676 - learning_rate: 3.5897e-06
# Epoch 30/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2213 - dice_coefficient: 0.0882 - iou_metric: 0.1246 - loss: 2.3396
# Epoch 30: val_iou_metric improved from 0.13718 to 0.13814, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2213 - dice_coefficient: 0.0882 - iou_metric: 0.1246 - loss: 2.3398 - val_accuracy: 0.2427 - val_dice_coefficient: 0.0903 - val_iou_metric: 0.1381 - val_loss: 2.2625 - learning_rate: 3.7179e-06
# Epoch 31/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2223 - dice_coefficient: 0.0889 - iou_metric: 0.1253 - loss: 2.3488
# Epoch 31: val_iou_metric improved from 0.13814 to 0.14069, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2224 - dice_coefficient: 0.0889 - iou_metric: 0.1253 - loss: 2.3486 - val_accuracy: 0.2466 - val_dice_coefficient: 0.0904 - val_iou_metric: 0.1407 - val_loss: 2.2589 - learning_rate: 3.8462e-06
# Epoch 32/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2240 - dice_coefficient: 0.0892 - iou_metric: 0.1263 - loss: 2.3529
# Epoch 32: val_iou_metric improved from 0.14069 to 0.14087, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2240 - dice_coefficient: 0.0892 - iou_metric: 0.1263 - loss: 2.3524 - val_accuracy: 0.2469 - val_dice_coefficient: 0.0906 - val_iou_metric: 0.1409 - val_loss: 2.2569 - learning_rate: 3.9744e-06
# Epoch 33/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2260 - dice_coefficient: 0.0885 - iou_metric: 0.1276 - loss: 2.3346
# Epoch 33: val_iou_metric improved from 0.14087 to 0.14258, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2260 - dice_coefficient: 0.0885 - iou_metric: 0.1276 - loss: 2.3346 - val_accuracy: 0.2496 - val_dice_coefficient: 0.0908 - val_iou_metric: 0.1426 - val_loss: 2.2520 - learning_rate: 4.1026e-06
# Epoch 34/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2278 - dice_coefficient: 0.0890 - iou_metric: 0.1287 - loss: 2.3293
# Epoch 34: val_iou_metric improved from 0.14258 to 0.14461, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2278 - dice_coefficient: 0.0890 - iou_metric: 0.1287 - loss: 2.3293 - val_accuracy: 0.2528 - val_dice_coefficient: 0.0910 - val_iou_metric: 0.1446 - val_loss: 2.2484 - learning_rate: 4.2308e-06
# Epoch 35/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2289 - dice_coefficient: 0.0900 - iou_metric: 0.1294 - loss: 2.3483
# Epoch 35: val_iou_metric improved from 0.14461 to 0.14470, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2289 - dice_coefficient: 0.0900 - iou_metric: 0.1295 - loss: 2.3473 - val_accuracy: 0.2529 - val_dice_coefficient: 0.0912 - val_iou_metric: 0.1447 - val_loss: 2.2463 - learning_rate: 4.3590e-06
# Epoch 36/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2318 - dice_coefficient: 0.0898 - iou_metric: 0.1313 - loss: 2.3190
# Epoch 36: val_iou_metric improved from 0.14470 to 0.14720, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2319 - dice_coefficient: 0.0898 - iou_metric: 0.1313 - loss: 2.3189 - val_accuracy: 0.2567 - val_dice_coefficient: 0.0915 - val_iou_metric: 0.1472 - val_loss: 2.2409 - learning_rate: 4.4872e-06
# Epoch 37/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2338 - dice_coefficient: 0.0898 - iou_metric: 0.1326 - loss: 2.3128
# Epoch 37: val_iou_metric improved from 0.14720 to 0.14917, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2339 - dice_coefficient: 0.0898 - iou_metric: 0.1326 - loss: 2.3128 - val_accuracy: 0.2598 - val_dice_coefficient: 0.0917 - val_iou_metric: 0.1492 - val_loss: 2.2343 - learning_rate: 4.6154e-06
# Epoch 38/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2364 - dice_coefficient: 0.0908 - iou_metric: 0.1343 - loss: 2.3272
# Epoch 38: val_iou_metric improved from 0.14917 to 0.15122, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2364 - dice_coefficient: 0.0907 - iou_metric: 0.1343 - loss: 2.3263 - val_accuracy: 0.2630 - val_dice_coefficient: 0.0920 - val_iou_metric: 0.1512 - val_loss: 2.2305 - learning_rate: 4.7436e-06
# Epoch 39/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2396 - dice_coefficient: 0.0909 - iou_metric: 0.1363 - loss: 2.3045
# Epoch 39: val_iou_metric improved from 0.15122 to 0.15293, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2396 - dice_coefficient: 0.0909 - iou_metric: 0.1363 - loss: 2.3042 - val_accuracy: 0.2656 - val_dice_coefficient: 0.0923 - val_iou_metric: 0.1529 - val_loss: 2.2273 - learning_rate: 4.8718e-06
# Epoch 40/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2424 - dice_coefficient: 0.0915 - iou_metric: 0.1381 - loss: 2.3087
# Epoch 40: val_iou_metric improved from 0.15293 to 0.15496, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2425 - dice_coefficient: 0.0915 - iou_metric: 0.1382 - loss: 2.3079 - val_accuracy: 0.2688 - val_dice_coefficient: 0.0926 - val_iou_metric: 0.1550 - val_loss: 2.2213 - learning_rate: 5.0000e-06
# Epoch 41/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2464 - dice_coefficient: 0.0910 - iou_metric: 0.1408 - loss: 2.2846
# Epoch 41: val_iou_metric improved from 0.15496 to 0.15686, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2465 - dice_coefficient: 0.0910 - iou_metric: 0.1408 - loss: 2.2845 - val_accuracy: 0.2716 - val_dice_coefficient: 0.0930 - val_iou_metric: 0.1569 - val_loss: 2.2169 - learning_rate: 5.1282e-06
# Epoch 42/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2497 - dice_coefficient: 0.0920 - iou_metric: 0.1429 - loss: 2.2816
# Epoch 42: val_iou_metric improved from 0.15686 to 0.16067, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2497 - dice_coefficient: 0.0919 - iou_metric: 0.1429 - loss: 2.2813 - val_accuracy: 0.2774 - val_dice_coefficient: 0.0933 - val_iou_metric: 0.1607 - val_loss: 2.2132 - learning_rate: 5.2564e-06
# Epoch 43/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2534 - dice_coefficient: 0.0923 - iou_metric: 0.1453 - loss: 2.2792
# Epoch 43: val_iou_metric improved from 0.16067 to 0.16392, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2534 - dice_coefficient: 0.0923 - iou_metric: 0.1453 - loss: 2.2789 - val_accuracy: 0.2822 - val_dice_coefficient: 0.0937 - val_iou_metric: 0.1639 - val_loss: 2.2074 - learning_rate: 5.3846e-06
# Epoch 44/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2579 - dice_coefficient: 0.0931 - iou_metric: 0.1483 - loss: 2.2813
# Epoch 44: val_iou_metric improved from 0.16392 to 0.16715, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2579 - dice_coefficient: 0.0930 - iou_metric: 0.1483 - loss: 2.2804 - val_accuracy: 0.2871 - val_dice_coefficient: 0.0940 - val_iou_metric: 0.1671 - val_loss: 2.1985 - learning_rate: 5.5128e-06
# Epoch 45/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2614 - dice_coefficient: 0.0941 - iou_metric: 0.1506 - loss: 2.2677
# Epoch 45: val_iou_metric improved from 0.16715 to 0.17094, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2614 - dice_coefficient: 0.0940 - iou_metric: 0.1506 - loss: 2.2670 - val_accuracy: 0.2927 - val_dice_coefficient: 0.0945 - val_iou_metric: 0.1709 - val_loss: 2.1890 - learning_rate: 5.6410e-06
# Epoch 46/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2671 - dice_coefficient: 0.0935 - iou_metric: 0.1544 - loss: 2.2640
# Epoch 46: val_iou_metric improved from 0.17094 to 0.17589, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2671 - dice_coefficient: 0.0935 - iou_metric: 0.1544 - loss: 2.2636 - val_accuracy: 0.2999 - val_dice_coefficient: 0.0950 - val_iou_metric: 0.1759 - val_loss: 2.1850 - learning_rate: 5.7692e-06
# Epoch 47/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2714 - dice_coefficient: 0.0946 - iou_metric: 0.1573 - loss: 2.2374
# Epoch 47: val_iou_metric improved from 0.17589 to 0.17882, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2715 - dice_coefficient: 0.0946 - iou_metric: 0.1573 - loss: 2.2371 - val_accuracy: 0.3042 - val_dice_coefficient: 0.0956 - val_iou_metric: 0.1788 - val_loss: 2.1751 - learning_rate: 5.8974e-06
# Epoch 48/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2770 - dice_coefficient: 0.0941 - iou_metric: 0.1610 - loss: 2.2219
# Epoch 48: val_iou_metric improved from 0.17882 to 0.18349, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2770 - dice_coefficient: 0.0941 - iou_metric: 0.1611 - loss: 2.2219 - val_accuracy: 0.3110 - val_dice_coefficient: 0.0961 - val_iou_metric: 0.1835 - val_loss: 2.1681 - learning_rate: 6.0256e-06
# Epoch 49/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2815 - dice_coefficient: 0.0955 - iou_metric: 0.1641 - loss: 2.2336
# Epoch 49: val_iou_metric improved from 0.18349 to 0.18799, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2815 - dice_coefficient: 0.0955 - iou_metric: 0.1641 - loss: 2.2329 - val_accuracy: 0.3174 - val_dice_coefficient: 0.0969 - val_iou_metric: 0.1880 - val_loss: 2.1540 - learning_rate: 6.1538e-06
# Epoch 50/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2869 - dice_coefficient: 0.0961 - iou_metric: 0.1678 - loss: 2.2182
# Epoch 50: val_iou_metric improved from 0.18799 to 0.19312, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.2869 - dice_coefficient: 0.0960 - iou_metric: 0.1678 - loss: 2.2179 - val_accuracy: 0.3246 - val_dice_coefficient: 0.0975 - val_iou_metric: 0.1931 - val_loss: 2.1418 - learning_rate: 6.2820e-06
# Epoch 51/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2926 - dice_coefficient: 0.0968 - iou_metric: 0.1719 - loss: 2.2045
# Epoch 51: val_iou_metric improved from 0.19312 to 0.19898, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.2927 - dice_coefficient: 0.0968 - iou_metric: 0.1719 - loss: 2.2042 - val_accuracy: 0.3328 - val_dice_coefficient: 0.0983 - val_iou_metric: 0.1990 - val_loss: 2.1291 - learning_rate: 6.4103e-06
# Epoch 52/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2959 - dice_coefficient: 0.0970 - iou_metric: 0.1741 - loss: 2.2025
# Epoch 52: val_iou_metric improved from 0.19898 to 0.20279, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.2960 - dice_coefficient: 0.0970 - iou_metric: 0.1742 - loss: 2.2019 - val_accuracy: 0.3381 - val_dice_coefficient: 0.0992 - val_iou_metric: 0.2028 - val_loss: 2.1184 - learning_rate: 6.5385e-06
# Epoch 53/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3026 - dice_coefficient: 0.0987 - iou_metric: 0.1788 - loss: 2.1909
# Epoch 53: val_iou_metric improved from 0.20279 to 0.20987, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3026 - dice_coefficient: 0.0987 - iou_metric: 0.1788 - loss: 2.1903 - val_accuracy: 0.3479 - val_dice_coefficient: 0.1003 - val_iou_metric: 0.2099 - val_loss: 2.1024 - learning_rate: 6.6667e-06
# Epoch 54/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3099 - dice_coefficient: 0.0996 - iou_metric: 0.1840 - loss: 2.1855
# Epoch 54: val_iou_metric improved from 0.20987 to 0.21525, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3100 - dice_coefficient: 0.0996 - iou_metric: 0.1840 - loss: 2.1851 - val_accuracy: 0.3551 - val_dice_coefficient: 0.1013 - val_iou_metric: 0.2153 - val_loss: 2.0903 - learning_rate: 6.7949e-06
# Epoch 55/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3166 - dice_coefficient: 0.1012 - iou_metric: 0.1887 - loss: 2.1925
# Epoch 55: val_iou_metric improved from 0.21525 to 0.21933, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3166 - dice_coefficient: 0.1012 - iou_metric: 0.1887 - loss: 2.1918 - val_accuracy: 0.3606 - val_dice_coefficient: 0.1027 - val_iou_metric: 0.2193 - val_loss: 2.0738 - learning_rate: 6.9231e-06
# Epoch 56/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3231 - dice_coefficient: 0.1012 - iou_metric: 0.1933 - loss: 2.1414
# Epoch 56: val_iou_metric improved from 0.21933 to 0.22674, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3231 - dice_coefficient: 0.1012 - iou_metric: 0.1934 - loss: 2.1413 - val_accuracy: 0.3705 - val_dice_coefficient: 0.1038 - val_iou_metric: 0.2267 - val_loss: 2.0597 - learning_rate: 7.0513e-06
# Epoch 57/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3323 - dice_coefficient: 0.1028 - iou_metric: 0.2000 - loss: 2.1492
# Epoch 57: val_iou_metric improved from 0.22674 to 0.23266, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3323 - dice_coefficient: 0.1028 - iou_metric: 0.2000 - loss: 2.1487 - val_accuracy: 0.3783 - val_dice_coefficient: 0.1052 - val_iou_metric: 0.2327 - val_loss: 2.0429 - learning_rate: 7.1795e-06
# Epoch 58/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3355 - dice_coefficient: 0.1019 - iou_metric: 0.2025 - loss: 2.1051
# Epoch 58: val_iou_metric improved from 0.23266 to 0.23797, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.3356 - dice_coefficient: 0.1019 - iou_metric: 0.2025 - loss: 2.1056 - val_accuracy: 0.3853 - val_dice_coefficient: 0.1066 - val_iou_metric: 0.2380 - val_loss: 2.0300 - learning_rate: 7.3077e-06
# Epoch 59/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3446 - dice_coefficient: 0.1043 - iou_metric: 0.2092 - loss: 2.1098
# Epoch 59: val_iou_metric improved from 0.23797 to 0.24380, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3447 - dice_coefficient: 0.1043 - iou_metric: 0.2093 - loss: 2.1096 - val_accuracy: 0.3927 - val_dice_coefficient: 0.1079 - val_iou_metric: 0.2438 - val_loss: 2.0120 - learning_rate: 7.4359e-06
# Epoch 60/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3542 - dice_coefficient: 0.1074 - iou_metric: 0.2163 - loss: 2.1153
# Epoch 60: val_iou_metric improved from 0.24380 to 0.25041, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3542 - dice_coefficient: 0.1073 - iou_metric: 0.2162 - loss: 2.1143 - val_accuracy: 0.4012 - val_dice_coefficient: 0.1096 - val_iou_metric: 0.2504 - val_loss: 1.9969 - learning_rate: 7.5641e-06
# Epoch 61/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3631 - dice_coefficient: 0.1070 - iou_metric: 0.2230 - loss: 2.0887
# Epoch 61: val_iou_metric improved from 0.25041 to 0.25874, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3631 - dice_coefficient: 0.1070 - iou_metric: 0.2230 - loss: 2.0883 - val_accuracy: 0.4117 - val_dice_coefficient: 0.1108 - val_iou_metric: 0.2587 - val_loss: 1.9869 - learning_rate: 7.6923e-06
# Epoch 62/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3677 - dice_coefficient: 0.1079 - iou_metric: 0.2266 - loss: 2.0740
# Epoch 62: val_iou_metric improved from 0.25874 to 0.26632, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3678 - dice_coefficient: 0.1079 - iou_metric: 0.2266 - loss: 2.0738 - val_accuracy: 0.4211 - val_dice_coefficient: 0.1122 - val_iou_metric: 0.2663 - val_loss: 1.9741 - learning_rate: 7.8205e-06
# Epoch 63/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3768 - dice_coefficient: 0.1094 - iou_metric: 0.2337 - loss: 2.0693
# Epoch 63: val_iou_metric improved from 0.26632 to 0.27412, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.3769 - dice_coefficient: 0.1094 - iou_metric: 0.2337 - loss: 2.0687 - val_accuracy: 0.4307 - val_dice_coefficient: 0.1138 - val_iou_metric: 0.2741 - val_loss: 1.9590 - learning_rate: 7.9487e-06
# Epoch 64/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3880 - dice_coefficient: 0.1116 - iou_metric: 0.2422 - loss: 2.0638
# Epoch 64: val_iou_metric improved from 0.27412 to 0.28404, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.3880 - dice_coefficient: 0.1116 - iou_metric: 0.2422 - loss: 2.0630 - val_accuracy: 0.4428 - val_dice_coefficient: 0.1151 - val_iou_metric: 0.2840 - val_loss: 1.9500 - learning_rate: 8.0769e-06
# Epoch 65/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3964 - dice_coefficient: 0.1120 - iou_metric: 0.2489 - loss: 2.0382
# Epoch 65: val_iou_metric improved from 0.28404 to 0.28843, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3965 - dice_coefficient: 0.1120 - iou_metric: 0.2489 - loss: 2.0378 - val_accuracy: 0.4478 - val_dice_coefficient: 0.1165 - val_iou_metric: 0.2884 - val_loss: 1.9361 - learning_rate: 8.2051e-06
# Epoch 66/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4075 - dice_coefficient: 0.1137 - iou_metric: 0.2577 - loss: 2.0231
# Epoch 66: val_iou_metric improved from 0.28843 to 0.29782, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4075 - dice_coefficient: 0.1136 - iou_metric: 0.2577 - loss: 2.0230 - val_accuracy: 0.4590 - val_dice_coefficient: 0.1180 - val_iou_metric: 0.2978 - val_loss: 1.9262 - learning_rate: 8.3333e-06
# Epoch 67/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4148 - dice_coefficient: 0.1161 - iou_metric: 0.2636 - loss: 2.0238
# Epoch 67: val_iou_metric improved from 0.29782 to 0.30861, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.4148 - dice_coefficient: 0.1161 - iou_metric: 0.2636 - loss: 2.0235 - val_accuracy: 0.4715 - val_dice_coefficient: 0.1192 - val_iou_metric: 0.3086 - val_loss: 1.9141 - learning_rate: 8.4615e-06
# Epoch 68/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4235 - dice_coefficient: 0.1163 - iou_metric: 0.2708 - loss: 2.0122
# Epoch 68: val_iou_metric improved from 0.30861 to 0.31716, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4235 - dice_coefficient: 0.1163 - iou_metric: 0.2707 - loss: 2.0119 - val_accuracy: 0.4813 - val_dice_coefficient: 0.1209 - val_iou_metric: 0.3172 - val_loss: 1.9009 - learning_rate: 8.5897e-06
# Epoch 69/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4302 - dice_coefficient: 0.1164 - iou_metric: 0.2764 - loss: 1.9876
# Epoch 69: val_iou_metric improved from 0.31716 to 0.32754, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4303 - dice_coefficient: 0.1164 - iou_metric: 0.2764 - loss: 1.9876 - val_accuracy: 0.4929 - val_dice_coefficient: 0.1221 - val_iou_metric: 0.3275 - val_loss: 1.8920 - learning_rate: 8.7180e-06
# Epoch 70/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4413 - dice_coefficient: 0.1183 - iou_metric: 0.2855 - loss: 1.9875
# Epoch 70: val_iou_metric improved from 0.32754 to 0.33322, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4413 - dice_coefficient: 0.1183 - iou_metric: 0.2855 - loss: 1.9873 - val_accuracy: 0.4991 - val_dice_coefficient: 0.1238 - val_iou_metric: 0.3332 - val_loss: 1.8774 - learning_rate: 8.8462e-06
# Epoch 71/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4474 - dice_coefficient: 0.1195 - iou_metric: 0.2908 - loss: 1.9690
# Epoch 71: val_iou_metric improved from 0.33322 to 0.34467, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.4475 - dice_coefficient: 0.1195 - iou_metric: 0.2908 - loss: 1.9690 - val_accuracy: 0.5118 - val_dice_coefficient: 0.1245 - val_iou_metric: 0.3447 - val_loss: 1.8751 - learning_rate: 8.9744e-06
# Epoch 72/150
# ...
# Epoch 119/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8129 - dice_coefficient: 0.1991 - iou_metric: 0.6996 - loss: 1.5571
# Epoch 119: val_iou_metric improved from 0.74217 to 0.74374, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8129 - dice_coefficient: 0.1991 - iou_metric: 0.6996 - loss: 1.5571 - val_accuracy: 0.8454 - val_dice_coefficient: 0.2134 - val_iou_metric: 0.7437 - val_loss: 1.4701 - learning_rate: 1.5128e-05
# Epoch 120/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8139 - dice_coefficient: 0.1997 - iou_metric: 0.7009 - loss: 1.5590
# Epoch 120: val_iou_metric did not improve from 0.74374
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8140 - dice_coefficient: 0.1997 - iou_metric: 0.7010 - loss: 1.5588 - val_accuracy: 0.8443 - val_dice_coefficient: 0.2140 - val_iou_metric: 0.7421 - val_loss: 1.4686 - learning_rate: 1.5256e-05
# Epoch 121/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8233 - dice_coefficient: 0.2031 - iou_metric: 0.7146 - loss: 1.5373
# Epoch 121: val_iou_metric improved from 0.74374 to 0.74624, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8233 - dice_coefficient: 0.2031 - iou_metric: 0.7145 - loss: 1.5375 - val_accuracy: 0.8471 - val_dice_coefficient: 0.2158 - val_iou_metric: 0.7462 - val_loss: 1.4631 - learning_rate: 1.5385e-05
# Epoch 122/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8195 - dice_coefficient: 0.2017 - iou_metric: 0.7090 - loss: 1.5451
# Epoch 122: val_iou_metric improved from 0.74624 to 0.75284, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.8195 - dice_coefficient: 0.2018 - iou_metric: 0.7091 - loss: 1.5451 - val_accuracy: 0.8520 - val_dice_coefficient: 0.2190 - val_iou_metric: 0.7528 - val_loss: 1.4523 - learning_rate: 1.5513e-05
# Epoch 123/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8263 - dice_coefficient: 0.2064 - iou_metric: 0.7194 - loss: 1.5276
# Epoch 123: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8263 - dice_coefficient: 0.2064 - iou_metric: 0.7194 - loss: 1.5278 - val_accuracy: 0.8478 - val_dice_coefficient: 0.2194 - val_iou_metric: 0.7467 - val_loss: 1.4526 - learning_rate: 1.5641e-05
# Epoch 124/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8331 - dice_coefficient: 0.2107 - iou_metric: 0.7287 - loss: 1.5210
# Epoch 124: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8331 - dice_coefficient: 0.2106 - iou_metric: 0.7286 - loss: 1.5210 - val_accuracy: 0.8487 - val_dice_coefficient: 0.2208 - val_iou_metric: 0.7481 - val_loss: 1.4478 - learning_rate: 1.5769e-05
# Epoch 125/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8349 - dice_coefficient: 0.2104 - iou_metric: 0.7305 - loss: 1.5145
# Epoch 125: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8348 - dice_coefficient: 0.2104 - iou_metric: 0.7304 - loss: 1.5146 - val_accuracy: 0.8490 - val_dice_coefficient: 0.2222 - val_iou_metric: 0.7483 - val_loss: 1.4439 - learning_rate: 1.5897e-05
# Epoch 126/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8335 - dice_coefficient: 0.2142 - iou_metric: 0.7278 - loss: 1.5120
# Epoch 126: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8336 - dice_coefficient: 0.2141 - iou_metric: 0.7279 - loss: 1.5119 - val_accuracy: 0.8489 - val_dice_coefficient: 0.2246 - val_iou_metric: 0.7484 - val_loss: 1.4365 - learning_rate: 1.6026e-05
# Epoch 127/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8363 - dice_coefficient: 0.2130 - iou_metric: 0.7339 - loss: 1.5161
# Epoch 127: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8363 - dice_coefficient: 0.2130 - iou_metric: 0.7339 - loss: 1.5159 - val_accuracy: 0.8497 - val_dice_coefficient: 0.2257 - val_iou_metric: 0.7492 - val_loss: 1.4326 - learning_rate: 1.6154e-05
# Epoch 128/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8391 - dice_coefficient: 0.2176 - iou_metric: 0.7373 - loss: 1.5017
# Epoch 128: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8391 - dice_coefficient: 0.2176 - iou_metric: 0.7373 - loss: 1.5016 - val_accuracy: 0.8515 - val_dice_coefficient: 0.2281 - val_iou_metric: 0.7513 - val_loss: 1.4245 - learning_rate: 1.6282e-05
# Epoch 129/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8407 - dice_coefficient: 0.2185 - iou_metric: 0.7395 - loss: 1.4911
# Epoch 129: val_iou_metric did not improve from 0.75284
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8407 - dice_coefficient: 0.2185 - iou_metric: 0.7395 - loss: 1.4911 - val_accuracy: 0.8517 - val_dice_coefficient: 0.2296 - val_iou_metric: 0.7521 - val_loss: 1.4222 - learning_rate: 1.6410e-05
# Epoch 130/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8432 - dice_coefficient: 0.2201 - iou_metric: 0.7436 - loss: 1.4857
# Epoch 130: val_iou_metric improved from 0.75284 to 0.75383, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.8431 - dice_coefficient: 0.2200 - iou_metric: 0.7435 - loss: 1.4858 - val_accuracy: 0.8530 - val_dice_coefficient: 0.2321 - val_iou_metric: 0.7538 - val_loss: 1.4144 - learning_rate: 1.6538e-05
# Epoch 131/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8467 - dice_coefficient: 0.2252 - iou_metric: 0.7476 - loss: 1.4744
# Epoch 131: val_iou_metric did not improve from 0.75383
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8466 - dice_coefficient: 0.2251 - iou_metric: 0.7475 - loss: 1.4745 - val_accuracy: 0.8524 - val_dice_coefficient: 0.2343 - val_iou_metric: 0.7527 - val_loss: 1.4081 - learning_rate: 1.6667e-05
# Epoch 132/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8531 - dice_coefficient: 0.2257 - iou_metric: 0.7571 - loss: 1.4702
# Epoch 132: val_iou_metric improved from 0.75383 to 0.75877, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.8530 - dice_coefficient: 0.2256 - iou_metric: 0.7569 - loss: 1.4703 - val_accuracy: 0.8567 - val_dice_coefficient: 0.2364 - val_iou_metric: 0.7588 - val_loss: 1.4010 - learning_rate: 1.6795e-05
# Epoch 133/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8487 - dice_coefficient: 0.2255 - iou_metric: 0.7516 - loss: 1.4657
# Epoch 133: val_iou_metric improved from 0.75877 to 0.75982, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8488 - dice_coefficient: 0.2255 - iou_metric: 0.7516 - loss: 1.4656 - val_accuracy: 0.8575 - val_dice_coefficient: 0.2383 - val_iou_metric: 0.7598 - val_loss: 1.3946 - learning_rate: 1.6923e-05
# Epoch 134/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8520 - dice_coefficient: 0.2272 - iou_metric: 0.7554 - loss: 1.4552
# Epoch 134: val_iou_metric improved from 0.75982 to 0.76196, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8520 - dice_coefficient: 0.2272 - iou_metric: 0.7554 - loss: 1.4553 - val_accuracy: 0.8591 - val_dice_coefficient: 0.2407 - val_iou_metric: 0.7620 - val_loss: 1.3876 - learning_rate: 1.7051e-05
# Epoch 135/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8467 - dice_coefficient: 0.2261 - iou_metric: 0.7483 - loss: 1.4725
# Epoch 135: val_iou_metric did not improve from 0.76196
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.8468 - dice_coefficient: 0.2262 - iou_metric: 0.7483 - loss: 1.4723 - val_accuracy: 0.8570 - val_dice_coefficient: 0.2413 - val_iou_metric: 0.7592 - val_loss: 1.3871 - learning_rate: 1.7179e-05
# Epoch 136/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8527 - dice_coefficient: 0.2320 - iou_metric: 0.7572 - loss: 1.4520
# Epoch 136: val_iou_metric did not improve from 0.76196
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8527 - dice_coefficient: 0.2320 - iou_metric: 0.7572 - loss: 1.4520 - val_accuracy: 0.8551 - val_dice_coefficient: 0.2428 - val_iou_metric: 0.7558 - val_loss: 1.3839 - learning_rate: 1.7308e-05
# Epoch 137/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8567 - dice_coefficient: 0.2344 - iou_metric: 0.7627 - loss: 1.4369
# Epoch 137: val_iou_metric did not improve from 0.76196
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8567 - dice_coefficient: 0.2344 - iou_metric: 0.7627 - loss: 1.4369 - val_accuracy: 0.8577 - val_dice_coefficient: 0.2441 - val_iou_metric: 0.7599 - val_loss: 1.3799 - learning_rate: 1.7436e-05
# Epoch 138/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8586 - dice_coefficient: 0.2359 - iou_metric: 0.7652 - loss: 1.4383
# Epoch 138: val_iou_metric improved from 0.76196 to 0.76267, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.8585 - dice_coefficient: 0.2359 - iou_metric: 0.7652 - loss: 1.4383 - val_accuracy: 0.8597 - val_dice_coefficient: 0.2463 - val_iou_metric: 0.7627 - val_loss: 1.3730 - learning_rate: 1.7564e-05
# Epoch 139/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8577 - dice_coefficient: 0.2376 - iou_metric: 0.7639 - loss: 1.4404
# Epoch 139: val_iou_metric did not improve from 0.76267
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.8577 - dice_coefficient: 0.2375 - iou_metric: 0.7639 - loss: 1.4403 - val_accuracy: 0.8587 - val_dice_coefficient: 0.2481 - val_iou_metric: 0.7614 - val_loss: 1.3690 - learning_rate: 1.7692e-05
# Epoch 140/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8592 - dice_coefficient: 0.2377 - iou_metric: 0.7663 - loss: 1.4254
# Epoch 140: val_iou_metric improved from 0.76267 to 0.77243, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.8592 - dice_coefficient: 0.2377 - iou_metric: 0.7664 - loss: 1.4254 - val_accuracy: 0.8667 - val_dice_coefficient: 0.2526 - val_iou_metric: 0.7724 - val_loss: 1.3520 - learning_rate: 1.7821e-05
# Epoch 141/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8598 - dice_coefficient: 0.2434 - iou_metric: 0.7671 - loss: 1.4172
# Epoch 141: val_iou_metric did not improve from 0.77243
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8597 - dice_coefficient: 0.2433 - iou_metric: 0.7670 - loss: 1.4173 - val_accuracy: 0.8646 - val_dice_coefficient: 0.2535 - val_iou_metric: 0.7692 - val_loss: 1.3510 - learning_rate: 1.7949e-05
# Epoch 142/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8558 - dice_coefficient: 0.2416 - iou_metric: 0.7619 - loss: 1.4266
# Epoch 142: val_iou_metric improved from 0.77243 to 0.77651, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.8559 - dice_coefficient: 0.2417 - iou_metric: 0.7621 - loss: 1.4264 - val_accuracy: 0.8693 - val_dice_coefficient: 0.2578 - val_iou_metric: 0.7765 - val_loss: 1.3396 - learning_rate: 1.8077e-05
# Epoch 143/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8634 - dice_coefficient: 0.2453 - iou_metric: 0.7727 - loss: 1.4075
# Epoch 143: val_iou_metric did not improve from 0.77651
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.8633 - dice_coefficient: 0.2452 - iou_metric: 0.7726 - loss: 1.4076 - val_accuracy: 0.8629 - val_dice_coefficient: 0.2565 - val_iou_metric: 0.7673 - val_loss: 1.3474 - learning_rate: 1.8205e-05
# Epoch 144/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8647 - dice_coefficient: 0.2479 - iou_metric: 0.7751 - loss: 1.3996
# Epoch 144: val_iou_metric did not improve from 0.77651
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8646 - dice_coefficient: 0.2479 - iou_metric: 0.7750 - loss: 1.3997 - val_accuracy: 0.8659 - val_dice_coefficient: 0.2596 - val_iou_metric: 0.7718 - val_loss: 1.3371 - learning_rate: 1.8333e-05
# Epoch 145/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8671 - dice_coefficient: 0.2509 - iou_metric: 0.7779 - loss: 1.4038
# Epoch 145: val_iou_metric did not improve from 0.77651
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8670 - dice_coefficient: 0.2508 - iou_metric: 0.7778 - loss: 1.4038 - val_accuracy: 0.8637 - val_dice_coefficient: 0.2604 - val_iou_metric: 0.7683 - val_loss: 1.3363 - learning_rate: 1.8462e-05
# Epoch 146/150
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8609 - dice_coefficient: 0.2503 - iou_metric: 0.7698 - loss: 1.4036
# Epoch 146: val_iou_metric did not improve from 0.77651
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8611 - dice_coefficient: 0.2503 - iou_metric: 0.7700 - loss: 1.4033 - val_accuracy: 0.8604 - val_dice_coefficient: 0.2612 - val_iou_metric: 0.7633 - val_loss: 1.3353 - learning_rate: 1.8590e-05
# Epoch 147/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8665 - dice_coefficient: 0.2575 - iou_metric: 0.7773 - loss: 1.3870
# Epoch 147: val_iou_metric did not improve from 0.77651
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8665 - dice_coefficient: 0.2574 - iou_metric: 0.7773 - loss: 1.3869 - val_accuracy: 0.8656 - val_dice_coefficient: 0.2647 - val_iou_metric: 0.7708 - val_loss: 1.3245 - learning_rate: 1.8718e-05
# Epoch 148/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8655 - dice_coefficient: 0.2531 - iou_metric: 0.7755 - loss: 1.3883
# Epoch 148: val_iou_metric improved from 0.77651 to 0.78484, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.8656 - dice_coefficient: 0.2532 - iou_metric: 0.7755 - loss: 1.3881 - val_accuracy: 0.8753 - val_dice_coefficient: 0.2710 - val_iou_metric: 0.7848 - val_loss: 1.3037 - learning_rate: 1.8846e-05
# Epoch 149/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8648 - dice_coefficient: 0.2547 - iou_metric: 0.7756 - loss: 1.3855
# Epoch 149: val_iou_metric improved from 0.78484 to 0.78682, saving model to efficient_weed_model_B0_best.keras
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.8649 - dice_coefficient: 0.2547 - iou_metric: 0.7757 - loss: 1.3854 - val_accuracy: 0.8767 - val_dice_coefficient: 0.2730 - val_iou_metric: 0.7868 - val_loss: 1.2973 - learning_rate: 1.8974e-05
# Epoch 150/150
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8699 - dice_coefficient: 0.2599 - iou_metric: 0.7823 - loss: 1.3632
# Epoch 150: val_iou_metric did not improve from 0.78682
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8699 - dice_coefficient: 0.2599 - iou_metric: 0.7823 - loss: 1.3632 - val_accuracy: 0.8669 - val_dice_coefficient: 0.2702 - val_iou_metric: 0.7731 - val_loss: 1.3136 - learning_rate: 1.9103e-05
#
# --- Entrenamiento Finalizado ---
# El mejor modelo se ha guardado en: efficient_weed_model_B0_best.keras
#
# Cargando el mejor modelo guardado para la evaluación en el conjunto de test...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'aspp_module_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Se encontraron 210 imágenes de test.
# Creando dataset de test...
#
# --- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 868ms/step - accuracy: 0.8686 - dice_coefficient: 0.2808 - iou_metric: 0.7807 - loss: 1.3149
#
# ## MÉTRICAS DE TEST - MODELO 'B0' ##
# Test Loss: 1.3049
# Test Dice Coefficient: 0.2784
# Test mIoU: 0.7892
# Test Global Accuracy: 0.8751
#
# Calculando IoU por clase en el conjunto de test...
#
# ## IoU por Clase (Test) ##
# IoU for Background: 0.8830
# IoU for Cow-tongue: 0.2672
# IoU for Dandelion: 0.5148
# IoU for Kikuyo: 0.5263
# IoU for Other: 0.5947
# IoU for Potato: 0.4873
#
# Promedio de IoU por clase: 0.5456
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
