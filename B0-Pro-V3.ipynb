# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/B0-Pro-V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# Configuración del modelo
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-4

# Paths
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')
TEST_IMAGES_PATH = os.path.join(BASE_PATH, 'test/images')
TEST_MASKS_PATH = os.path.join(BASE_PATH, 'test/masks')

class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True
    layer_names = [
        'block1a_project_activation',
        'block2b_add',
        'block3b_add',
        'block5c_add',
        'top_activation'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)
    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_B0')
    return model

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return (0.6 * f_loss_mean) + (0.4 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

def load_and_preprocess_data(image_paths, mask_paths, augment=False):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    # ##################################################################
    # ## INICIO DE LA CORRECCIÓN ###
    # ##################################################################
    def augment_and_preprocess(image, mask):
        # Volteos (sin cambios)
        if tf.random.uniform([]) > 0.5:
            image, mask = tf.image.flip_left_right(image), tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5:
            image, mask = tf.image.flip_up_down(image), tf.image.flip_up_down(mask)

        # CORRECCIÓN: Lógica para la rotación aleatoria compatible con modo Grafo
        # 1. Generar un número aleatorio entero entre 0 y 3
        k_rot = tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)

        # 2. Usar tf.switch_case para aplicar la rotación correcta
        image, mask = tf.switch_case(k_rot, branch_fns={
            0: lambda: (image, mask),  # k=0: No rotar
            1: lambda: (tf.image.rot90(image, k=1), tf.image.rot90(mask, k=1)), # k=1: 90 grados
            2: lambda: (tf.image.rot90(image, k=2), tf.image.rot90(mask, k=2)), # k=2: 180 grados
            3: lambda: (tf.image.rot90(image, k=3), tf.image.rot90(mask, k=3)), # k=3: 270 grados
        }, default=lambda: (image, mask))

        # Resto de las aumentaciones (sin cambios)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask
    # ##################################################################
    # ## FIN DE LA CORRECCIÓN ###
    # ##################################################################

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = tf.data.Dataset.zip((image_ds, mask_ds))
    if augment:
        dataset = dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_B0.keras'):
    model = create_weed_detection_model()
    model.summary()

    optimizer = tf.keras.optimizers.AdamW(
        learning_rate=LEARNING_RATE,
        weight_decay=1e-5
    )

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_iou_metric', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_iou_metric', patience=50, mode='max', restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1)
    ]

    print(f"Iniciando entrenamiento con BATCH_SIZE={BATCH_SIZE}...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history

if __name__ == "__main__":
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(TRAIN_MASKS_PATH, '*.png')))
    val_image_paths = sorted(glob(os.path.join(VAL_IMAGES_PATH, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(VAL_MASKS_PATH, '*.png')))

    print("Creando datasets de entrenamiento y validación...")
    train_ds = load_and_preprocess_data(train_image_paths, train_mask_paths, augment=True)
    val_ds = load_and_preprocess_data(val_image_paths, val_mask_paths, augment=False)

    model_save_path = 'efficient_weed_model_B0_best.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("\n--- Entrenamiento Finalizado ---")
    print(f"El mejor modelo se ha guardado en: {model_save_path}")

    print("\nCargando el mejor modelo guardado para la evaluación en el conjunto de test...")
    best_model = tf.keras.models.load_model(
        model_save_path,
        custom_objects={
            'ASPPModule': ASPPModule,
            'DeformableAttention': DeformableAttention,
            'combined_loss': combined_loss,
            'dice_coefficient': dice_coefficient,
            'iou_metric': iou_metric,
            'dice_loss': dice_loss
        }
    )

    test_image_paths = sorted(glob(os.path.join(TEST_IMAGES_PATH, '*.jpg')))
    test_mask_paths = sorted(glob(os.path.join(TEST_MASKS_PATH, '*.png')))

    if not test_image_paths:
        print("\nADVERTENCIA: No se encontraron imágenes en el directorio de test. Saltando la evaluación de test.")
    else:
        print(f"Se encontraron {len(test_image_paths)} imágenes de test.")
        print("Creando dataset de test...")
        test_ds = load_and_preprocess_data(test_image_paths, test_mask_paths, augment=False)

        print("\n--- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---")
        test_metrics = best_model.evaluate(test_ds)

        print("\n## MÉTRICAS DE TEST - MODELO 'B0' ##")
        print(f"Test Loss: {test_metrics[0]:.4f}")
        print(f"Test Dice Coefficient: {test_metrics[1]:.4f}")
        print(f"Test mIoU: {test_metrics[2]:.4f}")
        print(f"Test Global Accuracy: {test_metrics[3]:.4f}")

        print("\nCalculando IoU por clase en el conjunto de test...")
        iou_per_class_values = []
        for images_batch, masks_batch in test_ds:
            predictions_batch = best_model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()
        class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
        print("\n## IoU por Clase (Test) ##")
        for i, iou in enumerate(iou_per_class_values):
            print(f"IoU for {class_names[i]}: {iou:.4f}")
        print(f"\nPromedio de IoU por clase: {np.mean(iou_per_class_values):.4f}")

        # Mostrar ejemplos de máscaras reales y predichas
        for images_batch, masks_batch in test_ds.take(1):
            predictions_batch = best_model.predict(images_batch)
            plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)

        # Gráficas de Dice Coefficient y Loss durante el entrenamiento
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['dice_coefficient'], label='Dice Coefficient (Train)')
        plt.plot(history.history['val_dice_coefficient'], label='Dice Coefficient (Validation)')
        plt.title('Dice Coefficient over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Dice Coefficient')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Loss (Train)')
        plt.plot(history.history['val_loss'], label='Loss (Validation)')
        plt.title('Loss over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
# Out:
# Creando datasets de entrenamiento y validación...
# Model: "EfficientWeedDetectionModel_B0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer_8[0]… │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 32), (None,   │            │                   │
# │                     │ 16, 16, 48),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 112), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module_4       │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module_4[0]… │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 8, 8, 96)  │     10,752 │ EfficientNetV2B0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_97 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 8, 8, 96)  │          0 │ re_lu_97[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_98 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_43      │ (None, 8, 8, 192) │          0 │ dropout_39[0][0], │
# │ (Concatenate)       │                   │            │ re_lu_98[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_16 │ (None, 8, 8, 96)  │     20,160 │ concatenate_43[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_99 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 8, 8, 96)  │          0 │ re_lu_99[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_21 │ (None, 16, 16,    │     36,864 │ dropout_40[0][0]  │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 16, 16,    │      4,608 │ EfficientNetV2B0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_100 (ReLU)    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 16, 16,    │          0 │ re_lu_100[0][0]   │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_101 (ReLU)    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_44      │ (None, 16, 16,    │          0 │ dropout_41[0][0], │
# │ (Concatenate)       │ 192)              │            │ re_lu_101[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_17 │ (None, 16, 16,    │     20,160 │ concatenate_44[0… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_102 (ReLU)    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 16, 16,    │          0 │ re_lu_102[0][0]   │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_22 │ (None, 32, 32,    │     18,432 │ dropout_42[0][0]  │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 32, 32,    │      1,536 │ EfficientNetV2B0… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_103 (ReLU)    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 32, 32,    │          0 │ re_lu_103[0][0]   │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_104 (ReLU)    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_45      │ (None, 32, 32,    │          0 │ dropout_43[0][0], │
# │ (Concatenate)       │ 96)               │            │ re_lu_104[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 32, 32,    │      5,472 │ concatenate_45[0… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_105 (ReLU)    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 32, 32,    │          0 │ re_lu_105[0][0]   │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_23 │ (None, 64, 64,    │      4,608 │ dropout_44[0][0]  │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 64, 64,    │        384 │ EfficientNetV2B0… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_106 (ReLU)    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_61[0][0]   │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 64, 64,    │          0 │ re_lu_106[0][0]   │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_107 (ReLU)    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_46      │ (None, 64, 64,    │          0 │ dropout_45[0][0], │
# │ (Concatenate)       │ 48)               │            │ re_lu_107[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 64, 64,    │      1,584 │ concatenate_46[0… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_108 (ReLU)    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_46          │ (None, 64, 64,    │          0 │ re_lu_108[0][0]   │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_24 │ (None, 128, 128,  │        576 │ dropout_46[0][0]  │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,514,346 (51.55 MB)
#  Trainable params: 13,449,082 (51.30 MB)
#  Non-trainable params: 65,264 (254.94 KB)
# Iniciando entrenamiento con BATCH_SIZE=16...
# Epoch 1/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2171 - dice_coefficient: 0.0864 - iou_metric: 0.1221 - loss: 0.9362
# Epoch 1: val_iou_metric improved from -inf to 0.20046, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 125s 179ms/step - accuracy: 0.2174 - dice_coefficient: 0.0864 - iou_metric: 0.1223 - loss: 0.9359 - val_accuracy: 0.3368 - val_dice_coefficient: 0.0866 - val_iou_metric: 0.2005 - val_loss: 0.8678 - learning_rate: 1.0000e-04
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3464 - dice_coefficient: 0.0933 - iou_metric: 0.2116 - loss: 0.8612
# Epoch 2: val_iou_metric improved from 0.20046 to 0.30009, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.3467 - dice_coefficient: 0.0933 - iou_metric: 0.2118 - loss: 0.8610 - val_accuracy: 0.4655 - val_dice_coefficient: 0.0903 - val_iou_metric: 0.3001 - val_loss: 0.8353 - learning_rate: 1.0000e-04
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4374 - dice_coefficient: 0.1064 - iou_metric: 0.2830 - loss: 0.7812
# Epoch 3: val_iou_metric improved from 0.30009 to 0.34889, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4376 - dice_coefficient: 0.1065 - iou_metric: 0.2832 - loss: 0.7810 - val_accuracy: 0.5169 - val_dice_coefficient: 0.1012 - val_iou_metric: 0.3489 - val_loss: 0.7362 - learning_rate: 1.0000e-04
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5730 - dice_coefficient: 0.1291 - iou_metric: 0.4121 - loss: 0.6931
# Epoch 4: val_iou_metric improved from 0.34889 to 0.41660, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.5732 - dice_coefficient: 0.1291 - iou_metric: 0.4124 - loss: 0.6929 - val_accuracy: 0.5843 - val_dice_coefficient: 0.1178 - val_iou_metric: 0.4166 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6938 - dice_coefficient: 0.1458 - iou_metric: 0.5514 - loss: 0.6247
# Epoch 5: val_iou_metric improved from 0.41660 to 0.59984, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.6940 - dice_coefficient: 0.1458 - iou_metric: 0.5516 - loss: 0.6246 - val_accuracy: 0.7415 - val_dice_coefficient: 0.1421 - val_iou_metric: 0.5998 - val_loss: 0.5915 - learning_rate: 1.0000e-04
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7650 - dice_coefficient: 0.1645 - iou_metric: 0.6433 - loss: 0.5819
# Epoch 6: val_iou_metric improved from 0.59984 to 0.69728, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.7651 - dice_coefficient: 0.1645 - iou_metric: 0.6435 - loss: 0.5818 - val_accuracy: 0.8130 - val_dice_coefficient: 0.1693 - val_iou_metric: 0.6973 - val_loss: 0.5314 - learning_rate: 1.0000e-04
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8074 - dice_coefficient: 0.1813 - iou_metric: 0.6997 - loss: 0.5475
# Epoch 7: val_iou_metric improved from 0.69728 to 0.72547, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8074 - dice_coefficient: 0.1813 - iou_metric: 0.6997 - loss: 0.5474 - val_accuracy: 0.8314 - val_dice_coefficient: 0.1842 - val_iou_metric: 0.7255 - val_loss: 0.5034 - learning_rate: 1.0000e-04
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8290 - dice_coefficient: 0.1933 - iou_metric: 0.7294 - loss: 0.5265
# Epoch 8: val_iou_metric improved from 0.72547 to 0.74517, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8290 - dice_coefficient: 0.1933 - iou_metric: 0.7294 - loss: 0.5265 - val_accuracy: 0.8464 - val_dice_coefficient: 0.2026 - val_iou_metric: 0.7452 - val_loss: 0.4750 - learning_rate: 1.0000e-04
# Epoch 9/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8463 - dice_coefficient: 0.2123 - iou_metric: 0.7522 - loss: 0.5071
# Epoch 9: val_iou_metric improved from 0.74517 to 0.76558, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8462 - dice_coefficient: 0.2123 - iou_metric: 0.7521 - loss: 0.5070 - val_accuracy: 0.8606 - val_dice_coefficient: 0.2232 - val_iou_metric: 0.7656 - val_loss: 0.4490 - learning_rate: 1.0000e-04
# Epoch 10/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8517 - dice_coefficient: 0.2213 - iou_metric: 0.7599 - loss: 0.4849
# Epoch 10: val_iou_metric improved from 0.76558 to 0.77415, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8517 - dice_coefficient: 0.2213 - iou_metric: 0.7600 - loss: 0.4849 - val_accuracy: 0.8666 - val_dice_coefficient: 0.2363 - val_iou_metric: 0.7741 - val_loss: 0.4338 - learning_rate: 1.0000e-04
# Epoch 11/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8581 - dice_coefficient: 0.2348 - iou_metric: 0.7698 - loss: 0.4660
# Epoch 11: val_iou_metric improved from 0.77415 to 0.77927, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.8581 - dice_coefficient: 0.2349 - iou_metric: 0.7699 - loss: 0.4659 - val_accuracy: 0.8717 - val_dice_coefficient: 0.2475 - val_iou_metric: 0.7793 - val_loss: 0.4132 - learning_rate: 1.0000e-04
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8619 - dice_coefficient: 0.2466 - iou_metric: 0.7763 - loss: 0.4456
# Epoch 12: val_iou_metric improved from 0.77927 to 0.78552, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.8619 - dice_coefficient: 0.2466 - iou_metric: 0.7763 - loss: 0.4456 - val_accuracy: 0.8760 - val_dice_coefficient: 0.2671 - val_iou_metric: 0.7855 - val_loss: 0.3917 - learning_rate: 1.0000e-04
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8681 - dice_coefficient: 0.2659 - iou_metric: 0.7825 - loss: 0.4243
# Epoch 13: val_iou_metric improved from 0.78552 to 0.79228, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8681 - dice_coefficient: 0.2659 - iou_metric: 0.7825 - loss: 0.4243 - val_accuracy: 0.8820 - val_dice_coefficient: 0.2866 - val_iou_metric: 0.7923 - val_loss: 0.3724 - learning_rate: 1.0000e-04
# Epoch 14/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8733 - dice_coefficient: 0.2840 - iou_metric: 0.7902 - loss: 0.4065
# Epoch 14: val_iou_metric improved from 0.79228 to 0.80305, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8733 - dice_coefficient: 0.2841 - iou_metric: 0.7902 - loss: 0.4065 - val_accuracy: 0.8902 - val_dice_coefficient: 0.3077 - val_iou_metric: 0.8030 - val_loss: 0.3538 - learning_rate: 1.0000e-04
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8776 - dice_coefficient: 0.2993 - iou_metric: 0.7954 - loss: 0.3877
# Epoch 15: val_iou_metric did not improve from 0.80305
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8776 - dice_coefficient: 0.2993 - iou_metric: 0.7954 - loss: 0.3877 - val_accuracy: 0.8848 - val_dice_coefficient: 0.3152 - val_iou_metric: 0.7969 - val_loss: 0.3491 - learning_rate: 1.0000e-04
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8805 - dice_coefficient: 0.3164 - iou_metric: 0.7978 - loss: 0.3823
# Epoch 16: val_iou_metric improved from 0.80305 to 0.81148, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8805 - dice_coefficient: 0.3164 - iou_metric: 0.7979 - loss: 0.3822 - val_accuracy: 0.8944 - val_dice_coefficient: 0.3352 - val_iou_metric: 0.8115 - val_loss: 0.3341 - learning_rate: 1.0000e-04
# Epoch 17/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8848 - dice_coefficient: 0.3319 - iou_metric: 0.8057 - loss: 0.3639
# Epoch 17: val_iou_metric did not improve from 0.81148
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8849 - dice_coefficient: 0.3319 - iou_metric: 0.8057 - loss: 0.3639 - val_accuracy: 0.8829 - val_dice_coefficient: 0.3375 - val_iou_metric: 0.7940 - val_loss: 0.3326 - learning_rate: 1.0000e-04
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8936 - dice_coefficient: 0.3442 - iou_metric: 0.8178 - loss: 0.3595
# Epoch 18: val_iou_metric did not improve from 0.81148
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8935 - dice_coefficient: 0.3443 - iou_metric: 0.8178 - loss: 0.3594 - val_accuracy: 0.8867 - val_dice_coefficient: 0.3512 - val_iou_metric: 0.7990 - val_loss: 0.3243 - learning_rate: 1.0000e-04
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8912 - dice_coefficient: 0.3613 - iou_metric: 0.8154 - loss: 0.3561
# Epoch 19: val_iou_metric did not improve from 0.81148
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8912 - dice_coefficient: 0.3613 - iou_metric: 0.8154 - loss: 0.3560 - val_accuracy: 0.8947 - val_dice_coefficient: 0.3741 - val_iou_metric: 0.8106 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8972 - dice_coefficient: 0.3694 - iou_metric: 0.8249 - loss: 0.3437
# Epoch 20: val_iou_metric improved from 0.81148 to 0.81322, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8972 - dice_coefficient: 0.3694 - iou_metric: 0.8249 - loss: 0.3437 - val_accuracy: 0.8958 - val_dice_coefficient: 0.3828 - val_iou_metric: 0.8132 - val_loss: 0.3097 - learning_rate: 1.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8960 - dice_coefficient: 0.3837 - iou_metric: 0.8225 - loss: 0.3401
# Epoch 21: val_iou_metric did not improve from 0.81322
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8960 - dice_coefficient: 0.3837 - iou_metric: 0.8225 - loss: 0.3400 - val_accuracy: 0.8925 - val_dice_coefficient: 0.3834 - val_iou_metric: 0.8083 - val_loss: 0.3067 - learning_rate: 1.0000e-04
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8985 - dice_coefficient: 0.3878 - iou_metric: 0.8268 - loss: 0.3386
# Epoch 22: val_iou_metric improved from 0.81322 to 0.82100, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.8985 - dice_coefficient: 0.3879 - iou_metric: 0.8268 - loss: 0.3385 - val_accuracy: 0.9009 - val_dice_coefficient: 0.3947 - val_iou_metric: 0.8210 - val_loss: 0.2998 - learning_rate: 1.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9088 - dice_coefficient: 0.4032 - iou_metric: 0.8415 - loss: 0.3206
# Epoch 23: val_iou_metric did not improve from 0.82100
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9087 - dice_coefficient: 0.4032 - iou_metric: 0.8415 - loss: 0.3207 - val_accuracy: 0.8954 - val_dice_coefficient: 0.3970 - val_iou_metric: 0.8128 - val_loss: 0.3054 - learning_rate: 1.0000e-04
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9045 - dice_coefficient: 0.4057 - iou_metric: 0.8349 - loss: 0.3268
# Epoch 24: val_iou_metric improved from 0.82100 to 0.82172, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9045 - dice_coefficient: 0.4057 - iou_metric: 0.8349 - loss: 0.3268 - val_accuracy: 0.9017 - val_dice_coefficient: 0.4115 - val_iou_metric: 0.8217 - val_loss: 0.2946 - learning_rate: 1.0000e-04
# Epoch 25/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9084 - dice_coefficient: 0.4174 - iou_metric: 0.8413 - loss: 0.3160
# Epoch 25: val_iou_metric did not improve from 0.82172
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9084 - dice_coefficient: 0.4174 - iou_metric: 0.8413 - loss: 0.3160 - val_accuracy: 0.8970 - val_dice_coefficient: 0.4139 - val_iou_metric: 0.8145 - val_loss: 0.2916 - learning_rate: 1.0000e-04
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9074 - dice_coefficient: 0.4230 - iou_metric: 0.8394 - loss: 0.3113
# Epoch 26: val_iou_metric did not improve from 0.82172
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9075 - dice_coefficient: 0.4230 - iou_metric: 0.8394 - loss: 0.3112 - val_accuracy: 0.9012 - val_dice_coefficient: 0.4234 - val_iou_metric: 0.8196 - val_loss: 0.2864 - learning_rate: 1.0000e-04
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9082 - dice_coefficient: 0.4285 - iou_metric: 0.8409 - loss: 0.3119
# Epoch 27: val_iou_metric improved from 0.82172 to 0.82865, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9082 - dice_coefficient: 0.4285 - iou_metric: 0.8410 - loss: 0.3119 - val_accuracy: 0.9060 - val_dice_coefficient: 0.4287 - val_iou_metric: 0.8287 - val_loss: 0.2836 - learning_rate: 1.0000e-04
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9118 - dice_coefficient: 0.4406 - iou_metric: 0.8462 - loss: 0.3024
# Epoch 28: val_iou_metric did not improve from 0.82865
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9118 - dice_coefficient: 0.4406 - iou_metric: 0.8462 - loss: 0.3024 - val_accuracy: 0.8924 - val_dice_coefficient: 0.4214 - val_iou_metric: 0.8056 - val_loss: 0.2874 - learning_rate: 1.0000e-04
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9125 - dice_coefficient: 0.4446 - iou_metric: 0.8475 - loss: 0.3005
# Epoch 29: val_iou_metric did not improve from 0.82865
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9125 - dice_coefficient: 0.4446 - iou_metric: 0.8475 - loss: 0.3005 - val_accuracy: 0.9044 - val_dice_coefficient: 0.4295 - val_iou_metric: 0.8241 - val_loss: 0.2854 - learning_rate: 1.0000e-04
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9102 - dice_coefficient: 0.4507 - iou_metric: 0.8438 - loss: 0.3095
# Epoch 30: val_iou_metric improved from 0.82865 to 0.84042, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9102 - dice_coefficient: 0.4507 - iou_metric: 0.8439 - loss: 0.3094 - val_accuracy: 0.9152 - val_dice_coefficient: 0.4408 - val_iou_metric: 0.8404 - val_loss: 0.2784 - learning_rate: 1.0000e-04
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9171 - dice_coefficient: 0.4543 - iou_metric: 0.8540 - loss: 0.2982
# Epoch 31: val_iou_metric did not improve from 0.84042
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9171 - dice_coefficient: 0.4543 - iou_metric: 0.8540 - loss: 0.2981 - val_accuracy: 0.9133 - val_dice_coefficient: 0.4474 - val_iou_metric: 0.8370 - val_loss: 0.2747 - learning_rate: 1.0000e-04
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9154 - dice_coefficient: 0.4628 - iou_metric: 0.8516 - loss: 0.2916
# Epoch 32: val_iou_metric improved from 0.84042 to 0.84877, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9155 - dice_coefficient: 0.4628 - iou_metric: 0.8517 - loss: 0.2916 - val_accuracy: 0.9219 - val_dice_coefficient: 0.4532 - val_iou_metric: 0.8488 - val_loss: 0.2704 - learning_rate: 1.0000e-04
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9218 - dice_coefficient: 0.4701 - iou_metric: 0.8612 - loss: 0.2858
# Epoch 33: val_iou_metric improved from 0.84877 to 0.85935, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9218 - dice_coefficient: 0.4701 - iou_metric: 0.8612 - loss: 0.2858 - val_accuracy: 0.9277 - val_dice_coefficient: 0.4538 - val_iou_metric: 0.8594 - val_loss: 0.2696 - learning_rate: 1.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9237 - dice_coefficient: 0.4807 - iou_metric: 0.8639 - loss: 0.2846
# Epoch 34: val_iou_metric improved from 0.85935 to 0.87686, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9238 - dice_coefficient: 0.4807 - iou_metric: 0.8639 - loss: 0.2845 - val_accuracy: 0.9344 - val_dice_coefficient: 0.4725 - val_iou_metric: 0.8769 - val_loss: 0.2598 - learning_rate: 1.0000e-04
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9275 - dice_coefficient: 0.4927 - iou_metric: 0.8696 - loss: 0.2723
# Epoch 35: val_iou_metric improved from 0.87686 to 0.87986, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9275 - dice_coefficient: 0.4927 - iou_metric: 0.8696 - loss: 0.2724 - val_accuracy: 0.9350 - val_dice_coefficient: 0.4805 - val_iou_metric: 0.8799 - val_loss: 0.2563 - learning_rate: 1.0000e-04
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9275 - dice_coefficient: 0.4943 - iou_metric: 0.8697 - loss: 0.2723
# Epoch 36: val_iou_metric did not improve from 0.87986
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9275 - dice_coefficient: 0.4943 - iou_metric: 0.8697 - loss: 0.2723 - val_accuracy: 0.9344 - val_dice_coefficient: 0.4900 - val_iou_metric: 0.8789 - val_loss: 0.2534 - learning_rate: 1.0000e-04
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9260 - dice_coefficient: 0.5082 - iou_metric: 0.8669 - loss: 0.2720
# Epoch 37: val_iou_metric did not improve from 0.87986
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9260 - dice_coefficient: 0.5082 - iou_metric: 0.8669 - loss: 0.2720 - val_accuracy: 0.9295 - val_dice_coefficient: 0.5005 - val_iou_metric: 0.8689 - val_loss: 0.2491 - learning_rate: 1.0000e-04
# Epoch 38/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9280 - dice_coefficient: 0.4983 - iou_metric: 0.8707 - loss: 0.2716
# Epoch 38: val_iou_metric did not improve from 0.87986
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9280 - dice_coefficient: 0.4984 - iou_metric: 0.8707 - loss: 0.2715 - val_accuracy: 0.9341 - val_dice_coefficient: 0.5099 - val_iou_metric: 0.8761 - val_loss: 0.2424 - learning_rate: 1.0000e-04
# Epoch 39/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9298 - dice_coefficient: 0.5253 - iou_metric: 0.8729 - loss: 0.2587
# Epoch 39: val_iou_metric improved from 0.87986 to 0.88078, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9298 - dice_coefficient: 0.5252 - iou_metric: 0.8729 - loss: 0.2588 - val_accuracy: 0.9355 - val_dice_coefficient: 0.5192 - val_iou_metric: 0.8808 - val_loss: 0.2398 - learning_rate: 1.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9325 - dice_coefficient: 0.5333 - iou_metric: 0.8776 - loss: 0.2506
# Epoch 40: val_iou_metric improved from 0.88078 to 0.88099, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9324 - dice_coefficient: 0.5333 - iou_metric: 0.8775 - loss: 0.2507 - val_accuracy: 0.9355 - val_dice_coefficient: 0.5174 - val_iou_metric: 0.8810 - val_loss: 0.2388 - learning_rate: 1.0000e-04
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9322 - dice_coefficient: 0.5257 - iou_metric: 0.8773 - loss: 0.2579
# Epoch 41: val_iou_metric did not improve from 0.88099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9322 - dice_coefficient: 0.5258 - iou_metric: 0.8773 - loss: 0.2578 - val_accuracy: 0.9360 - val_dice_coefficient: 0.5338 - val_iou_metric: 0.8802 - val_loss: 0.2319 - learning_rate: 1.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9327 - dice_coefficient: 0.5413 - iou_metric: 0.8781 - loss: 0.2518
# Epoch 42: val_iou_metric did not improve from 0.88099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9327 - dice_coefficient: 0.5413 - iou_metric: 0.8781 - loss: 0.2518 - val_accuracy: 0.9353 - val_dice_coefficient: 0.5269 - val_iou_metric: 0.8801 - val_loss: 0.2359 - learning_rate: 1.0000e-04
# Epoch 43/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9331 - dice_coefficient: 0.5482 - iou_metric: 0.8788 - loss: 0.2505
# Epoch 43: val_iou_metric improved from 0.88099 to 0.88203, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9331 - dice_coefficient: 0.5482 - iou_metric: 0.8788 - loss: 0.2505 - val_accuracy: 0.9366 - val_dice_coefficient: 0.5393 - val_iou_metric: 0.8820 - val_loss: 0.2329 - learning_rate: 1.0000e-04
# Epoch 44/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9346 - dice_coefficient: 0.5612 - iou_metric: 0.8808 - loss: 0.2424
# Epoch 44: val_iou_metric improved from 0.88203 to 0.88840, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9346 - dice_coefficient: 0.5611 - iou_metric: 0.8808 - loss: 0.2424 - val_accuracy: 0.9393 - val_dice_coefficient: 0.5525 - val_iou_metric: 0.8884 - val_loss: 0.2269 - learning_rate: 1.0000e-04
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9312 - dice_coefficient: 0.5553 - iou_metric: 0.8757 - loss: 0.2428
# Epoch 45: val_iou_metric improved from 0.88840 to 0.89612, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9312 - dice_coefficient: 0.5553 - iou_metric: 0.8758 - loss: 0.2428 - val_accuracy: 0.9440 - val_dice_coefficient: 0.5567 - val_iou_metric: 0.8961 - val_loss: 0.2265 - learning_rate: 1.0000e-04
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9321 - dice_coefficient: 0.5553 - iou_metric: 0.8776 - loss: 0.2446
# Epoch 46: val_iou_metric did not improve from 0.89612
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9321 - dice_coefficient: 0.5552 - iou_metric: 0.8776 - loss: 0.2446 - val_accuracy: 0.9326 - val_dice_coefficient: 0.5433 - val_iou_metric: 0.8762 - val_loss: 0.2289 - learning_rate: 1.0000e-04
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9340 - dice_coefficient: 0.5600 - iou_metric: 0.8804 - loss: 0.2408
# Epoch 47: val_iou_metric did not improve from 0.89612
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9340 - dice_coefficient: 0.5600 - iou_metric: 0.8804 - loss: 0.2408 - val_accuracy: 0.9383 - val_dice_coefficient: 0.5468 - val_iou_metric: 0.8867 - val_loss: 0.2279 - learning_rate: 1.0000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9329 - dice_coefficient: 0.5572 - iou_metric: 0.8792 - loss: 0.2466
# Epoch 48: val_iou_metric improved from 0.89612 to 0.89669, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9329 - dice_coefficient: 0.5572 - iou_metric: 0.8792 - loss: 0.2466 - val_accuracy: 0.9443 - val_dice_coefficient: 0.5584 - val_iou_metric: 0.8967 - val_loss: 0.2278 - learning_rate: 1.0000e-04
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9358 - dice_coefficient: 0.5594 - iou_metric: 0.8833 - loss: 0.2372
# Epoch 49: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9358 - dice_coefficient: 0.5594 - iou_metric: 0.8833 - loss: 0.2372 - val_accuracy: 0.9408 - val_dice_coefficient: 0.5544 - val_iou_metric: 0.8911 - val_loss: 0.2270 - learning_rate: 1.0000e-04
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9348 - dice_coefficient: 0.5693 - iou_metric: 0.8815 - loss: 0.2367
# Epoch 50: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9348 - dice_coefficient: 0.5693 - iou_metric: 0.8815 - loss: 0.2367 - val_accuracy: 0.9376 - val_dice_coefficient: 0.5574 - val_iou_metric: 0.8853 - val_loss: 0.2259 - learning_rate: 1.0000e-04
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9344 - dice_coefficient: 0.5704 - iou_metric: 0.8811 - loss: 0.2400
# Epoch 51: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9344 - dice_coefficient: 0.5704 - iou_metric: 0.8811 - loss: 0.2399 - val_accuracy: 0.9400 - val_dice_coefficient: 0.5628 - val_iou_metric: 0.8898 - val_loss: 0.2217 - learning_rate: 1.0000e-04
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9372 - dice_coefficient: 0.5829 - iou_metric: 0.8859 - loss: 0.2301
# Epoch 52: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9372 - dice_coefficient: 0.5828 - iou_metric: 0.8858 - loss: 0.2301 - val_accuracy: 0.9392 - val_dice_coefficient: 0.5650 - val_iou_metric: 0.8888 - val_loss: 0.2219 - learning_rate: 1.0000e-04
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9379 - dice_coefficient: 0.5813 - iou_metric: 0.8873 - loss: 0.2342
# Epoch 53: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9379 - dice_coefficient: 0.5813 - iou_metric: 0.8873 - loss: 0.2342 - val_accuracy: 0.9409 - val_dice_coefficient: 0.5678 - val_iou_metric: 0.8905 - val_loss: 0.2193 - learning_rate: 1.0000e-04
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9382 - dice_coefficient: 0.5756 - iou_metric: 0.8870 - loss: 0.2336
# Epoch 54: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9382 - dice_coefficient: 0.5757 - iou_metric: 0.8870 - loss: 0.2336 - val_accuracy: 0.9410 - val_dice_coefficient: 0.5725 - val_iou_metric: 0.8913 - val_loss: 0.2190 - learning_rate: 1.0000e-04
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9366 - dice_coefficient: 0.5799 - iou_metric: 0.8853 - loss: 0.2335
# Epoch 55: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9366 - dice_coefficient: 0.5800 - iou_metric: 0.8853 - loss: 0.2335 - val_accuracy: 0.9390 - val_dice_coefficient: 0.5666 - val_iou_metric: 0.8871 - val_loss: 0.2210 - learning_rate: 1.0000e-04
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9384 - dice_coefficient: 0.5831 - iou_metric: 0.8881 - loss: 0.2296
# Epoch 56: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9384 - dice_coefficient: 0.5831 - iou_metric: 0.8881 - loss: 0.2296 - val_accuracy: 0.9427 - val_dice_coefficient: 0.5729 - val_iou_metric: 0.8927 - val_loss: 0.2172 - learning_rate: 1.0000e-04
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9374 - dice_coefficient: 0.5899 - iou_metric: 0.8862 - loss: 0.2244
# Epoch 57: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9374 - dice_coefficient: 0.5900 - iou_metric: 0.8862 - loss: 0.2244 - val_accuracy: 0.9438 - val_dice_coefficient: 0.5783 - val_iou_metric: 0.8948 - val_loss: 0.2150 - learning_rate: 1.0000e-04
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9389 - dice_coefficient: 0.5935 - iou_metric: 0.8885 - loss: 0.2245
# Epoch 58: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9389 - dice_coefficient: 0.5935 - iou_metric: 0.8885 - loss: 0.2245 - val_accuracy: 0.9405 - val_dice_coefficient: 0.5757 - val_iou_metric: 0.8883 - val_loss: 0.2172 - learning_rate: 1.0000e-04
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9406 - dice_coefficient: 0.6017 - iou_metric: 0.8912 - loss: 0.2178
# Epoch 59: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9406 - dice_coefficient: 0.6017 - iou_metric: 0.8911 - loss: 0.2178 - val_accuracy: 0.9411 - val_dice_coefficient: 0.5761 - val_iou_metric: 0.8903 - val_loss: 0.2158 - learning_rate: 1.0000e-04
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9391 - dice_coefficient: 0.6034 - iou_metric: 0.8893 - loss: 0.2209
# Epoch 60: val_iou_metric did not improve from 0.89669
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9391 - dice_coefficient: 0.6033 - iou_metric: 0.8893 - loss: 0.2209 - val_accuracy: 0.9428 - val_dice_coefficient: 0.5771 - val_iou_metric: 0.8940 - val_loss: 0.2150 - learning_rate: 1.0000e-04
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9383 - dice_coefficient: 0.5943 - iou_metric: 0.8879 - loss: 0.2252
# Epoch 61: val_iou_metric improved from 0.89669 to 0.89704, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9383 - dice_coefficient: 0.5943 - iou_metric: 0.8879 - loss: 0.2252 - val_accuracy: 0.9446 - val_dice_coefficient: 0.5803 - val_iou_metric: 0.8970 - val_loss: 0.2149 - learning_rate: 1.0000e-04
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9404 - dice_coefficient: 0.5984 - iou_metric: 0.8908 - loss: 0.2203
# Epoch 62: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9404 - dice_coefficient: 0.5985 - iou_metric: 0.8908 - loss: 0.2203 - val_accuracy: 0.9433 - val_dice_coefficient: 0.5740 - val_iou_metric: 0.8937 - val_loss: 0.2165 - learning_rate: 1.0000e-04
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9411 - dice_coefficient: 0.6068 - iou_metric: 0.8925 - loss: 0.2139
# Epoch 63: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9411 - dice_coefficient: 0.6068 - iou_metric: 0.8925 - loss: 0.2139 - val_accuracy: 0.9455 - val_dice_coefficient: 0.5806 - val_iou_metric: 0.8968 - val_loss: 0.2113 - learning_rate: 1.0000e-04
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9413 - dice_coefficient: 0.6078 - iou_metric: 0.8930 - loss: 0.2131
# Epoch 64: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9413 - dice_coefficient: 0.6078 - iou_metric: 0.8930 - loss: 0.2131 - val_accuracy: 0.9422 - val_dice_coefficient: 0.5830 - val_iou_metric: 0.8915 - val_loss: 0.2104 - learning_rate: 1.0000e-04
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9416 - dice_coefficient: 0.6053 - iou_metric: 0.8930 - loss: 0.2167
# Epoch 65: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9416 - dice_coefficient: 0.6054 - iou_metric: 0.8930 - loss: 0.2167 - val_accuracy: 0.9431 - val_dice_coefficient: 0.5840 - val_iou_metric: 0.8933 - val_loss: 0.2133 - learning_rate: 1.0000e-04
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9398 - dice_coefficient: 0.5992 - iou_metric: 0.8902 - loss: 0.2224
# Epoch 66: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9398 - dice_coefficient: 0.5993 - iou_metric: 0.8902 - loss: 0.2223 - val_accuracy: 0.9403 - val_dice_coefficient: 0.5757 - val_iou_metric: 0.8891 - val_loss: 0.2159 - learning_rate: 1.0000e-04
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9430 - dice_coefficient: 0.6155 - iou_metric: 0.8955 - loss: 0.2121
# Epoch 67: val_iou_metric improved from 0.89704 to 0.90069, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9430 - dice_coefficient: 0.6154 - iou_metric: 0.8955 - loss: 0.2121 - val_accuracy: 0.9468 - val_dice_coefficient: 0.5914 - val_iou_metric: 0.9007 - val_loss: 0.2079 - learning_rate: 1.0000e-04
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9412 - dice_coefficient: 0.6174 - iou_metric: 0.8927 - loss: 0.2099
# Epoch 68: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9412 - dice_coefficient: 0.6174 - iou_metric: 0.8927 - loss: 0.2100 - val_accuracy: 0.9429 - val_dice_coefficient: 0.5806 - val_iou_metric: 0.8927 - val_loss: 0.2117 - learning_rate: 1.0000e-04
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9438 - dice_coefficient: 0.6216 - iou_metric: 0.8967 - loss: 0.2057
# Epoch 69: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9438 - dice_coefficient: 0.6215 - iou_metric: 0.8967 - loss: 0.2057 - val_accuracy: 0.9452 - val_dice_coefficient: 0.5883 - val_iou_metric: 0.8977 - val_loss: 0.2094 - learning_rate: 1.0000e-04
# Epoch 70/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9425 - dice_coefficient: 0.6125 - iou_metric: 0.8947 - loss: 0.2091
# Epoch 70: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9425 - dice_coefficient: 0.6126 - iou_metric: 0.8947 - loss: 0.2091 - val_accuracy: 0.9381 - val_dice_coefficient: 0.5790 - val_iou_metric: 0.8833 - val_loss: 0.2132 - learning_rate: 1.0000e-04
# Epoch 71/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9426 - dice_coefficient: 0.6074 - iou_metric: 0.8950 - loss: 0.2167
# Epoch 71: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9426 - dice_coefficient: 0.6074 - iou_metric: 0.8950 - loss: 0.2167 - val_accuracy: 0.9444 - val_dice_coefficient: 0.5956 - val_iou_metric: 0.8952 - val_loss: 0.2076 - learning_rate: 1.0000e-04
# Epoch 72/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9414 - dice_coefficient: 0.6109 - iou_metric: 0.8927 - loss: 0.2124
# Epoch 72: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9414 - dice_coefficient: 0.6109 - iou_metric: 0.8927 - loss: 0.2124 - val_accuracy: 0.9414 - val_dice_coefficient: 0.5881 - val_iou_metric: 0.8897 - val_loss: 0.2079 - learning_rate: 1.0000e-04
# Epoch 73/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9422 - dice_coefficient: 0.6188 - iou_metric: 0.8943 - loss: 0.2075
# Epoch 73: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9422 - dice_coefficient: 0.6188 - iou_metric: 0.8943 - loss: 0.2075 - val_accuracy: 0.9451 - val_dice_coefficient: 0.5939 - val_iou_metric: 0.8970 - val_loss: 0.2049 - learning_rate: 1.0000e-04
# Epoch 74/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9453 - dice_coefficient: 0.6247 - iou_metric: 0.8992 - loss: 0.2034
# Epoch 74: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9452 - dice_coefficient: 0.6247 - iou_metric: 0.8991 - loss: 0.2034 - val_accuracy: 0.9415 - val_dice_coefficient: 0.5892 - val_iou_metric: 0.8909 - val_loss: 0.2061 - learning_rate: 1.0000e-04
# Epoch 75/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9442 - dice_coefficient: 0.6222 - iou_metric: 0.8977 - loss: 0.2071
# Epoch 75: val_iou_metric did not improve from 0.90069
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9442 - dice_coefficient: 0.6222 - iou_metric: 0.8977 - loss: 0.2071 - val_accuracy: 0.9424 - val_dice_coefficient: 0.5914 - val_iou_metric: 0.8912 - val_loss: 0.2052 - learning_rate: 1.0000e-04
# Epoch 76/150
# ...
# Epoch 119/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9526 - dice_coefficient: 0.7253 - iou_metric: 0.9119 - loss: 0.1543
# Epoch 119: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9526 - dice_coefficient: 0.7252 - iou_metric: 0.9119 - loss: 0.1543 - val_accuracy: 0.9509 - val_dice_coefficient: 0.6746 - val_iou_metric: 0.9075 - val_loss: 0.1760 - learning_rate: 1.0000e-04
# Epoch 120/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9529 - dice_coefficient: 0.7296 - iou_metric: 0.9124 - loss: 0.1512
# Epoch 120: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9529 - dice_coefficient: 0.7295 - iou_metric: 0.9124 - loss: 0.1513 - val_accuracy: 0.9518 - val_dice_coefficient: 0.6767 - val_iou_metric: 0.9103 - val_loss: 0.1756 - learning_rate: 1.0000e-04
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9528 - dice_coefficient: 0.7244 - iou_metric: 0.9123 - loss: 0.1534
# Epoch 121: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9528 - dice_coefficient: 0.7245 - iou_metric: 0.9123 - loss: 0.1534 - val_accuracy: 0.9520 - val_dice_coefficient: 0.6770 - val_iou_metric: 0.9106 - val_loss: 0.1741 - learning_rate: 1.0000e-04
# Epoch 122/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9531 - dice_coefficient: 0.7204 - iou_metric: 0.9126 - loss: 0.1543
# Epoch 122: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9531 - dice_coefficient: 0.7204 - iou_metric: 0.9126 - loss: 0.1543 - val_accuracy: 0.9513 - val_dice_coefficient: 0.6801 - val_iou_metric: 0.9082 - val_loss: 0.1759 - learning_rate: 1.0000e-04
# Epoch 123/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9540 - dice_coefficient: 0.7359 - iou_metric: 0.9143 - loss: 0.1493
# Epoch 123: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9540 - dice_coefficient: 0.7359 - iou_metric: 0.9143 - loss: 0.1493 - val_accuracy: 0.9523 - val_dice_coefficient: 0.6829 - val_iou_metric: 0.9106 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9529 - dice_coefficient: 0.7200 - iou_metric: 0.9123 - loss: 0.1623
# Epoch 124: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9529 - dice_coefficient: 0.7199 - iou_metric: 0.9123 - loss: 0.1623 - val_accuracy: 0.9453 - val_dice_coefficient: 0.6728 - val_iou_metric: 0.8966 - val_loss: 0.1806 - learning_rate: 1.0000e-04
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9529 - dice_coefficient: 0.7202 - iou_metric: 0.9124 - loss: 0.1557
# Epoch 125: val_iou_metric did not improve from 0.91283
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9529 - dice_coefficient: 0.7202 - iou_metric: 0.9124 - loss: 0.1557 - val_accuracy: 0.9515 - val_dice_coefficient: 0.6800 - val_iou_metric: 0.9095 - val_loss: 0.1747 - learning_rate: 1.0000e-04
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9534 - dice_coefficient: 0.7395 - iou_metric: 0.9133 - loss: 0.1473
# Epoch 126: val_iou_metric improved from 0.91283 to 0.91322, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9534 - dice_coefficient: 0.7395 - iou_metric: 0.9133 - loss: 0.1473 - val_accuracy: 0.9535 - val_dice_coefficient: 0.6852 - val_iou_metric: 0.9132 - val_loss: 0.1724 - learning_rate: 1.0000e-04
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9528 - dice_coefficient: 0.7268 - iou_metric: 0.9122 - loss: 0.1553
# Epoch 127: val_iou_metric did not improve from 0.91322
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9528 - dice_coefficient: 0.7268 - iou_metric: 0.9122 - loss: 0.1553 - val_accuracy: 0.9505 - val_dice_coefficient: 0.6810 - val_iou_metric: 0.9076 - val_loss: 0.1742 - learning_rate: 1.0000e-04
# Epoch 128/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9527 - dice_coefficient: 0.7345 - iou_metric: 0.9121 - loss: 0.1502
# Epoch 128: val_iou_metric improved from 0.91322 to 0.91324, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9527 - dice_coefficient: 0.7345 - iou_metric: 0.9121 - loss: 0.1502 - val_accuracy: 0.9532 - val_dice_coefficient: 0.6886 - val_iou_metric: 0.9132 - val_loss: 0.1711 - learning_rate: 1.0000e-04
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9535 - dice_coefficient: 0.7283 - iou_metric: 0.9136 - loss: 0.1569
# Epoch 129: val_iou_metric did not improve from 0.91324
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9535 - dice_coefficient: 0.7283 - iou_metric: 0.9136 - loss: 0.1569 - val_accuracy: 0.9479 - val_dice_coefficient: 0.6756 - val_iou_metric: 0.9024 - val_loss: 0.1778 - learning_rate: 1.0000e-04
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9545 - dice_coefficient: 0.7263 - iou_metric: 0.9152 - loss: 0.1536
# Epoch 130: val_iou_metric did not improve from 0.91324
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9545 - dice_coefficient: 0.7264 - iou_metric: 0.9152 - loss: 0.1536 - val_accuracy: 0.9505 - val_dice_coefficient: 0.6858 - val_iou_metric: 0.9069 - val_loss: 0.1747 - learning_rate: 1.0000e-04
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9530 - dice_coefficient: 0.7359 - iou_metric: 0.9126 - loss: 0.1491
# Epoch 131: val_iou_metric did not improve from 0.91324
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9530 - dice_coefficient: 0.7359 - iou_metric: 0.9126 - loss: 0.1491 - val_accuracy: 0.9516 - val_dice_coefficient: 0.6897 - val_iou_metric: 0.9105 - val_loss: 0.1711 - learning_rate: 1.0000e-04
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9537 - dice_coefficient: 0.7364 - iou_metric: 0.9137 - loss: 0.1482
# Epoch 132: val_iou_metric did not improve from 0.91324
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9537 - dice_coefficient: 0.7363 - iou_metric: 0.9137 - loss: 0.1482 - val_accuracy: 0.9511 - val_dice_coefficient: 0.6890 - val_iou_metric: 0.9071 - val_loss: 0.1744 - learning_rate: 1.0000e-04
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9522 - dice_coefficient: 0.7348 - iou_metric: 0.9112 - loss: 0.1508
# Epoch 133: val_iou_metric improved from 0.91324 to 0.91448, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9522 - dice_coefficient: 0.7347 - iou_metric: 0.9112 - loss: 0.1507 - val_accuracy: 0.9545 - val_dice_coefficient: 0.6925 - val_iou_metric: 0.9145 - val_loss: 0.1741 - learning_rate: 1.0000e-04
# Epoch 134/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9547 - dice_coefficient: 0.7477 - iou_metric: 0.9154 - loss: 0.1425
# Epoch 134: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9547 - dice_coefficient: 0.7477 - iou_metric: 0.9154 - loss: 0.1425 - val_accuracy: 0.9522 - val_dice_coefficient: 0.6910 - val_iou_metric: 0.9115 - val_loss: 0.1741 - learning_rate: 1.0000e-04
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9550 - dice_coefficient: 0.7498 - iou_metric: 0.9166 - loss: 0.1411
# Epoch 135: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9550 - dice_coefficient: 0.7497 - iou_metric: 0.9165 - loss: 0.1412 - val_accuracy: 0.9503 - val_dice_coefficient: 0.6859 - val_iou_metric: 0.9075 - val_loss: 0.1733 - learning_rate: 1.0000e-04
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9527 - dice_coefficient: 0.7298 - iou_metric: 0.9122 - loss: 0.1522
# Epoch 136: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9527 - dice_coefficient: 0.7298 - iou_metric: 0.9122 - loss: 0.1522 - val_accuracy: 0.9518 - val_dice_coefficient: 0.6875 - val_iou_metric: 0.9097 - val_loss: 0.1733 - learning_rate: 1.0000e-04
# Epoch 137/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9551 - dice_coefficient: 0.7406 - iou_metric: 0.9163 - loss: 0.1444
# Epoch 137: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9551 - dice_coefficient: 0.7406 - iou_metric: 0.9163 - loss: 0.1444 - val_accuracy: 0.9528 - val_dice_coefficient: 0.6883 - val_iou_metric: 0.9105 - val_loss: 0.1741 - learning_rate: 1.0000e-04
# Epoch 138/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9532 - dice_coefficient: 0.7524 - iou_metric: 0.9131 - loss: 0.1419
# Epoch 138: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9532 - dice_coefficient: 0.7524 - iou_metric: 0.9131 - loss: 0.1419 - val_accuracy: 0.9497 - val_dice_coefficient: 0.6828 - val_iou_metric: 0.9055 - val_loss: 0.1775 - learning_rate: 1.0000e-04
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9561 - dice_coefficient: 0.7475 - iou_metric: 0.9179 - loss: 0.1406
# Epoch 139: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9561 - dice_coefficient: 0.7475 - iou_metric: 0.9179 - loss: 0.1407 - val_accuracy: 0.9536 - val_dice_coefficient: 0.6926 - val_iou_metric: 0.9129 - val_loss: 0.1731 - learning_rate: 1.0000e-04
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9537 - dice_coefficient: 0.7358 - iou_metric: 0.9138 - loss: 0.1463
# Epoch 140: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9537 - dice_coefficient: 0.7358 - iou_metric: 0.9138 - loss: 0.1463 - val_accuracy: 0.9529 - val_dice_coefficient: 0.6886 - val_iou_metric: 0.9125 - val_loss: 0.1742 - learning_rate: 1.0000e-04
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9553 - dice_coefficient: 0.7434 - iou_metric: 0.9166 - loss: 0.1433
# Epoch 141: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9553 - dice_coefficient: 0.7434 - iou_metric: 0.9166 - loss: 0.1434 - val_accuracy: 0.9521 - val_dice_coefficient: 0.6924 - val_iou_metric: 0.9098 - val_loss: 0.1720 - learning_rate: 1.0000e-04
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9533 - dice_coefficient: 0.7491 - iou_metric: 0.9132 - loss: 0.1398
# Epoch 142: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9533 - dice_coefficient: 0.7490 - iou_metric: 0.9133 - loss: 0.1398 - val_accuracy: 0.9531 - val_dice_coefficient: 0.6923 - val_iou_metric: 0.9117 - val_loss: 0.1743 - learning_rate: 1.0000e-04
# Epoch 143/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9562 - dice_coefficient: 0.7585 - iou_metric: 0.9181 - loss: 0.1365
# Epoch 143: val_iou_metric did not improve from 0.91448
#
# Epoch 143: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9562 - dice_coefficient: 0.7585 - iou_metric: 0.9181 - loss: 0.1365 - val_accuracy: 0.9532 - val_dice_coefficient: 0.6889 - val_iou_metric: 0.9125 - val_loss: 0.1775 - learning_rate: 1.0000e-04
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9560 - dice_coefficient: 0.7445 - iou_metric: 0.9179 - loss: 0.1390
# Epoch 144: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9560 - dice_coefficient: 0.7445 - iou_metric: 0.9179 - loss: 0.1390 - val_accuracy: 0.9531 - val_dice_coefficient: 0.6917 - val_iou_metric: 0.9117 - val_loss: 0.1742 - learning_rate: 3.0000e-05
# Epoch 145/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9568 - dice_coefficient: 0.7458 - iou_metric: 0.9193 - loss: 0.1396
# Epoch 145: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9568 - dice_coefficient: 0.7459 - iou_metric: 0.9192 - loss: 0.1396 - val_accuracy: 0.9537 - val_dice_coefficient: 0.6929 - val_iou_metric: 0.9138 - val_loss: 0.1729 - learning_rate: 3.0000e-05
# Epoch 146/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9560 - dice_coefficient: 0.7589 - iou_metric: 0.9179 - loss: 0.1334
# Epoch 146: val_iou_metric did not improve from 0.91448
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9560 - dice_coefficient: 0.7588 - iou_metric: 0.9179 - loss: 0.1335 - val_accuracy: 0.9532 - val_dice_coefficient: 0.6944 - val_iou_metric: 0.9127 - val_loss: 0.1734 - learning_rate: 3.0000e-05
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9565 - dice_coefficient: 0.7515 - iou_metric: 0.9186 - loss: 0.1410
# Epoch 147: val_iou_metric improved from 0.91448 to 0.91693, saving model to efficient_weed_model_B0_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.9565 - dice_coefficient: 0.7515 - iou_metric: 0.9186 - loss: 0.1410 - val_accuracy: 0.9555 - val_dice_coefficient: 0.6962 - val_iou_metric: 0.9169 - val_loss: 0.1742 - learning_rate: 3.0000e-05
# Epoch 148/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9558 - dice_coefficient: 0.7444 - iou_metric: 0.9176 - loss: 0.1423
# Epoch 148: val_iou_metric did not improve from 0.91693
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9558 - dice_coefficient: 0.7445 - iou_metric: 0.9176 - loss: 0.1423 - val_accuracy: 0.9533 - val_dice_coefficient: 0.6933 - val_iou_metric: 0.9130 - val_loss: 0.1726 - learning_rate: 3.0000e-05
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9555 - dice_coefficient: 0.7543 - iou_metric: 0.9171 - loss: 0.1355
# Epoch 149: val_iou_metric did not improve from 0.91693
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9555 - dice_coefficient: 0.7543 - iou_metric: 0.9171 - loss: 0.1355 - val_accuracy: 0.9529 - val_dice_coefficient: 0.6937 - val_iou_metric: 0.9116 - val_loss: 0.1722 - learning_rate: 3.0000e-05
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9547 - dice_coefficient: 0.7586 - iou_metric: 0.9161 - loss: 0.1363
# Epoch 150: val_iou_metric did not improve from 0.91693
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9547 - dice_coefficient: 0.7586 - iou_metric: 0.9161 - loss: 0.1363 - val_accuracy: 0.9547 - val_dice_coefficient: 0.6944 - val_iou_metric: 0.9149 - val_loss: 0.1737 - learning_rate: 3.0000e-05
#
# --- Entrenamiento Finalizado ---
# El mejor modelo se ha guardado en: efficient_weed_model_B0_best.keras
#
# Cargando el mejor modelo guardado para la evaluación en el conjunto de test...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'aspp_module_4', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Se encontraron 210 imágenes de test.
# Creando dataset de test...
#
# --- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 353ms/step - accuracy: 0.9573 - dice_coefficient: 0.6405 - iou_metric: 0.9202 - loss: 0.2142
#
# ## MÉTRICAS DE TEST - MODELO 'B0' ##
# Test Loss: 0.1777
# Test Dice Coefficient: 0.6727
# Test mIoU: 0.9284
# Test Global Accuracy: 0.9618
#
# Calculando IoU por clase en el conjunto de test...
#
# ## IoU por Clase (Test) ##
# IoU for Background: 0.9464
# IoU for Cow-tongue: 0.9089
# IoU for Dandelion: 0.8972
# IoU for Kikuyo: 0.9002
# IoU for Other: 0.6335
# IoU for Potato: 0.8787
#
# Promedio de IoU por clase: 0.8608
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
