# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/Vitest/blob/main/Ejemplofinal150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6   # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()

        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)

        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))

        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])

        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True

    # Confirm these layer names and their resolutions are correct for your TF/Keras version
    # and EfficientNetV2B0 weights.
    layer_names = [
        'block1a_project_activation', # Expected: (N, 64, 64, 16)
        'block2a_expand_activation',  # Expected: (N, 32, 32, 24)
        'block3a_expand_activation',  # Expected: (N, 16, 16, 48)
        'block4a_expand_activation',  # Expected: (N, 8, 8, 80)
        'top_activation'              # Expected: (N, 4, 4, 1280)
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)

    # Unpack outputs directly from the backbone call
    # IMPORTANT: The order here must match the order in `layer_names` in create_efficient_backbone
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)

    # --- DEBUGGING PRINTS ---
    print(f"\n--- Backbone Feature Shapes ---")
    print(f"feat1_out (64x64): {feat1_out.shape}")
    print(f"feat2_out (32x32): {feat2_out.shape}")
    print(f"feat3_out (16x16): {feat3_out.shape}")
    print(f"feat4_out (8x8): {feat4_out.shape}")
    print(f"feat5_out (4x4, ASPP input): {feat5_out.shape}")
    print(f"-------------------------------\n")
    # --- END DEBUGGING PRINTS ---

    deep_features = feat5_out # (N, 4, 4, 1280) -> input to ASPP
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features) # (N, 4, 4, 192)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features) # (N, 4, 4, 192)

    # --- Decoder Path ---

   # UP1: From (4,4) to (8,8)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)
    print(f"Shape of decoder_up1 (after upsampling from 4x4): {decoder_up1.shape}") # Expected: (None, 8, 8, 96)

    # Concat with feat4_out (which is actually 16x16, needs downsampling to 8x8)
    # Original feat4_out from backbone: (N, 16, 16, 192) - according to your print

    # 1. Downsample feat4_out from 16x16 to 8x8
    feat4_downsampled = layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2), padding='same')(feat4_out)
    print(f"Shape of feat4_downsampled (from 16x16 downsampled to 8x8): {feat4_downsampled.shape}") # Expected: (None, 8, 8, 192)

    # 2. Process the downsampled feat4 to match channels (96)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_downsampled)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    print(f"Shape of feat4_processed (from 8x8 backbone feature): {feat4_processed.shape}") # Expected: (None, 8, 8, 96)

    # CONCATENATION POINT 1: Now both inputs should be 8x8
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    print(f"Shape of decoder_concat_8x8: {decoder_concat_8x8.shape}") # Expected: (None, 8, 8, 192)

    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)
    print(f"Shape of decoder_conv_8x8: {decoder_conv_8x8.shape}") # Expected: (None, 8, 8, 96)

    # UP2: From (8,8) to (16,16)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    print(f"Shape of decoder_up2 (after upsampling from 8x8): {decoder_up2.shape}") # Expected: (None, 16, 16, 96)

    # Concat with feat3_out (16x16)
    # Original feat3_out from backbone: (N, 16, 16, 48)
    # Process feat3_out to match channels (96) but keep spatial (16x16)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    print(f"Shape of feat3_processed (from 16x16 backbone feature): {feat3_processed.shape}") # Expected: (None, 16, 16, 96)

    # CONCATENATION POINT 2: Both inputs MUST be 16x16.
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    print(f"Shape of decoder_concat_16x16: {decoder_concat_16x16.shape}") # Expected: (None, 16, 16, 192)

    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)
    print(f"Shape of decoder_conv_16x16: {decoder_conv_16x16.shape}") # Expected: (None, 16, 16, 96)

    # UP3: From (16,16) to (32,32)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    print(f"Shape of decoder_up3 (after upsampling from 16x16): {decoder_up3.shape}") # Expected: (None, 32, 32, 48)

    # Concat with feat2_out (32x32)
    # Original feat2_out from backbone: (N, 32, 32, 24)
    # Process feat2_out to match channels (48) but keep spatial (32x32)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    print(f"Shape of feat2_processed (from 32x32 backbone feature): {feat2_processed.shape}") # Expected: (None, 32, 32, 48)

    # CONCATENATION POINT 3: Both inputs MUST be 32x32.
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    print(f"Shape of decoder_concat_32x32: {decoder_concat_32x32.shape}") # Expected: (None, 32, 32, 96)

    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)
    print(f"Shape of decoder_conv_32x32: {decoder_conv_32x32.shape}") # Expected: (None, 32, 32, 48)


    # UP4: From (32,32) to (64,64)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    print(f"Shape of decoder_up4 (after upsampling from 32x32): {decoder_up4.shape}") # Expected: (None, 64, 64, 24)

    # Concat with feat1_out (64x64)
    # Original feat1_out from backbone: (N, 64, 64, 16)
    # Process feat1_out to match channels (24) but keep spatial (64x64)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    print(f"Shape of feat1_processed (from 64x64 backbone feature): {feat1_processed.shape}") # Expected: (None, 64, 64, 24)

    # CONCATENATION POINT 4: Both inputs MUST be 64x64.
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    print(f"Shape of decoder_concat_64x64: {decoder_concat_64x64.shape}") # Expected: (None, 64, 64, 48)

    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)
    print(f"Shape of decoder_conv_64x64: {decoder_conv_64x64.shape}") # Expected: (None, 64, 64, 24)

    # Final Upsampling to IMG_HEIGHT, IMG_WIDTH (128x128)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    print(f"Shape of final outputs: {outputs.shape}") # Expected: (None, 128, 128, 6)

    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel')
    return model

# --- Métricas y Funciones de Pérdida (sin cambios) ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos (sin cambios) ---
def load_and_preprocess_data(train_img_path, train_msk_path, val_img_path, val_msk_path):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5:
            k = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
            image = tf.image.rot90(image, k)
            mask = tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    train_image_paths = sorted(glob(os.path.join(train_img_path, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(train_msk_path, '*.png')))
    val_image_paths = sorted(glob(os.path.join(val_img_path, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(val_msk_path, '*.png')))

    if not train_image_paths or not train_mask_paths or not val_image_paths or not val_mask_paths:
        raise FileNotFoundError("Una o más rutas de datos no encontraron archivos. Verifica las rutas.")

    print(f"Found {len(train_image_paths)} training images and {len(train_mask_paths)} training masks")
    print(f"Found {len(val_image_paths)} validation images and {len(val_mask_paths)} validation masks")

    train_image_ds = tf.data.Dataset.from_tensor_slices(train_image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    train_mask_ds = tf.data.Dataset.from_tensor_slices(train_mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = tf.data.Dataset.zip((train_image_ds, train_mask_ds))
    train_dataset = train_dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_image_ds = tf.data.Dataset.from_tensor_slices(val_image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    val_mask_ds = tf.data.Dataset.from_tensor_slices(val_mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    val_dataset = tf.data.Dataset.zip((val_image_ds, val_mask_ds))
    val_dataset = val_dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    val_dataset = val_dataset.cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model.keras'):
    model = create_weed_detection_model()
    model.summary()
    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-5)
    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path, monitor='val_dice_coefficient', save_best_only=True, mode='max', verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient', patience=50, mode='max', restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1
        ),
    ]
    print(f"Starting training for {EPOCHS} epochs...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    print(f"Visualizing {num_samples} samples from the validation set...")
    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)
        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))
        for i in range(min(num_samples, images.shape[0])):
            original_image = images[i]
            original_image = (original_image - original_image.numpy().min()) / (original_image.numpy().min()) * 255 # Fixed to avoid division by zero if all values are same
            if np.isclose(original_image.numpy().max(), original_image.numpy().min()): # Better check for constant image
                original_image = tf.cast(original_image, tf.uint8) # No scaling needed, just cast
            else:
                original_image = (original_image - original_image.numpy().min()) / (original_image.numpy().max() - original_image.numpy().min()) * 255
                original_image = tf.cast(original_image, tf.uint8)

            axes[i, 0].imshow(original_image)
            axes[i, 0].set_title('Original Image')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('True Mask')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Predicted Mask')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

if __name__ == "__main__":
    for path in [TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH]:
        if not os.path.exists(path):
            print(f"Error: La ruta de datos NO existe: {path}")
            print(f"Creando directorio: {path}")
            os.makedirs(path, exist_ok=True)

    print("Creando datasets...")
    train_ds, val_ds = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH)

    if not any(True for _ in train_ds.take(1)):
        print("Error: El dataset de entrenamiento está vacío. Asegúrate de que haya imágenes y máscaras en las rutas correctas.")
        exit()

    print("Entrenando modelo...")
    model_save_path = 'efficient_weed_model.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print(f"¡Entrenamiento completado! El mejor modelo se guardó como '{model_save_path}'")

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)')
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)')
    plt.title('Dice Coefficient over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)')
    plt.plot(history.history['val_loss'], label='Loss (Validation)')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Validation Loss: {final_metrics[0]:.4f}")
    print(f"Validation Dice Coefficient: {final_metrics[1]:.4f}")
    print(f"Validation IoU: {final_metrics[2]:.4f}")
    print(f"Validation Accuracy: {final_metrics[3]:.4f}")

    iou_per_class_values = []
    print("Calculando IoU por clase...")
    for images_batch, masks_batch in val_ds:
        predictions_batch = model.predict(images_batch, verbose=0)
        iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

    iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()

    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets...
# Found 1680 training images and 1680 training masks
# Found 210 validation images and 210 validation masks
# Entrenando modelo...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# --- Backbone Feature Shapes ---
# feat1_out (64x64): (None, 64, 64, 16)
# feat2_out (32x32): (None, 32, 32, 64)
# feat3_out (16x16): (None, 16, 16, 128)
# feat4_out (8x8): (None, 16, 16, 192)
# feat5_out (4x4, ASPP input): (None, 4, 4, 1280)
# -------------------------------
#
# Shape of decoder_up1 (after upsampling from 4x4): (None, 8, 8, 96)
# Shape of feat4_downsampled (from 16x16 downsampled to 8x8): (None, 8, 8, 192)
# Shape of feat4_processed (from 8x8 backbone feature): (None, 8, 8, 96)
# Shape of decoder_concat_8x8: (None, 8, 8, 192)
# Shape of decoder_conv_8x8: (None, 8, 8, 96)
# Shape of decoder_up2 (after upsampling from 8x8): (None, 16, 16, 96)
# Shape of feat3_processed (from 16x16 backbone feature): (None, 16, 16, 96)
# Shape of decoder_concat_16x16: (None, 16, 16, 192)
# Shape of decoder_conv_16x16: (None, 16, 16, 96)
# Shape of decoder_up3 (after upsampling from 16x16): (None, 32, 32, 48)
# Shape of feat2_processed (from 32x32 backbone feature): (None, 32, 32, 48)
# Shape of decoder_concat_32x32: (None, 32, 32, 96)
# Shape of decoder_conv_32x32: (None, 32, 32, 48)
# Shape of decoder_up4 (after upsampling from 32x32): (None, 64, 64, 24)
# Shape of feat1_processed (from 64x64 backbone feature): (None, 64, 64, 24)
# Shape of decoder_concat_64x64: (None, 64, 64, 48)
# Shape of decoder_conv_64x64: (None, 64, 64, 24)
# Shape of final outputs: (None, 128, 128, 6)
# Model: "EfficientWeedDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer[0][0] │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 64), (None,   │            │                   │
# │                     │ 16, 16, 128),     │            │                   │
# │                     │ (None, 16, 16,    │            │                   │
# │                     │ 192), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 8, 192) │          0 │ EfficientNetV2B0… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 96)  │     18,432 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 192) │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 8, 8, 96)  │     20,160 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     36,864 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │     12,288 │ EfficientNetV2B0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_10[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │     20,160 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_12[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     18,432 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      3,072 │ EfficientNetV2B0… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │ 96)               │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      5,472 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      4,608 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │        384 │ EfficientNetV2B0… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_16[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │ 48)               │            │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │      1,584 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_18[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        576 │ dropout_8[0][0]   │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,531,242 (51.62 MB)
#  Trainable params: 13,465,978 (51.37 MB)
#  Non-trainable params: 65,264 (254.94 KB)
# Starting training for 150 epochs...
# Epoch 1/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.2462 - dice_coefficient: 0.0917 - iou_metric: 0.1409 - loss: 2.2948
# Epoch 1: val_dice_coefficient improved from -inf to 0.08737, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 171s 310ms/step - accuracy: 0.2465 - dice_coefficient: 0.0918 - iou_metric: 0.1412 - loss: 2.2941 - val_accuracy: 0.4335 - val_dice_coefficient: 0.0874 - val_iou_metric: 0.2781 - val_loss: 2.2059 - learning_rate: 1.0000e-04
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4286 - dice_coefficient: 0.1129 - iou_metric: 0.2779 - loss: 2.0443
# Epoch 2: val_dice_coefficient improved from 0.08737 to 0.09331, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 165ms/step - accuracy: 0.4290 - dice_coefficient: 0.1130 - iou_metric: 0.2783 - loss: 2.0438 - val_accuracy: 0.6951 - val_dice_coefficient: 0.0933 - val_iou_metric: 0.5376 - val_loss: 2.1336 - learning_rate: 1.0000e-04
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6245 - dice_coefficient: 0.1354 - iou_metric: 0.4662 - loss: 1.8664
# Epoch 3: val_dice_coefficient improved from 0.09331 to 0.11014, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 163ms/step - accuracy: 0.6248 - dice_coefficient: 0.1355 - iou_metric: 0.4666 - loss: 1.8662 - val_accuracy: 0.8143 - val_dice_coefficient: 0.1101 - val_iou_metric: 0.6955 - val_loss: 1.9376 - learning_rate: 1.0000e-04
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7658 - dice_coefficient: 0.1571 - iou_metric: 0.6398 - loss: 1.7533
# Epoch 4: val_dice_coefficient improved from 0.11014 to 0.14372, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.7659 - dice_coefficient: 0.1572 - iou_metric: 0.6400 - loss: 1.7531 - val_accuracy: 0.8075 - val_dice_coefficient: 0.1437 - val_iou_metric: 0.6885 - val_loss: 1.7192 - learning_rate: 1.0000e-04
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8289 - dice_coefficient: 0.1785 - iou_metric: 0.7309 - loss: 1.6649
# Epoch 5: val_dice_coefficient improved from 0.14372 to 0.17316, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 170ms/step - accuracy: 0.8289 - dice_coefficient: 0.1785 - iou_metric: 0.7309 - loss: 1.6648 - val_accuracy: 0.7993 - val_dice_coefficient: 0.1732 - val_iou_metric: 0.6759 - val_loss: 1.6213 - learning_rate: 1.0000e-04
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8448 - dice_coefficient: 0.1962 - iou_metric: 0.7529 - loss: 1.6073
# Epoch 6: val_dice_coefficient improved from 0.17316 to 0.20355, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 164ms/step - accuracy: 0.8448 - dice_coefficient: 0.1963 - iou_metric: 0.7529 - loss: 1.6072 - val_accuracy: 0.8351 - val_dice_coefficient: 0.2036 - val_iou_metric: 0.7250 - val_loss: 1.5185 - learning_rate: 1.0000e-04
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8533 - dice_coefficient: 0.2152 - iou_metric: 0.7647 - loss: 1.5485
# Epoch 7: val_dice_coefficient improved from 0.20355 to 0.23480, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.8533 - dice_coefficient: 0.2152 - iou_metric: 0.7647 - loss: 1.5485 - val_accuracy: 0.8611 - val_dice_coefficient: 0.2348 - val_iou_metric: 0.7646 - val_loss: 1.4262 - learning_rate: 1.0000e-04
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8569 - dice_coefficient: 0.2303 - iou_metric: 0.7693 - loss: 1.5050
# Epoch 8: val_dice_coefficient improved from 0.23480 to 0.24160, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - accuracy: 0.8569 - dice_coefficient: 0.2304 - iou_metric: 0.7694 - loss: 1.5049 - val_accuracy: 0.8643 - val_dice_coefficient: 0.2416 - val_iou_metric: 0.7693 - val_loss: 1.4075 - learning_rate: 1.0000e-04
# Epoch 9/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8690 - dice_coefficient: 0.2454 - iou_metric: 0.7854 - loss: 1.4604
# Epoch 9: val_dice_coefficient improved from 0.24160 to 0.24831, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.8690 - dice_coefficient: 0.2454 - iou_metric: 0.7854 - loss: 1.4604 - val_accuracy: 0.8610 - val_dice_coefficient: 0.2483 - val_iou_metric: 0.7638 - val_loss: 1.4032 - learning_rate: 1.0000e-04
# Epoch 10/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8711 - dice_coefficient: 0.2583 - iou_metric: 0.7889 - loss: 1.4443
# Epoch 10: val_dice_coefficient improved from 0.24831 to 0.26650, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 170ms/step - accuracy: 0.8711 - dice_coefficient: 0.2583 - iou_metric: 0.7889 - loss: 1.4442 - val_accuracy: 0.8802 - val_dice_coefficient: 0.2665 - val_iou_metric: 0.7915 - val_loss: 1.3489 - learning_rate: 1.0000e-04
# Epoch 11/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8830 - dice_coefficient: 0.2714 - iou_metric: 0.8047 - loss: 1.4077
# Epoch 11: val_dice_coefficient improved from 0.26650 to 0.27555, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.8829 - dice_coefficient: 0.2714 - iou_metric: 0.8047 - loss: 1.4076 - val_accuracy: 0.8791 - val_dice_coefficient: 0.2756 - val_iou_metric: 0.7887 - val_loss: 1.3332 - learning_rate: 1.0000e-04
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8834 - dice_coefficient: 0.2853 - iou_metric: 0.8056 - loss: 1.3894
# Epoch 12: val_dice_coefficient did not improve from 0.27555
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - accuracy: 0.8834 - dice_coefficient: 0.2853 - iou_metric: 0.8056 - loss: 1.3893 - val_accuracy: 0.8745 - val_dice_coefficient: 0.2723 - val_iou_metric: 0.7813 - val_loss: 1.3404 - learning_rate: 1.0000e-04
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8956 - dice_coefficient: 0.2940 - iou_metric: 0.8224 - loss: 1.3391
# Epoch 13: val_dice_coefficient improved from 0.27555 to 0.28153, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8955 - dice_coefficient: 0.2940 - iou_metric: 0.8223 - loss: 1.3392 - val_accuracy: 0.8804 - val_dice_coefficient: 0.2815 - val_iou_metric: 0.7891 - val_loss: 1.3176 - learning_rate: 1.0000e-04
# Epoch 14/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8908 - dice_coefficient: 0.2966 - iou_metric: 0.8163 - loss: 1.3512
# Epoch 14: val_dice_coefficient improved from 0.28153 to 0.30101, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 166ms/step - accuracy: 0.8908 - dice_coefficient: 0.2966 - iou_metric: 0.8163 - loss: 1.3512 - val_accuracy: 0.8913 - val_dice_coefficient: 0.3010 - val_iou_metric: 0.8075 - val_loss: 1.2707 - learning_rate: 1.0000e-04
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8900 - dice_coefficient: 0.3105 - iou_metric: 0.8135 - loss: 1.3125
# Epoch 15: val_dice_coefficient did not improve from 0.30101
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 151ms/step - accuracy: 0.8900 - dice_coefficient: 0.3105 - iou_metric: 0.8135 - loss: 1.3125 - val_accuracy: 0.8822 - val_dice_coefficient: 0.2954 - val_iou_metric: 0.7935 - val_loss: 1.2826 - learning_rate: 1.0000e-04
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8959 - dice_coefficient: 0.3142 - iou_metric: 0.8226 - loss: 1.3059
# Epoch 16: val_dice_coefficient improved from 0.30101 to 0.30234, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 165ms/step - accuracy: 0.8959 - dice_coefficient: 0.3142 - iou_metric: 0.8226 - loss: 1.3059 - val_accuracy: 0.8808 - val_dice_coefficient: 0.3023 - val_iou_metric: 0.7900 - val_loss: 1.2601 - learning_rate: 1.0000e-04
# Epoch 17/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8983 - dice_coefficient: 0.3186 - iou_metric: 0.8251 - loss: 1.2781
# Epoch 17: val_dice_coefficient improved from 0.30234 to 0.31369, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.8982 - dice_coefficient: 0.3186 - iou_metric: 0.8250 - loss: 1.2782 - val_accuracy: 0.8884 - val_dice_coefficient: 0.3137 - val_iou_metric: 0.8015 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8999 - dice_coefficient: 0.3298 - iou_metric: 0.8273 - loss: 1.2589
# Epoch 18: val_dice_coefficient improved from 0.31369 to 0.31530, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 169ms/step - accuracy: 0.8999 - dice_coefficient: 0.3298 - iou_metric: 0.8273 - loss: 1.2589 - val_accuracy: 0.8819 - val_dice_coefficient: 0.3153 - val_iou_metric: 0.7896 - val_loss: 1.2248 - learning_rate: 1.0000e-04
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8997 - dice_coefficient: 0.3388 - iou_metric: 0.8277 - loss: 1.2465
# Epoch 19: val_dice_coefficient improved from 0.31530 to 0.32991, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.8997 - dice_coefficient: 0.3388 - iou_metric: 0.8277 - loss: 1.2464 - val_accuracy: 0.8843 - val_dice_coefficient: 0.3299 - val_iou_metric: 0.7953 - val_loss: 1.1831 - learning_rate: 1.0000e-04
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9026 - dice_coefficient: 0.3467 - iou_metric: 0.8313 - loss: 1.2148
# Epoch 20: val_dice_coefficient improved from 0.32991 to 0.33448, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9026 - dice_coefficient: 0.3466 - iou_metric: 0.8313 - loss: 1.2149 - val_accuracy: 0.8809 - val_dice_coefficient: 0.3345 - val_iou_metric: 0.7903 - val_loss: 1.1738 - learning_rate: 1.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9042 - dice_coefficient: 0.3543 - iou_metric: 0.8336 - loss: 1.1888
# Epoch 21: val_dice_coefficient improved from 0.33448 to 0.34348, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - accuracy: 0.9041 - dice_coefficient: 0.3543 - iou_metric: 0.8336 - loss: 1.1888 - val_accuracy: 0.8932 - val_dice_coefficient: 0.3435 - val_iou_metric: 0.8092 - val_loss: 1.1547 - learning_rate: 1.0000e-04
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9039 - dice_coefficient: 0.3628 - iou_metric: 0.8331 - loss: 1.1747
# Epoch 22: val_dice_coefficient improved from 0.34348 to 0.34999, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 173ms/step - accuracy: 0.9039 - dice_coefficient: 0.3628 - iou_metric: 0.8330 - loss: 1.1747 - val_accuracy: 0.8907 - val_dice_coefficient: 0.3500 - val_iou_metric: 0.8059 - val_loss: 1.1347 - learning_rate: 1.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9002 - dice_coefficient: 0.3710 - iou_metric: 0.8283 - loss: 1.1779
# Epoch 23: val_dice_coefficient improved from 0.34999 to 0.36277, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9002 - dice_coefficient: 0.3710 - iou_metric: 0.8283 - loss: 1.1777 - val_accuracy: 0.8949 - val_dice_coefficient: 0.3628 - val_iou_metric: 0.8120 - val_loss: 1.1076 - learning_rate: 1.0000e-04
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9054 - dice_coefficient: 0.3798 - iou_metric: 0.8353 - loss: 1.1474
# Epoch 24: val_dice_coefficient improved from 0.36277 to 0.36316, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 175ms/step - accuracy: 0.9054 - dice_coefficient: 0.3797 - iou_metric: 0.8353 - loss: 1.1474 - val_accuracy: 0.8970 - val_dice_coefficient: 0.3632 - val_iou_metric: 0.8150 - val_loss: 1.1056 - learning_rate: 1.0000e-04
# Epoch 25/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9083 - dice_coefficient: 0.3874 - iou_metric: 0.8400 - loss: 1.1296
# Epoch 25: val_dice_coefficient improved from 0.36316 to 0.37258, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9083 - dice_coefficient: 0.3873 - iou_metric: 0.8400 - loss: 1.1298 - val_accuracy: 0.9063 - val_dice_coefficient: 0.3726 - val_iou_metric: 0.8293 - val_loss: 1.0879 - learning_rate: 1.0000e-04
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9052 - dice_coefficient: 0.3855 - iou_metric: 0.8351 - loss: 1.1419
# Epoch 26: val_dice_coefficient did not improve from 0.37258
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 151ms/step - accuracy: 0.9052 - dice_coefficient: 0.3855 - iou_metric: 0.8351 - loss: 1.1418 - val_accuracy: 0.9002 - val_dice_coefficient: 0.3722 - val_iou_metric: 0.8196 - val_loss: 1.0934 - learning_rate: 1.0000e-04
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9087 - dice_coefficient: 0.3970 - iou_metric: 0.8407 - loss: 1.1199
# Epoch 27: val_dice_coefficient improved from 0.37258 to 0.37668, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9086 - dice_coefficient: 0.3969 - iou_metric: 0.8407 - loss: 1.1199 - val_accuracy: 0.9034 - val_dice_coefficient: 0.3767 - val_iou_metric: 0.8257 - val_loss: 1.0833 - learning_rate: 1.0000e-04
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9132 - dice_coefficient: 0.4048 - iou_metric: 0.8470 - loss: 1.0933
# Epoch 28: val_dice_coefficient improved from 0.37668 to 0.39270, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.9132 - dice_coefficient: 0.4048 - iou_metric: 0.8470 - loss: 1.0933 - val_accuracy: 0.9126 - val_dice_coefficient: 0.3927 - val_iou_metric: 0.8399 - val_loss: 1.0490 - learning_rate: 1.0000e-04
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9151 - dice_coefficient: 0.4126 - iou_metric: 0.8496 - loss: 1.0706
# Epoch 29: val_dice_coefficient improved from 0.39270 to 0.39933, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 169ms/step - accuracy: 0.9151 - dice_coefficient: 0.4126 - iou_metric: 0.8496 - loss: 1.0706 - val_accuracy: 0.9101 - val_dice_coefficient: 0.3993 - val_iou_metric: 0.8373 - val_loss: 1.0378 - learning_rate: 1.0000e-04
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9170 - dice_coefficient: 0.4195 - iou_metric: 0.8524 - loss: 1.0612
# Epoch 30: val_dice_coefficient improved from 0.39933 to 0.42458, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9170 - dice_coefficient: 0.4195 - iou_metric: 0.8524 - loss: 1.0613 - val_accuracy: 0.9154 - val_dice_coefficient: 0.4246 - val_iou_metric: 0.8458 - val_loss: 0.9930 - learning_rate: 1.0000e-04
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9129 - dice_coefficient: 0.4299 - iou_metric: 0.8455 - loss: 1.0575
# Epoch 31: val_dice_coefficient improved from 0.42458 to 0.44624, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9129 - dice_coefficient: 0.4300 - iou_metric: 0.8455 - loss: 1.0574 - val_accuracy: 0.9181 - val_dice_coefficient: 0.4462 - val_iou_metric: 0.8531 - val_loss: 0.9545 - learning_rate: 1.0000e-04
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9187 - dice_coefficient: 0.4455 - iou_metric: 0.8548 - loss: 1.0190
# Epoch 32: val_dice_coefficient improved from 0.44624 to 0.46634, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 170ms/step - accuracy: 0.9187 - dice_coefficient: 0.4456 - iou_metric: 0.8548 - loss: 1.0189 - val_accuracy: 0.9243 - val_dice_coefficient: 0.4663 - val_iou_metric: 0.8601 - val_loss: 0.9271 - learning_rate: 1.0000e-04
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9166 - dice_coefficient: 0.4632 - iou_metric: 0.8516 - loss: 0.9969
# Epoch 33: val_dice_coefficient improved from 0.46634 to 0.46769, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.9166 - dice_coefficient: 0.4631 - iou_metric: 0.8516 - loss: 0.9969 - val_accuracy: 0.9171 - val_dice_coefficient: 0.4677 - val_iou_metric: 0.8518 - val_loss: 0.9259 - learning_rate: 1.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9205 - dice_coefficient: 0.4641 - iou_metric: 0.8576 - loss: 0.9956
# Epoch 34: val_dice_coefficient improved from 0.46769 to 0.46948, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - accuracy: 0.9205 - dice_coefficient: 0.4641 - iou_metric: 0.8576 - loss: 0.9956 - val_accuracy: 0.9141 - val_dice_coefficient: 0.4695 - val_iou_metric: 0.8458 - val_loss: 0.9252 - learning_rate: 1.0000e-04
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9247 - dice_coefficient: 0.4756 - iou_metric: 0.8638 - loss: 0.9617
# Epoch 35: val_dice_coefficient improved from 0.46948 to 0.47525, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 169ms/step - accuracy: 0.9247 - dice_coefficient: 0.4756 - iou_metric: 0.8638 - loss: 0.9617 - val_accuracy: 0.9172 - val_dice_coefficient: 0.4753 - val_iou_metric: 0.8515 - val_loss: 0.9118 - learning_rate: 1.0000e-04
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9237 - dice_coefficient: 0.4722 - iou_metric: 0.8625 - loss: 0.9775
# Epoch 36: val_dice_coefficient improved from 0.47525 to 0.47910, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.9237 - dice_coefficient: 0.4723 - iou_metric: 0.8625 - loss: 0.9774 - val_accuracy: 0.9220 - val_dice_coefficient: 0.4791 - val_iou_metric: 0.8594 - val_loss: 0.9064 - learning_rate: 1.0000e-04
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9238 - dice_coefficient: 0.4838 - iou_metric: 0.8630 - loss: 0.9566
# Epoch 37: val_dice_coefficient improved from 0.47910 to 0.48061, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - accuracy: 0.9238 - dice_coefficient: 0.4838 - iou_metric: 0.8630 - loss: 0.9566 - val_accuracy: 0.9169 - val_dice_coefficient: 0.4806 - val_iou_metric: 0.8511 - val_loss: 0.9069 - learning_rate: 1.0000e-04
# Epoch 38/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9262 - dice_coefficient: 0.4927 - iou_metric: 0.8669 - loss: 0.9351
# Epoch 38: val_dice_coefficient improved from 0.48061 to 0.48763, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 172ms/step - accuracy: 0.9262 - dice_coefficient: 0.4927 - iou_metric: 0.8669 - loss: 0.9351 - val_accuracy: 0.9285 - val_dice_coefficient: 0.4876 - val_iou_metric: 0.8694 - val_loss: 0.8902 - learning_rate: 1.0000e-04
# Epoch 39/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9275 - dice_coefficient: 0.4897 - iou_metric: 0.8688 - loss: 0.9434
# Epoch 39: val_dice_coefficient improved from 0.48763 to 0.48868, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 168ms/step - accuracy: 0.9274 - dice_coefficient: 0.4897 - iou_metric: 0.8688 - loss: 0.9434 - val_accuracy: 0.9232 - val_dice_coefficient: 0.4887 - val_iou_metric: 0.8600 - val_loss: 0.8928 - learning_rate: 1.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9261 - dice_coefficient: 0.4918 - iou_metric: 0.8665 - loss: 0.9331
# Epoch 40: val_dice_coefficient improved from 0.48868 to 0.49594, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - accuracy: 0.9261 - dice_coefficient: 0.4918 - iou_metric: 0.8665 - loss: 0.9332 - val_accuracy: 0.9302 - val_dice_coefficient: 0.4959 - val_iou_metric: 0.8724 - val_loss: 0.8792 - learning_rate: 1.0000e-04
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9261 - dice_coefficient: 0.4978 - iou_metric: 0.8665 - loss: 0.9218
# Epoch 41: val_dice_coefficient did not improve from 0.49594
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 148ms/step - accuracy: 0.9261 - dice_coefficient: 0.4979 - iou_metric: 0.8665 - loss: 0.9218 - val_accuracy: 0.9198 - val_dice_coefficient: 0.4860 - val_iou_metric: 0.8539 - val_loss: 0.8971 - learning_rate: 1.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9276 - dice_coefficient: 0.5049 - iou_metric: 0.8689 - loss: 0.9164
# Epoch 42: val_dice_coefficient improved from 0.49594 to 0.50257, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.9276 - dice_coefficient: 0.5049 - iou_metric: 0.8689 - loss: 0.9164 - val_accuracy: 0.9297 - val_dice_coefficient: 0.5026 - val_iou_metric: 0.8714 - val_loss: 0.8724 - learning_rate: 1.0000e-04
# Epoch 43/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9300 - dice_coefficient: 0.5195 - iou_metric: 0.8729 - loss: 0.8880
# Epoch 43: val_dice_coefficient did not improve from 0.50257
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - accuracy: 0.9300 - dice_coefficient: 0.5194 - iou_metric: 0.8729 - loss: 0.8881 - val_accuracy: 0.9223 - val_dice_coefficient: 0.4945 - val_iou_metric: 0.8586 - val_loss: 0.8839 - learning_rate: 1.0000e-04
# Epoch 44/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9307 - dice_coefficient: 0.5165 - iou_metric: 0.8739 - loss: 0.8925
# Epoch 44: val_dice_coefficient did not improve from 0.50257
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.9307 - dice_coefficient: 0.5165 - iou_metric: 0.8739 - loss: 0.8925 - val_accuracy: 0.9335 - val_dice_coefficient: 0.5025 - val_iou_metric: 0.8785 - val_loss: 0.8705 - learning_rate: 1.0000e-04
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9302 - dice_coefficient: 0.5123 - iou_metric: 0.8729 - loss: 0.8959
# Epoch 45: val_dice_coefficient improved from 0.50257 to 0.50490, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9302 - dice_coefficient: 0.5123 - iou_metric: 0.8729 - loss: 0.8960 - val_accuracy: 0.9291 - val_dice_coefficient: 0.5049 - val_iou_metric: 0.8711 - val_loss: 0.8678 - learning_rate: 1.0000e-04
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9284 - dice_coefficient: 0.5093 - iou_metric: 0.8707 - loss: 0.8986
# Epoch 46: val_dice_coefficient improved from 0.50490 to 0.50926, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9284 - dice_coefficient: 0.5093 - iou_metric: 0.8707 - loss: 0.8985 - val_accuracy: 0.9388 - val_dice_coefficient: 0.5093 - val_iou_metric: 0.8874 - val_loss: 0.8575 - learning_rate: 1.0000e-04
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9300 - dice_coefficient: 0.5195 - iou_metric: 0.8734 - loss: 0.8854
# Epoch 47: val_dice_coefficient did not improve from 0.50926
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - accuracy: 0.9300 - dice_coefficient: 0.5194 - iou_metric: 0.8734 - loss: 0.8854 - val_accuracy: 0.9294 - val_dice_coefficient: 0.5027 - val_iou_metric: 0.8725 - val_loss: 0.8703 - learning_rate: 1.0000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9300 - dice_coefficient: 0.5211 - iou_metric: 0.8731 - loss: 0.8952
# Epoch 48: val_dice_coefficient did not improve from 0.50926
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.9300 - dice_coefficient: 0.5211 - iou_metric: 0.8731 - loss: 0.8950 - val_accuracy: 0.9331 - val_dice_coefficient: 0.5076 - val_iou_metric: 0.8780 - val_loss: 0.8627 - learning_rate: 1.0000e-04
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9336 - dice_coefficient: 0.5339 - iou_metric: 0.8790 - loss: 0.8555
# Epoch 49: val_dice_coefficient improved from 0.50926 to 0.51020, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 177ms/step - accuracy: 0.9336 - dice_coefficient: 0.5339 - iou_metric: 0.8790 - loss: 0.8556 - val_accuracy: 0.9304 - val_dice_coefficient: 0.5102 - val_iou_metric: 0.8746 - val_loss: 0.8602 - learning_rate: 1.0000e-04
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9334 - dice_coefficient: 0.5288 - iou_metric: 0.8788 - loss: 0.8694
# Epoch 50: val_dice_coefficient did not improve from 0.51020
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 153ms/step - accuracy: 0.9334 - dice_coefficient: 0.5288 - iou_metric: 0.8788 - loss: 0.8693 - val_accuracy: 0.9282 - val_dice_coefficient: 0.5084 - val_iou_metric: 0.8706 - val_loss: 0.8620 - learning_rate: 1.0000e-04
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9319 - dice_coefficient: 0.5278 - iou_metric: 0.8771 - loss: 0.8735
# Epoch 51: val_dice_coefficient improved from 0.51020 to 0.52150, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.9319 - dice_coefficient: 0.5278 - iou_metric: 0.8771 - loss: 0.8736 - val_accuracy: 0.9384 - val_dice_coefficient: 0.5215 - val_iou_metric: 0.8878 - val_loss: 0.8405 - learning_rate: 1.0000e-04
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9311 - dice_coefficient: 0.5293 - iou_metric: 0.8749 - loss: 0.8740
# Epoch 52: val_dice_coefficient did not improve from 0.52150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.9312 - dice_coefficient: 0.5293 - iou_metric: 0.8749 - loss: 0.8739 - val_accuracy: 0.9353 - val_dice_coefficient: 0.5178 - val_iou_metric: 0.8820 - val_loss: 0.8410 - learning_rate: 1.0000e-04
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9348 - dice_coefficient: 0.5346 - iou_metric: 0.8811 - loss: 0.8680
# Epoch 53: val_dice_coefficient improved from 0.52150 to 0.52187, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.9348 - dice_coefficient: 0.5346 - iou_metric: 0.8811 - loss: 0.8679 - val_accuracy: 0.9391 - val_dice_coefficient: 0.5219 - val_iou_metric: 0.8889 - val_loss: 0.8365 - learning_rate: 1.0000e-04
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9364 - dice_coefficient: 0.5240 - iou_metric: 0.8839 - loss: 0.8719
# Epoch 54: val_dice_coefficient did not improve from 0.52187
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 16s 150ms/step - accuracy: 0.9364 - dice_coefficient: 0.5241 - iou_metric: 0.8839 - loss: 0.8718 - val_accuracy: 0.9355 - val_dice_coefficient: 0.5166 - val_iou_metric: 0.8833 - val_loss: 0.8413 - learning_rate: 1.0000e-04
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9374 - dice_coefficient: 0.5371 - iou_metric: 0.8855 - loss: 0.8388
# Epoch 55: val_dice_coefficient did not improve from 0.52187
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step - accuracy: 0.9374 - dice_coefficient: 0.5371 - iou_metric: 0.8855 - loss: 0.8388 - val_accuracy: 0.9392 - val_dice_coefficient: 0.5169 - val_iou_metric: 0.8888 - val_loss: 0.8402 - learning_rate: 1.0000e-04
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9387 - dice_coefficient: 0.5444 - iou_metric: 0.8874 - loss: 0.8426
# Epoch 56: val_dice_coefficient improved from 0.52187 to 0.52460, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9387 - dice_coefficient: 0.5444 - iou_metric: 0.8874 - loss: 0.8426 - val_accuracy: 0.9441 - val_dice_coefficient: 0.5246 - val_iou_metric: 0.8973 - val_loss: 0.8240 - learning_rate: 1.0000e-04
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9392 - dice_coefficient: 0.5538 - iou_metric: 0.8889 - loss: 0.8129
# Epoch 57: val_dice_coefficient improved from 0.52460 to 0.52793, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.9392 - dice_coefficient: 0.5538 - iou_metric: 0.8889 - loss: 0.8129 - val_accuracy: 0.9447 - val_dice_coefficient: 0.5279 - val_iou_metric: 0.8976 - val_loss: 0.8180 - learning_rate: 1.0000e-04
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9408 - dice_coefficient: 0.5590 - iou_metric: 0.8915 - loss: 0.8058
# Epoch 58: val_dice_coefficient improved from 0.52793 to 0.53861, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9408 - dice_coefficient: 0.5589 - iou_metric: 0.8915 - loss: 0.8058 - val_accuracy: 0.9468 - val_dice_coefficient: 0.5386 - val_iou_metric: 0.9017 - val_loss: 0.7978 - learning_rate: 1.0000e-04
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9403 - dice_coefficient: 0.5676 - iou_metric: 0.8910 - loss: 0.7925
# Epoch 59: val_dice_coefficient improved from 0.53861 to 0.54575, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9403 - dice_coefficient: 0.5675 - iou_metric: 0.8910 - loss: 0.7925 - val_accuracy: 0.9443 - val_dice_coefficient: 0.5458 - val_iou_metric: 0.8971 - val_loss: 0.7815 - learning_rate: 1.0000e-04
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9410 - dice_coefficient: 0.5738 - iou_metric: 0.8921 - loss: 0.7804
# Epoch 60: val_dice_coefficient improved from 0.54575 to 0.55613, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.9410 - dice_coefficient: 0.5738 - iou_metric: 0.8921 - loss: 0.7804 - val_accuracy: 0.9423 - val_dice_coefficient: 0.5561 - val_iou_metric: 0.8938 - val_loss: 0.7633 - learning_rate: 1.0000e-04
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9433 - dice_coefficient: 0.5889 - iou_metric: 0.8960 - loss: 0.7551
# Epoch 61: val_dice_coefficient improved from 0.55613 to 0.56906, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.9433 - dice_coefficient: 0.5889 - iou_metric: 0.8960 - loss: 0.7551 - val_accuracy: 0.9464 - val_dice_coefficient: 0.5691 - val_iou_metric: 0.9009 - val_loss: 0.7430 - learning_rate: 1.0000e-04
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9446 - dice_coefficient: 0.5912 - iou_metric: 0.8979 - loss: 0.7529
# Epoch 62: val_dice_coefficient improved from 0.56906 to 0.57707, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.9445 - dice_coefficient: 0.5912 - iou_metric: 0.8978 - loss: 0.7529 - val_accuracy: 0.9464 - val_dice_coefficient: 0.5771 - val_iou_metric: 0.9005 - val_loss: 0.7365 - learning_rate: 1.0000e-04
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9436 - dice_coefficient: 0.6016 - iou_metric: 0.8964 - loss: 0.7405
# Epoch 63: val_dice_coefficient did not improve from 0.57707
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 152ms/step - accuracy: 0.9436 - dice_coefficient: 0.6016 - iou_metric: 0.8964 - loss: 0.7405 - val_accuracy: 0.9351 - val_dice_coefficient: 0.5691 - val_iou_metric: 0.8809 - val_loss: 0.7476 - learning_rate: 1.0000e-04
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9446 - dice_coefficient: 0.6143 - iou_metric: 0.8983 - loss: 0.7169
# Epoch 64: val_dice_coefficient improved from 0.57707 to 0.57895, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.9446 - dice_coefficient: 0.6143 - iou_metric: 0.8983 - loss: 0.7169 - val_accuracy: 0.9446 - val_dice_coefficient: 0.5789 - val_iou_metric: 0.8975 - val_loss: 0.7301 - learning_rate: 1.0000e-04
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9468 - dice_coefficient: 0.6075 - iou_metric: 0.9019 - loss: 0.7219
# Epoch 65: val_dice_coefficient improved from 0.57895 to 0.58972, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.9468 - dice_coefficient: 0.6075 - iou_metric: 0.9019 - loss: 0.7219 - val_accuracy: 0.9479 - val_dice_coefficient: 0.5897 - val_iou_metric: 0.9034 - val_loss: 0.7128 - learning_rate: 1.0000e-04
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9443 - dice_coefficient: 0.6249 - iou_metric: 0.8976 - loss: 0.6951
# Epoch 66: val_dice_coefficient did not improve from 0.58972
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.9443 - dice_coefficient: 0.6249 - iou_metric: 0.8976 - loss: 0.6952 - val_accuracy: 0.9441 - val_dice_coefficient: 0.5895 - val_iou_metric: 0.8971 - val_loss: 0.7117 - learning_rate: 1.0000e-04
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9464 - dice_coefficient: 0.6196 - iou_metric: 0.9011 - loss: 0.7043
# Epoch 67: val_dice_coefficient did not improve from 0.58972
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9464 - dice_coefficient: 0.6196 - iou_metric: 0.9010 - loss: 0.7042 - val_accuracy: 0.9420 - val_dice_coefficient: 0.5858 - val_iou_metric: 0.8935 - val_loss: 0.7192 - learning_rate: 1.0000e-04
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9464 - dice_coefficient: 0.6286 - iou_metric: 0.9013 - loss: 0.6901
# Epoch 68: val_dice_coefficient improved from 0.58972 to 0.59663, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.9464 - dice_coefficient: 0.6286 - iou_metric: 0.9012 - loss: 0.6902 - val_accuracy: 0.9465 - val_dice_coefficient: 0.5966 - val_iou_metric: 0.9010 - val_loss: 0.6962 - learning_rate: 1.0000e-04
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9466 - dice_coefficient: 0.6367 - iou_metric: 0.9014 - loss: 0.6749
# ...
# Epoch 118/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9546 - dice_coefficient: 0.7305 - iou_metric: 0.9154 - loss: 0.5075
# Epoch 118: val_dice_coefficient did not improve from 0.69788
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9546 - dice_coefficient: 0.7306 - iou_metric: 0.9154 - loss: 0.5074 - val_accuracy: 0.9563 - val_dice_coefficient: 0.6946 - val_iou_metric: 0.9181 - val_loss: 0.5415 - learning_rate: 1.0000e-04
# Epoch 119/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9561 - dice_coefficient: 0.7354 - iou_metric: 0.9178 - loss: 0.5030
# Epoch 119: val_dice_coefficient improved from 0.69788 to 0.70412, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9561 - dice_coefficient: 0.7354 - iou_metric: 0.9178 - loss: 0.5031 - val_accuracy: 0.9588 - val_dice_coefficient: 0.7041 - val_iou_metric: 0.9222 - val_loss: 0.5247 - learning_rate: 1.0000e-04
# Epoch 120/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9550 - dice_coefficient: 0.7484 - iou_metric: 0.9159 - loss: 0.4750
# Epoch 120: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 156ms/step - accuracy: 0.9550 - dice_coefficient: 0.7483 - iou_metric: 0.9159 - loss: 0.4750 - val_accuracy: 0.9549 - val_dice_coefficient: 0.6934 - val_iou_metric: 0.9156 - val_loss: 0.5540 - learning_rate: 1.0000e-04
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9582 - dice_coefficient: 0.7391 - iou_metric: 0.9215 - loss: 0.4985
# Epoch 121: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.9582 - dice_coefficient: 0.7391 - iou_metric: 0.9214 - loss: 0.4985 - val_accuracy: 0.9571 - val_dice_coefficient: 0.6980 - val_iou_metric: 0.9195 - val_loss: 0.5418 - learning_rate: 1.0000e-04
# Epoch 122/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9560 - dice_coefficient: 0.7395 - iou_metric: 0.9177 - loss: 0.4933
# Epoch 122: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.9560 - dice_coefficient: 0.7395 - iou_metric: 0.9178 - loss: 0.4933 - val_accuracy: 0.9573 - val_dice_coefficient: 0.6966 - val_iou_metric: 0.9200 - val_loss: 0.5517 - learning_rate: 1.0000e-04
# Epoch 123/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9549 - dice_coefficient: 0.7448 - iou_metric: 0.9159 - loss: 0.4891
# Epoch 123: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.9550 - dice_coefficient: 0.7448 - iou_metric: 0.9160 - loss: 0.4892 - val_accuracy: 0.9553 - val_dice_coefficient: 0.6945 - val_iou_metric: 0.9162 - val_loss: 0.5484 - learning_rate: 1.0000e-04
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9561 - dice_coefficient: 0.7510 - iou_metric: 0.9180 - loss: 0.4763
# Epoch 124: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9561 - dice_coefficient: 0.7510 - iou_metric: 0.9180 - loss: 0.4764 - val_accuracy: 0.9560 - val_dice_coefficient: 0.6926 - val_iou_metric: 0.9160 - val_loss: 0.5466 - learning_rate: 1.0000e-04
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9586 - dice_coefficient: 0.7437 - iou_metric: 0.9224 - loss: 0.4823
# Epoch 125: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 157ms/step - accuracy: 0.9585 - dice_coefficient: 0.7438 - iou_metric: 0.9224 - loss: 0.4822 - val_accuracy: 0.9576 - val_dice_coefficient: 0.6968 - val_iou_metric: 0.9202 - val_loss: 0.5506 - learning_rate: 1.0000e-04
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9581 - dice_coefficient: 0.7612 - iou_metric: 0.9213 - loss: 0.4558
# Epoch 126: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9580 - dice_coefficient: 0.7611 - iou_metric: 0.9213 - loss: 0.4560 - val_accuracy: 0.9572 - val_dice_coefficient: 0.6969 - val_iou_metric: 0.9199 - val_loss: 0.5570 - learning_rate: 1.0000e-04
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9571 - dice_coefficient: 0.7562 - iou_metric: 0.9197 - loss: 0.4685
# Epoch 127: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9571 - dice_coefficient: 0.7561 - iou_metric: 0.9197 - loss: 0.4686 - val_accuracy: 0.9544 - val_dice_coefficient: 0.6926 - val_iou_metric: 0.9151 - val_loss: 0.5611 - learning_rate: 1.0000e-04
# Epoch 128/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9581 - dice_coefficient: 0.7502 - iou_metric: 0.9214 - loss: 0.4816
# Epoch 128: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step - accuracy: 0.9581 - dice_coefficient: 0.7501 - iou_metric: 0.9214 - loss: 0.4817 - val_accuracy: 0.9579 - val_dice_coefficient: 0.6964 - val_iou_metric: 0.9209 - val_loss: 0.5495 - learning_rate: 1.0000e-04
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9565 - dice_coefficient: 0.7426 - iou_metric: 0.9187 - loss: 0.4967
# Epoch 129: val_dice_coefficient did not improve from 0.70412
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9565 - dice_coefficient: 0.7427 - iou_metric: 0.9187 - loss: 0.4966 - val_accuracy: 0.9556 - val_dice_coefficient: 0.6988 - val_iou_metric: 0.9167 - val_loss: 0.5410 - learning_rate: 1.0000e-04
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9566 - dice_coefficient: 0.7488 - iou_metric: 0.9189 - loss: 0.4773
# Epoch 130: val_dice_coefficient improved from 0.70412 to 0.70879, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 176ms/step - accuracy: 0.9566 - dice_coefficient: 0.7488 - iou_metric: 0.9189 - loss: 0.4773 - val_accuracy: 0.9590 - val_dice_coefficient: 0.7088 - val_iou_metric: 0.9227 - val_loss: 0.5317 - learning_rate: 1.0000e-04
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9568 - dice_coefficient: 0.7576 - iou_metric: 0.9192 - loss: 0.4674
# Epoch 131: val_dice_coefficient did not improve from 0.70879
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.9568 - dice_coefficient: 0.7576 - iou_metric: 0.9192 - loss: 0.4674 - val_accuracy: 0.9560 - val_dice_coefficient: 0.7028 - val_iou_metric: 0.9175 - val_loss: 0.5383 - learning_rate: 1.0000e-04
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9585 - dice_coefficient: 0.7565 - iou_metric: 0.9221 - loss: 0.4684
# Epoch 132: val_dice_coefficient did not improve from 0.70879
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9585 - dice_coefficient: 0.7565 - iou_metric: 0.9221 - loss: 0.4684 - val_accuracy: 0.9565 - val_dice_coefficient: 0.7026 - val_iou_metric: 0.9179 - val_loss: 0.5442 - learning_rate: 1.0000e-04
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9581 - dice_coefficient: 0.7555 - iou_metric: 0.9217 - loss: 0.4661
# Epoch 133: val_dice_coefficient did not improve from 0.70879
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9581 - dice_coefficient: 0.7556 - iou_metric: 0.9217 - loss: 0.4660 - val_accuracy: 0.9603 - val_dice_coefficient: 0.7087 - val_iou_metric: 0.9246 - val_loss: 0.5353 - learning_rate: 1.0000e-04
# Epoch 134/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9569 - dice_coefficient: 0.7529 - iou_metric: 0.9195 - loss: 0.4881
# Epoch 134: val_dice_coefficient did not improve from 0.70879
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step - accuracy: 0.9569 - dice_coefficient: 0.7530 - iou_metric: 0.9195 - loss: 0.4879 - val_accuracy: 0.9561 - val_dice_coefficient: 0.7012 - val_iou_metric: 0.9183 - val_loss: 0.5384 - learning_rate: 1.0000e-04
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9572 - dice_coefficient: 0.7552 - iou_metric: 0.9201 - loss: 0.4626
# Epoch 135: val_dice_coefficient improved from 0.70879 to 0.70960, saving model to efficient_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - accuracy: 0.9572 - dice_coefficient: 0.7552 - iou_metric: 0.9201 - loss: 0.4626 - val_accuracy: 0.9589 - val_dice_coefficient: 0.7096 - val_iou_metric: 0.9227 - val_loss: 0.5274 - learning_rate: 1.0000e-04
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9591 - dice_coefficient: 0.7686 - iou_metric: 0.9232 - loss: 0.4432
# Epoch 136: val_dice_coefficient did not improve from 0.70960
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 37s 155ms/step - accuracy: 0.9591 - dice_coefficient: 0.7686 - iou_metric: 0.9232 - loss: 0.4432 - val_accuracy: 0.9555 - val_dice_coefficient: 0.7004 - val_iou_metric: 0.9168 - val_loss: 0.5363 - learning_rate: 1.0000e-04
# Epoch 137/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9599 - dice_coefficient: 0.7620 - iou_metric: 0.9247 - loss: 0.4524
# Epoch 137: val_dice_coefficient did not improve from 0.70960
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.9599 - dice_coefficient: 0.7620 - iou_metric: 0.9246 - loss: 0.4525 - val_accuracy: 0.9583 - val_dice_coefficient: 0.7002 - val_iou_metric: 0.9224 - val_loss: 0.5625 - learning_rate: 1.0000e-04
# Epoch 138/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9580 - dice_coefficient: 0.7698 - iou_metric: 0.9216 - loss: 0.4448
# Epoch 138: val_dice_coefficient did not improve from 0.70960
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.9580 - dice_coefficient: 0.7698 - iou_metric: 0.9216 - loss: 0.4449 - val_accuracy: 0.9576 - val_dice_coefficient: 0.7030 - val_iou_metric: 0.9212 - val_loss: 0.5484 - learning_rate: 1.0000e-04
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9596 - dice_coefficient: 0.7779 - iou_metric: 0.9240 - loss: 0.4214
# Epoch 139: val_dice_coefficient improved from 0.70960 to 0.71022, saving model to efficient_weed_model.keras
#
# Epoch 139: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9596 - dice_coefficient: 0.7778 - iou_metric: 0.9240 - loss: 0.4216 - val_accuracy: 0.9589 - val_dice_coefficient: 0.7102 - val_iou_metric: 0.9231 - val_loss: 0.5294 - learning_rate: 1.0000e-04
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9595 - dice_coefficient: 0.7735 - iou_metric: 0.9242 - loss: 0.4364
# Epoch 140: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 18s 152ms/step - accuracy: 0.9595 - dice_coefficient: 0.7735 - iou_metric: 0.9242 - loss: 0.4365 - val_accuracy: 0.9575 - val_dice_coefficient: 0.7095 - val_iou_metric: 0.9211 - val_loss: 0.5263 - learning_rate: 3.0000e-05
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9581 - dice_coefficient: 0.7703 - iou_metric: 0.9215 - loss: 0.4401
# Epoch 141: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 157ms/step - accuracy: 0.9581 - dice_coefficient: 0.7703 - iou_metric: 0.9215 - loss: 0.4401 - val_accuracy: 0.9567 - val_dice_coefficient: 0.7025 - val_iou_metric: 0.9199 - val_loss: 0.5379 - learning_rate: 3.0000e-05
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9601 - dice_coefficient: 0.7779 - iou_metric: 0.9251 - loss: 0.4178
# Epoch 142: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.9601 - dice_coefficient: 0.7780 - iou_metric: 0.9251 - loss: 0.4177 - val_accuracy: 0.9584 - val_dice_coefficient: 0.7047 - val_iou_metric: 0.9228 - val_loss: 0.5373 - learning_rate: 3.0000e-05
# Epoch 143/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9593 - dice_coefficient: 0.7811 - iou_metric: 0.9236 - loss: 0.4156
# Epoch 143: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9593 - dice_coefficient: 0.7811 - iou_metric: 0.9236 - loss: 0.4158 - val_accuracy: 0.9577 - val_dice_coefficient: 0.7058 - val_iou_metric: 0.9219 - val_loss: 0.5343 - learning_rate: 3.0000e-05
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9578 - dice_coefficient: 0.7780 - iou_metric: 0.9212 - loss: 0.4266
# Epoch 144: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9578 - dice_coefficient: 0.7780 - iou_metric: 0.9213 - loss: 0.4266 - val_accuracy: 0.9576 - val_dice_coefficient: 0.7070 - val_iou_metric: 0.9217 - val_loss: 0.5303 - learning_rate: 3.0000e-05
# Epoch 145/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9600 - dice_coefficient: 0.7730 - iou_metric: 0.9250 - loss: 0.4321
# Epoch 145: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9600 - dice_coefficient: 0.7731 - iou_metric: 0.9249 - loss: 0.4321 - val_accuracy: 0.9559 - val_dice_coefficient: 0.7034 - val_iou_metric: 0.9187 - val_loss: 0.5392 - learning_rate: 3.0000e-05
# Epoch 146/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9607 - dice_coefficient: 0.7824 - iou_metric: 0.9262 - loss: 0.4134
# Epoch 146: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9607 - dice_coefficient: 0.7824 - iou_metric: 0.9261 - loss: 0.4134 - val_accuracy: 0.9591 - val_dice_coefficient: 0.7075 - val_iou_metric: 0.9237 - val_loss: 0.5339 - learning_rate: 3.0000e-05
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9591 - dice_coefficient: 0.7816 - iou_metric: 0.9235 - loss: 0.4169
# Epoch 147: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - accuracy: 0.9591 - dice_coefficient: 0.7815 - iou_metric: 0.9235 - loss: 0.4170 - val_accuracy: 0.9577 - val_dice_coefficient: 0.7073 - val_iou_metric: 0.9218 - val_loss: 0.5322 - learning_rate: 3.0000e-05
# Epoch 148/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9598 - dice_coefficient: 0.7781 - iou_metric: 0.9245 - loss: 0.4231
# Epoch 148: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.9598 - dice_coefficient: 0.7781 - iou_metric: 0.9245 - loss: 0.4231 - val_accuracy: 0.9577 - val_dice_coefficient: 0.7098 - val_iou_metric: 0.9220 - val_loss: 0.5274 - learning_rate: 3.0000e-05
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9606 - dice_coefficient: 0.7766 - iou_metric: 0.9259 - loss: 0.4216
# Epoch 149: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 155ms/step - accuracy: 0.9606 - dice_coefficient: 0.7766 - iou_metric: 0.9259 - loss: 0.4216 - val_accuracy: 0.9567 - val_dice_coefficient: 0.7059 - val_iou_metric: 0.9200 - val_loss: 0.5371 - learning_rate: 3.0000e-05
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9587 - dice_coefficient: 0.7823 - iou_metric: 0.9227 - loss: 0.4212
# Epoch 150: val_dice_coefficient did not improve from 0.71022
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 17s 158ms/step - accuracy: 0.9588 - dice_coefficient: 0.7822 - iou_metric: 0.9227 - loss: 0.4212 - val_accuracy: 0.9575 - val_dice_coefficient: 0.7088 - val_iou_metric: 0.9216 - val_loss: 0.5357 - learning_rate: 3.0000e-05
# Visualizando predicciones...
# Visualizing 4 samples from the validation set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'efficient_weed_model.keras'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9585 - dice_coefficient: 0.7045 - iou_metric: 0.9224 - loss: 0.5837
# Validation Loss: 0.5294
# Validation Dice Coefficient: 0.7102
# Validation IoU: 0.9231
# Validation Accuracy: 0.9589
# Calculando IoU por clase...
# IoU for Background: 0.9480
# IoU for Cow-tongue: 0.8954
# IoU for Dandelion: 0.8968
# IoU for Kikuyo: 0.8810
# IoU for Other: 0.6154
# IoU for Potato: 0.8808

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!
