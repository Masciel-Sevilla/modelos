# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/Small-Pro-V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# Configuración del modelo
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-5  # Tasa de aprendizaje más baja

# Paths
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')
TEST_IMAGES_PATH = os.path.join(BASE_PATH, 'test/images')
TEST_MASKS_PATH = os.path.join(BASE_PATH, 'test/masks')

# Definición de clases y funciones del modelo
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.1)  # Tasa de dropout más baja

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2S(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True
    layer_names = [
        'block1a_project_activation',
        'block2c_add',
        'block3c_add',
        'block6a_expand_activation',
        'top_activation'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2S_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)
    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.1)(decoder_up1)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.1)(decoder_conv_8x8)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.1)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.1)(decoder_conv_16x16)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.1)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.1)(decoder_conv_32x32)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.1)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.1)(decoder_conv_64x64)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_S')
    return model

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

def load_and_preprocess_data(image_paths, mask_paths, augment=False):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.7: image, mask = tf.image.flip_left_right(image), tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.7: image, mask = tf.image.flip_up_down(image), tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.7: k = tf.random.uniform([], 1, 4, dtype=tf.int32); image, mask = tf.image.rot90(image, k), tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.3 * 255)
        image = tf.image.random_contrast(image, lower=0.7, upper=1.3)
        image = tf.image.random_hue(image, max_delta=0.1)
        image = tf.image.random_saturation(image, lower=0.7, upper=1.3)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = tf.data.Dataset.zip((image_ds, mask_ds))
    if augment:
        dataset = dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_S.keras'):
    model = create_weed_detection_model()
    model.summary()

    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_iou_metric', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_iou_metric', patience=30, mode='max', restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-7, verbose=1),
    ]

    print(f"Iniciando entrenamiento por {EPOCHS} épocas...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )

    return model, history

if __name__ == "__main__":
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(TRAIN_MASKS_PATH, '*.png')))
    val_image_paths = sorted(glob(os.path.join(VAL_IMAGES_PATH, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(VAL_MASKS_PATH, '*.png')))

    print("Creando datasets de entrenamiento y validación...")
    train_ds = load_and_preprocess_data(train_image_paths, train_mask_paths, augment=True)
    val_ds = load_and_preprocess_data(val_image_paths, val_mask_paths, augment=False)

    model_save_path = 'efficient_weed_model_S_best.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("\n--- Entrenamiento Finalizado ---")
    print(f"El mejor modelo se ha guardado en: {model_save_path}")

    print("\nCargando el mejor modelo guardado para la evaluación en el conjunto de test...")
    best_model = tf.keras.models.load_model(
        model_save_path,
        custom_objects={
            'ASPPModule': ASPPModule,
            'DeformableAttention': DeformableAttention,
            'combined_loss': combined_loss,
            'dice_coefficient': dice_coefficient,
            'iou_metric': iou_metric,
            'dice_loss': dice_loss
        }
    )

    test_image_paths = sorted(glob(os.path.join(TEST_IMAGES_PATH, '*.jpg')))
    test_mask_paths = sorted(glob(os.path.join(TEST_MASKS_PATH, '*.png')))

    if not test_image_paths:
        print("\nADVERTENCIA: No se encontraron imágenes en el directorio de test. Saltando la evaluación de test.")
    else:
        print(f"Se encontraron {len(test_image_paths)} imágenes de test.")
        print("Creando dataset de test...")
        test_ds = load_and_preprocess_data(test_image_paths, test_mask_paths, augment=False)

        print("\n--- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---")
        test_metrics = best_model.evaluate(test_ds)

        print("\n## MÉTRICAS DE TEST - MODELO 'SMALL' ##")
        print(f"Test Loss: {test_metrics[0]:.4f}")
        print(f"Test Dice Coefficient: {test_metrics[1]:.4f}")
        print(f"Test mIoU: {test_metrics[2]:.4f}")
        print(f"Test Global Accuracy: {test_metrics[3]:.4f}")

        print("\nCalculando IoU por clase en el conjunto de test...")
        iou_per_class_values = []
        for images_batch, masks_batch in test_ds:
            predictions_batch = best_model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()
        class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
        print("\n## IoU por Clase (Test) ##")
        for i, iou in enumerate(iou_per_class_values):
            print(f"IoU for {class_names[i]}: {iou:.4f}")


        print("\nCalculando el promedio de IoU por clase en el conjunto de test...")
        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()


        print(f"\nPromedio de IoU por clase: {np.mean(iou_per_class_values):.4f}")

        # Mostrar ejemplos de máscaras reales y predichas
        for images_batch, masks_batch in test_ds.take(1):
            predictions_batch = best_model.predict(images_batch)
            plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)

        # Gráficas de Dice Coefficient y Loss durante el entrenamiento
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['dice_coefficient'], label='Dice Coefficient (Train)')
        plt.plot(history.history['val_dice_coefficient'], label='Dice Coefficient (Validation)')
        plt.title('Dice Coefficient over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Dice Coefficient')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Loss (Train)')
        plt.plot(history.history['val_loss'], label='Loss (Validation)')
        plt.title('Loss over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
# Out:
# Creando datasets de entrenamiento y validación...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "EfficientWeedDetectionModel_S"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2S_Ba… │ [(None, 64, 64,   │ 20,331,360 │ input_layer[0][0] │
# │ (Functional)        │ 24), (None, 32,   │            │                   │
# │                     │ 32, 48), (None,   │            │                   │
# │                     │ 16, 16, 64),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 960), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2S_… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 96)  │     92,160 │ EfficientNetV2S_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 192) │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 8, 8, 96)  │     20,160 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     36,864 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      6,144 │ EfficientNetV2S_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_10[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │     20,160 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_12[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     18,432 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      2,304 │ EfficientNetV2S_… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │ 96)               │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      5,472 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      4,608 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │        576 │ EfficientNetV2S_… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_16[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │ 48)               │            │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │      1,584 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_18[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        576 │ dropout_8[0][0]   │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 28,010,298 (106.85 MB)
#  Trainable params: 27,851,770 (106.25 MB)
#  Non-trainable params: 158,528 (619.25 KB)
# Iniciando entrenamiento por 150 épocas...
# Epoch 1/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2813 - dice_coefficient: 0.0928 - iou_metric: 0.1648 - loss: 2.2852
# Epoch 1: val_iou_metric improved from -inf to 0.17459, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 221s 298ms/step - accuracy: 0.2813 - dice_coefficient: 0.0928 - iou_metric: 0.1648 - loss: 2.2852 - val_accuracy: 0.2974 - val_dice_coefficient: 0.0868 - val_iou_metric: 0.1746 - val_loss: 2.2192 - learning_rate: 1.0000e-05
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2970 - dice_coefficient: 0.0944 - iou_metric: 0.1756 - loss: 2.2630
# Epoch 2: val_iou_metric improved from 0.17459 to 0.19695, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.2970 - dice_coefficient: 0.0944 - iou_metric: 0.1756 - loss: 2.2629 - val_accuracy: 0.3291 - val_dice_coefficient: 0.0882 - val_iou_metric: 0.1969 - val_loss: 2.2116 - learning_rate: 1.0000e-05
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3134 - dice_coefficient: 0.0961 - iou_metric: 0.1872 - loss: 2.2665
# Epoch 3: val_iou_metric improved from 0.19695 to 0.21466, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.3135 - dice_coefficient: 0.0961 - iou_metric: 0.1873 - loss: 2.2663 - val_accuracy: 0.3536 - val_dice_coefficient: 0.0902 - val_iou_metric: 0.2147 - val_loss: 2.2004 - learning_rate: 1.0000e-05
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3326 - dice_coefficient: 0.0963 - iou_metric: 0.2009 - loss: 2.2319
# Epoch 4: val_iou_metric improved from 0.21466 to 0.23087, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.3327 - dice_coefficient: 0.0963 - iou_metric: 0.2010 - loss: 2.2318 - val_accuracy: 0.3755 - val_dice_coefficient: 0.0928 - val_iou_metric: 0.2309 - val_loss: 2.1843 - learning_rate: 1.0000e-05
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3521 - dice_coefficient: 0.0990 - iou_metric: 0.2153 - loss: 2.2319
# Epoch 5: val_iou_metric improved from 0.23087 to 0.24924, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.3521 - dice_coefficient: 0.0990 - iou_metric: 0.2153 - loss: 2.2316 - val_accuracy: 0.4006 - val_dice_coefficient: 0.0954 - val_iou_metric: 0.2492 - val_loss: 2.1622 - learning_rate: 1.0000e-05
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3748 - dice_coefficient: 0.1001 - iou_metric: 0.2324 - loss: 2.1826
# Epoch 6: val_iou_metric improved from 0.24924 to 0.27133, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.3749 - dice_coefficient: 0.1001 - iou_metric: 0.2325 - loss: 2.1825 - val_accuracy: 0.4291 - val_dice_coefficient: 0.0982 - val_iou_metric: 0.2713 - val_loss: 2.1352 - learning_rate: 1.0000e-05
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3994 - dice_coefficient: 0.1027 - iou_metric: 0.2517 - loss: 2.1713
# Epoch 7: val_iou_metric improved from 0.27133 to 0.29872, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.3995 - dice_coefficient: 0.1027 - iou_metric: 0.2517 - loss: 2.1711 - val_accuracy: 0.4623 - val_dice_coefficient: 0.1008 - val_iou_metric: 0.2987 - val_loss: 2.1039 - learning_rate: 1.0000e-05
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4272 - dice_coefficient: 0.1057 - iou_metric: 0.2741 - loss: 2.1523
# Epoch 8: val_iou_metric improved from 0.29872 to 0.31730, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.4272 - dice_coefficient: 0.1057 - iou_metric: 0.2741 - loss: 2.1520 - val_accuracy: 0.4842 - val_dice_coefficient: 0.1036 - val_iou_metric: 0.3173 - val_loss: 2.0712 - learning_rate: 1.0000e-05
# Epoch 9/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4546 - dice_coefficient: 0.1080 - iou_metric: 0.2974 - loss: 2.1150
# Epoch 9: val_iou_metric improved from 0.31730 to 0.34444, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.4547 - dice_coefficient: 0.1080 - iou_metric: 0.2975 - loss: 2.1146 - val_accuracy: 0.5146 - val_dice_coefficient: 0.1062 - val_iou_metric: 0.3444 - val_loss: 2.0400 - learning_rate: 1.0000e-05
# Epoch 10/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4804 - dice_coefficient: 0.1110 - iou_metric: 0.3197 - loss: 2.0745
# Epoch 10: val_iou_metric improved from 0.34444 to 0.37597, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.4805 - dice_coefficient: 0.1110 - iou_metric: 0.3198 - loss: 2.0743 - val_accuracy: 0.5486 - val_dice_coefficient: 0.1094 - val_iou_metric: 0.3760 - val_loss: 2.0092 - learning_rate: 1.0000e-05
# Epoch 11/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5052 - dice_coefficient: 0.1130 - iou_metric: 0.3425 - loss: 2.0475
# Epoch 11: val_iou_metric improved from 0.37597 to 0.39335, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.5052 - dice_coefficient: 0.1130 - iou_metric: 0.3425 - loss: 2.0474 - val_accuracy: 0.5663 - val_dice_coefficient: 0.1119 - val_iou_metric: 0.3933 - val_loss: 1.9807 - learning_rate: 1.0000e-05
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5300 - dice_coefficient: 0.1174 - iou_metric: 0.3658 - loss: 2.0270
# Epoch 12: val_iou_metric improved from 0.39335 to 0.42508, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.5300 - dice_coefficient: 0.1174 - iou_metric: 0.3659 - loss: 2.0268 - val_accuracy: 0.5978 - val_dice_coefficient: 0.1153 - val_iou_metric: 0.4251 - val_loss: 1.9501 - learning_rate: 1.0000e-05
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5578 - dice_coefficient: 0.1209 - iou_metric: 0.3928 - loss: 2.0062
# Epoch 13: val_iou_metric improved from 0.42508 to 0.43037, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.5578 - dice_coefficient: 0.1209 - iou_metric: 0.3929 - loss: 2.0060 - val_accuracy: 0.6023 - val_dice_coefficient: 0.1176 - val_iou_metric: 0.4304 - val_loss: 1.9230 - learning_rate: 1.0000e-05
# Epoch 14/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5753 - dice_coefficient: 0.1211 - iou_metric: 0.4109 - loss: 1.9576
# Epoch 14: val_iou_metric improved from 0.43037 to 0.48147, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.5753 - dice_coefficient: 0.1211 - iou_metric: 0.4110 - loss: 1.9576 - val_accuracy: 0.6504 - val_dice_coefficient: 0.1220 - val_iou_metric: 0.4815 - val_loss: 1.8907 - learning_rate: 1.0000e-05
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5969 - dice_coefficient: 0.1248 - iou_metric: 0.4336 - loss: 1.9323
# Epoch 15: val_iou_metric improved from 0.48147 to 0.49547, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.5970 - dice_coefficient: 0.1248 - iou_metric: 0.4337 - loss: 1.9323 - val_accuracy: 0.6625 - val_dice_coefficient: 0.1245 - val_iou_metric: 0.4955 - val_loss: 1.8655 - learning_rate: 1.0000e-05
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6220 - dice_coefficient: 0.1289 - iou_metric: 0.4597 - loss: 1.9113
# Epoch 16: val_iou_metric improved from 0.49547 to 0.51980, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.6220 - dice_coefficient: 0.1289 - iou_metric: 0.4598 - loss: 1.9112 - val_accuracy: 0.6841 - val_dice_coefficient: 0.1284 - val_iou_metric: 0.5198 - val_loss: 1.8321 - learning_rate: 1.0000e-05
# Epoch 17/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6399 - dice_coefficient: 0.1315 - iou_metric: 0.4805 - loss: 1.8831
# Epoch 17: val_iou_metric improved from 0.51980 to 0.54544, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.6399 - dice_coefficient: 0.1315 - iou_metric: 0.4805 - loss: 1.8830 - val_accuracy: 0.7057 - val_dice_coefficient: 0.1311 - val_iou_metric: 0.5454 - val_loss: 1.8090 - learning_rate: 1.0000e-05
# Epoch 18/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6614 - dice_coefficient: 0.1354 - iou_metric: 0.5046 - loss: 1.8713
# Epoch 18: val_iou_metric improved from 0.54544 to 0.55928, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.6615 - dice_coefficient: 0.1354 - iou_metric: 0.5047 - loss: 1.8710 - val_accuracy: 0.7172 - val_dice_coefficient: 0.1337 - val_iou_metric: 0.5593 - val_loss: 1.7849 - learning_rate: 1.0000e-05
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6810 - dice_coefficient: 0.1377 - iou_metric: 0.5270 - loss: 1.8413
# Epoch 19: val_iou_metric improved from 0.55928 to 0.58917, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.6810 - dice_coefficient: 0.1377 - iou_metric: 0.5270 - loss: 1.8412 - val_accuracy: 0.7411 - val_dice_coefficient: 0.1374 - val_iou_metric: 0.5892 - val_loss: 1.7601 - learning_rate: 1.0000e-05
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6999 - dice_coefficient: 0.1420 - iou_metric: 0.5510 - loss: 1.8162
# Epoch 20: val_iou_metric improved from 0.58917 to 0.60801, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.6999 - dice_coefficient: 0.1420 - iou_metric: 0.5510 - loss: 1.8161 - val_accuracy: 0.7551 - val_dice_coefficient: 0.1415 - val_iou_metric: 0.6080 - val_loss: 1.7332 - learning_rate: 1.0000e-05
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7160 - dice_coefficient: 0.1450 - iou_metric: 0.5703 - loss: 1.8040
# Epoch 21: val_iou_metric improved from 0.60801 to 0.63591, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7161 - dice_coefficient: 0.1450 - iou_metric: 0.5704 - loss: 1.8038 - val_accuracy: 0.7760 - val_dice_coefficient: 0.1444 - val_iou_metric: 0.6359 - val_loss: 1.7145 - learning_rate: 1.0000e-05
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7345 - dice_coefficient: 0.1480 - iou_metric: 0.5955 - loss: 1.7817
# Epoch 22: val_iou_metric improved from 0.63591 to 0.64886, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7345 - dice_coefficient: 0.1480 - iou_metric: 0.5954 - loss: 1.7816 - val_accuracy: 0.7857 - val_dice_coefficient: 0.1479 - val_iou_metric: 0.6489 - val_loss: 1.6921 - learning_rate: 1.0000e-05
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7466 - dice_coefficient: 0.1519 - iou_metric: 0.6108 - loss: 1.7599
# Epoch 23: val_iou_metric improved from 0.64886 to 0.67529, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.7466 - dice_coefficient: 0.1519 - iou_metric: 0.6108 - loss: 1.7599 - val_accuracy: 0.8044 - val_dice_coefficient: 0.1507 - val_iou_metric: 0.6753 - val_loss: 1.6748 - learning_rate: 1.0000e-05
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7609 - dice_coefficient: 0.1549 - iou_metric: 0.6294 - loss: 1.7529
# Epoch 24: val_iou_metric did not improve from 0.67529
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.7608 - dice_coefficient: 0.1549 - iou_metric: 0.6294 - loss: 1.7527 - val_accuracy: 0.7906 - val_dice_coefficient: 0.1521 - val_iou_metric: 0.6580 - val_loss: 1.6637 - learning_rate: 1.0000e-05
# Epoch 25/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7637 - dice_coefficient: 0.1560 - iou_metric: 0.6341 - loss: 1.7191
# Epoch 25: val_iou_metric improved from 0.67529 to 0.70298, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.7639 - dice_coefficient: 0.1560 - iou_metric: 0.6343 - loss: 1.7190 - val_accuracy: 0.8235 - val_dice_coefficient: 0.1576 - val_iou_metric: 0.7030 - val_loss: 1.6384 - learning_rate: 1.0000e-05
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7796 - dice_coefficient: 0.1604 - iou_metric: 0.6545 - loss: 1.7038
# Epoch 26: val_iou_metric improved from 0.70298 to 0.70913, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7796 - dice_coefficient: 0.1604 - iou_metric: 0.6545 - loss: 1.7037 - val_accuracy: 0.8274 - val_dice_coefficient: 0.1604 - val_iou_metric: 0.7091 - val_loss: 1.6230 - learning_rate: 1.0000e-05
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7853 - dice_coefficient: 0.1613 - iou_metric: 0.6636 - loss: 1.6935
# Epoch 27: val_iou_metric improved from 0.70913 to 0.70913, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.7853 - dice_coefficient: 0.1613 - iou_metric: 0.6637 - loss: 1.6934 - val_accuracy: 0.8273 - val_dice_coefficient: 0.1638 - val_iou_metric: 0.7091 - val_loss: 1.6058 - learning_rate: 1.0000e-05
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7940 - dice_coefficient: 0.1642 - iou_metric: 0.6768 - loss: 1.6777
# Epoch 28: val_iou_metric improved from 0.70913 to 0.71027, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7940 - dice_coefficient: 0.1643 - iou_metric: 0.6768 - loss: 1.6776 - val_accuracy: 0.8280 - val_dice_coefficient: 0.1659 - val_iou_metric: 0.7103 - val_loss: 1.5920 - learning_rate: 1.0000e-05
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8000 - dice_coefficient: 0.1691 - iou_metric: 0.6834 - loss: 1.6631
# Epoch 29: val_iou_metric improved from 0.71027 to 0.73424, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8000 - dice_coefficient: 0.1691 - iou_metric: 0.6833 - loss: 1.6631 - val_accuracy: 0.8447 - val_dice_coefficient: 0.1701 - val_iou_metric: 0.7342 - val_loss: 1.5753 - learning_rate: 1.0000e-05
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8025 - dice_coefficient: 0.1712 - iou_metric: 0.6874 - loss: 1.6399
# Epoch 30: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8025 - dice_coefficient: 0.1712 - iou_metric: 0.6874 - loss: 1.6399 - val_accuracy: 0.8407 - val_dice_coefficient: 0.1721 - val_iou_metric: 0.7281 - val_loss: 1.5628 - learning_rate: 1.0000e-05
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8116 - dice_coefficient: 0.1767 - iou_metric: 0.7001 - loss: 1.6365
# Epoch 31: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8116 - dice_coefficient: 0.1767 - iou_metric: 0.7000 - loss: 1.6364 - val_accuracy: 0.8286 - val_dice_coefficient: 0.1740 - val_iou_metric: 0.7117 - val_loss: 1.5527 - learning_rate: 1.0000e-05
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8200 - dice_coefficient: 0.1799 - iou_metric: 0.7120 - loss: 1.6152
# Epoch 32: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8200 - dice_coefficient: 0.1799 - iou_metric: 0.7119 - loss: 1.6152 - val_accuracy: 0.8386 - val_dice_coefficient: 0.1778 - val_iou_metric: 0.7261 - val_loss: 1.5375 - learning_rate: 1.0000e-05
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8144 - dice_coefficient: 0.1792 - iou_metric: 0.7053 - loss: 1.6022
# Epoch 33: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8144 - dice_coefficient: 0.1792 - iou_metric: 0.7053 - loss: 1.6022 - val_accuracy: 0.8440 - val_dice_coefficient: 0.1813 - val_iou_metric: 0.7341 - val_loss: 1.5252 - learning_rate: 1.0000e-05
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8259 - dice_coefficient: 0.1845 - iou_metric: 0.7203 - loss: 1.5876
# Epoch 34: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8258 - dice_coefficient: 0.1845 - iou_metric: 0.7202 - loss: 1.5876 - val_accuracy: 0.8393 - val_dice_coefficient: 0.1819 - val_iou_metric: 0.7271 - val_loss: 1.5191 - learning_rate: 1.0000e-05
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8286 - dice_coefficient: 0.1880 - iou_metric: 0.7236 - loss: 1.5690
# Epoch 35: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8286 - dice_coefficient: 0.1879 - iou_metric: 0.7236 - loss: 1.5690 - val_accuracy: 0.8340 - val_dice_coefficient: 0.1840 - val_iou_metric: 0.7194 - val_loss: 1.5091 - learning_rate: 1.0000e-05
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8225 - dice_coefficient: 0.1850 - iou_metric: 0.7159 - loss: 1.5810
# Epoch 36: val_iou_metric did not improve from 0.73424
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8225 - dice_coefficient: 0.1851 - iou_metric: 0.7160 - loss: 1.5809 - val_accuracy: 0.8387 - val_dice_coefficient: 0.1878 - val_iou_metric: 0.7269 - val_loss: 1.4962 - learning_rate: 1.0000e-05
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8311 - dice_coefficient: 0.1930 - iou_metric: 0.7281 - loss: 1.5655
# Epoch 37: val_iou_metric improved from 0.73424 to 0.73643, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.8311 - dice_coefficient: 0.1930 - iou_metric: 0.7281 - loss: 1.5654 - val_accuracy: 0.8460 - val_dice_coefficient: 0.1910 - val_iou_metric: 0.7364 - val_loss: 1.4826 - learning_rate: 1.0000e-05
# Epoch 38/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8294 - dice_coefficient: 0.1947 - iou_metric: 0.7265 - loss: 1.5447
# Epoch 38: val_iou_metric did not improve from 0.73643
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8294 - dice_coefficient: 0.1946 - iou_metric: 0.7265 - loss: 1.5448 - val_accuracy: 0.8378 - val_dice_coefficient: 0.1919 - val_iou_metric: 0.7256 - val_loss: 1.4794 - learning_rate: 1.0000e-05
# Epoch 39/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8312 - dice_coefficient: 0.1942 - iou_metric: 0.7286 - loss: 1.5424
# Epoch 39: val_iou_metric did not improve from 0.73643
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8312 - dice_coefficient: 0.1943 - iou_metric: 0.7286 - loss: 1.5424 - val_accuracy: 0.8413 - val_dice_coefficient: 0.1936 - val_iou_metric: 0.7299 - val_loss: 1.4718 - learning_rate: 1.0000e-05
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8330 - dice_coefficient: 0.1973 - iou_metric: 0.7316 - loss: 1.5353
# Epoch 40: val_iou_metric did not improve from 0.73643
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8330 - dice_coefficient: 0.1973 - iou_metric: 0.7316 - loss: 1.5352 - val_accuracy: 0.8396 - val_dice_coefficient: 0.1971 - val_iou_metric: 0.7277 - val_loss: 1.4595 - learning_rate: 1.0000e-05
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8417 - dice_coefficient: 0.2040 - iou_metric: 0.7429 - loss: 1.5111
# Epoch 41: val_iou_metric improved from 0.73643 to 0.73784, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.8416 - dice_coefficient: 0.2040 - iou_metric: 0.7428 - loss: 1.5111 - val_accuracy: 0.8469 - val_dice_coefficient: 0.2011 - val_iou_metric: 0.7378 - val_loss: 1.4458 - learning_rate: 1.0000e-05
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8402 - dice_coefficient: 0.2058 - iou_metric: 0.7417 - loss: 1.5104
# Epoch 42: val_iou_metric did not improve from 0.73784
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.8402 - dice_coefficient: 0.2058 - iou_metric: 0.7417 - loss: 1.5103 - val_accuracy: 0.8365 - val_dice_coefficient: 0.2015 - val_iou_metric: 0.7235 - val_loss: 1.4435 - learning_rate: 1.0000e-05
# Epoch 43/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8427 - dice_coefficient: 0.2070 - iou_metric: 0.7450 - loss: 1.5031
# Epoch 43: val_iou_metric did not improve from 0.73784
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8427 - dice_coefficient: 0.2070 - iou_metric: 0.7449 - loss: 1.5030 - val_accuracy: 0.8334 - val_dice_coefficient: 0.2020 - val_iou_metric: 0.7182 - val_loss: 1.4424 - learning_rate: 1.0000e-05
# Epoch 44/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8424 - dice_coefficient: 0.2113 - iou_metric: 0.7455 - loss: 1.4854
# Epoch 44: val_iou_metric improved from 0.73784 to 0.74068, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.8424 - dice_coefficient: 0.2113 - iou_metric: 0.7455 - loss: 1.4854 - val_accuracy: 0.8489 - val_dice_coefficient: 0.2079 - val_iou_metric: 0.7407 - val_loss: 1.4210 - learning_rate: 1.0000e-05
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8421 - dice_coefficient: 0.2096 - iou_metric: 0.7444 - loss: 1.4979
# Epoch 45: val_iou_metric did not improve from 0.74068
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8420 - dice_coefficient: 0.2096 - iou_metric: 0.7444 - loss: 1.4978 - val_accuracy: 0.8390 - val_dice_coefficient: 0.2086 - val_iou_metric: 0.7264 - val_loss: 1.4202 - learning_rate: 1.0000e-05
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8478 - dice_coefficient: 0.2149 - iou_metric: 0.7517 - loss: 1.4637
# Epoch 46: val_iou_metric did not improve from 0.74068
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8478 - dice_coefficient: 0.2149 - iou_metric: 0.7517 - loss: 1.4637 - val_accuracy: 0.8378 - val_dice_coefficient: 0.2113 - val_iou_metric: 0.7254 - val_loss: 1.4123 - learning_rate: 1.0000e-05
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8511 - dice_coefficient: 0.2177 - iou_metric: 0.7564 - loss: 1.4745
# Epoch 47: val_iou_metric did not improve from 0.74068
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8510 - dice_coefficient: 0.2176 - iou_metric: 0.7562 - loss: 1.4745 - val_accuracy: 0.8382 - val_dice_coefficient: 0.2127 - val_iou_metric: 0.7255 - val_loss: 1.4065 - learning_rate: 1.0000e-05
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8503 - dice_coefficient: 0.2221 - iou_metric: 0.7546 - loss: 1.4572
# Epoch 48: val_iou_metric did not improve from 0.74068
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8503 - dice_coefficient: 0.2221 - iou_metric: 0.7545 - loss: 1.4572 - val_accuracy: 0.8395 - val_dice_coefficient: 0.2166 - val_iou_metric: 0.7272 - val_loss: 1.3957 - learning_rate: 1.0000e-05
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8470 - dice_coefficient: 0.2203 - iou_metric: 0.7500 - loss: 1.4428
# Epoch 49: val_iou_metric did not improve from 0.74068
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8470 - dice_coefficient: 0.2203 - iou_metric: 0.7501 - loss: 1.4428 - val_accuracy: 0.8431 - val_dice_coefficient: 0.2179 - val_iou_metric: 0.7339 - val_loss: 1.3906 - learning_rate: 1.0000e-05
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8470 - dice_coefficient: 0.2231 - iou_metric: 0.7519 - loss: 1.4544
# Epoch 50: val_iou_metric did not improve from 0.74068
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8470 - dice_coefficient: 0.2231 - iou_metric: 0.7519 - loss: 1.4543 - val_accuracy: 0.8424 - val_dice_coefficient: 0.2199 - val_iou_metric: 0.7318 - val_loss: 1.3848 - learning_rate: 1.0000e-05
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8552 - dice_coefficient: 0.2309 - iou_metric: 0.7619 - loss: 1.4273
# Epoch 51: val_iou_metric improved from 0.74068 to 0.74377, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.8551 - dice_coefficient: 0.2309 - iou_metric: 0.7618 - loss: 1.4273 - val_accuracy: 0.8509 - val_dice_coefficient: 0.2226 - val_iou_metric: 0.7438 - val_loss: 1.3748 - learning_rate: 1.0000e-05
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8489 - dice_coefficient: 0.2290 - iou_metric: 0.7549 - loss: 1.4434
# Epoch 52: val_iou_metric did not improve from 0.74377
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8489 - dice_coefficient: 0.2290 - iou_metric: 0.7549 - loss: 1.4432 - val_accuracy: 0.8495 - val_dice_coefficient: 0.2244 - val_iou_metric: 0.7411 - val_loss: 1.3705 - learning_rate: 1.0000e-05
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8565 - dice_coefficient: 0.2343 - iou_metric: 0.7637 - loss: 1.4025
# Epoch 53: val_iou_metric improved from 0.74377 to 0.74598, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.8565 - dice_coefficient: 0.2343 - iou_metric: 0.7637 - loss: 1.4025 - val_accuracy: 0.8526 - val_dice_coefficient: 0.2273 - val_iou_metric: 0.7460 - val_loss: 1.3616 - learning_rate: 1.0000e-05
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8538 - dice_coefficient: 0.2315 - iou_metric: 0.7602 - loss: 1.4120
# Epoch 54: val_iou_metric improved from 0.74598 to 0.74649, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8538 - dice_coefficient: 0.2315 - iou_metric: 0.7602 - loss: 1.4120 - val_accuracy: 0.8531 - val_dice_coefficient: 0.2303 - val_iou_metric: 0.7465 - val_loss: 1.3534 - learning_rate: 1.0000e-05
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8592 - dice_coefficient: 0.2369 - iou_metric: 0.7681 - loss: 1.3940
# Epoch 55: val_iou_metric improved from 0.74649 to 0.75508, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.8592 - dice_coefficient: 0.2369 - iou_metric: 0.7680 - loss: 1.3940 - val_accuracy: 0.8588 - val_dice_coefficient: 0.2323 - val_iou_metric: 0.7551 - val_loss: 1.3464 - learning_rate: 1.0000e-05
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8571 - dice_coefficient: 0.2334 - iou_metric: 0.7646 - loss: 1.4016
# Epoch 56: val_iou_metric did not improve from 0.75508
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.8571 - dice_coefficient: 0.2335 - iou_metric: 0.7646 - loss: 1.4015 - val_accuracy: 0.8519 - val_dice_coefficient: 0.2323 - val_iou_metric: 0.7440 - val_loss: 1.3476 - learning_rate: 1.0000e-05
# Epoch 57/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8644 - dice_coefficient: 0.2433 - iou_metric: 0.7748 - loss: 1.3871
# Epoch 57: val_iou_metric did not improve from 0.75508
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8643 - dice_coefficient: 0.2432 - iou_metric: 0.7747 - loss: 1.3871 - val_accuracy: 0.8501 - val_dice_coefficient: 0.2344 - val_iou_metric: 0.7424 - val_loss: 1.3426 - learning_rate: 1.0000e-05
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8601 - dice_coefficient: 0.2439 - iou_metric: 0.7678 - loss: 1.3797
# Epoch 58: val_iou_metric did not improve from 0.75508
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8601 - dice_coefficient: 0.2439 - iou_metric: 0.7678 - loss: 1.3797 - val_accuracy: 0.8563 - val_dice_coefficient: 0.2384 - val_iou_metric: 0.7519 - val_loss: 1.3312 - learning_rate: 1.0000e-05
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8672 - dice_coefficient: 0.2505 - iou_metric: 0.7791 - loss: 1.3666
# Epoch 59: val_iou_metric did not improve from 0.75508
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8671 - dice_coefficient: 0.2504 - iou_metric: 0.7790 - loss: 1.3666 - val_accuracy: 0.8514 - val_dice_coefficient: 0.2389 - val_iou_metric: 0.7442 - val_loss: 1.3311 - learning_rate: 1.0000e-05
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8622 - dice_coefficient: 0.2459 - iou_metric: 0.7710 - loss: 1.3665
# Epoch 60: val_iou_metric improved from 0.75508 to 0.77094, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - accuracy: 0.8622 - dice_coefficient: 0.2459 - iou_metric: 0.7710 - loss: 1.3665 - val_accuracy: 0.8692 - val_dice_coefficient: 0.2458 - val_iou_metric: 0.7709 - val_loss: 1.3121 - learning_rate: 1.0000e-05
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8606 - dice_coefficient: 0.2484 - iou_metric: 0.7701 - loss: 1.3638
# Epoch 61: val_iou_metric did not improve from 0.77094
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.8606 - dice_coefficient: 0.2484 - iou_metric: 0.7701 - loss: 1.3638 - val_accuracy: 0.8585 - val_dice_coefficient: 0.2439 - val_iou_metric: 0.7544 - val_loss: 1.3174 - learning_rate: 1.0000e-05
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8670 - dice_coefficient: 0.2525 - iou_metric: 0.7781 - loss: 1.3553
# Epoch 62: val_iou_metric did not improve from 0.77094
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8670 - dice_coefficient: 0.2525 - iou_metric: 0.7780 - loss: 1.3553 - val_accuracy: 0.8636 - val_dice_coefficient: 0.2477 - val_iou_metric: 0.7616 - val_loss: 1.3070 - learning_rate: 1.0000e-05
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8669 - dice_coefficient: 0.2561 - iou_metric: 0.7782 - loss: 1.3560
# Epoch 63: val_iou_metric did not improve from 0.77094
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8669 - dice_coefficient: 0.2561 - iou_metric: 0.7782 - loss: 1.3560 - val_accuracy: 0.8572 - val_dice_coefficient: 0.2471 - val_iou_metric: 0.7527 - val_loss: 1.3095 - learning_rate: 1.0000e-05
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8667 - dice_coefficient: 0.2559 - iou_metric: 0.7789 - loss: 1.3452
# Epoch 64: val_iou_metric did not improve from 0.77094
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8667 - dice_coefficient: 0.2559 - iou_metric: 0.7789 - loss: 1.3452 - val_accuracy: 0.8608 - val_dice_coefficient: 0.2492 - val_iou_metric: 0.7572 - val_loss: 1.3040 - learning_rate: 1.0000e-05
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8649 - dice_coefficient: 0.2577 - iou_metric: 0.7745 - loss: 1.3360
# Epoch 65: val_iou_metric improved from 0.77094 to 0.77187, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8649 - dice_coefficient: 0.2577 - iou_metric: 0.7745 - loss: 1.3360 - val_accuracy: 0.8702 - val_dice_coefficient: 0.2537 - val_iou_metric: 0.7719 - val_loss: 1.2912 - learning_rate: 1.0000e-05
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8713 - dice_coefficient: 0.2668 - iou_metric: 0.7844 - loss: 1.3223
# Epoch 66: val_iou_metric did not improve from 0.77187
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.8713 - dice_coefficient: 0.2668 - iou_metric: 0.7843 - loss: 1.3223 - val_accuracy: 0.8588 - val_dice_coefficient: 0.2523 - val_iou_metric: 0.7544 - val_loss: 1.2969 - learning_rate: 1.0000e-05
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8789 - dice_coefficient: 0.2673 - iou_metric: 0.7958 - loss: 1.3095
# Epoch 67: val_iou_metric improved from 0.77187 to 0.77338, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.8788 - dice_coefficient: 0.2673 - iou_metric: 0.7956 - loss: 1.3096 - val_accuracy: 0.8710 - val_dice_coefficient: 0.2574 - val_iou_metric: 0.7734 - val_loss: 1.2821 - learning_rate: 1.0000e-05
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8723 - dice_coefficient: 0.2693 - iou_metric: 0.7866 - loss: 1.3123
# Epoch 68: val_iou_metric improved from 0.77338 to 0.77357, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.8723 - dice_coefficient: 0.2692 - iou_metric: 0.7866 - loss: 1.3124 - val_accuracy: 0.8712 - val_dice_coefficient: 0.2607 - val_iou_metric: 0.7736 - val_loss: 1.2753 - learning_rate: 1.0000e-05
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8732 - dice_coefficient: 0.2709 - iou_metric: 0.7865 - loss: 1.3050
# Epoch 69: val_iou_metric did not improve from 0.77357
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8732 - dice_coefficient: 0.2709 - iou_metric: 0.7865 - loss: 1.3050 - val_accuracy: 0.8638 - val_dice_coefficient: 0.2596 - val_iou_metric: 0.7625 - val_loss: 1.2795 - learning_rate: 1.0000e-05
# Epoch 70/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8744 - dice_coefficient: 0.2749 - iou_metric: 0.7886 - loss: 1.2929
# Epoch 70: val_iou_metric did not improve from 0.77357
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8744 - dice_coefficient: 0.2748 - iou_metric: 0.7886 - loss: 1.2930 - val_accuracy: 0.8680 - val_dice_coefficient: 0.2630 - val_iou_metric: 0.7687 - val_loss: 1.2707 - learning_rate: 1.0000e-05
# Epoch 71/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8746 - dice_coefficient: 0.2727 - iou_metric: 0.7886 - loss: 1.3046
# Epoch 71: val_iou_metric did not improve from 0.77357
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8746 - dice_coefficient: 0.2727 - iou_metric: 0.7886 - loss: 1.3045 - val_accuracy: 0.8701 - val_dice_coefficient: 0.2650 - val_iou_metric: 0.7715 - val_loss: 1.2665 - learning_rate: 1.0000e-05
# Epoch 72/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8777 - dice_coefficient: 0.2754 - iou_metric: 0.7938 - loss: 1.3041
# Epoch 72: val_iou_metric did not improve from 0.77357
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8777 - dice_coefficient: 0.2754 - iou_metric: 0.7937 - loss: 1.3041 - val_accuracy: 0.8684 - val_dice_coefficient: 0.2663 - val_iou_metric: 0.7695 - val_loss: 1.2641 - learning_rate: 1.0000e-05
# Epoch 73/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8817 - dice_coefficient: 0.2840 - iou_metric: 0.7990 - loss: 1.2765
# Epoch 73: val_iou_metric did not improve from 0.77357
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8817 - dice_coefficient: 0.2839 - iou_metric: 0.7990 - loss: 1.2765 - val_accuracy: 0.8656 - val_dice_coefficient: 0.2668 - val_iou_metric: 0.7650 - val_loss: 1.2637 - learning_rate: 1.0000e-05
# Epoch 74/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8827 - dice_coefficient: 0.2858 - iou_metric: 0.8010 - loss: 1.2778
# Epoch 74: val_iou_metric did not improve from 0.77357
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.8826 - dice_coefficient: 0.2857 - iou_metric: 0.8009 - loss: 1.2779 - val_accuracy: 0.8706 - val_dice_coefficient: 0.2705 - val_iou_metric: 0.7723 - val_loss: 1.2543 - learning_rate: 1.0000e-05
# Epoch 75/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8815 - dice_coefficient: 0.2864 - iou_metric: 0.7995 - loss: 1.2721
# ...
# Epoch 120/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9119 - dice_coefficient: 0.3776 - iou_metric: 0.8459 - loss: 1.0913
# Epoch 120: val_iou_metric improved from 0.82772 to 0.82909, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9119 - dice_coefficient: 0.3776 - iou_metric: 0.8460 - loss: 1.0913 - val_accuracy: 0.9064 - val_dice_coefficient: 0.3587 - val_iou_metric: 0.8291 - val_loss: 1.0866 - learning_rate: 1.0000e-05
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9165 - dice_coefficient: 0.3812 - iou_metric: 0.8533 - loss: 1.0786
# Epoch 121: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9164 - dice_coefficient: 0.3812 - iou_metric: 0.8532 - loss: 1.0786 - val_accuracy: 0.9024 - val_dice_coefficient: 0.3585 - val_iou_metric: 0.8229 - val_loss: 1.0885 - learning_rate: 1.0000e-05
# Epoch 122/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9154 - dice_coefficient: 0.3887 - iou_metric: 0.8516 - loss: 1.0745
# Epoch 122: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9153 - dice_coefficient: 0.3886 - iou_metric: 0.8516 - loss: 1.0746 - val_accuracy: 0.9053 - val_dice_coefficient: 0.3603 - val_iou_metric: 0.8273 - val_loss: 1.0841 - learning_rate: 1.0000e-05
# Epoch 123/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9143 - dice_coefficient: 0.3843 - iou_metric: 0.8505 - loss: 1.0820
# Epoch 123: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9143 - dice_coefficient: 0.3843 - iou_metric: 0.8505 - loss: 1.0821 - val_accuracy: 0.9042 - val_dice_coefficient: 0.3613 - val_iou_metric: 0.8253 - val_loss: 1.0833 - learning_rate: 1.0000e-05
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9193 - dice_coefficient: 0.3898 - iou_metric: 0.8582 - loss: 1.0625
# Epoch 124: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9193 - dice_coefficient: 0.3898 - iou_metric: 0.8581 - loss: 1.0625 - val_accuracy: 0.9055 - val_dice_coefficient: 0.3637 - val_iou_metric: 0.8277 - val_loss: 1.0795 - learning_rate: 1.0000e-05
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9153 - dice_coefficient: 0.3860 - iou_metric: 0.8523 - loss: 1.0730
# Epoch 125: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9153 - dice_coefficient: 0.3860 - iou_metric: 0.8524 - loss: 1.0730 - val_accuracy: 0.9048 - val_dice_coefficient: 0.3647 - val_iou_metric: 0.8265 - val_loss: 1.0782 - learning_rate: 1.0000e-05
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9180 - dice_coefficient: 0.3928 - iou_metric: 0.8565 - loss: 1.0631
# Epoch 126: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9180 - dice_coefficient: 0.3928 - iou_metric: 0.8564 - loss: 1.0632 - val_accuracy: 0.9036 - val_dice_coefficient: 0.3648 - val_iou_metric: 0.8246 - val_loss: 1.0769 - learning_rate: 1.0000e-05
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9186 - dice_coefficient: 0.3919 - iou_metric: 0.8570 - loss: 1.0669
# Epoch 127: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9185 - dice_coefficient: 0.3919 - iou_metric: 0.8569 - loss: 1.0669 - val_accuracy: 0.9045 - val_dice_coefficient: 0.3662 - val_iou_metric: 0.8258 - val_loss: 1.0733 - learning_rate: 1.0000e-05
# Epoch 128/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9172 - dice_coefficient: 0.3970 - iou_metric: 0.8549 - loss: 1.0549
# Epoch 128: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9172 - dice_coefficient: 0.3970 - iou_metric: 0.8549 - loss: 1.0550 - val_accuracy: 0.9034 - val_dice_coefficient: 0.3669 - val_iou_metric: 0.8244 - val_loss: 1.0728 - learning_rate: 1.0000e-05
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9182 - dice_coefficient: 0.4002 - iou_metric: 0.8570 - loss: 1.0485
# Epoch 129: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9182 - dice_coefficient: 0.4002 - iou_metric: 0.8570 - loss: 1.0486 - val_accuracy: 0.9028 - val_dice_coefficient: 0.3681 - val_iou_metric: 0.8231 - val_loss: 1.0724 - learning_rate: 1.0000e-05
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9153 - dice_coefficient: 0.3991 - iou_metric: 0.8526 - loss: 1.0671
# Epoch 130: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9153 - dice_coefficient: 0.3991 - iou_metric: 0.8526 - loss: 1.0670 - val_accuracy: 0.9035 - val_dice_coefficient: 0.3702 - val_iou_metric: 0.8244 - val_loss: 1.0678 - learning_rate: 1.0000e-05
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9162 - dice_coefficient: 0.3980 - iou_metric: 0.8532 - loss: 1.0545
# Epoch 131: val_iou_metric did not improve from 0.82909
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9162 - dice_coefficient: 0.3979 - iou_metric: 0.8532 - loss: 1.0545 - val_accuracy: 0.9049 - val_dice_coefficient: 0.3732 - val_iou_metric: 0.8268 - val_loss: 1.0630 - learning_rate: 1.0000e-05
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9193 - dice_coefficient: 0.4029 - iou_metric: 0.8584 - loss: 1.0399
# Epoch 132: val_iou_metric improved from 0.82909 to 0.83251, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.9193 - dice_coefficient: 0.4029 - iou_metric: 0.8584 - loss: 1.0399 - val_accuracy: 0.9086 - val_dice_coefficient: 0.3762 - val_iou_metric: 0.8325 - val_loss: 1.0574 - learning_rate: 1.0000e-05
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9194 - dice_coefficient: 0.4034 - iou_metric: 0.8588 - loss: 1.0486
# Epoch 133: val_iou_metric did not improve from 0.83251
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9193 - dice_coefficient: 0.4034 - iou_metric: 0.8588 - loss: 1.0486 - val_accuracy: 0.9056 - val_dice_coefficient: 0.3754 - val_iou_metric: 0.8276 - val_loss: 1.0589 - learning_rate: 1.0000e-05
# Epoch 134/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9179 - dice_coefficient: 0.4057 - iou_metric: 0.8566 - loss: 1.0424
# Epoch 134: val_iou_metric did not improve from 0.83251
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9180 - dice_coefficient: 0.4057 - iou_metric: 0.8566 - loss: 1.0425 - val_accuracy: 0.9081 - val_dice_coefficient: 0.3784 - val_iou_metric: 0.8316 - val_loss: 1.0539 - learning_rate: 1.0000e-05
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9173 - dice_coefficient: 0.4046 - iou_metric: 0.8553 - loss: 1.0461
# Epoch 135: val_iou_metric did not improve from 0.83251
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9174 - dice_coefficient: 0.4046 - iou_metric: 0.8553 - loss: 1.0461 - val_accuracy: 0.9035 - val_dice_coefficient: 0.3762 - val_iou_metric: 0.8243 - val_loss: 1.0574 - learning_rate: 1.0000e-05
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9176 - dice_coefficient: 0.4031 - iou_metric: 0.8565 - loss: 1.0496
# Epoch 136: val_iou_metric improved from 0.83251 to 0.83399, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9176 - dice_coefficient: 0.4031 - iou_metric: 0.8565 - loss: 1.0496 - val_accuracy: 0.9096 - val_dice_coefficient: 0.3810 - val_iou_metric: 0.8340 - val_loss: 1.0494 - learning_rate: 1.0000e-05
# Epoch 137/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9185 - dice_coefficient: 0.4056 - iou_metric: 0.8571 - loss: 1.0375
# Epoch 137: val_iou_metric did not improve from 0.83399
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9185 - dice_coefficient: 0.4056 - iou_metric: 0.8571 - loss: 1.0375 - val_accuracy: 0.9089 - val_dice_coefficient: 0.3827 - val_iou_metric: 0.8329 - val_loss: 1.0457 - learning_rate: 1.0000e-05
# Epoch 138/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9200 - dice_coefficient: 0.4105 - iou_metric: 0.8593 - loss: 1.0356
# Epoch 138: val_iou_metric did not improve from 0.83399
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9200 - dice_coefficient: 0.4105 - iou_metric: 0.8593 - loss: 1.0356 - val_accuracy: 0.9077 - val_dice_coefficient: 0.3828 - val_iou_metric: 0.8311 - val_loss: 1.0471 - learning_rate: 1.0000e-05
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9205 - dice_coefficient: 0.4099 - iou_metric: 0.8602 - loss: 1.0349
# Epoch 139: val_iou_metric improved from 0.83399 to 0.83626, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9205 - dice_coefficient: 0.4099 - iou_metric: 0.8602 - loss: 1.0349 - val_accuracy: 0.9109 - val_dice_coefficient: 0.3864 - val_iou_metric: 0.8363 - val_loss: 1.0411 - learning_rate: 1.0000e-05
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9186 - dice_coefficient: 0.4120 - iou_metric: 0.8573 - loss: 1.0399
# Epoch 140: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9186 - dice_coefficient: 0.4120 - iou_metric: 0.8573 - loss: 1.0399 - val_accuracy: 0.9066 - val_dice_coefficient: 0.3839 - val_iou_metric: 0.8292 - val_loss: 1.0426 - learning_rate: 1.0000e-05
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9242 - dice_coefficient: 0.4214 - iou_metric: 0.8665 - loss: 1.0036
# Epoch 141: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9241 - dice_coefficient: 0.4214 - iou_metric: 0.8665 - loss: 1.0037 - val_accuracy: 0.9074 - val_dice_coefficient: 0.3854 - val_iou_metric: 0.8307 - val_loss: 1.0424 - learning_rate: 1.0000e-05
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9206 - dice_coefficient: 0.4177 - iou_metric: 0.8604 - loss: 1.0254
# Epoch 142: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9206 - dice_coefficient: 0.4177 - iou_metric: 0.8604 - loss: 1.0253 - val_accuracy: 0.9049 - val_dice_coefficient: 0.3849 - val_iou_metric: 0.8266 - val_loss: 1.0424 - learning_rate: 1.0000e-05
# Epoch 143/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9232 - dice_coefficient: 0.4272 - iou_metric: 0.8645 - loss: 1.0032
# Epoch 143: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9232 - dice_coefficient: 0.4271 - iou_metric: 0.8644 - loss: 1.0034 - val_accuracy: 0.9099 - val_dice_coefficient: 0.3893 - val_iou_metric: 0.8346 - val_loss: 1.0355 - learning_rate: 1.0000e-05
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9232 - dice_coefficient: 0.4227 - iou_metric: 0.8649 - loss: 1.0058
# Epoch 144: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9232 - dice_coefficient: 0.4227 - iou_metric: 0.8649 - loss: 1.0059 - val_accuracy: 0.9088 - val_dice_coefficient: 0.3899 - val_iou_metric: 0.8326 - val_loss: 1.0341 - learning_rate: 1.0000e-05
# Epoch 145/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9207 - dice_coefficient: 0.4278 - iou_metric: 0.8616 - loss: 1.0060
# Epoch 145: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9207 - dice_coefficient: 0.4277 - iou_metric: 0.8615 - loss: 1.0061 - val_accuracy: 0.9044 - val_dice_coefficient: 0.3879 - val_iou_metric: 0.8256 - val_loss: 1.0369 - learning_rate: 1.0000e-05
# Epoch 146/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9224 - dice_coefficient: 0.4230 - iou_metric: 0.8638 - loss: 1.0117
# Epoch 146: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9224 - dice_coefficient: 0.4229 - iou_metric: 0.8638 - loss: 1.0117 - val_accuracy: 0.9088 - val_dice_coefficient: 0.3920 - val_iou_metric: 0.8327 - val_loss: 1.0306 - learning_rate: 1.0000e-05
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9225 - dice_coefficient: 0.4231 - iou_metric: 0.8635 - loss: 1.0133
# Epoch 147: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9225 - dice_coefficient: 0.4231 - iou_metric: 0.8634 - loss: 1.0133 - val_accuracy: 0.9074 - val_dice_coefficient: 0.3917 - val_iou_metric: 0.8304 - val_loss: 1.0300 - learning_rate: 1.0000e-05
# Epoch 148/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9199 - dice_coefficient: 0.4260 - iou_metric: 0.8598 - loss: 1.0117
# Epoch 148: val_iou_metric did not improve from 0.83626
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9199 - dice_coefficient: 0.4260 - iou_metric: 0.8599 - loss: 1.0116 - val_accuracy: 0.9081 - val_dice_coefficient: 0.3927 - val_iou_metric: 0.8315 - val_loss: 1.0282 - learning_rate: 1.0000e-05
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9208 - dice_coefficient: 0.4293 - iou_metric: 0.8610 - loss: 1.0091
# Epoch 149: val_iou_metric improved from 0.83626 to 0.83641, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9208 - dice_coefficient: 0.4293 - iou_metric: 0.8610 - loss: 1.0091 - val_accuracy: 0.9112 - val_dice_coefficient: 0.3959 - val_iou_metric: 0.8364 - val_loss: 1.0248 - learning_rate: 1.0000e-05
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9208 - dice_coefficient: 0.4312 - iou_metric: 0.8612 - loss: 0.9965
# Epoch 150: val_iou_metric did not improve from 0.83641
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9208 - dice_coefficient: 0.4312 - iou_metric: 0.8612 - loss: 0.9965 - val_accuracy: 0.9055 - val_dice_coefficient: 0.3934 - val_iou_metric: 0.8276 - val_loss: 1.0270 - learning_rate: 1.0000e-05
#
# --- Entrenamiento Finalizado ---
# El mejor modelo se ha guardado en: efficient_weed_model_S_best.keras
#
# Cargando el mejor modelo guardado para la evaluación en el conjunto de test...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'aspp_module', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Se encontraron 210 imágenes de test.
# Creando dataset de test...
#
# --- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 509ms/step - accuracy: 0.9292 - dice_coefficient: 0.4362 - iou_metric: 0.8724 - loss: 0.9634
#
# ## MÉTRICAS DE TEST - MODELO 'SMALL' ##
# Test Loss: 0.9620
# Test Dice Coefficient: 0.4254
# Test mIoU: 0.8674
# Test Global Accuracy: 0.9315
#
# Calculando IoU por clase en el conjunto de test...
#
# ## IoU por Clase (Test) ##
# IoU for Background: 0.9358
# IoU for Cow-tongue: 0.3522
# IoU for Dandelion: 0.5444
# IoU for Kikuyo: 0.4651
# IoU for Other: 0.5982
# IoU for Potato: 0.4118
#
# Calculando el promedio de IoU por clase en el conjunto de test...
#
# Promedio de IoU por clase: 0.5513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1627568666.py in <cell line: 0>()
#     344         for images_batch, masks_batch in test_ds.take(1):
#     345             predictions_batch = best_model.predict(images_batch)
# --> 346             plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)
#     347
#     348         # Gráficas de Dice Coefficient y Loss durante el entrenamiento
#
# NameError: name 'plot_sample_masks' is not defined
