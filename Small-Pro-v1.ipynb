# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/Small-Pro-v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6   # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-4

# --- Paths ---
# Asegúrate de que estas rutas coincidan con la estructura de tus carpetas
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')
# NUEVO: Paths para el conjunto de test, como lo pide tu tarea
TEST_IMAGES_PATH = os.path.join(BASE_PATH, 'test/images')
TEST_MASKS_PATH = os.path.join(BASE_PATH, 'test/masks')


# --- Módulos del modelo (ASPP, DeformableAttention) ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

# --- Backbone y Arquitectura del Modelo ---
def create_efficient_backbone(input_shape):
    """Crea el backbone usando EfficientNetV2S y extrae los mapas de características."""
    base_model = tf.keras.applications.EfficientNetV2S(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True
    layer_names = [
        'block1a_project_activation',
        'block2c_add',
        'block3c_add',
        'block6a_expand_activation',
        'top_activation'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2S_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)
    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_S')
    return model

# --- Métricas y Funciones de Pérdida ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

# La métrica 'accuracy' es la global accuracy.
# Para mIoU, usaremos iou_metric que es un buen proxy (Mean IoU).
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos ---
def load_and_preprocess_data(image_paths, mask_paths, augment=False):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5: image, mask = tf.image.flip_left_right(image), tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5: image, mask = tf.image.flip_up_down(image), tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5: k = tf.random.uniform([], 1, 4, dtype=tf.int32); image, mask = tf.image.rot90(image, k), tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = tf.data.Dataset.zip((image_ds, mask_ds))

    if augment:
        dataset = dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_S.keras'):
    model = create_weed_detection_model()
    model.summary()
    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-5)

    # Aquí ya estás pidiendo las métricas correctas
    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy'] # accuracy es global accuracy
    )
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_iou_metric', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_iou_metric', patience=50, mode='max', restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1),
    ]
    print(f"Iniciando entrenamiento por {EPOCHS} épocas...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history


# --- Bloque de Ejecución Principal ---
if __name__ == "__main__":
    # 1. Cargar datos de entrenamiento y validación
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(TRAIN_MASKS_PATH, '*.png')))
    val_image_paths = sorted(glob(os.path.join(VAL_IMAGES_PATH, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(VAL_MASKS_PATH, '*.png')))

    print("Creando datasets de entrenamiento y validación...")
    train_ds = load_and_preprocess_data(train_image_paths, train_mask_paths, augment=True)
    val_ds = load_and_preprocess_data(val_image_paths, val_mask_paths, augment=False)

    # 2. Entrenar el modelo
    model_save_path = 'efficient_weed_model_S_best.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("\n--- Entrenamiento Finalizado ---")
    print(f"El mejor modelo se ha guardado en: {model_save_path}")

    # 3. Cargar el MEJOR modelo guardado para la evaluación final
    print("\nCargando el mejor modelo guardado para la evaluación en el conjunto de test...")
    best_model = tf.keras.models.load_model(
        model_save_path,
        custom_objects={
            'ASPPModule': ASPPModule,
            'DeformableAttention': DeformableAttention,
            'combined_loss': combined_loss,
            'dice_coefficient': dice_coefficient,
            'iou_metric': iou_metric,
            'dice_loss': dice_loss # Añadido por si acaso es necesario
        }
    )

    # 4. Cargar datos de test
    test_image_paths = sorted(glob(os.path.join(TEST_IMAGES_PATH, '*.jpg')))
    test_mask_paths = sorted(glob(os.path.join(TEST_MASKS_PATH, '*.png')))

    if not test_image_paths:
        print("\nADVERTENCIA: No se encontraron imágenes en el directorio de test. Saltando la evaluación de test.")
    else:
        print(f"Se encontraron {len(test_image_paths)} imágenes de test.")
        print("Creando dataset de test...")
        test_ds = load_and_preprocess_data(test_image_paths, test_mask_paths, augment=False)

        # 5. Evaluar en el conjunto de TEST
        print("\n--- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---")
        test_metrics = best_model.evaluate(test_ds)

        print("\n## MÉTRICAS DE TEST - MODELO 'SMALL' ##")
        print(f"Test Loss: {test_metrics[0]:.4f}")
        print(f"Test Dice Coefficient: {test_metrics[1]:.4f}")
        print(f"Test mIoU: {test_metrics[2]:.4f}")
        print(f"Test Global Accuracy: {test_metrics[3]:.4f}")

        # Calcular IoU por clase en el conjunto de test
        print("\nCalculando IoU por clase en el conjunto de test...")
        iou_per_class_values = []
        for images_batch, masks_batch in test_ds:
            predictions_batch = best_model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()
        class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
        print("\n## IoU por Clase (Test) ##")
        for i, iou in enumerate(iou_per_class_values):
            print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets de entrenamiento y validación...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "EfficientWeedDetectionModel_S"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2S_Ba… │ [(None, 64, 64,   │ 20,331,360 │ input_layer[0][0] │
# │ (Functional)        │ 24), (None, 32,   │            │                   │
# │                     │ 32, 48), (None,   │            │                   │
# │                     │ 16, 16, 64),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 960), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2S_… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 96)  │     92,160 │ EfficientNetV2S_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 192) │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 8, 8, 96)  │     20,160 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     36,864 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      6,144 │ EfficientNetV2S_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_10[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │     20,160 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_12[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     18,432 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      2,304 │ EfficientNetV2S_… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │ 96)               │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      5,472 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      4,608 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │        576 │ EfficientNetV2S_… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_16[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │ 48)               │            │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │      1,584 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_18[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        576 │ dropout_8[0][0]   │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 28,010,298 (106.85 MB)
#  Trainable params: 27,851,770 (106.25 MB)
#  Non-trainable params: 158,528 (619.25 KB)
# Iniciando entrenamiento por 150 épocas...
# Epoch 1/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1018 - dice_coefficient: 0.0833 - iou_metric: 0.0539 - loss: 2.3735
# Epoch 1: val_iou_metric improved from -inf to 0.11546, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 221s 315ms/step - accuracy: 0.1019 - dice_coefficient: 0.0833 - iou_metric: 0.0540 - loss: 2.3730 - val_accuracy: 0.2080 - val_dice_coefficient: 0.0862 - val_iou_metric: 0.1155 - val_loss: 2.2141 - learning_rate: 1.0000e-04
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1793 - dice_coefficient: 0.0937 - iou_metric: 0.1015 - loss: 2.1782
# Epoch 2: val_iou_metric improved from 0.11546 to 0.20706, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.1796 - dice_coefficient: 0.0937 - iou_metric: 0.1017 - loss: 2.1777 - val_accuracy: 0.3436 - val_dice_coefficient: 0.0907 - val_iou_metric: 0.2071 - val_loss: 2.1391 - learning_rate: 1.0000e-04
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3041 - dice_coefficient: 0.1137 - iou_metric: 0.1872 - loss: 1.9958
# Epoch 3: val_iou_metric improved from 0.20706 to 0.33507, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.3043 - dice_coefficient: 0.1137 - iou_metric: 0.1874 - loss: 1.9954 - val_accuracy: 0.5047 - val_dice_coefficient: 0.1037 - val_iou_metric: 0.3351 - val_loss: 1.9630 - learning_rate: 1.0000e-04
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4391 - dice_coefficient: 0.1310 - iou_metric: 0.2907 - loss: 1.8610
# Epoch 4: val_iou_metric improved from 0.33507 to 0.47253, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.4393 - dice_coefficient: 0.1310 - iou_metric: 0.2909 - loss: 1.8607 - val_accuracy: 0.6455 - val_dice_coefficient: 0.1262 - val_iou_metric: 0.4725 - val_loss: 1.7763 - learning_rate: 1.0000e-04
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5605 - dice_coefficient: 0.1503 - iou_metric: 0.3991 - loss: 1.7548
# Epoch 5: val_iou_metric improved from 0.47253 to 0.58723, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.5606 - dice_coefficient: 0.1503 - iou_metric: 0.3993 - loss: 1.7546 - val_accuracy: 0.7406 - val_dice_coefficient: 0.1526 - val_iou_metric: 0.5872 - val_loss: 1.6373 - learning_rate: 1.0000e-04
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6507 - dice_coefficient: 0.1627 - iou_metric: 0.4936 - loss: 1.6788
# Epoch 6: val_iou_metric improved from 0.58723 to 0.72095, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.6509 - dice_coefficient: 0.1628 - iou_metric: 0.4939 - loss: 1.6786 - val_accuracy: 0.8328 - val_dice_coefficient: 0.1795 - val_iou_metric: 0.7210 - val_loss: 1.5279 - learning_rate: 1.0000e-04
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7383 - dice_coefficient: 0.1798 - iou_metric: 0.5991 - loss: 1.6077
# Epoch 7: val_iou_metric improved from 0.72095 to 0.73875, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.7385 - dice_coefficient: 0.1798 - iou_metric: 0.5993 - loss: 1.6075 - val_accuracy: 0.8426 - val_dice_coefficient: 0.1999 - val_iou_metric: 0.7388 - val_loss: 1.4576 - learning_rate: 1.0000e-04
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8032 - dice_coefficient: 0.2011 - iou_metric: 0.6839 - loss: 1.5258
# Epoch 8: val_iou_metric improved from 0.73875 to 0.75751, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.8032 - dice_coefficient: 0.2011 - iou_metric: 0.6840 - loss: 1.5256 - val_accuracy: 0.8544 - val_dice_coefficient: 0.2188 - val_iou_metric: 0.7575 - val_loss: 1.3934 - learning_rate: 1.0000e-04
# Epoch 9/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8348 - dice_coefficient: 0.2198 - iou_metric: 0.7297 - loss: 1.4686
# Epoch 9: val_iou_metric improved from 0.75751 to 0.77951, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8348 - dice_coefficient: 0.2199 - iou_metric: 0.7297 - loss: 1.4685 - val_accuracy: 0.8724 - val_dice_coefficient: 0.2344 - val_iou_metric: 0.7795 - val_loss: 1.3390 - learning_rate: 1.0000e-04
# Epoch 10/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8585 - dice_coefficient: 0.2413 - iou_metric: 0.7647 - loss: 1.4022
# Epoch 10: val_iou_metric improved from 0.77951 to 0.78078, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 13s 118ms/step - accuracy: 0.8585 - dice_coefficient: 0.2413 - iou_metric: 0.7647 - loss: 1.4020 - val_accuracy: 0.8740 - val_dice_coefficient: 0.2513 - val_iou_metric: 0.7808 - val_loss: 1.2923 - learning_rate: 1.0000e-04
# Epoch 11/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8785 - dice_coefficient: 0.2581 - iou_metric: 0.7929 - loss: 1.3483
# Epoch 11: val_iou_metric improved from 0.78078 to 0.79490, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.8785 - dice_coefficient: 0.2582 - iou_metric: 0.7929 - loss: 1.3482 - val_accuracy: 0.8833 - val_dice_coefficient: 0.2719 - val_iou_metric: 0.7949 - val_loss: 1.2428 - learning_rate: 1.0000e-04
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8888 - dice_coefficient: 0.2759 - iou_metric: 0.8083 - loss: 1.3008
# Epoch 12: val_iou_metric improved from 0.79490 to 0.80962, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.8888 - dice_coefficient: 0.2759 - iou_metric: 0.8083 - loss: 1.3007 - val_accuracy: 0.8924 - val_dice_coefficient: 0.2917 - val_iou_metric: 0.8096 - val_loss: 1.1994 - learning_rate: 1.0000e-04
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8938 - dice_coefficient: 0.2908 - iou_metric: 0.8160 - loss: 1.2723
# Epoch 13: val_iou_metric improved from 0.80962 to 0.81289, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.8938 - dice_coefficient: 0.2909 - iou_metric: 0.8160 - loss: 1.2721 - val_accuracy: 0.8942 - val_dice_coefficient: 0.3084 - val_iou_metric: 0.8129 - val_loss: 1.1649 - learning_rate: 1.0000e-04
# Epoch 14/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8984 - dice_coefficient: 0.3101 - iou_metric: 0.8231 - loss: 1.2254
# Epoch 14: val_iou_metric improved from 0.81289 to 0.83233, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.8984 - dice_coefficient: 0.3101 - iou_metric: 0.8232 - loss: 1.2253 - val_accuracy: 0.9057 - val_dice_coefficient: 0.3318 - val_iou_metric: 0.8323 - val_loss: 1.1194 - learning_rate: 1.0000e-04
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9070 - dice_coefficient: 0.3354 - iou_metric: 0.8365 - loss: 1.1715
# Epoch 15: val_iou_metric improved from 0.83233 to 0.84832, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9070 - dice_coefficient: 0.3354 - iou_metric: 0.8365 - loss: 1.1714 - val_accuracy: 0.9151 - val_dice_coefficient: 0.3495 - val_iou_metric: 0.8483 - val_loss: 1.0838 - learning_rate: 1.0000e-04
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9118 - dice_coefficient: 0.3514 - iou_metric: 0.8431 - loss: 1.1422
# Epoch 16: val_iou_metric improved from 0.84832 to 0.85267, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9118 - dice_coefficient: 0.3514 - iou_metric: 0.8431 - loss: 1.1421 - val_accuracy: 0.9176 - val_dice_coefficient: 0.3673 - val_iou_metric: 0.8527 - val_loss: 1.0544 - learning_rate: 1.0000e-04
# Epoch 17/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9113 - dice_coefficient: 0.3656 - iou_metric: 0.8428 - loss: 1.1148
# Epoch 17: val_iou_metric improved from 0.85267 to 0.85460, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9113 - dice_coefficient: 0.3656 - iou_metric: 0.8428 - loss: 1.1148 - val_accuracy: 0.9190 - val_dice_coefficient: 0.3837 - val_iou_metric: 0.8546 - val_loss: 1.0286 - learning_rate: 1.0000e-04
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9137 - dice_coefficient: 0.3839 - iou_metric: 0.8461 - loss: 1.0829
# Epoch 18: val_iou_metric improved from 0.85460 to 0.86107, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9137 - dice_coefficient: 0.3839 - iou_metric: 0.8461 - loss: 1.0828 - val_accuracy: 0.9230 - val_dice_coefficient: 0.3990 - val_iou_metric: 0.8611 - val_loss: 1.0016 - learning_rate: 1.0000e-04
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9193 - dice_coefficient: 0.4045 - iou_metric: 0.8554 - loss: 1.0494
# Epoch 19: val_iou_metric improved from 0.86107 to 0.86108, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9193 - dice_coefficient: 0.4045 - iou_metric: 0.8554 - loss: 1.0494 - val_accuracy: 0.9235 - val_dice_coefficient: 0.4149 - val_iou_metric: 0.8611 - val_loss: 0.9739 - learning_rate: 1.0000e-04
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9178 - dice_coefficient: 0.4087 - iou_metric: 0.8533 - loss: 1.0455
# Epoch 20: val_iou_metric did not improve from 0.86108
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9178 - dice_coefficient: 0.4088 - iou_metric: 0.8533 - loss: 1.0454 - val_accuracy: 0.9191 - val_dice_coefficient: 0.4240 - val_iou_metric: 0.8531 - val_loss: 0.9610 - learning_rate: 1.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9221 - dice_coefficient: 0.4295 - iou_metric: 0.8597 - loss: 1.0065
# Epoch 21: val_iou_metric did not improve from 0.86108
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9220 - dice_coefficient: 0.4295 - iou_metric: 0.8596 - loss: 1.0065 - val_accuracy: 0.9228 - val_dice_coefficient: 0.4324 - val_iou_metric: 0.8590 - val_loss: 0.9476 - learning_rate: 1.0000e-04
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9251 - dice_coefficient: 0.4430 - iou_metric: 0.8652 - loss: 0.9849
# Epoch 22: val_iou_metric improved from 0.86108 to 0.86865, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9251 - dice_coefficient: 0.4429 - iou_metric: 0.8651 - loss: 0.9850 - val_accuracy: 0.9282 - val_dice_coefficient: 0.4454 - val_iou_metric: 0.8687 - val_loss: 0.9267 - learning_rate: 1.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9230 - dice_coefficient: 0.4541 - iou_metric: 0.8619 - loss: 0.9728
# Epoch 23: val_iou_metric did not improve from 0.86865
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9230 - dice_coefficient: 0.4540 - iou_metric: 0.8619 - loss: 0.9728 - val_accuracy: 0.9274 - val_dice_coefficient: 0.4548 - val_iou_metric: 0.8665 - val_loss: 0.9145 - learning_rate: 1.0000e-04
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9255 - dice_coefficient: 0.4587 - iou_metric: 0.8658 - loss: 0.9737
# Epoch 24: val_iou_metric improved from 0.86865 to 0.87443, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.9255 - dice_coefficient: 0.4587 - iou_metric: 0.8658 - loss: 0.9736 - val_accuracy: 0.9314 - val_dice_coefficient: 0.4601 - val_iou_metric: 0.8744 - val_loss: 0.9062 - learning_rate: 1.0000e-04
# Epoch 25/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9261 - dice_coefficient: 0.4650 - iou_metric: 0.8672 - loss: 0.9718
# Epoch 25: val_iou_metric improved from 0.87443 to 0.87888, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.9261 - dice_coefficient: 0.4650 - iou_metric: 0.8672 - loss: 0.9717 - val_accuracy: 0.9341 - val_dice_coefficient: 0.4650 - val_iou_metric: 0.8789 - val_loss: 0.8978 - learning_rate: 1.0000e-04
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9289 - dice_coefficient: 0.4744 - iou_metric: 0.8708 - loss: 0.9353
# Epoch 26: val_iou_metric did not improve from 0.87888
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9289 - dice_coefficient: 0.4743 - iou_metric: 0.8708 - loss: 0.9354 - val_accuracy: 0.9307 - val_dice_coefficient: 0.4706 - val_iou_metric: 0.8730 - val_loss: 0.8885 - learning_rate: 1.0000e-04
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9318 - dice_coefficient: 0.4871 - iou_metric: 0.8760 - loss: 0.9105
# Epoch 27: val_iou_metric did not improve from 0.87888
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9318 - dice_coefficient: 0.4870 - iou_metric: 0.8760 - loss: 0.9106 - val_accuracy: 0.9320 - val_dice_coefficient: 0.4764 - val_iou_metric: 0.8745 - val_loss: 0.8785 - learning_rate: 1.0000e-04
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9306 - dice_coefficient: 0.4758 - iou_metric: 0.8737 - loss: 0.9283
# Epoch 28: val_iou_metric did not improve from 0.87888
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9306 - dice_coefficient: 0.4758 - iou_metric: 0.8737 - loss: 0.9282 - val_accuracy: 0.9321 - val_dice_coefficient: 0.4810 - val_iou_metric: 0.8735 - val_loss: 0.8718 - learning_rate: 1.0000e-04
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9304 - dice_coefficient: 0.4930 - iou_metric: 0.8736 - loss: 0.9042
# Epoch 29: val_iou_metric improved from 0.87888 to 0.88903, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 13s 117ms/step - accuracy: 0.9304 - dice_coefficient: 0.4930 - iou_metric: 0.8737 - loss: 0.9042 - val_accuracy: 0.9402 - val_dice_coefficient: 0.4876 - val_iou_metric: 0.8890 - val_loss: 0.8635 - learning_rate: 1.0000e-04
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9319 - dice_coefficient: 0.4935 - iou_metric: 0.8764 - loss: 0.8984
# Epoch 30: val_iou_metric did not improve from 0.88903
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9319 - dice_coefficient: 0.4936 - iou_metric: 0.8764 - loss: 0.8984 - val_accuracy: 0.9345 - val_dice_coefficient: 0.4845 - val_iou_metric: 0.8798 - val_loss: 0.8712 - learning_rate: 1.0000e-04
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9307 - dice_coefficient: 0.5025 - iou_metric: 0.8746 - loss: 0.8887
# Epoch 31: val_iou_metric did not improve from 0.88903
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9307 - dice_coefficient: 0.5025 - iou_metric: 0.8746 - loss: 0.8887 - val_accuracy: 0.9391 - val_dice_coefficient: 0.4935 - val_iou_metric: 0.8870 - val_loss: 0.8570 - learning_rate: 1.0000e-04
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9357 - dice_coefficient: 0.5069 - iou_metric: 0.8824 - loss: 0.8802
# Epoch 32: val_iou_metric did not improve from 0.88903
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9357 - dice_coefficient: 0.5069 - iou_metric: 0.8824 - loss: 0.8803 - val_accuracy: 0.9357 - val_dice_coefficient: 0.4933 - val_iou_metric: 0.8808 - val_loss: 0.8550 - learning_rate: 1.0000e-04
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9339 - dice_coefficient: 0.5092 - iou_metric: 0.8797 - loss: 0.8782
# Epoch 33: val_iou_metric did not improve from 0.88903
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9339 - dice_coefficient: 0.5092 - iou_metric: 0.8797 - loss: 0.8782 - val_accuracy: 0.9399 - val_dice_coefficient: 0.4959 - val_iou_metric: 0.8884 - val_loss: 0.8509 - learning_rate: 1.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9346 - dice_coefficient: 0.5131 - iou_metric: 0.8807 - loss: 0.8667
# Epoch 34: val_iou_metric improved from 0.88903 to 0.89594, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9346 - dice_coefficient: 0.5131 - iou_metric: 0.8807 - loss: 0.8666 - val_accuracy: 0.9443 - val_dice_coefficient: 0.5019 - val_iou_metric: 0.8959 - val_loss: 0.8434 - learning_rate: 1.0000e-04
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9363 - dice_coefficient: 0.5211 - iou_metric: 0.8838 - loss: 0.8511
# Epoch 35: val_iou_metric did not improve from 0.89594
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9363 - dice_coefficient: 0.5211 - iou_metric: 0.8837 - loss: 0.8511 - val_accuracy: 0.9408 - val_dice_coefficient: 0.5064 - val_iou_metric: 0.8899 - val_loss: 0.8352 - learning_rate: 1.0000e-04
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9371 - dice_coefficient: 0.5242 - iou_metric: 0.8846 - loss: 0.8434
# Epoch 36: val_iou_metric did not improve from 0.89594
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9370 - dice_coefficient: 0.5242 - iou_metric: 0.8846 - loss: 0.8435 - val_accuracy: 0.9378 - val_dice_coefficient: 0.5087 - val_iou_metric: 0.8842 - val_loss: 0.8357 - learning_rate: 1.0000e-04
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9390 - dice_coefficient: 0.5259 - iou_metric: 0.8881 - loss: 0.8440
# Epoch 37: val_iou_metric improved from 0.89594 to 0.89704, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.9390 - dice_coefficient: 0.5259 - iou_metric: 0.8881 - loss: 0.8440 - val_accuracy: 0.9453 - val_dice_coefficient: 0.5061 - val_iou_metric: 0.8970 - val_loss: 0.8389 - learning_rate: 1.0000e-04
# Epoch 38/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9366 - dice_coefficient: 0.5274 - iou_metric: 0.8847 - loss: 0.8433
# Epoch 38: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9366 - dice_coefficient: 0.5273 - iou_metric: 0.8847 - loss: 0.8434 - val_accuracy: 0.9427 - val_dice_coefficient: 0.5134 - val_iou_metric: 0.8931 - val_loss: 0.8258 - learning_rate: 1.0000e-04
# Epoch 39/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9392 - dice_coefficient: 0.5343 - iou_metric: 0.8892 - loss: 0.8236
# Epoch 39: val_iou_metric did not improve from 0.89704
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9392 - dice_coefficient: 0.5343 - iou_metric: 0.8892 - loss: 0.8235 - val_accuracy: 0.9426 - val_dice_coefficient: 0.5152 - val_iou_metric: 0.8931 - val_loss: 0.8179 - learning_rate: 1.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9388 - dice_coefficient: 0.5370 - iou_metric: 0.8880 - loss: 0.8277
# Epoch 40: val_iou_metric improved from 0.89704 to 0.89916, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9388 - dice_coefficient: 0.5370 - iou_metric: 0.8880 - loss: 0.8276 - val_accuracy: 0.9462 - val_dice_coefficient: 0.5197 - val_iou_metric: 0.8992 - val_loss: 0.8152 - learning_rate: 1.0000e-04
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9416 - dice_coefficient: 0.5356 - iou_metric: 0.8928 - loss: 0.8237
# Epoch 41: val_iou_metric did not improve from 0.89916
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9416 - dice_coefficient: 0.5357 - iou_metric: 0.8928 - loss: 0.8236 - val_accuracy: 0.9434 - val_dice_coefficient: 0.5218 - val_iou_metric: 0.8938 - val_loss: 0.8119 - learning_rate: 1.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9423 - dice_coefficient: 0.5485 - iou_metric: 0.8943 - loss: 0.8090
# Epoch 42: val_iou_metric improved from 0.89916 to 0.90825, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9423 - dice_coefficient: 0.5485 - iou_metric: 0.8943 - loss: 0.8090 - val_accuracy: 0.9517 - val_dice_coefficient: 0.5253 - val_iou_metric: 0.9083 - val_loss: 0.8068 - learning_rate: 1.0000e-04
# Epoch 43/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9448 - dice_coefficient: 0.5473 - iou_metric: 0.8985 - loss: 0.8029
# Epoch 43: val_iou_metric did not improve from 0.90825
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9448 - dice_coefficient: 0.5472 - iou_metric: 0.8985 - loss: 0.8030 - val_accuracy: 0.9496 - val_dice_coefficient: 0.5297 - val_iou_metric: 0.9043 - val_loss: 0.7927 - learning_rate: 1.0000e-04
# Epoch 44/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9482 - dice_coefficient: 0.5636 - iou_metric: 0.9043 - loss: 0.7712
# Epoch 44: val_iou_metric did not improve from 0.90825
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9482 - dice_coefficient: 0.5636 - iou_metric: 0.9043 - loss: 0.7712 - val_accuracy: 0.9515 - val_dice_coefficient: 0.5384 - val_iou_metric: 0.9076 - val_loss: 0.7738 - learning_rate: 1.0000e-04
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9486 - dice_coefficient: 0.5694 - iou_metric: 0.9051 - loss: 0.7600
# Epoch 45: val_iou_metric improved from 0.90825 to 0.90976, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9485 - dice_coefficient: 0.5694 - iou_metric: 0.9050 - loss: 0.7601 - val_accuracy: 0.9529 - val_dice_coefficient: 0.5534 - val_iou_metric: 0.9098 - val_loss: 0.7464 - learning_rate: 1.0000e-04
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9490 - dice_coefficient: 0.5803 - iou_metric: 0.9059 - loss: 0.7425
# Epoch 46: val_iou_metric did not improve from 0.90976
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9490 - dice_coefficient: 0.5803 - iou_metric: 0.9059 - loss: 0.7424 - val_accuracy: 0.9511 - val_dice_coefficient: 0.5664 - val_iou_metric: 0.9075 - val_loss: 0.7278 - learning_rate: 1.0000e-04
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9503 - dice_coefficient: 0.5882 - iou_metric: 0.9080 - loss: 0.7343
# Epoch 47: val_iou_metric improved from 0.90976 to 0.91025, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.9503 - dice_coefficient: 0.5883 - iou_metric: 0.9080 - loss: 0.7341 - val_accuracy: 0.9528 - val_dice_coefficient: 0.5738 - val_iou_metric: 0.9103 - val_loss: 0.7172 - learning_rate: 1.0000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9499 - dice_coefficient: 0.6116 - iou_metric: 0.9074 - loss: 0.6953
# Epoch 48: val_iou_metric improved from 0.91025 to 0.91377, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9499 - dice_coefficient: 0.6116 - iou_metric: 0.9074 - loss: 0.6954 - val_accuracy: 0.9546 - val_dice_coefficient: 0.5886 - val_iou_metric: 0.9138 - val_loss: 0.6988 - learning_rate: 1.0000e-04
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9515 - dice_coefficient: 0.6175 - iou_metric: 0.9103 - loss: 0.6867
# Epoch 49: val_iou_metric improved from 0.91377 to 0.91398, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9515 - dice_coefficient: 0.6175 - iou_metric: 0.9102 - loss: 0.6867 - val_accuracy: 0.9549 - val_dice_coefficient: 0.5899 - val_iou_metric: 0.9140 - val_loss: 0.6959 - learning_rate: 1.0000e-04
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9511 - dice_coefficient: 0.6246 - iou_metric: 0.9101 - loss: 0.6775
# Epoch 50: val_iou_metric did not improve from 0.91398
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9511 - dice_coefficient: 0.6246 - iou_metric: 0.9101 - loss: 0.6775 - val_accuracy: 0.9538 - val_dice_coefficient: 0.5918 - val_iou_metric: 0.9115 - val_loss: 0.6869 - learning_rate: 1.0000e-04
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9509 - dice_coefficient: 0.6274 - iou_metric: 0.9093 - loss: 0.6758
# Epoch 51: val_iou_metric improved from 0.91398 to 0.91465, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.9509 - dice_coefficient: 0.6274 - iou_metric: 0.9093 - loss: 0.6759 - val_accuracy: 0.9555 - val_dice_coefficient: 0.6020 - val_iou_metric: 0.9147 - val_loss: 0.6804 - learning_rate: 1.0000e-04
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9545 - dice_coefficient: 0.6371 - iou_metric: 0.9152 - loss: 0.6515
# Epoch 52: val_iou_metric did not improve from 0.91465
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9545 - dice_coefficient: 0.6370 - iou_metric: 0.9152 - loss: 0.6517 - val_accuracy: 0.9534 - val_dice_coefficient: 0.6043 - val_iou_metric: 0.9109 - val_loss: 0.6720 - learning_rate: 1.0000e-04
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9524 - dice_coefficient: 0.6380 - iou_metric: 0.9117 - loss: 0.6517
# Epoch 53: val_iou_metric did not improve from 0.91465
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9524 - dice_coefficient: 0.6380 - iou_metric: 0.9117 - loss: 0.6517 - val_accuracy: 0.9541 - val_dice_coefficient: 0.6063 - val_iou_metric: 0.9123 - val_loss: 0.6626 - learning_rate: 1.0000e-04
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9535 - dice_coefficient: 0.6458 - iou_metric: 0.9134 - loss: 0.6374
# Epoch 54: val_iou_metric improved from 0.91465 to 0.91804, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9535 - dice_coefficient: 0.6458 - iou_metric: 0.9134 - loss: 0.6374 - val_accuracy: 0.9577 - val_dice_coefficient: 0.6134 - val_iou_metric: 0.9180 - val_loss: 0.6575 - learning_rate: 1.0000e-04
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9523 - dice_coefficient: 0.6519 - iou_metric: 0.9117 - loss: 0.6371
# Epoch 55: val_iou_metric did not improve from 0.91804
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9523 - dice_coefficient: 0.6519 - iou_metric: 0.9118 - loss: 0.6371 - val_accuracy: 0.9575 - val_dice_coefficient: 0.6183 - val_iou_metric: 0.9179 - val_loss: 0.6486 - learning_rate: 1.0000e-04
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9537 - dice_coefficient: 0.6514 - iou_metric: 0.9139 - loss: 0.6275
# Epoch 56: val_iou_metric improved from 0.91804 to 0.91842, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9537 - dice_coefficient: 0.6514 - iou_metric: 0.9139 - loss: 0.6276 - val_accuracy: 0.9574 - val_dice_coefficient: 0.6164 - val_iou_metric: 0.9184 - val_loss: 0.6538 - learning_rate: 1.0000e-04
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9525 - dice_coefficient: 0.6580 - iou_metric: 0.9118 - loss: 0.6186
# Epoch 57: val_iou_metric did not improve from 0.91842
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9525 - dice_coefficient: 0.6580 - iou_metric: 0.9118 - loss: 0.6186 - val_accuracy: 0.9564 - val_dice_coefficient: 0.6230 - val_iou_metric: 0.9169 - val_loss: 0.6426 - learning_rate: 1.0000e-04
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9524 - dice_coefficient: 0.6622 - iou_metric: 0.9120 - loss: 0.6116
# Epoch 58: val_iou_metric did not improve from 0.91842
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9524 - dice_coefficient: 0.6622 - iou_metric: 0.9120 - loss: 0.6115 - val_accuracy: 0.9570 - val_dice_coefficient: 0.6267 - val_iou_metric: 0.9182 - val_loss: 0.6344 - learning_rate: 1.0000e-04
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9523 - dice_coefficient: 0.6700 - iou_metric: 0.9119 - loss: 0.6063
# Epoch 59: val_iou_metric did not improve from 0.91842
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9523 - dice_coefficient: 0.6700 - iou_metric: 0.9120 - loss: 0.6062 - val_accuracy: 0.9562 - val_dice_coefficient: 0.6269 - val_iou_metric: 0.9177 - val_loss: 0.6338 - learning_rate: 1.0000e-04
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9544 - dice_coefficient: 0.6544 - iou_metric: 0.9155 - loss: 0.6283
# Epoch 60: val_iou_metric did not improve from 0.91842
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9544 - dice_coefficient: 0.6546 - iou_metric: 0.9155 - loss: 0.6281 - val_accuracy: 0.9565 - val_dice_coefficient: 0.6255 - val_iou_metric: 0.9157 - val_loss: 0.6388 - learning_rate: 1.0000e-04
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9541 - dice_coefficient: 0.6737 - iou_metric: 0.9148 - loss: 0.5955
# Epoch 61: val_iou_metric did not improve from 0.91842
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9541 - dice_coefficient: 0.6737 - iou_metric: 0.9148 - loss: 0.5956 - val_accuracy: 0.9571 - val_dice_coefficient: 0.6273 - val_iou_metric: 0.9180 - val_loss: 0.6331 - learning_rate: 1.0000e-04
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9546 - dice_coefficient: 0.6688 - iou_metric: 0.9154 - loss: 0.6016
# Epoch 62: val_iou_metric improved from 0.91842 to 0.91996, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9546 - dice_coefficient: 0.6689 - iou_metric: 0.9154 - loss: 0.6016 - val_accuracy: 0.9579 - val_dice_coefficient: 0.6258 - val_iou_metric: 0.9200 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9570 - dice_coefficient: 0.6810 - iou_metric: 0.9195 - loss: 0.5753
# Epoch 63: val_iou_metric did not improve from 0.91996
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9570 - dice_coefficient: 0.6810 - iou_metric: 0.9195 - loss: 0.5753 - val_accuracy: 0.9571 - val_dice_coefficient: 0.6278 - val_iou_metric: 0.9189 - val_loss: 0.6222 - learning_rate: 1.0000e-04
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9553 - dice_coefficient: 0.6810 - iou_metric: 0.9167 - loss: 0.5787
# Epoch 64: val_iou_metric improved from 0.91996 to 0.92482, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 13s 118ms/step - accuracy: 0.9553 - dice_coefficient: 0.6810 - iou_metric: 0.9167 - loss: 0.5787 - val_accuracy: 0.9601 - val_dice_coefficient: 0.6379 - val_iou_metric: 0.9248 - val_loss: 0.6163 - learning_rate: 1.0000e-04
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9567 - dice_coefficient: 0.6719 - iou_metric: 0.9195 - loss: 0.5901
# Epoch 65: val_iou_metric did not improve from 0.92482
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9567 - dice_coefficient: 0.6720 - iou_metric: 0.9195 - loss: 0.5901 - val_accuracy: 0.9586 - val_dice_coefficient: 0.6320 - val_iou_metric: 0.9219 - val_loss: 0.6185 - learning_rate: 1.0000e-04
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9573 - dice_coefficient: 0.6870 - iou_metric: 0.9201 - loss: 0.5646
# Epoch 66: val_iou_metric did not improve from 0.92482
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9573 - dice_coefficient: 0.6870 - iou_metric: 0.9201 - loss: 0.5646 - val_accuracy: 0.9588 - val_dice_coefficient: 0.6410 - val_iou_metric: 0.9222 - val_loss: 0.6133 - learning_rate: 1.0000e-04
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9565 - dice_coefficient: 0.6927 - iou_metric: 0.9189 - loss: 0.5584
# Epoch 67: val_iou_metric improved from 0.92482 to 0.92847, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9565 - dice_coefficient: 0.6926 - iou_metric: 0.9190 - loss: 0.5584 - val_accuracy: 0.9622 - val_dice_coefficient: 0.6478 - val_iou_metric: 0.9285 - val_loss: 0.6074 - learning_rate: 1.0000e-04
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9557 - dice_coefficient: 0.6864 - iou_metric: 0.9173 - loss: 0.5705
# Epoch 68: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9557 - dice_coefficient: 0.6864 - iou_metric: 0.9173 - loss: 0.5705 - val_accuracy: 0.9609 - val_dice_coefficient: 0.6524 - val_iou_metric: 0.9268 - val_loss: 0.5906 - learning_rate: 1.0000e-04
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9584 - dice_coefficient: 0.7044 - iou_metric: 0.9219 - loss: 0.5349
# Epoch 69: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9584 - dice_coefficient: 0.7044 - iou_metric: 0.9219 - loss: 0.5350 - val_accuracy: 0.9602 - val_dice_coefficient: 0.6591 - val_iou_metric: 0.9257 - val_loss: 0.5808 - learning_rate: 1.0000e-04
# Epoch 70/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9587 - dice_coefficient: 0.7191 - iou_metric: 0.9226 - loss: 0.5135
# Epoch 70: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9587 - dice_coefficient: 0.7190 - iou_metric: 0.9226 - loss: 0.5137 - val_accuracy: 0.9602 - val_dice_coefficient: 0.6709 - val_iou_metric: 0.9254 - val_loss: 0.5616 - learning_rate: 1.0000e-04
# Epoch 71/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9572 - dice_coefficient: 0.7204 - iou_metric: 0.9201 - loss: 0.5195
# Epoch 71: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9572 - dice_coefficient: 0.7204 - iou_metric: 0.9201 - loss: 0.5196 - val_accuracy: 0.9580 - val_dice_coefficient: 0.6654 - val_iou_metric: 0.9221 - val_loss: 0.5916 - learning_rate: 1.0000e-04
# Epoch 72/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9578 - dice_coefficient: 0.7289 - iou_metric: 0.9212 - loss: 0.5064
# Epoch 72: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9578 - dice_coefficient: 0.7289 - iou_metric: 0.9212 - loss: 0.5064 - val_accuracy: 0.9603 - val_dice_coefficient: 0.6866 - val_iou_metric: 0.9257 - val_loss: 0.5448 - learning_rate: 1.0000e-04
# Epoch 73/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9575 - dice_coefficient: 0.7235 - iou_metric: 0.9205 - loss: 0.5186
# Epoch 73: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9575 - dice_coefficient: 0.7235 - iou_metric: 0.9205 - loss: 0.5186 - val_accuracy: 0.9600 - val_dice_coefficient: 0.6948 - val_iou_metric: 0.9249 - val_loss: 0.5379 - learning_rate: 1.0000e-04
# Epoch 74/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9584 - dice_coefficient: 0.7275 - iou_metric: 0.9222 - loss: 0.5148
# Epoch 74: val_iou_metric did not improve from 0.92847
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9584 - dice_coefficient: 0.7276 - iou_metric: 0.9222 - loss: 0.5147 - val_accuracy: 0.9596 - val_dice_coefficient: 0.6966 - val_iou_metric: 0.9237 - val_loss: 0.5359 - learning_rate: 1.0000e-04
# Epoch 75/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9597 - dice_coefficient: 0.7473 - iou_metric: 0.9243 - loss: 0.4733
# Epoch 75: val_iou_metric did not improve from 0.92847
# ...
# Epoch 118: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9639 - dice_coefficient: 0.8049 - iou_metric: 0.9318 - loss: 0.3710 - val_accuracy: 0.9621 - val_dice_coefficient: 0.7257 - val_iou_metric: 0.9289 - val_loss: 0.4995 - learning_rate: 1.0000e-04
# Epoch 119/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9650 - dice_coefficient: 0.8131 - iou_metric: 0.9340 - loss: 0.3562
# Epoch 119: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9650 - dice_coefficient: 0.8131 - iou_metric: 0.9340 - loss: 0.3562 - val_accuracy: 0.9630 - val_dice_coefficient: 0.7283 - val_iou_metric: 0.9300 - val_loss: 0.5013 - learning_rate: 1.0000e-04
# Epoch 120/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9665 - dice_coefficient: 0.8046 - iou_metric: 0.9364 - loss: 0.3660
# Epoch 120: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9664 - dice_coefficient: 0.8046 - iou_metric: 0.9364 - loss: 0.3660 - val_accuracy: 0.9642 - val_dice_coefficient: 0.7211 - val_iou_metric: 0.9322 - val_loss: 0.5112 - learning_rate: 1.0000e-04
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9635 - dice_coefficient: 0.8138 - iou_metric: 0.9311 - loss: 0.3566
# Epoch 121: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9636 - dice_coefficient: 0.8138 - iou_metric: 0.9311 - loss: 0.3566 - val_accuracy: 0.9613 - val_dice_coefficient: 0.7221 - val_iou_metric: 0.9281 - val_loss: 0.5111 - learning_rate: 1.0000e-04
# Epoch 122/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9664 - dice_coefficient: 0.8213 - iou_metric: 0.9364 - loss: 0.3417
# Epoch 122: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9664 - dice_coefficient: 0.8212 - iou_metric: 0.9364 - loss: 0.3418 - val_accuracy: 0.9628 - val_dice_coefficient: 0.7286 - val_iou_metric: 0.9310 - val_loss: 0.5017 - learning_rate: 1.0000e-04
# Epoch 123/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9660 - dice_coefficient: 0.8103 - iou_metric: 0.9357 - loss: 0.3620
# Epoch 123: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9660 - dice_coefficient: 0.8103 - iou_metric: 0.9356 - loss: 0.3620 - val_accuracy: 0.9625 - val_dice_coefficient: 0.7363 - val_iou_metric: 0.9300 - val_loss: 0.4804 - learning_rate: 1.0000e-04
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9646 - dice_coefficient: 0.8220 - iou_metric: 0.9331 - loss: 0.3432
# Epoch 124: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9646 - dice_coefficient: 0.8219 - iou_metric: 0.9331 - loss: 0.3433 - val_accuracy: 0.9639 - val_dice_coefficient: 0.7324 - val_iou_metric: 0.9321 - val_loss: 0.4898 - learning_rate: 1.0000e-04
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9644 - dice_coefficient: 0.8087 - iou_metric: 0.9327 - loss: 0.3593
# Epoch 125: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9644 - dice_coefficient: 0.8087 - iou_metric: 0.9327 - loss: 0.3592 - val_accuracy: 0.9636 - val_dice_coefficient: 0.7354 - val_iou_metric: 0.9319 - val_loss: 0.4849 - learning_rate: 1.0000e-04
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9644 - dice_coefficient: 0.8065 - iou_metric: 0.9328 - loss: 0.3687
# Epoch 126: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9644 - dice_coefficient: 0.8065 - iou_metric: 0.9328 - loss: 0.3687 - val_accuracy: 0.9632 - val_dice_coefficient: 0.7275 - val_iou_metric: 0.9313 - val_loss: 0.5040 - learning_rate: 1.0000e-04
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9649 - dice_coefficient: 0.8068 - iou_metric: 0.9335 - loss: 0.3713
# Epoch 127: val_iou_metric did not improve from 0.93271
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9649 - dice_coefficient: 0.8068 - iou_metric: 0.9335 - loss: 0.3713 - val_accuracy: 0.9629 - val_dice_coefficient: 0.7208 - val_iou_metric: 0.9307 - val_loss: 0.5448 - learning_rate: 1.0000e-04
# Epoch 128/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9649 - dice_coefficient: 0.8169 - iou_metric: 0.9334 - loss: 0.3563
# Epoch 128: val_iou_metric improved from 0.93271 to 0.93284, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9649 - dice_coefficient: 0.8169 - iou_metric: 0.9334 - loss: 0.3564 - val_accuracy: 0.9641 - val_dice_coefficient: 0.7271 - val_iou_metric: 0.9328 - val_loss: 0.5039 - learning_rate: 1.0000e-04
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9646 - dice_coefficient: 0.8181 - iou_metric: 0.9329 - loss: 0.3542
# Epoch 129: val_iou_metric improved from 0.93284 to 0.93347, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.9646 - dice_coefficient: 0.8181 - iou_metric: 0.9329 - loss: 0.3542 - val_accuracy: 0.9644 - val_dice_coefficient: 0.7289 - val_iou_metric: 0.9335 - val_loss: 0.4992 - learning_rate: 1.0000e-04
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9643 - dice_coefficient: 0.8176 - iou_metric: 0.9326 - loss: 0.3467
# Epoch 130: val_iou_metric did not improve from 0.93347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9643 - dice_coefficient: 0.8177 - iou_metric: 0.9326 - loss: 0.3467 - val_accuracy: 0.9629 - val_dice_coefficient: 0.7242 - val_iou_metric: 0.9300 - val_loss: 0.5063 - learning_rate: 1.0000e-04
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9651 - dice_coefficient: 0.8233 - iou_metric: 0.9340 - loss: 0.3424
# Epoch 131: val_iou_metric did not improve from 0.93347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9651 - dice_coefficient: 0.8232 - iou_metric: 0.9340 - loss: 0.3425 - val_accuracy: 0.9634 - val_dice_coefficient: 0.7354 - val_iou_metric: 0.9312 - val_loss: 0.4891 - learning_rate: 1.0000e-04
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9657 - dice_coefficient: 0.8085 - iou_metric: 0.9350 - loss: 0.3600
# Epoch 132: val_iou_metric did not improve from 0.93347
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9657 - dice_coefficient: 0.8085 - iou_metric: 0.9350 - loss: 0.3600 - val_accuracy: 0.9641 - val_dice_coefficient: 0.7247 - val_iou_metric: 0.9330 - val_loss: 0.5095 - learning_rate: 1.0000e-04
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9642 - dice_coefficient: 0.8225 - iou_metric: 0.9325 - loss: 0.3440
# Epoch 133: val_iou_metric improved from 0.93347 to 0.93359, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9642 - dice_coefficient: 0.8224 - iou_metric: 0.9325 - loss: 0.3441 - val_accuracy: 0.9645 - val_dice_coefficient: 0.7212 - val_iou_metric: 0.9336 - val_loss: 0.5187 - learning_rate: 1.0000e-04
# Epoch 134/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9640 - dice_coefficient: 0.8108 - iou_metric: 0.9320 - loss: 0.3615
# Epoch 134: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9640 - dice_coefficient: 0.8109 - iou_metric: 0.9320 - loss: 0.3615 - val_accuracy: 0.9642 - val_dice_coefficient: 0.7287 - val_iou_metric: 0.9330 - val_loss: 0.5050 - learning_rate: 1.0000e-04
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9650 - dice_coefficient: 0.8143 - iou_metric: 0.9338 - loss: 0.3523
# Epoch 135: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9650 - dice_coefficient: 0.8143 - iou_metric: 0.9339 - loss: 0.3523 - val_accuracy: 0.9645 - val_dice_coefficient: 0.7320 - val_iou_metric: 0.9331 - val_loss: 0.4907 - learning_rate: 1.0000e-04
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9650 - dice_coefficient: 0.8179 - iou_metric: 0.9338 - loss: 0.3459
# Epoch 136: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9650 - dice_coefficient: 0.8179 - iou_metric: 0.9338 - loss: 0.3459 - val_accuracy: 0.9636 - val_dice_coefficient: 0.7236 - val_iou_metric: 0.9319 - val_loss: 0.5130 - learning_rate: 1.0000e-04
# Epoch 137/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9647 - dice_coefficient: 0.8201 - iou_metric: 0.9333 - loss: 0.3497
# Epoch 137: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9647 - dice_coefficient: 0.8201 - iou_metric: 0.9333 - loss: 0.3497 - val_accuracy: 0.9639 - val_dice_coefficient: 0.7244 - val_iou_metric: 0.9324 - val_loss: 0.5115 - learning_rate: 1.0000e-04
# Epoch 138/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9655 - dice_coefficient: 0.8288 - iou_metric: 0.9347 - loss: 0.3266
# Epoch 138: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9655 - dice_coefficient: 0.8287 - iou_metric: 0.9347 - loss: 0.3267 - val_accuracy: 0.9642 - val_dice_coefficient: 0.7225 - val_iou_metric: 0.9327 - val_loss: 0.5169 - learning_rate: 1.0000e-04
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9669 - dice_coefficient: 0.8172 - iou_metric: 0.9372 - loss: 0.3461
# Epoch 139: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9669 - dice_coefficient: 0.8172 - iou_metric: 0.9372 - loss: 0.3460 - val_accuracy: 0.9637 - val_dice_coefficient: 0.7353 - val_iou_metric: 0.9319 - val_loss: 0.4856 - learning_rate: 1.0000e-04
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9653 - dice_coefficient: 0.8196 - iou_metric: 0.9343 - loss: 0.3447
# Epoch 140: val_iou_metric did not improve from 0.93359
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9653 - dice_coefficient: 0.8196 - iou_metric: 0.9343 - loss: 0.3448 - val_accuracy: 0.9631 - val_dice_coefficient: 0.7276 - val_iou_metric: 0.9310 - val_loss: 0.5017 - learning_rate: 1.0000e-04
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9666 - dice_coefficient: 0.8217 - iou_metric: 0.9368 - loss: 0.3379
# Epoch 141: val_iou_metric improved from 0.93359 to 0.93407, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.9666 - dice_coefficient: 0.8216 - iou_metric: 0.9368 - loss: 0.3380 - val_accuracy: 0.9650 - val_dice_coefficient: 0.7344 - val_iou_metric: 0.9341 - val_loss: 0.4882 - learning_rate: 1.0000e-04
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9645 - dice_coefficient: 0.8175 - iou_metric: 0.9329 - loss: 0.3494
# Epoch 142: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9645 - dice_coefficient: 0.8175 - iou_metric: 0.9329 - loss: 0.3493 - val_accuracy: 0.9635 - val_dice_coefficient: 0.7314 - val_iou_metric: 0.9315 - val_loss: 0.4960 - learning_rate: 1.0000e-04
# Epoch 143/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9660 - dice_coefficient: 0.8323 - iou_metric: 0.9356 - loss: 0.3229
# Epoch 143: val_iou_metric did not improve from 0.93407
#
# Epoch 143: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9660 - dice_coefficient: 0.8323 - iou_metric: 0.9356 - loss: 0.3229 - val_accuracy: 0.9635 - val_dice_coefficient: 0.7349 - val_iou_metric: 0.9320 - val_loss: 0.4896 - learning_rate: 1.0000e-04
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9653 - dice_coefficient: 0.8282 - iou_metric: 0.9344 - loss: 0.3310
# Epoch 144: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9653 - dice_coefficient: 0.8281 - iou_metric: 0.9344 - loss: 0.3311 - val_accuracy: 0.9641 - val_dice_coefficient: 0.7335 - val_iou_metric: 0.9331 - val_loss: 0.4946 - learning_rate: 3.0000e-05
# Epoch 145/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9656 - dice_coefficient: 0.8180 - iou_metric: 0.9350 - loss: 0.3415
# Epoch 145: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 79ms/step - accuracy: 0.9656 - dice_coefficient: 0.8181 - iou_metric: 0.9351 - loss: 0.3414 - val_accuracy: 0.9642 - val_dice_coefficient: 0.7360 - val_iou_metric: 0.9333 - val_loss: 0.4902 - learning_rate: 3.0000e-05
# Epoch 146/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9664 - dice_coefficient: 0.8248 - iou_metric: 0.9362 - loss: 0.3337
# Epoch 146: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9664 - dice_coefficient: 0.8248 - iou_metric: 0.9362 - loss: 0.3337 - val_accuracy: 0.9633 - val_dice_coefficient: 0.7296 - val_iou_metric: 0.9318 - val_loss: 0.5027 - learning_rate: 3.0000e-05
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9672 - dice_coefficient: 0.8261 - iou_metric: 0.9378 - loss: 0.3305
# Epoch 147: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9672 - dice_coefficient: 0.8261 - iou_metric: 0.9378 - loss: 0.3305 - val_accuracy: 0.9643 - val_dice_coefficient: 0.7324 - val_iou_metric: 0.9337 - val_loss: 0.5003 - learning_rate: 3.0000e-05
# Epoch 148/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9661 - dice_coefficient: 0.8264 - iou_metric: 0.9357 - loss: 0.3271
# Epoch 148: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9661 - dice_coefficient: 0.8264 - iou_metric: 0.9357 - loss: 0.3271 - val_accuracy: 0.9638 - val_dice_coefficient: 0.7325 - val_iou_metric: 0.9326 - val_loss: 0.4982 - learning_rate: 3.0000e-05
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9658 - dice_coefficient: 0.8323 - iou_metric: 0.9354 - loss: 0.3246
# Epoch 149: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9659 - dice_coefficient: 0.8323 - iou_metric: 0.9355 - loss: 0.3246 - val_accuracy: 0.9638 - val_dice_coefficient: 0.7288 - val_iou_metric: 0.9327 - val_loss: 0.5099 - learning_rate: 3.0000e-05
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9662 - dice_coefficient: 0.8293 - iou_metric: 0.9360 - loss: 0.3213
# Epoch 150: val_iou_metric did not improve from 0.93407
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9662 - dice_coefficient: 0.8293 - iou_metric: 0.9360 - loss: 0.3213 - val_accuracy: 0.9642 - val_dice_coefficient: 0.7297 - val_iou_metric: 0.9333 - val_loss: 0.5070 - learning_rate: 3.0000e-05
#
# --- Entrenamiento Finalizado ---
# El mejor modelo se ha guardado en: efficient_weed_model_S_best.keras
#
# Cargando el mejor modelo guardado para la evaluación en el conjunto de test...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'aspp_module', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Se encontraron 210 imágenes de test.
# Creando dataset de test...
#
# --- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 465ms/step - accuracy: 0.9668 - dice_coefficient: 0.7174 - iou_metric: 0.9372 - loss: 0.5342
#
# ## MÉTRICAS DE TEST - MODELO 'SMALL' ##
# Test Loss: 0.4899
# Test Dice Coefficient: 0.7210
# Test mIoU: 0.9419
# Test Global Accuracy: 0.9698
#
# Calculando IoU por clase en el conjunto de test...
#
# ## IoU por Clase (Test) ##
# IoU for Background: 0.9571
# IoU for Cow-tongue: 0.9093
# IoU for Dandelion: 0.9133
# IoU for Kikuyo: 0.9125
# IoU for Other: 0.7227
# IoU for Potato: 0.9079
