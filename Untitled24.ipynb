# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf

# Busca y lista los dispositivos físicos de tipo 'GPU'
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  try:
    # Opcional pero recomendado: Configura TensorFlow para que la memoria de la GPU no se asigne toda de golpe.
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)

    # Imprime un mensaje de éxito si se detectan GPUs
    print(f"✅ ¡Éxito! TensorFlow ha detectado {len(gpus)} GPU(s):")
    for i, gpu in enumerate(gpus):
        print(f"  - GPU {i}: {gpu.name}")

  except RuntimeError as e:
    # Este error puede ocurrir si las GPUs ya están en uso.
    print(f"⚠️ Error durante la configuración de la GPU: {e}")
else:
  print("❌ Error: TensorFlow no ha detectado ninguna GPU.")
  print("Asegúrate de haber activado el acelerador de GPU como se indica en el Paso 1.")
# Out:
# ✅ ¡Éxito! TensorFlow ha detectado 1 GPU(s):
#   - GPU 0: /physical_device:GPU:0

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6   # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 75
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo (sin cambios) ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

# CAMBIO 1: Se usa EfficientNetV2B2 y se actualizan los nombres de las capas.
def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B2(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True

    # Nombres de las capas de EfficientNetV2B2 para extraer características.
    # Nota: El bloque 4 en V2B2 no reduce el tamaño, la reducción a 8x8 ocurre en el bloque 5.
    layer_names = [
        'block1a_project_activation', # Salida: (N, 64, 64, 24)
        'block2a_expand_activation',  # Salida: (N, 32, 32, 48)
        'block3a_expand_activation',  # Salida: (N, 16, 16, 64)
        'block5a_expand_activation',  # Salida: (N, 8, 8, 160)
        'top_activation'              # Salida: (N, 4, 4, 1408)
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B2_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)

    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)

    print(f"\n--- Formas de las Características del Backbone (EfficientNetV2B2) ---")
    print(f"feat1_out (64x64): {feat1_out.shape}")
    print(f"feat2_out (32x32): {feat2_out.shape}")
    print(f"feat3_out (16x16): {feat3_out.shape}")
    print(f"feat4_out (8x8):   {feat4_out.shape}")
    print(f"feat5_out (4x4, entrada a ASPP): {feat5_out.shape}")
    print(f"-------------------------------------------------------------------\n")

    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)

    # --- Ruta del Decodificador (la lógica se mantiene) ---
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)

    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)

    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)

    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)

    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)

    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)

    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_V2B2')
    return model

# --- Métricas y Funciones de Pérdida (sin cambios) ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos ---
def load_and_preprocess_data(train_img_path, train_msk_path, val_img_path, val_msk_path):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5: image = tf.image.flip_left_right(image); mask = tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5: image = tf.image.flip_up_down(image); mask = tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5: k = tf.random.uniform([], 1, 4, tf.int32); image = tf.image.rot90(image, k); mask = tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)

        # CAMBIO 2: Usar la función de preprocesamiento para EfficientNetV2
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    train_image_paths = sorted(glob(os.path.join(train_img_path, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(train_msk_path, '*.png')))
    val_image_paths = sorted(glob(os.path.join(val_img_path, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(val_msk_path, '*.png')))

    if not train_image_paths or not train_mask_paths: raise FileNotFoundError(f"No se encontraron archivos en las rutas de entrenamiento: {train_img_path}, {train_msk_path}")
    if not val_image_paths or not val_mask_paths: raise FileNotFoundError(f"No se encontraron archivos en las rutas de validación: {val_img_path}, {val_msk_path}")

    print(f"Se encontraron {len(train_image_paths)} imágenes y {len(train_mask_paths)} máscaras de entrenamiento.")
    print(f"Se encontraron {len(val_image_paths)} imágenes y {len(val_mask_paths)} máscaras de validación.")

    train_ds = tf.data.Dataset.zip((
        tf.data.Dataset.from_tensor_slices(train_image_paths).map(load_image_only, tf.data.AUTOTUNE),
        tf.data.Dataset.from_tensor_slices(train_mask_paths).map(load_mask_only, tf.data.AUTOTUNE)
    )).shuffle(1000).map(augment_and_preprocess, tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_ds = tf.data.Dataset.zip((
        tf.data.Dataset.from_tensor_slices(val_image_paths).map(load_image_only, tf.data.AUTOTUNE),
        tf.data.Dataset.from_tensor_slices(val_mask_paths).map(load_mask_only, tf.data.AUTOTUNE)
    )).map(lambda img, msk: (tf.keras.applications.efficientnet_v2.preprocess_input(img), msk), tf.data.AUTOTUNE).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_ds, val_ds

def train_model(train_dataset, val_dataset, model_save_path='efficient_v2b2_weed_model.keras'):
    model = create_weed_detection_model()
    model.summary(line_length=120)
    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-5)
    model.compile(optimizer=optimizer, loss=combined_loss, metrics=[dice_coefficient, iou_metric, 'accuracy'])
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_dice_coefficient', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_dice_coefficient', patience=50, mode='max', restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1),
    ]
    print(f"Iniciando entrenamiento con {model.name} por {EPOCHS} épocas...")
    history = model.fit(train_dataset, epochs=EPOCHS, validation_data=val_dataset, callbacks=callbacks, verbose=1)
    return model, history

# CAMBIO 3: Función de visualización ajustada para el preprocesamiento de V2.
def visualize_predictions(model, val_dataset, num_samples=4):
    print(f"Visualizando {num_samples} muestras del conjunto de validación...")
    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)
        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

        for i in range(min(num_samples, images.shape[0])):
            # Invierte el preprocesamiento de EfficientNetV2 para mostrar la imagen
            proc_image = images[i].numpy()
            min_val, max_val = proc_image.min(), proc_image.max()
            # Evita la división por cero si la imagen es constante
            if max_val == min_val:
                original_image = np.full(proc_image.shape, min_val, dtype=np.uint8)
            else:
                original_image = (proc_image - min_val) / (max_val - min_val) * 255
            original_image = original_image.astype(np.uint8)

            axes[i, 0].imshow(original_image)
            axes[i, 0].set_title('Imagen Original')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('Máscara Real')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Máscara Predicha')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break # Solo muestra un lote de predicciones

if __name__ == "__main__":
    # Verifica que las carpetas de datos existan, si no, las crea.
    for path in [TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH]:
        if not os.path.exists(path):
            print(f"Advertencia: La ruta de datos no existe: {path}")
            print(f"Creando directorio: {path}")
            os.makedirs(path, exist_ok=True)

    try:
        print("Creando datasets...")
        train_ds, val_ds = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH)

        # Verifica que el dataset de entrenamiento no esté vacío
        if not any(True for _ in train_ds.take(1)):
            print("\nError: El dataset de entrenamiento está vacío.")
            print("Asegúrate de que las imágenes y máscaras estén en las rutas correctas:")
            print(f" - {TRAIN_IMAGES_PATH}")
            print(f" - {TRAIN_MASKS_PATH}")
            exit()

        print("Entrenando modelo...")
        model_save_path = 'efficient_v2b2_weed_model.keras'
        model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

        print("\nVisualizando predicciones del mejor modelo...")
        visualize_predictions(model, val_ds)

        print(f"¡Entrenamiento completado! El mejor modelo se guardó como '{model_save_path}'")

        # --- Gráficas de Entrenamiento ---
        plt.figure(figsize=(14, 6))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['dice_coefficient'], label='Coef. Dice (Entrenamiento)')
        plt.plot(history.history['val_dice_coefficient'], label='Coef. Dice (Validación)')
        plt.title('Coeficiente de Dice por Época')
        plt.xlabel('Época')
        plt.ylabel('Coeficiente de Dice')
        plt.legend()
        plt.grid(True)

        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Pérdida (Entrenamiento)')
        plt.plot(history.history['val_loss'], label='Pérdida (Validación)')
        plt.title('Pérdida por Época')
        plt.xlabel('Época')
        plt.ylabel('Pérdida')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

        # --- Evaluación Final ---
        print("\nEvaluando el modelo final en el conjunto de validación:")
        final_metrics = model.evaluate(val_ds)
        print(f"Pérdida en Validación: {final_metrics[0]:.4f}")
        print(f"Coeficiente de Dice en Validación: {final_metrics[1]:.4f}")
        print(f"IoU en Validación: {final_metrics[2]:.4f}")
        print(f"Accuracy en Validación: {final_metrics[3]:.4f}")

        # --- IoU por Clase ---
        print("\nCalculando IoU por clase...")
        iou_per_class_values = []
        for images_batch, masks_batch in val_ds:
            predictions_batch = model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        # Promedia los resultados de IoU de todos los lotes
        mean_iou_per_class = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()

        class_names = ['Fondo', 'Lengua de Vaca', 'Diente de León', 'Kikuyo', 'Otras', 'Papa']
        for i, iou in enumerate(mean_iou_per_class):
            print(f"IoU para {class_names[i]}: {iou:.4f}")

    except FileNotFoundError as e:
        print(f"\nError de archivo no encontrado: {e}")
    except Exception as e:
        print(f"\nOcurrió un error inesperado: {e}")
# Out:
# Creando datasets...
# Se encontraron 1680 imágenes y 1680 máscaras de entrenamiento.
# Se encontraron 210 imágenes y 210 máscaras de validación.
# Entrenando modelo...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Formas de las Características del Backbone (EfficientNetV2B2) ---
# feat1_out (64x64): (None, 64, 64, 16)
# feat2_out (32x32): (None, 32, 32, 64)
# feat3_out (16x16): (None, 16, 16, 128)
# feat4_out (8x8):   (None, 8, 8, 624)
# feat5_out (4x4, entrada a ASPP): (None, 4, 4, 1408)
# -------------------------------------------------------------------
# Model: "EfficientWeedDetectionModel_V2B2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ┃ Layer (type)                      ┃ Output Shape                 ┃           Param # ┃ Connected to
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━
# │ input_layer (InputLayer)          │ (None, 128, 128, 3)          │                 0 │ -
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ EfficientNetV2B2_Backbone         │ [(None, 64, 64, 16), (None,  │         8,769,374 │ input_layer[0][0]
# │ (Functional)                      │ 32, 32, 64), (None, 16, 16,  │                   │
# │                                   │ 128), (None, 8, 8, 624),     │                   │
# │                                   │ (None, 4, 4, 1408)]          │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ aspp_module (ASPPModule)          │ (None, 4, 4, 192)            │         8,028,672 │ EfficientNetV2B2_Backbone[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ deformable_attention              │ (None, 4, 4, 192)            │            76,992 │ aspp_module[0][0]
# │ (DeformableAttention)             │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_transpose                  │ (None, 8, 8, 96)             │            73,728 │ deformable_attention[0][0]
# │ (Conv2DTranspose)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_8             │ (None, 8, 8, 96)             │               384 │ conv2d_transpose[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_6 (Conv2D)                 │ (None, 8, 8, 96)             │            59,904 │ EfficientNetV2B2_Backbone[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_7 (ReLU)                    │ (None, 8, 8, 96)             │                 0 │ batch_normalization_8[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_9             │ (None, 8, 8, 96)             │               384 │ conv2d_6[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_1 (Dropout)               │ (None, 8, 8, 96)             │                 0 │ re_lu_7[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_8 (ReLU)                    │ (None, 8, 8, 96)             │                 0 │ batch_normalization_9[0][0
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ concatenate_2 (Concatenate)       │ (None, 8, 8, 192)            │                 0 │ dropout_1[0][0],
# │                                   │                              │                   │ re_lu_8[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ separable_conv2d                  │ (None, 8, 8, 96)             │            20,160 │ concatenate_2[0][0]
# │ (SeparableConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_10            │ (None, 8, 8, 96)             │               384 │ separable_conv2d[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_9 (ReLU)                    │ (None, 8, 8, 96)             │                 0 │ batch_normalization_10[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_2 (Dropout)               │ (None, 8, 8, 96)             │                 0 │ re_lu_9[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_transpose_1                │ (None, 16, 16, 96)           │            36,864 │ dropout_2[0][0]
# │ (Conv2DTranspose)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_11            │ (None, 16, 16, 96)           │               384 │ conv2d_transpose_1[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_7 (Conv2D)                 │ (None, 16, 16, 96)           │            12,288 │ EfficientNetV2B2_Backbone[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_10 (ReLU)                   │ (None, 16, 16, 96)           │                 0 │ batch_normalization_11[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_12            │ (None, 16, 16, 96)           │               384 │ conv2d_7[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_3 (Dropout)               │ (None, 16, 16, 96)           │                 0 │ re_lu_10[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_11 (ReLU)                   │ (None, 16, 16, 96)           │                 0 │ batch_normalization_12[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ concatenate_3 (Concatenate)       │ (None, 16, 16, 192)          │                 0 │ dropout_3[0][0],
# │                                   │                              │                   │ re_lu_11[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ separable_conv2d_1                │ (None, 16, 16, 96)           │            20,160 │ concatenate_3[0][0]
# │ (SeparableConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_13            │ (None, 16, 16, 96)           │               384 │ separable_conv2d_1[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_12 (ReLU)                   │ (None, 16, 16, 96)           │                 0 │ batch_normalization_13[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_4 (Dropout)               │ (None, 16, 16, 96)           │                 0 │ re_lu_12[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_transpose_2                │ (None, 32, 32, 48)           │            18,432 │ dropout_4[0][0]
# │ (Conv2DTranspose)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_14            │ (None, 32, 32, 48)           │               192 │ conv2d_transpose_2[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_8 (Conv2D)                 │ (None, 32, 32, 48)           │             3,072 │ EfficientNetV2B2_Backbone[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_13 (ReLU)                   │ (None, 32, 32, 48)           │                 0 │ batch_normalization_14[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_15            │ (None, 32, 32, 48)           │               192 │ conv2d_8[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_5 (Dropout)               │ (None, 32, 32, 48)           │                 0 │ re_lu_13[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_14 (ReLU)                   │ (None, 32, 32, 48)           │                 0 │ batch_normalization_15[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ concatenate_4 (Concatenate)       │ (None, 32, 32, 96)           │                 0 │ dropout_5[0][0],
# │                                   │                              │                   │ re_lu_14[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ separable_conv2d_2                │ (None, 32, 32, 48)           │             5,472 │ concatenate_4[0][0]
# │ (SeparableConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_16            │ (None, 32, 32, 48)           │               192 │ separable_conv2d_2[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_15 (ReLU)                   │ (None, 32, 32, 48)           │                 0 │ batch_normalization_16[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_6 (Dropout)               │ (None, 32, 32, 48)           │                 0 │ re_lu_15[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_transpose_3                │ (None, 64, 64, 24)           │             4,608 │ dropout_6[0][0]
# │ (Conv2DTranspose)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_17            │ (None, 64, 64, 24)           │                96 │ conv2d_transpose_3[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_9 (Conv2D)                 │ (None, 64, 64, 24)           │               384 │ EfficientNetV2B2_Backbone[
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_16 (ReLU)                   │ (None, 64, 64, 24)           │                 0 │ batch_normalization_17[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_18            │ (None, 64, 64, 24)           │                96 │ conv2d_9[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_7 (Dropout)               │ (None, 64, 64, 24)           │                 0 │ re_lu_16[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_17 (ReLU)                   │ (None, 64, 64, 24)           │                 0 │ batch_normalization_18[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ concatenate_5 (Concatenate)       │ (None, 64, 64, 48)           │                 0 │ dropout_7[0][0],
# │                                   │                              │                   │ re_lu_17[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ separable_conv2d_3                │ (None, 64, 64, 24)           │             1,584 │ concatenate_5[0][0]
# │ (SeparableConv2D)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ batch_normalization_19            │ (None, 64, 64, 24)           │                96 │ separable_conv2d_3[0][0]
# │ (BatchNormalization)              │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ re_lu_18 (ReLU)                   │ (None, 64, 64, 24)           │                 0 │ batch_normalization_19[0][
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ dropout_8 (Dropout)               │ (None, 64, 64, 24)           │                 0 │ re_lu_18[0][0]
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ conv2d_transpose_4                │ (None, 128, 128, 6)          │               576 │ dropout_8[0][0]
# │ (Conv2DTranspose)                 │                              │                   │
# ├───────────────────────────────────┼──────────────────────────────┼───────────────────┼───────────────────────────
# │ segmentation_output (Conv2D)      │ (None, 128, 128, 6)          │                42 │ conv2d_transpose_4[0][0]
# └───────────────────────────────────┴──────────────────────────────┴───────────────────┴───────────────────────────
#  Total params: 17,135,480 (65.37 MB)
#  Trainable params: 17,048,536 (65.04 MB)
#  Non-trainable params: 86,944 (339.62 KB)
# Iniciando entrenamiento con EfficientWeedDetectionModel_V2B2 por 75 épocas...
# Epoch 1/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.1443 - dice_coefficient: 0.0864 - iou_metric: 0.0780 - loss: 2.3393
# Epoch 1: val_dice_coefficient improved from -inf to 0.08632, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 204s 371ms/step - accuracy: 0.1444 - dice_coefficient: 0.0864 - iou_metric: 0.0781 - loss: 2.3390 - val_accuracy: 0.2497 - val_dice_coefficient: 0.0863 - val_iou_metric: 0.1426 - val_loss: 2.2151 - learning_rate: 1.0000e-04
# Epoch 2/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.2203 - dice_coefficient: 0.0971 - iou_metric: 0.1251 - loss: 2.1936
# Epoch 2: val_dice_coefficient improved from 0.08632 to 0.09038, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 189ms/step - accuracy: 0.2206 - dice_coefficient: 0.0972 - iou_metric: 0.1253 - loss: 2.1930 - val_accuracy: 0.3727 - val_dice_coefficient: 0.0904 - val_iou_metric: 0.2282 - val_loss: 2.1519 - learning_rate: 1.0000e-04
# Epoch 3/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4054 - dice_coefficient: 0.1132 - iou_metric: 0.2608 - loss: 1.9870
# Epoch 3: val_dice_coefficient improved from 0.09038 to 0.10450, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 195ms/step - accuracy: 0.4060 - dice_coefficient: 0.1133 - iou_metric: 0.2613 - loss: 1.9865 - val_accuracy: 0.6031 - val_dice_coefficient: 0.1045 - val_iou_metric: 0.4353 - val_loss: 1.9518 - learning_rate: 1.0000e-04
# Epoch 4/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6320 - dice_coefficient: 0.1404 - iou_metric: 0.4752 - loss: 1.8096
# Epoch 4: val_dice_coefficient improved from 0.10450 to 0.13510, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 192ms/step - accuracy: 0.6324 - dice_coefficient: 0.1404 - iou_metric: 0.4756 - loss: 1.8093 - val_accuracy: 0.7544 - val_dice_coefficient: 0.1351 - val_iou_metric: 0.6150 - val_loss: 1.7281 - learning_rate: 1.0000e-04
# Epoch 5/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7661 - dice_coefficient: 0.1644 - iou_metric: 0.6363 - loss: 1.6875
# Epoch 5: val_dice_coefficient improved from 0.13510 to 0.16651, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 196ms/step - accuracy: 0.7662 - dice_coefficient: 0.1645 - iou_metric: 0.6365 - loss: 1.6873 - val_accuracy: 0.8121 - val_dice_coefficient: 0.1665 - val_iou_metric: 0.6947 - val_loss: 1.5972 - learning_rate: 1.0000e-04
# Epoch 6/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8124 - dice_coefficient: 0.1787 - iou_metric: 0.7028 - loss: 1.6228
# Epoch 6: val_dice_coefficient improved from 0.16651 to 0.19237, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 195ms/step - accuracy: 0.8124 - dice_coefficient: 0.1788 - iou_metric: 0.7029 - loss: 1.6225 - val_accuracy: 0.8376 - val_dice_coefficient: 0.1924 - val_iou_metric: 0.7355 - val_loss: 1.4977 - learning_rate: 1.0000e-04
# Epoch 7/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8308 - dice_coefficient: 0.1987 - iou_metric: 0.7304 - loss: 1.5621
# Epoch 7: val_dice_coefficient improved from 0.19237 to 0.21313, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.8308 - dice_coefficient: 0.1987 - iou_metric: 0.7305 - loss: 1.5619 - val_accuracy: 0.8544 - val_dice_coefficient: 0.2131 - val_iou_metric: 0.7572 - val_loss: 1.4253 - learning_rate: 1.0000e-04
# Epoch 8/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8509 - dice_coefficient: 0.2199 - iou_metric: 0.7580 - loss: 1.4817
# Epoch 8: val_dice_coefficient improved from 0.21313 to 0.22687, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 198ms/step - accuracy: 0.8509 - dice_coefficient: 0.2200 - iou_metric: 0.7580 - loss: 1.4816 - val_accuracy: 0.8407 - val_dice_coefficient: 0.2269 - val_iou_metric: 0.7366 - val_loss: 1.3789 - learning_rate: 1.0000e-04
# Epoch 9/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8551 - dice_coefficient: 0.2355 - iou_metric: 0.7636 - loss: 1.4265
# Epoch 9: val_dice_coefficient improved from 0.22687 to 0.24573, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 236ms/step - accuracy: 0.8551 - dice_coefficient: 0.2355 - iou_metric: 0.7637 - loss: 1.4263 - val_accuracy: 0.8491 - val_dice_coefficient: 0.2457 - val_iou_metric: 0.7481 - val_loss: 1.3277 - learning_rate: 1.0000e-04
# Epoch 10/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8606 - dice_coefficient: 0.2547 - iou_metric: 0.7704 - loss: 1.3729
# Epoch 10: val_dice_coefficient improved from 0.24573 to 0.26026, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8606 - dice_coefficient: 0.2547 - iou_metric: 0.7704 - loss: 1.3727 - val_accuracy: 0.8510 - val_dice_coefficient: 0.2603 - val_iou_metric: 0.7498 - val_loss: 1.2860 - learning_rate: 1.0000e-04
# Epoch 11/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8676 - dice_coefficient: 0.2703 - iou_metric: 0.7802 - loss: 1.3323
# Epoch 11: val_dice_coefficient improved from 0.26026 to 0.28378, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 24s 219ms/step - accuracy: 0.8676 - dice_coefficient: 0.2703 - iou_metric: 0.7802 - loss: 1.3322 - val_accuracy: 0.8544 - val_dice_coefficient: 0.2838 - val_iou_metric: 0.7505 - val_loss: 1.2318 - learning_rate: 1.0000e-04
# Epoch 12/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8766 - dice_coefficient: 0.2907 - iou_metric: 0.7931 - loss: 1.2761
# Epoch 12: val_dice_coefficient improved from 0.28378 to 0.30083, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 44s 242ms/step - accuracy: 0.8766 - dice_coefficient: 0.2907 - iou_metric: 0.7931 - loss: 1.2761 - val_accuracy: 0.8716 - val_dice_coefficient: 0.3008 - val_iou_metric: 0.7755 - val_loss: 1.1853 - learning_rate: 1.0000e-04
# Epoch 13/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8820 - dice_coefficient: 0.3107 - iou_metric: 0.8011 - loss: 1.2328
# Epoch 13: val_dice_coefficient improved from 0.30083 to 0.31740, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 197ms/step - accuracy: 0.8820 - dice_coefficient: 0.3107 - iou_metric: 0.8011 - loss: 1.2327 - val_accuracy: 0.8855 - val_dice_coefficient: 0.3174 - val_iou_metric: 0.7978 - val_loss: 1.1509 - learning_rate: 1.0000e-04
# Epoch 14/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8833 - dice_coefficient: 0.3268 - iou_metric: 0.8033 - loss: 1.2005
# Epoch 14: val_dice_coefficient improved from 0.31740 to 0.33707, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.8834 - dice_coefficient: 0.3269 - iou_metric: 0.8034 - loss: 1.2004 - val_accuracy: 0.8832 - val_dice_coefficient: 0.3371 - val_iou_metric: 0.7931 - val_loss: 1.1118 - learning_rate: 1.0000e-04
# Epoch 15/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8924 - dice_coefficient: 0.3434 - iou_metric: 0.8157 - loss: 1.1632
# Epoch 15: val_dice_coefficient improved from 0.33707 to 0.35161, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.8924 - dice_coefficient: 0.3434 - iou_metric: 0.8157 - loss: 1.1632 - val_accuracy: 0.8894 - val_dice_coefficient: 0.3516 - val_iou_metric: 0.8024 - val_loss: 1.0869 - learning_rate: 1.0000e-04
# Epoch 16/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8971 - dice_coefficient: 0.3596 - iou_metric: 0.8236 - loss: 1.1268
# Epoch 16: val_dice_coefficient improved from 0.35161 to 0.36182, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 45s 234ms/step - accuracy: 0.8971 - dice_coefficient: 0.3597 - iou_metric: 0.8236 - loss: 1.1268 - val_accuracy: 0.8918 - val_dice_coefficient: 0.3618 - val_iou_metric: 0.8060 - val_loss: 1.0673 - learning_rate: 1.0000e-04
# Epoch 17/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8967 - dice_coefficient: 0.3688 - iou_metric: 0.8222 - loss: 1.1153
# Epoch 17: val_dice_coefficient improved from 0.36182 to 0.37614, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - accuracy: 0.8967 - dice_coefficient: 0.3688 - iou_metric: 0.8222 - loss: 1.1152 - val_accuracy: 0.8979 - val_dice_coefficient: 0.3761 - val_iou_metric: 0.8156 - val_loss: 1.0473 - learning_rate: 1.0000e-04
# Epoch 18/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8989 - dice_coefficient: 0.3751 - iou_metric: 0.8265 - loss: 1.1192
# Epoch 18: val_dice_coefficient improved from 0.37614 to 0.38260, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 236ms/step - accuracy: 0.8988 - dice_coefficient: 0.3752 - iou_metric: 0.8264 - loss: 1.1191 - val_accuracy: 0.8889 - val_dice_coefficient: 0.3826 - val_iou_metric: 0.8020 - val_loss: 1.0389 - learning_rate: 1.0000e-04
# Epoch 19/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9079 - dice_coefficient: 0.3943 - iou_metric: 0.8399 - loss: 1.0718
# Epoch 19: val_dice_coefficient improved from 0.38260 to 0.39098, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - accuracy: 0.9078 - dice_coefficient: 0.3943 - iou_metric: 0.8398 - loss: 1.0717 - val_accuracy: 0.8947 - val_dice_coefficient: 0.3910 - val_iou_metric: 0.8114 - val_loss: 1.0209 - learning_rate: 1.0000e-04
# Epoch 20/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9063 - dice_coefficient: 0.4000 - iou_metric: 0.8379 - loss: 1.0659
# Epoch 20: val_dice_coefficient improved from 0.39098 to 0.40666, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9063 - dice_coefficient: 0.4000 - iou_metric: 0.8379 - loss: 1.0658 - val_accuracy: 0.9068 - val_dice_coefficient: 0.4067 - val_iou_metric: 0.8302 - val_loss: 0.9947 - learning_rate: 1.0000e-04
# Epoch 21/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9082 - dice_coefficient: 0.4116 - iou_metric: 0.8405 - loss: 1.0420
# Epoch 21: val_dice_coefficient improved from 0.40666 to 0.41042, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 226ms/step - accuracy: 0.9082 - dice_coefficient: 0.4117 - iou_metric: 0.8405 - loss: 1.0419 - val_accuracy: 0.9051 - val_dice_coefficient: 0.4104 - val_iou_metric: 0.8262 - val_loss: 0.9888 - learning_rate: 1.0000e-04
# Epoch 22/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9133 - dice_coefficient: 0.4268 - iou_metric: 0.8487 - loss: 1.0135
# Epoch 22: val_dice_coefficient improved from 0.41042 to 0.42392, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 233ms/step - accuracy: 0.9133 - dice_coefficient: 0.4268 - iou_metric: 0.8487 - loss: 1.0136 - val_accuracy: 0.9180 - val_dice_coefficient: 0.4239 - val_iou_metric: 0.8482 - val_loss: 0.9710 - learning_rate: 1.0000e-04
# Epoch 23/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9067 - dice_coefficient: 0.4297 - iou_metric: 0.8393 - loss: 1.0205
# Epoch 23: val_dice_coefficient did not improve from 0.42392
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.9067 - dice_coefficient: 0.4297 - iou_metric: 0.8394 - loss: 1.0205 - val_accuracy: 0.9049 - val_dice_coefficient: 0.4216 - val_iou_metric: 0.8259 - val_loss: 0.9692 - learning_rate: 1.0000e-04
# Epoch 24/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9156 - dice_coefficient: 0.4397 - iou_metric: 0.8526 - loss: 0.9928
# Epoch 24: val_dice_coefficient improved from 0.42392 to 0.42423, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 226ms/step - accuracy: 0.9156 - dice_coefficient: 0.4397 - iou_metric: 0.8526 - loss: 0.9928 - val_accuracy: 0.9023 - val_dice_coefficient: 0.4242 - val_iou_metric: 0.8226 - val_loss: 0.9779 - learning_rate: 1.0000e-04
# Epoch 25/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9162 - dice_coefficient: 0.4461 - iou_metric: 0.8538 - loss: 0.9864
# Epoch 25: val_dice_coefficient improved from 0.42423 to 0.43723, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 227ms/step - accuracy: 0.9162 - dice_coefficient: 0.4461 - iou_metric: 0.8538 - loss: 0.9863 - val_accuracy: 0.9125 - val_dice_coefficient: 0.4372 - val_iou_metric: 0.8393 - val_loss: 0.9430 - learning_rate: 1.0000e-04
# Epoch 26/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9142 - dice_coefficient: 0.4518 - iou_metric: 0.8503 - loss: 0.9704
# Epoch 26: val_dice_coefficient improved from 0.43723 to 0.43850, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 24s 226ms/step - accuracy: 0.9142 - dice_coefficient: 0.4518 - iou_metric: 0.8504 - loss: 0.9703 - val_accuracy: 0.9089 - val_dice_coefficient: 0.4385 - val_iou_metric: 0.8330 - val_loss: 0.9453 - learning_rate: 1.0000e-04
# Epoch 27/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9199 - dice_coefficient: 0.4639 - iou_metric: 0.8594 - loss: 0.9601
# Epoch 27: val_dice_coefficient improved from 0.43850 to 0.44667, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 227ms/step - accuracy: 0.9199 - dice_coefficient: 0.4640 - iou_metric: 0.8594 - loss: 0.9600 - val_accuracy: 0.9172 - val_dice_coefficient: 0.4467 - val_iou_metric: 0.8465 - val_loss: 0.9279 - learning_rate: 1.0000e-04
# Epoch 28/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9219 - dice_coefficient: 0.4676 - iou_metric: 0.8618 - loss: 0.9498
# Epoch 28: val_dice_coefficient improved from 0.44667 to 0.45087, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 229ms/step - accuracy: 0.9219 - dice_coefficient: 0.4677 - iou_metric: 0.8618 - loss: 0.9497 - val_accuracy: 0.9181 - val_dice_coefficient: 0.4509 - val_iou_metric: 0.8485 - val_loss: 0.9165 - learning_rate: 1.0000e-04
# Epoch 29/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9230 - dice_coefficient: 0.4753 - iou_metric: 0.8635 - loss: 0.9394
# Epoch 29: val_dice_coefficient improved from 0.45087 to 0.45847, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 228ms/step - accuracy: 0.9230 - dice_coefficient: 0.4753 - iou_metric: 0.8635 - loss: 0.9395 - val_accuracy: 0.9220 - val_dice_coefficient: 0.4585 - val_iou_metric: 0.8537 - val_loss: 0.9070 - learning_rate: 1.0000e-04
# Epoch 30/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9223 - dice_coefficient: 0.4770 - iou_metric: 0.8631 - loss: 0.9376
# Epoch 30: val_dice_coefficient improved from 0.45847 to 0.46704, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 226ms/step - accuracy: 0.9223 - dice_coefficient: 0.4770 - iou_metric: 0.8631 - loss: 0.9376 - val_accuracy: 0.9268 - val_dice_coefficient: 0.4670 - val_iou_metric: 0.8648 - val_loss: 0.8957 - learning_rate: 1.0000e-04
# Epoch 31/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9242 - dice_coefficient: 0.4850 - iou_metric: 0.8652 - loss: 0.9266
# Epoch 31: val_dice_coefficient improved from 0.46704 to 0.47342, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 228ms/step - accuracy: 0.9242 - dice_coefficient: 0.4851 - iou_metric: 0.8652 - loss: 0.9264 - val_accuracy: 0.9315 - val_dice_coefficient: 0.4734 - val_iou_metric: 0.8739 - val_loss: 0.8802 - learning_rate: 1.0000e-04
# Epoch 32/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9310 - dice_coefficient: 0.5020 - iou_metric: 0.8761 - loss: 0.8917
# Epoch 32: val_dice_coefficient improved from 0.47342 to 0.48690, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 227ms/step - accuracy: 0.9310 - dice_coefficient: 0.5020 - iou_metric: 0.8761 - loss: 0.8917 - val_accuracy: 0.9360 - val_dice_coefficient: 0.4869 - val_iou_metric: 0.8820 - val_loss: 0.8552 - learning_rate: 1.0000e-04
# Epoch 33/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9299 - dice_coefficient: 0.5070 - iou_metric: 0.8736 - loss: 0.8857
# Epoch 33: val_dice_coefficient improved from 0.48690 to 0.50264, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - accuracy: 0.9299 - dice_coefficient: 0.5071 - iou_metric: 0.8736 - loss: 0.8856 - val_accuracy: 0.9366 - val_dice_coefficient: 0.5026 - val_iou_metric: 0.8822 - val_loss: 0.8273 - learning_rate: 1.0000e-04
# Epoch 34/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9329 - dice_coefficient: 0.5221 - iou_metric: 0.8787 - loss: 0.8572
# Epoch 34: val_dice_coefficient improved from 0.50264 to 0.52290, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - accuracy: 0.9329 - dice_coefficient: 0.5221 - iou_metric: 0.8787 - loss: 0.8573 - val_accuracy: 0.9423 - val_dice_coefficient: 0.5229 - val_iou_metric: 0.8915 - val_loss: 0.8019 - learning_rate: 1.0000e-04
# Epoch 35/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9322 - dice_coefficient: 0.5382 - iou_metric: 0.8772 - loss: 0.8326
# Epoch 35: val_dice_coefficient improved from 0.52290 to 0.53521, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 234ms/step - accuracy: 0.9322 - dice_coefficient: 0.5382 - iou_metric: 0.8772 - loss: 0.8326 - val_accuracy: 0.9348 - val_dice_coefficient: 0.5352 - val_iou_metric: 0.8787 - val_loss: 0.7840 - learning_rate: 1.0000e-04
# Epoch 36/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9340 - dice_coefficient: 0.5396 - iou_metric: 0.8806 - loss: 0.8361
# Epoch 36: val_dice_coefficient improved from 0.53521 to 0.54510, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 223ms/step - accuracy: 0.9340 - dice_coefficient: 0.5396 - iou_metric: 0.8806 - loss: 0.8361 - val_accuracy: 0.9396 - val_dice_coefficient: 0.5451 - val_iou_metric: 0.8865 - val_loss: 0.7704 - learning_rate: 1.0000e-04
# Epoch 37/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9353 - dice_coefficient: 0.5602 - iou_metric: 0.8825 - loss: 0.8082
# Epoch 37: val_dice_coefficient improved from 0.54510 to 0.55740, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - accuracy: 0.9353 - dice_coefficient: 0.5602 - iou_metric: 0.8825 - loss: 0.8082 - val_accuracy: 0.9398 - val_dice_coefficient: 0.5574 - val_iou_metric: 0.8877 - val_loss: 0.7492 - learning_rate: 1.0000e-04
# Epoch 38/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9360 - dice_coefficient: 0.5605 - iou_metric: 0.8837 - loss: 0.8017
# Epoch 38: val_dice_coefficient improved from 0.55740 to 0.55956, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 244ms/step - accuracy: 0.9360 - dice_coefficient: 0.5605 - iou_metric: 0.8837 - loss: 0.8017 - val_accuracy: 0.9394 - val_dice_coefficient: 0.5596 - val_iou_metric: 0.8861 - val_loss: 0.7451 - learning_rate: 1.0000e-04
# Epoch 39/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9362 - dice_coefficient: 0.5662 - iou_metric: 0.8835 - loss: 0.8119
# Epoch 39: val_dice_coefficient improved from 0.55956 to 0.56752, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 238ms/step - accuracy: 0.9362 - dice_coefficient: 0.5662 - iou_metric: 0.8835 - loss: 0.8118 - val_accuracy: 0.9411 - val_dice_coefficient: 0.5675 - val_iou_metric: 0.8902 - val_loss: 0.7322 - learning_rate: 1.0000e-04
# Epoch 40/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9365 - dice_coefficient: 0.5727 - iou_metric: 0.8845 - loss: 0.7927
# Epoch 40: val_dice_coefficient improved from 0.56752 to 0.57542, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 28s 257ms/step - accuracy: 0.9365 - dice_coefficient: 0.5728 - iou_metric: 0.8845 - loss: 0.7926 - val_accuracy: 0.9388 - val_dice_coefficient: 0.5754 - val_iou_metric: 0.8857 - val_loss: 0.7243 - learning_rate: 1.0000e-04
# Epoch 41/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9391 - dice_coefficient: 0.5840 - iou_metric: 0.8889 - loss: 0.7701
# Epoch 41: val_dice_coefficient improved from 0.57542 to 0.58624, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 227ms/step - accuracy: 0.9391 - dice_coefficient: 0.5841 - iou_metric: 0.8889 - loss: 0.7700 - val_accuracy: 0.9442 - val_dice_coefficient: 0.5862 - val_iou_metric: 0.8955 - val_loss: 0.7051 - learning_rate: 1.0000e-04
# Epoch 42/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9392 - dice_coefficient: 0.5910 - iou_metric: 0.8892 - loss: 0.7500
# Epoch 42: val_dice_coefficient improved from 0.58624 to 0.58816, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 228ms/step - accuracy: 0.9392 - dice_coefficient: 0.5909 - iou_metric: 0.8892 - loss: 0.7501 - val_accuracy: 0.9427 - val_dice_coefficient: 0.5882 - val_iou_metric: 0.8918 - val_loss: 0.7127 - learning_rate: 1.0000e-04
# Epoch 43/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9377 - dice_coefficient: 0.5974 - iou_metric: 0.8866 - loss: 0.7495
# Epoch 43: val_dice_coefficient improved from 0.58816 to 0.59886, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 220ms/step - accuracy: 0.9377 - dice_coefficient: 0.5974 - iou_metric: 0.8866 - loss: 0.7494 - val_accuracy: 0.9439 - val_dice_coefficient: 0.5989 - val_iou_metric: 0.8950 - val_loss: 0.6851 - learning_rate: 1.0000e-04
# Epoch 44/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9425 - dice_coefficient: 0.6011 - iou_metric: 0.8945 - loss: 0.7378
# Epoch 44: val_dice_coefficient improved from 0.59886 to 0.60697, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 230ms/step - accuracy: 0.9425 - dice_coefficient: 0.6011 - iou_metric: 0.8945 - loss: 0.7378 - val_accuracy: 0.9429 - val_dice_coefficient: 0.6070 - val_iou_metric: 0.8936 - val_loss: 0.6766 - learning_rate: 1.0000e-04
# Epoch 45/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9420 - dice_coefficient: 0.6121 - iou_metric: 0.8939 - loss: 0.7203
# Epoch 45: val_dice_coefficient improved from 0.60697 to 0.61661, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 227ms/step - accuracy: 0.9420 - dice_coefficient: 0.6121 - iou_metric: 0.8938 - loss: 0.7204 - val_accuracy: 0.9481 - val_dice_coefficient: 0.6166 - val_iou_metric: 0.9032 - val_loss: 0.6615 - learning_rate: 1.0000e-04
# Epoch 46/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9395 - dice_coefficient: 0.6109 - iou_metric: 0.8899 - loss: 0.7330
# Epoch 46: val_dice_coefficient did not improve from 0.61661
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 173ms/step - accuracy: 0.9395 - dice_coefficient: 0.6109 - iou_metric: 0.8899 - loss: 0.7329 - val_accuracy: 0.9437 - val_dice_coefficient: 0.6166 - val_iou_metric: 0.8946 - val_loss: 0.6619 - learning_rate: 1.0000e-04
# Epoch 47/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9424 - dice_coefficient: 0.6186 - iou_metric: 0.8945 - loss: 0.7095
# Epoch 47: val_dice_coefficient improved from 0.61661 to 0.62693, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.9424 - dice_coefficient: 0.6186 - iou_metric: 0.8944 - loss: 0.7094 - val_accuracy: 0.9465 - val_dice_coefficient: 0.6269 - val_iou_metric: 0.8999 - val_loss: 0.6431 - learning_rate: 1.0000e-04
# Epoch 48/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9418 - dice_coefficient: 0.6291 - iou_metric: 0.8935 - loss: 0.7008
# Epoch 48: val_dice_coefficient improved from 0.62693 to 0.63573, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 38s 224ms/step - accuracy: 0.9418 - dice_coefficient: 0.6290 - iou_metric: 0.8935 - loss: 0.7009 - val_accuracy: 0.9491 - val_dice_coefficient: 0.6357 - val_iou_metric: 0.9053 - val_loss: 0.6357 - learning_rate: 1.0000e-04
# Epoch 49/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9399 - dice_coefficient: 0.6233 - iou_metric: 0.8907 - loss: 0.7159
# Epoch 49: val_dice_coefficient did not improve from 0.63573
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 176ms/step - accuracy: 0.9399 - dice_coefficient: 0.6233 - iou_metric: 0.8908 - loss: 0.7159 - val_accuracy: 0.9439 - val_dice_coefficient: 0.6238 - val_iou_metric: 0.8952 - val_loss: 0.6557 - learning_rate: 1.0000e-04
# Epoch 50/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9449 - dice_coefficient: 0.6440 - iou_metric: 0.8985 - loss: 0.6818
# Epoch 50: val_dice_coefficient did not improve from 0.63573
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.9449 - dice_coefficient: 0.6440 - iou_metric: 0.8985 - loss: 0.6818 - val_accuracy: 0.9446 - val_dice_coefficient: 0.6328 - val_iou_metric: 0.8957 - val_loss: 0.6387 - learning_rate: 1.0000e-04
# Epoch 51/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9458 - dice_coefficient: 0.6495 - iou_metric: 0.9001 - loss: 0.6606
# Epoch 51: val_dice_coefficient improved from 0.63573 to 0.64044, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 198ms/step - accuracy: 0.9458 - dice_coefficient: 0.6495 - iou_metric: 0.9001 - loss: 0.6607 - val_accuracy: 0.9469 - val_dice_coefficient: 0.6404 - val_iou_metric: 0.9008 - val_loss: 0.6266 - learning_rate: 1.0000e-04
# Epoch 52/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9451 - dice_coefficient: 0.6397 - iou_metric: 0.8991 - loss: 0.6801
# Epoch 52: val_dice_coefficient improved from 0.64044 to 0.64052, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 229ms/step - accuracy: 0.9451 - dice_coefficient: 0.6397 - iou_metric: 0.8991 - loss: 0.6800 - val_accuracy: 0.9451 - val_dice_coefficient: 0.6405 - val_iou_metric: 0.8965 - val_loss: 0.6311 - learning_rate: 1.0000e-04
# Epoch 53/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9469 - dice_coefficient: 0.6538 - iou_metric: 0.9022 - loss: 0.6573
# Epoch 53: val_dice_coefficient improved from 0.64052 to 0.64070, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 27s 244ms/step - accuracy: 0.9469 - dice_coefficient: 0.6539 - iou_metric: 0.9022 - loss: 0.6573 - val_accuracy: 0.9484 - val_dice_coefficient: 0.6407 - val_iou_metric: 0.9034 - val_loss: 0.6315 - learning_rate: 1.0000e-04
# Epoch 54/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9476 - dice_coefficient: 0.6582 - iou_metric: 0.9035 - loss: 0.6544
# Epoch 54: val_dice_coefficient did not improve from 0.64070
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.9476 - dice_coefficient: 0.6581 - iou_metric: 0.9035 - loss: 0.6546 - val_accuracy: 0.9434 - val_dice_coefficient: 0.6359 - val_iou_metric: 0.8948 - val_loss: 0.6451 - learning_rate: 1.0000e-04
# Epoch 55/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9487 - dice_coefficient: 0.6660 - iou_metric: 0.9050 - loss: 0.6288
# Epoch 55: val_dice_coefficient improved from 0.64070 to 0.64434, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 226ms/step - accuracy: 0.9487 - dice_coefficient: 0.6659 - iou_metric: 0.9049 - loss: 0.6289 - val_accuracy: 0.9507 - val_dice_coefficient: 0.6443 - val_iou_metric: 0.9072 - val_loss: 0.6229 - learning_rate: 1.0000e-04
# Epoch 56/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9474 - dice_coefficient: 0.6623 - iou_metric: 0.9026 - loss: 0.6379
# Epoch 56: val_dice_coefficient improved from 0.64434 to 0.65376, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 237ms/step - accuracy: 0.9474 - dice_coefficient: 0.6623 - iou_metric: 0.9026 - loss: 0.6381 - val_accuracy: 0.9485 - val_dice_coefficient: 0.6538 - val_iou_metric: 0.9025 - val_loss: 0.6033 - learning_rate: 1.0000e-04
# Epoch 57/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9480 - dice_coefficient: 0.6758 - iou_metric: 0.9038 - loss: 0.6176
# Epoch 57: val_dice_coefficient improved from 0.65376 to 0.65977, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 231ms/step - accuracy: 0.9480 - dice_coefficient: 0.6758 - iou_metric: 0.9038 - loss: 0.6178 - val_accuracy: 0.9519 - val_dice_coefficient: 0.6598 - val_iou_metric: 0.9086 - val_loss: 0.5962 - learning_rate: 1.0000e-04
# Epoch 58/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9473 - dice_coefficient: 0.6715 - iou_metric: 0.9029 - loss: 0.6323
# Epoch 58: val_dice_coefficient improved from 0.65977 to 0.66101, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 227ms/step - accuracy: 0.9473 - dice_coefficient: 0.6715 - iou_metric: 0.9029 - loss: 0.6322 - val_accuracy: 0.9501 - val_dice_coefficient: 0.6610 - val_iou_metric: 0.9055 - val_loss: 0.5945 - learning_rate: 1.0000e-04
# Epoch 59/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9496 - dice_coefficient: 0.6804 - iou_metric: 0.9069 - loss: 0.6058
# Epoch 59: val_dice_coefficient did not improve from 0.66101
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 35s 175ms/step - accuracy: 0.9496 - dice_coefficient: 0.6804 - iou_metric: 0.9069 - loss: 0.6060 - val_accuracy: 0.9513 - val_dice_coefficient: 0.6573 - val_iou_metric: 0.9085 - val_loss: 0.6055 - learning_rate: 1.0000e-04
# Epoch 60/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9484 - dice_coefficient: 0.6562 - iou_metric: 0.9047 - loss: 0.6687
# Epoch 60: val_dice_coefficient improved from 0.66101 to 0.66646, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 30s 276ms/step - accuracy: 0.9484 - dice_coefficient: 0.6562 - iou_metric: 0.9047 - loss: 0.6686 - val_accuracy: 0.9510 - val_dice_coefficient: 0.6665 - val_iou_metric: 0.9080 - val_loss: 0.5891 - learning_rate: 1.0000e-04
# Epoch 61/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9493 - dice_coefficient: 0.6729 - iou_metric: 0.9062 - loss: 0.6306
# Epoch 61: val_dice_coefficient did not improve from 0.66646
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 30s 174ms/step - accuracy: 0.9493 - dice_coefficient: 0.6730 - iou_metric: 0.9062 - loss: 0.6305 - val_accuracy: 0.9520 - val_dice_coefficient: 0.6628 - val_iou_metric: 0.9096 - val_loss: 0.5938 - learning_rate: 1.0000e-04
# Epoch 62/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9508 - dice_coefficient: 0.6857 - iou_metric: 0.9091 - loss: 0.5979
# Epoch 62: val_dice_coefficient did not improve from 0.66646
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 20s 173ms/step - accuracy: 0.9508 - dice_coefficient: 0.6857 - iou_metric: 0.9091 - loss: 0.5980 - val_accuracy: 0.9489 - val_dice_coefficient: 0.6609 - val_iou_metric: 0.9032 - val_loss: 0.6026 - learning_rate: 1.0000e-04
# Epoch 63/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9506 - dice_coefficient: 0.6920 - iou_metric: 0.9083 - loss: 0.5928
# Epoch 63: val_dice_coefficient did not improve from 0.66646
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - accuracy: 0.9506 - dice_coefficient: 0.6919 - iou_metric: 0.9083 - loss: 0.5929 - val_accuracy: 0.9513 - val_dice_coefficient: 0.6659 - val_iou_metric: 0.9059 - val_loss: 0.5884 - learning_rate: 1.0000e-04
# Epoch 64/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9488 - dice_coefficient: 0.6928 - iou_metric: 0.9054 - loss: 0.5918
# Epoch 64: val_dice_coefficient did not improve from 0.66646
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9488 - dice_coefficient: 0.6927 - iou_metric: 0.9054 - loss: 0.5919 - val_accuracy: 0.9489 - val_dice_coefficient: 0.6637 - val_iou_metric: 0.9025 - val_loss: 0.5909 - learning_rate: 1.0000e-04
# Epoch 65/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9525 - dice_coefficient: 0.7022 - iou_metric: 0.9117 - loss: 0.5693
# Epoch 65: val_dice_coefficient improved from 0.66646 to 0.66758, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.9525 - dice_coefficient: 0.7021 - iou_metric: 0.9117 - loss: 0.5695 - val_accuracy: 0.9485 - val_dice_coefficient: 0.6676 - val_iou_metric: 0.9017 - val_loss: 0.5849 - learning_rate: 1.0000e-04
# Epoch 66/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9510 - dice_coefficient: 0.7050 - iou_metric: 0.9093 - loss: 0.5724
# Epoch 66: val_dice_coefficient improved from 0.66758 to 0.67770, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9510 - dice_coefficient: 0.7049 - iou_metric: 0.9093 - loss: 0.5724 - val_accuracy: 0.9545 - val_dice_coefficient: 0.6777 - val_iou_metric: 0.9135 - val_loss: 0.5756 - learning_rate: 1.0000e-04
# Epoch 67/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9500 - dice_coefficient: 0.6950 - iou_metric: 0.9074 - loss: 0.5918
# Epoch 67: val_dice_coefficient did not improve from 0.67770
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 177ms/step - accuracy: 0.9500 - dice_coefficient: 0.6950 - iou_metric: 0.9074 - loss: 0.5917 - val_accuracy: 0.9502 - val_dice_coefficient: 0.6725 - val_iou_metric: 0.9045 - val_loss: 0.5808 - learning_rate: 1.0000e-04
# Epoch 68/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9504 - dice_coefficient: 0.6976 - iou_metric: 0.9083 - loss: 0.5917
# Epoch 68: val_dice_coefficient did not improve from 0.67770
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 182ms/step - accuracy: 0.9504 - dice_coefficient: 0.6976 - iou_metric: 0.9083 - loss: 0.5915 - val_accuracy: 0.9487 - val_dice_coefficient: 0.6681 - val_iou_metric: 0.9013 - val_loss: 0.5878 - learning_rate: 1.0000e-04
# Epoch 69/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9509 - dice_coefficient: 0.7071 - iou_metric: 0.9088 - loss: 0.5782
# Epoch 69: val_dice_coefficient did not improve from 0.67770
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 171ms/step - accuracy: 0.9509 - dice_coefficient: 0.7070 - iou_metric: 0.9088 - loss: 0.5782 - val_accuracy: 0.9542 - val_dice_coefficient: 0.6753 - val_iou_metric: 0.9127 - val_loss: 0.5802 - learning_rate: 1.0000e-04
# Epoch 70/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9527 - dice_coefficient: 0.7113 - iou_metric: 0.9120 - loss: 0.5540
# Epoch 70: val_dice_coefficient improved from 0.67770 to 0.68032, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 245ms/step - accuracy: 0.9527 - dice_coefficient: 0.7113 - iou_metric: 0.9119 - loss: 0.5542 - val_accuracy: 0.9560 - val_dice_coefficient: 0.6803 - val_iou_metric: 0.9169 - val_loss: 0.5858 - learning_rate: 1.0000e-04
# Epoch 71/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9511 - dice_coefficient: 0.6946 - iou_metric: 0.9092 - loss: 0.5799
# Epoch 71: val_dice_coefficient did not improve from 0.68032
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.9511 - dice_coefficient: 0.6947 - iou_metric: 0.9092 - loss: 0.5799 - val_accuracy: 0.9523 - val_dice_coefficient: 0.6763 - val_iou_metric: 0.9091 - val_loss: 0.5762 - learning_rate: 1.0000e-04
# Epoch 72/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9511 - dice_coefficient: 0.7150 - iou_metric: 0.9093 - loss: 0.5576
# Epoch 72: val_dice_coefficient did not improve from 0.68032
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 178ms/step - accuracy: 0.9511 - dice_coefficient: 0.7150 - iou_metric: 0.9093 - loss: 0.5576 - val_accuracy: 0.9528 - val_dice_coefficient: 0.6778 - val_iou_metric: 0.9103 - val_loss: 0.5744 - learning_rate: 1.0000e-04
# Epoch 73/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9544 - dice_coefficient: 0.7188 - iou_metric: 0.9150 - loss: 0.5447
# Epoch 73: val_dice_coefficient improved from 0.68032 to 0.68736, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 29s 274ms/step - accuracy: 0.9543 - dice_coefficient: 0.7187 - iou_metric: 0.9149 - loss: 0.5449 - val_accuracy: 0.9536 - val_dice_coefficient: 0.6874 - val_iou_metric: 0.9129 - val_loss: 0.5580 - learning_rate: 1.0000e-04
# Epoch 74/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9531 - dice_coefficient: 0.7134 - iou_metric: 0.9131 - loss: 0.5527
# Epoch 74: val_dice_coefficient did not improve from 0.68736
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9531 - dice_coefficient: 0.7134 - iou_metric: 0.9131 - loss: 0.5526 - val_accuracy: 0.9513 - val_dice_coefficient: 0.6767 - val_iou_metric: 0.9068 - val_loss: 0.5709 - learning_rate: 1.0000e-04
# Epoch 75/75
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9546 - dice_coefficient: 0.7209 - iou_metric: 0.9155 - loss: 0.5377
# Epoch 75: val_dice_coefficient improved from 0.68736 to 0.69154, saving model to efficient_v2b2_weed_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 228ms/step - accuracy: 0.9546 - dice_coefficient: 0.7209 - iou_metric: 0.9154 - loss: 0.5377 - val_accuracy: 0.9565 - val_dice_coefficient: 0.6915 - val_iou_metric: 0.9174 - val_loss: 0.5507 - learning_rate: 1.0000e-04
#
# Visualizando predicciones del mejor modelo...
# Visualizando 4 muestras del conjunto de validación...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'efficient_v2b2_weed_model.keras'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9565 - dice_coefficient: 0.6867 - iou_metric: 0.9186 - loss: 0.5940
# Pérdida en Validación: 0.5507
# Coeficiente de Dice en Validación: 0.6915
# IoU en Validación: 0.9174
# Accuracy en Validación: 0.9565
#
# Calculando IoU por clase...
# IoU para Fondo: 0.9435
# IoU para Lengua de Vaca: 0.8693
# IoU para Diente de León: 0.8872
# IoU para Kikuyo: 0.8709
# IoU para Otras: 0.6379
# IoU para Papa: 0.8699
