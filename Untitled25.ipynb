# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6   # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()

        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)

        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))

        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])

        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

# CORREGIDO: Se ajusta el nombre de la capa para la escala 16x16
def create_efficient_backbone(input_shape):
    """Crea el backbone usando EfficientNetV2S y extrae los mapas de características correctos."""
    base_model = tf.keras.applications.EfficientNetV2S(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True

    # Nombres de capa DEFINITIVOS para EfficientNetV2S con entrada 128x128
    layer_names = [
        'block1a_project_activation', # Salida: (N, 64, 64, 24)
        'block2c_add',                # Salida: (N, 32, 32, 48)
        'block3c_add',                # Salida: (N, 16, 16, 64) <-- Capa corregida para 16x16
        'block6a_expand_activation',  # Salida: (N, 8, 8, 160)
        'top_activation'              # Salida: (N, 4, 4, 1280)
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2S_Backbone_Corrected_v2')


# MODIFICADO: Se ajusta el decodificador para las nuevas dimensiones de canal y se simplifica la lógica
def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)

    # El orden aquí DEBE coincidir con el orden en `layer_names`
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)

    # --- PRINTS DE DEPURACIÓN (Actualizados para EfficientNetV2S) ---
    print(f"\n--- Formas de Características del Backbone (EfficientNetV2S) ---")
    print(f"feat1_out (64x64): {feat1_out.shape}")  # Esperado: (None, 64, 64, 48)
    print(f"feat2_out (32x32): {feat2_out.shape}")  # Esperado: (None, 32, 32, 64)
    print(f"feat3_out (16x16): {feat3_out.shape}")  # Esperado: (None, 16, 16, 128)
    print(f"feat4_out (8x8):   {feat4_out.shape}")  # Esperado: (None, 8, 8, 160)
    print(f"feat5_out (4x4):   {feat5_out.shape}")  # Esperado: (None, 4, 4, 1280)
    print(f"----------------------------------------------------------\n")

    # --- Encoder/Puente ---
    deep_features = feat5_out # Entrada para ASPP: (N, 4, 4, 1280)
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features) # (N, 4, 4, 192)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features) # (N, 4, 4, 192)

    # --- Ruta del Decodificador ---

    # UP1: De (4,4) a (8,8)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)

    # Concat con feat4_out (8x8, 160 canales)
    # Procesar feat4 para que coincida con los canales del decodificador (96)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)

    # PUNTO DE CONCATENACIÓN 1 (8x8)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)

    # UP2: De (8,8) a (16,16)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)

    # Concat con feat3_out (16x16, 128 canales)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)

    # PUNTO DE CONCATENACIÓN 2 (16x16)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)

    # UP3: De (16,16) a (32,32)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)

    # Concat con feat2_out (32x32, 64 canales)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)

    # PUNTO DE CONCATENACIÓN 3 (32x32)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)

    # UP4: De (32,32) a (64,64)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)

    # Concat con feat1_out (64x64, 48 canales)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)

    # PUNTO DE CONCATENACIÓN 4 (64x64)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)

    # Upsampling Final a la resolución de la imagen de entrada (128x128)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    print(f"Forma de la salida final: {outputs.shape}") # Esperado: (None, 128, 128, 6)

    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_S')
    return model

# --- Métricas y Funciones de Pérdida (sin cambios) ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos (sin cambios) ---
def load_and_preprocess_data(train_img_path, train_msk_path, val_img_path, val_msk_path):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5:
            k = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
            image = tf.image.rot90(image, k)
            mask = tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image) # Es el mismo preprocesamiento para todas las variantes de EfficientNetV2
        return image, mask

    train_image_paths = sorted(glob(os.path.join(train_img_path, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(train_msk_path, '*.png')))
    val_image_paths = sorted(glob(os.path.join(val_img_path, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(val_msk_path, '*.png')))

    if not train_image_paths or not train_mask_paths or not val_image_paths or not val_mask_paths:
        raise FileNotFoundError("Una o más rutas de datos no encontraron archivos. Verifica las rutas.")

    print(f"Se encontraron {len(train_image_paths)} imágenes de entrenamiento y {len(train_mask_paths)} máscaras de entrenamiento")
    print(f"Se encontraron {len(val_image_paths)} imágenes de validación y {len(val_mask_paths)} máscaras de validación")

    train_image_ds = tf.data.Dataset.from_tensor_slices(train_image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    train_mask_ds = tf.data.Dataset.from_tensor_slices(train_mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = tf.data.Dataset.zip((train_image_ds, train_mask_ds))
    train_dataset = train_dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_image_ds = tf.data.Dataset.from_tensor_slices(val_image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    val_mask_ds = tf.data.Dataset.from_tensor_slices(val_mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    val_dataset = tf.data.Dataset.zip((val_image_ds, val_mask_ds))
    val_dataset = val_dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    val_dataset = val_dataset.cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_S.keras'):
    model = create_weed_detection_model()
    model.summary()
    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-5)
    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path, monitor='val_dice_coefficient', save_best_only=True, mode='max', verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient', patience=50, mode='max', restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1
        ),
    ]
    print(f"Iniciando entrenamiento por {EPOCHS} épocas...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    print(f"Visualizando {num_samples} muestras del conjunto de validación...")
    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)
        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))
        for i in range(min(num_samples, images.shape[0])):
            original_image = images[i]
            # Desnormalizar la imagen para visualización
            img_min = tf.reduce_min(original_image)
            img_max = tf.reduce_max(original_image)
            if tf.math.equal(img_max, img_min):
                original_image = tf.cast(original_image - img_min, tf.uint8)
            else:
                original_image = (original_image - img_min) / (img_max - img_min) * 255
            original_image = tf.cast(original_image, tf.uint8)

            axes[i, 0].imshow(original_image)
            axes[i, 0].set_title('Imagen Original')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('Máscara Real')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Máscara Predicha')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

if __name__ == "__main__":
    for path in [TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH]:
        if not os.path.exists(path):
            print(f"Error: La ruta de datos NO existe: {path}")
            print(f"Creando directorio: {path}")
            os.makedirs(path, exist_ok=True)

    print("Creando datasets...")
    try:
        train_ds, val_ds = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH)
        if not any(True for _ in train_ds.take(1)):
            print("Error: El dataset de entrenamiento está vacío. Asegúrate de que haya imágenes y máscaras en las rutas correctas.")
            exit()
    except FileNotFoundError as e:
        print(f"Error: {e}")
        exit()

    print("Entrenando modelo...")
    model_save_path = 'efficient_weed_model_S.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print(f"¡Entrenamiento completado! El mejor modelo se guardó como '{model_save_path}'")

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)')
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)')
    plt.title('Coeficiente de Dice sobre Épocas')
    plt.xlabel('Época')
    plt.ylabel('Coeficiente de Dice')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)')
    plt.plot(history.history['val_loss'], label='Loss (Validation)')
    plt.title('Pérdida sobre Épocas')
    plt.xlabel('Época')
    plt.ylabel('Pérdida')
    plt.legend()
    plt.grid(True)
    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Pérdida en Validación: {final_metrics[0]:.4f}")
    print(f"Coeficiente de Dice en Validación: {final_metrics[1]:.4f}")
    print(f"IoU en Validación: {final_metrics[2]:.4f}")
    print(f"Accuracy en Validación: {final_metrics[3]:.4f}")

    iou_per_class_values = []
    print("Calculando IoU por clase...")
    for images_batch, masks_batch in val_ds:
        predictions_batch = model.predict(images_batch, verbose=0)
        iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

    iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()

    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets...
# Se encontraron 1680 imágenes de entrenamiento y 1680 máscaras de entrenamiento
# Se encontraron 210 imágenes de validación y 210 máscaras de validación
# Entrenando modelo...
#
# --- Formas de Características del Backbone (EfficientNetV2S) ---
# feat1_out (64x64): (None, 64, 64, 24)
# feat2_out (32x32): (None, 32, 32, 48)
# feat3_out (16x16): (None, 16, 16, 64)
# feat4_out (8x8):   (None, 8, 8, 960)
# feat5_out (4x4):   (None, 4, 4, 1280)
# ----------------------------------------------------------
#
# Forma de la salida final: (None, 128, 128, 6)
# Model: "EfficientWeedDetectionModel_S"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2S_Ba… │ [(None, 64, 64,   │ 20,331,360 │ input_layer_4[0]… │
# │ (Functional)        │ 24), (None, 32,   │            │                   │
# │                     │ 32, 48), (None,   │            │                   │
# │                     │ 16, 16, 64),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 960), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module_2       │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2S_… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module_2[0]… │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 96)  │     92,160 │ EfficientNetV2S_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 8, 8, 96)  │          0 │ re_lu_34[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 8, 8, 192) │          0 │ dropout_11[0][0], │
# │ (Concatenate)       │                   │            │ re_lu_35[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 8, 8, 96)  │     20,160 │ concatenate_11[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 8, 8, 96)  │          0 │ re_lu_36[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 16, 16,    │     36,864 │ dropout_12[0][0]  │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 16, 16,    │      6,144 │ EfficientNetV2S_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 16, 16,    │          0 │ re_lu_37[0][0]    │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 16, 16,    │          0 │ dropout_13[0][0], │
# │ (Concatenate)       │ 192)              │            │ re_lu_38[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 16, 16,    │     20,160 │ concatenate_12[0… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 16, 16,    │          0 │ re_lu_39[0][0]    │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 32, 32,    │     18,432 │ dropout_14[0][0]  │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 32, 32,    │      2,304 │ EfficientNetV2S_… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 32, 32,    │          0 │ re_lu_40[0][0]    │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 32, 32,    │          0 │ dropout_15[0][0], │
# │ (Concatenate)       │ 96)               │            │ re_lu_41[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 32, 32,    │      5,472 │ concatenate_13[0… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 32, 32,    │          0 │ re_lu_42[0][0]    │
# │ (Dropout)           │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 64, 64,    │      4,608 │ dropout_16[0][0]  │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 64, 64,    │        576 │ EfficientNetV2S_… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 64, 64,    │          0 │ re_lu_43[0][0]    │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 64, 64,    │          0 │ dropout_17[0][0], │
# │ (Concatenate)       │ 48)               │            │ re_lu_44[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 64, 64,    │      1,584 │ concatenate_14[0… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 64, 64,    │          0 │ re_lu_45[0][0]    │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 128, 128,  │        576 │ dropout_18[0][0]  │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 28,010,298 (106.85 MB)
#  Trainable params: 27,851,770 (106.25 MB)
#  Non-trainable params: 158,528 (619.25 KB)
# Iniciando entrenamiento por 150 épocas...
# Epoch 1/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.2734 - dice_coefficient: 0.0939 - iou_metric: 0.1595 - loss: 2.2187
# Epoch 1: val_dice_coefficient improved from -inf to 0.08748, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 247s 435ms/step - accuracy: 0.2737 - dice_coefficient: 0.0939 - iou_metric: 0.1597 - loss: 2.2180 - val_accuracy: 0.2954 - val_dice_coefficient: 0.0875 - val_iou_metric: 0.1714 - val_loss: 2.1758 - learning_rate: 1.0000e-04
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.4308 - dice_coefficient: 0.1199 - iou_metric: 0.2803 - loss: 1.9614
# Epoch 2: val_dice_coefficient improved from 0.08748 to 0.09226, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 29s 266ms/step - accuracy: 0.4311 - dice_coefficient: 0.1199 - iou_metric: 0.2806 - loss: 1.9610 - val_accuracy: 0.5242 - val_dice_coefficient: 0.0923 - val_iou_metric: 0.3517 - val_loss: 2.1200 - learning_rate: 1.0000e-04
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5535 - dice_coefficient: 0.1403 - iou_metric: 0.3915 - loss: 1.8223
# Epoch 3: val_dice_coefficient improved from 0.09226 to 0.10214, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 248ms/step - accuracy: 0.5537 - dice_coefficient: 0.1403 - iou_metric: 0.3917 - loss: 1.8221 - val_accuracy: 0.6322 - val_dice_coefficient: 0.1021 - val_iou_metric: 0.4581 - val_loss: 2.0277 - learning_rate: 1.0000e-04
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6523 - dice_coefficient: 0.1562 - iou_metric: 0.4943 - loss: 1.7472
# Epoch 4: val_dice_coefficient improved from 0.10214 to 0.12443, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 231ms/step - accuracy: 0.6525 - dice_coefficient: 0.1562 - iou_metric: 0.4945 - loss: 1.7471 - val_accuracy: 0.7169 - val_dice_coefficient: 0.1244 - val_iou_metric: 0.5552 - val_loss: 1.8353 - learning_rate: 1.0000e-04
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7420 - dice_coefficient: 0.1668 - iou_metric: 0.6049 - loss: 1.6855
# Epoch 5: val_dice_coefficient improved from 0.12443 to 0.16209, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - accuracy: 0.7422 - dice_coefficient: 0.1668 - iou_metric: 0.6050 - loss: 1.6853 - val_accuracy: 0.8178 - val_dice_coefficient: 0.1621 - val_iou_metric: 0.6900 - val_loss: 1.6261 - learning_rate: 1.0000e-04
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7990 - dice_coefficient: 0.1824 - iou_metric: 0.6817 - loss: 1.6142
# Epoch 6: val_dice_coefficient improved from 0.16209 to 0.18792, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 251ms/step - accuracy: 0.7990 - dice_coefficient: 0.1825 - iou_metric: 0.6818 - loss: 1.6142 - val_accuracy: 0.8607 - val_dice_coefficient: 0.1879 - val_iou_metric: 0.7555 - val_loss: 1.5260 - learning_rate: 1.0000e-04
# Epoch 7/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8224 - dice_coefficient: 0.1993 - iou_metric: 0.7174 - loss: 1.5577
# Epoch 7: val_dice_coefficient improved from 0.18792 to 0.21196, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 268ms/step - accuracy: 0.8224 - dice_coefficient: 0.1993 - iou_metric: 0.7175 - loss: 1.5575 - val_accuracy: 0.8597 - val_dice_coefficient: 0.2120 - val_iou_metric: 0.7560 - val_loss: 1.4566 - learning_rate: 1.0000e-04
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8402 - dice_coefficient: 0.2152 - iou_metric: 0.7415 - loss: 1.5085
# Epoch 8: val_dice_coefficient improved from 0.21196 to 0.22716, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 37s 234ms/step - accuracy: 0.8402 - dice_coefficient: 0.2152 - iou_metric: 0.7415 - loss: 1.5083 - val_accuracy: 0.8678 - val_dice_coefficient: 0.2272 - val_iou_metric: 0.7679 - val_loss: 1.4027 - learning_rate: 1.0000e-04
# Epoch 9/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8561 - dice_coefficient: 0.2354 - iou_metric: 0.7637 - loss: 1.4359
# Epoch 9: val_dice_coefficient improved from 0.22716 to 0.25004, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 257ms/step - accuracy: 0.8562 - dice_coefficient: 0.2354 - iou_metric: 0.7638 - loss: 1.4358 - val_accuracy: 0.8868 - val_dice_coefficient: 0.2500 - val_iou_metric: 0.7977 - val_loss: 1.3269 - learning_rate: 1.0000e-04
# Epoch 10/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8704 - dice_coefficient: 0.2590 - iou_metric: 0.7830 - loss: 1.3692
# Epoch 10: val_dice_coefficient improved from 0.25004 to 0.26553, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - accuracy: 0.8704 - dice_coefficient: 0.2590 - iou_metric: 0.7830 - loss: 1.3691 - val_accuracy: 0.8753 - val_dice_coefficient: 0.2655 - val_iou_metric: 0.7814 - val_loss: 1.2803 - learning_rate: 1.0000e-04
# Epoch 11/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8784 - dice_coefficient: 0.2742 - iou_metric: 0.7948 - loss: 1.3127
# Epoch 11: val_dice_coefficient improved from 0.26553 to 0.29315, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 243ms/step - accuracy: 0.8784 - dice_coefficient: 0.2743 - iou_metric: 0.7948 - loss: 1.3126 - val_accuracy: 0.8826 - val_dice_coefficient: 0.2932 - val_iou_metric: 0.7933 - val_loss: 1.2076 - learning_rate: 1.0000e-04
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8862 - dice_coefficient: 0.3011 - iou_metric: 0.8066 - loss: 1.2510
# Epoch 12: val_dice_coefficient improved from 0.29315 to 0.31712, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 249ms/step - accuracy: 0.8862 - dice_coefficient: 0.3011 - iou_metric: 0.8067 - loss: 1.2508 - val_accuracy: 0.8881 - val_dice_coefficient: 0.3171 - val_iou_metric: 0.8019 - val_loss: 1.1540 - learning_rate: 1.0000e-04
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8941 - dice_coefficient: 0.3243 - iou_metric: 0.8175 - loss: 1.1949
# Epoch 13: val_dice_coefficient improved from 0.31712 to 0.33459, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 29s 268ms/step - accuracy: 0.8941 - dice_coefficient: 0.3244 - iou_metric: 0.8175 - loss: 1.1948 - val_accuracy: 0.8828 - val_dice_coefficient: 0.3346 - val_iou_metric: 0.7935 - val_loss: 1.1260 - learning_rate: 1.0000e-04
# Epoch 14/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9022 - dice_coefficient: 0.3485 - iou_metric: 0.8297 - loss: 1.1422
# Epoch 14: val_dice_coefficient improved from 0.33459 to 0.35800, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 45s 306ms/step - accuracy: 0.9022 - dice_coefficient: 0.3485 - iou_metric: 0.8297 - loss: 1.1421 - val_accuracy: 0.8944 - val_dice_coefficient: 0.3580 - val_iou_metric: 0.8105 - val_loss: 1.0721 - learning_rate: 1.0000e-04
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9017 - dice_coefficient: 0.3675 - iou_metric: 0.8295 - loss: 1.1166
# Epoch 15: val_dice_coefficient improved from 0.35800 to 0.36453, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 34s 241ms/step - accuracy: 0.9017 - dice_coefficient: 0.3675 - iou_metric: 0.8295 - loss: 1.1165 - val_accuracy: 0.8895 - val_dice_coefficient: 0.3645 - val_iou_metric: 0.8050 - val_loss: 1.0864 - learning_rate: 1.0000e-04
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9022 - dice_coefficient: 0.3824 - iou_metric: 0.8297 - loss: 1.0927
# Epoch 16: val_dice_coefficient improved from 0.36453 to 0.38671, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 25s 235ms/step - accuracy: 0.9021 - dice_coefficient: 0.3824 - iou_metric: 0.8297 - loss: 1.0928 - val_accuracy: 0.8867 - val_dice_coefficient: 0.3867 - val_iou_metric: 0.7998 - val_loss: 1.0237 - learning_rate: 1.0000e-04
# Epoch 17/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9088 - dice_coefficient: 0.4038 - iou_metric: 0.8412 - loss: 1.0404
# Epoch 17: val_dice_coefficient improved from 0.38671 to 0.40604, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 257ms/step - accuracy: 0.9088 - dice_coefficient: 0.4038 - iou_metric: 0.8412 - loss: 1.0404 - val_accuracy: 0.9005 - val_dice_coefficient: 0.4060 - val_iou_metric: 0.8208 - val_loss: 0.9864 - learning_rate: 1.0000e-04
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9102 - dice_coefficient: 0.4165 - iou_metric: 0.8426 - loss: 1.0240
# Epoch 18: val_dice_coefficient improved from 0.40604 to 0.41788, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 26s 241ms/step - accuracy: 0.9102 - dice_coefficient: 0.4165 - iou_metric: 0.8426 - loss: 1.0241 - val_accuracy: 0.8998 - val_dice_coefficient: 0.4179 - val_iou_metric: 0.8193 - val_loss: 0.9677 - learning_rate: 1.0000e-04
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9125 - dice_coefficient: 0.4380 - iou_metric: 0.8472 - loss: 0.9917
# Epoch 19: val_dice_coefficient improved from 0.41788 to 0.43115, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 47s 302ms/step - accuracy: 0.9125 - dice_coefficient: 0.4380 - iou_metric: 0.8472 - loss: 0.9917 - val_accuracy: 0.9132 - val_dice_coefficient: 0.4311 - val_iou_metric: 0.8403 - val_loss: 0.9445 - learning_rate: 1.0000e-04
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9146 - dice_coefficient: 0.4418 - iou_metric: 0.8501 - loss: 0.9779
# Epoch 20: val_dice_coefficient improved from 0.43115 to 0.44059, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - accuracy: 0.9146 - dice_coefficient: 0.4418 - iou_metric: 0.8501 - loss: 0.9778 - val_accuracy: 0.9107 - val_dice_coefficient: 0.4406 - val_iou_metric: 0.8375 - val_loss: 0.9305 - learning_rate: 1.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9202 - dice_coefficient: 0.4560 - iou_metric: 0.8596 - loss: 0.9476
# Epoch 21: val_dice_coefficient improved from 0.44059 to 0.44494, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 33s 306ms/step - accuracy: 0.9202 - dice_coefficient: 0.4560 - iou_metric: 0.8596 - loss: 0.9476 - val_accuracy: 0.9114 - val_dice_coefficient: 0.4449 - val_iou_metric: 0.8394 - val_loss: 0.9266 - learning_rate: 1.0000e-04
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9223 - dice_coefficient: 0.4647 - iou_metric: 0.8631 - loss: 0.9416
# Epoch 22: val_dice_coefficient improved from 0.44494 to 0.45229, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 34s 236ms/step - accuracy: 0.9223 - dice_coefficient: 0.4647 - iou_metric: 0.8630 - loss: 0.9416 - val_accuracy: 0.9113 - val_dice_coefficient: 0.4523 - val_iou_metric: 0.8387 - val_loss: 0.9172 - learning_rate: 1.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9252 - dice_coefficient: 0.4785 - iou_metric: 0.8677 - loss: 0.9103
# Epoch 23: val_dice_coefficient improved from 0.45229 to 0.46089, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 54s 366ms/step - accuracy: 0.9251 - dice_coefficient: 0.4784 - iou_metric: 0.8677 - loss: 0.9104 - val_accuracy: 0.9181 - val_dice_coefficient: 0.4609 - val_iou_metric: 0.8491 - val_loss: 0.9050 - learning_rate: 1.0000e-04
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9245 - dice_coefficient: 0.4828 - iou_metric: 0.8670 - loss: 0.9121
# Epoch 24: val_dice_coefficient improved from 0.46089 to 0.46648, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 31s 265ms/step - accuracy: 0.9245 - dice_coefficient: 0.4828 - iou_metric: 0.8670 - loss: 0.9121 - val_accuracy: 0.9180 - val_dice_coefficient: 0.4665 - val_iou_metric: 0.8490 - val_loss: 0.8929 - learning_rate: 1.0000e-04
# Epoch 25/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9248 - dice_coefficient: 0.4900 - iou_metric: 0.8675 - loss: 0.9017
# Epoch 25: val_dice_coefficient improved from 0.46648 to 0.46950, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 45s 305ms/step - accuracy: 0.9248 - dice_coefficient: 0.4900 - iou_metric: 0.8675 - loss: 0.9017 - val_accuracy: 0.9131 - val_dice_coefficient: 0.4695 - val_iou_metric: 0.8413 - val_loss: 0.8831 - learning_rate: 1.0000e-04
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9308 - dice_coefficient: 0.5016 - iou_metric: 0.8770 - loss: 0.8683
# Epoch 26: val_dice_coefficient improved from 0.46950 to 0.47386, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 29s 266ms/step - accuracy: 0.9308 - dice_coefficient: 0.5016 - iou_metric: 0.8769 - loss: 0.8684 - val_accuracy: 0.9148 - val_dice_coefficient: 0.4739 - val_iou_metric: 0.8433 - val_loss: 0.8827 - learning_rate: 1.0000e-04
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9282 - dice_coefficient: 0.5053 - iou_metric: 0.8728 - loss: 0.8683
# Epoch 27: val_dice_coefficient improved from 0.47386 to 0.48120, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 266ms/step - accuracy: 0.9282 - dice_coefficient: 0.5052 - iou_metric: 0.8728 - loss: 0.8684 - val_accuracy: 0.9248 - val_dice_coefficient: 0.4812 - val_iou_metric: 0.8593 - val_loss: 0.8714 - learning_rate: 1.0000e-04
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9334 - dice_coefficient: 0.5131 - iou_metric: 0.8812 - loss: 0.8534
# Epoch 28: val_dice_coefficient improved from 0.48120 to 0.48887, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 271ms/step - accuracy: 0.9334 - dice_coefficient: 0.5131 - iou_metric: 0.8811 - loss: 0.8534 - val_accuracy: 0.9285 - val_dice_coefficient: 0.4889 - val_iou_metric: 0.8669 - val_loss: 0.8564 - learning_rate: 1.0000e-04
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9340 - dice_coefficient: 0.5175 - iou_metric: 0.8815 - loss: 0.8509
# Epoch 29: val_dice_coefficient improved from 0.48887 to 0.49562, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 34s 321ms/step - accuracy: 0.9340 - dice_coefficient: 0.5175 - iou_metric: 0.8815 - loss: 0.8509 - val_accuracy: 0.9380 - val_dice_coefficient: 0.4956 - val_iou_metric: 0.8837 - val_loss: 0.8366 - learning_rate: 1.0000e-04
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9374 - dice_coefficient: 0.5273 - iou_metric: 0.8869 - loss: 0.8350
# Epoch 30: val_dice_coefficient improved from 0.49562 to 0.50611, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 33s 303ms/step - accuracy: 0.9374 - dice_coefficient: 0.5272 - iou_metric: 0.8869 - loss: 0.8351 - val_accuracy: 0.9414 - val_dice_coefficient: 0.5061 - val_iou_metric: 0.8886 - val_loss: 0.8175 - learning_rate: 1.0000e-04
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9377 - dice_coefficient: 0.5366 - iou_metric: 0.8874 - loss: 0.8271
# Epoch 31: val_dice_coefficient improved from 0.50611 to 0.52091, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 33s 307ms/step - accuracy: 0.9378 - dice_coefficient: 0.5367 - iou_metric: 0.8875 - loss: 0.8271 - val_accuracy: 0.9450 - val_dice_coefficient: 0.5209 - val_iou_metric: 0.8948 - val_loss: 0.7971 - learning_rate: 1.0000e-04
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9398 - dice_coefficient: 0.5521 - iou_metric: 0.8905 - loss: 0.7915
# Epoch 32: val_dice_coefficient improved from 0.52091 to 0.53471, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 362ms/step - accuracy: 0.9399 - dice_coefficient: 0.5522 - iou_metric: 0.8905 - loss: 0.7915 - val_accuracy: 0.9518 - val_dice_coefficient: 0.5347 - val_iou_metric: 0.9088 - val_loss: 0.7766 - learning_rate: 1.0000e-04
# Epoch 33/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9416 - dice_coefficient: 0.5546 - iou_metric: 0.8935 - loss: 0.7951
# Epoch 33: val_dice_coefficient improved from 0.53471 to 0.55086, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 35s 304ms/step - accuracy: 0.9416 - dice_coefficient: 0.5546 - iou_metric: 0.8935 - loss: 0.7950 - val_accuracy: 0.9511 - val_dice_coefficient: 0.5509 - val_iou_metric: 0.9075 - val_loss: 0.7522 - learning_rate: 1.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9439 - dice_coefficient: 0.5800 - iou_metric: 0.8966 - loss: 0.7476
# Epoch 34: val_dice_coefficient improved from 0.55086 to 0.56473, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 33s 303ms/step - accuracy: 0.9439 - dice_coefficient: 0.5800 - iou_metric: 0.8967 - loss: 0.7477 - val_accuracy: 0.9510 - val_dice_coefficient: 0.5647 - val_iou_metric: 0.9079 - val_loss: 0.7331 - learning_rate: 1.0000e-04
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9465 - dice_coefficient: 0.5887 - iou_metric: 0.9010 - loss: 0.7299
# Epoch 35: val_dice_coefficient improved from 0.56473 to 0.57152, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 311ms/step - accuracy: 0.9465 - dice_coefficient: 0.5887 - iou_metric: 0.9010 - loss: 0.7299 - val_accuracy: 0.9503 - val_dice_coefficient: 0.5715 - val_iou_metric: 0.9064 - val_loss: 0.7260 - learning_rate: 1.0000e-04
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9461 - dice_coefficient: 0.6028 - iou_metric: 0.9009 - loss: 0.7192
# Epoch 36: val_dice_coefficient improved from 0.57152 to 0.58796, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 38s 355ms/step - accuracy: 0.9461 - dice_coefficient: 0.6028 - iou_metric: 0.9009 - loss: 0.7192 - val_accuracy: 0.9533 - val_dice_coefficient: 0.5880 - val_iou_metric: 0.9113 - val_loss: 0.7014 - learning_rate: 1.0000e-04
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9475 - dice_coefficient: 0.6132 - iou_metric: 0.9034 - loss: 0.6975
# Epoch 37: val_dice_coefficient did not improve from 0.58796
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 24s 194ms/step - accuracy: 0.9475 - dice_coefficient: 0.6132 - iou_metric: 0.9034 - loss: 0.6976 - val_accuracy: 0.9470 - val_dice_coefficient: 0.5873 - val_iou_metric: 0.9006 - val_loss: 0.6981 - learning_rate: 1.0000e-04
# Epoch 38/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9492 - dice_coefficient: 0.6165 - iou_metric: 0.9057 - loss: 0.6920
# Epoch 38: val_dice_coefficient improved from 0.58796 to 0.59853, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 364ms/step - accuracy: 0.9492 - dice_coefficient: 0.6165 - iou_metric: 0.9057 - loss: 0.6920 - val_accuracy: 0.9546 - val_dice_coefficient: 0.5985 - val_iou_metric: 0.9135 - val_loss: 0.6805 - learning_rate: 1.0000e-04
# Epoch 39/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9497 - dice_coefficient: 0.6302 - iou_metric: 0.9070 - loss: 0.6667
# Epoch 39: val_dice_coefficient improved from 0.59853 to 0.60023, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 34s 318ms/step - accuracy: 0.9497 - dice_coefficient: 0.6301 - iou_metric: 0.9070 - loss: 0.6668 - val_accuracy: 0.9529 - val_dice_coefficient: 0.6002 - val_iou_metric: 0.9103 - val_loss: 0.6836 - learning_rate: 1.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9498 - dice_coefficient: 0.6287 - iou_metric: 0.9069 - loss: 0.6691
# Epoch 40: val_dice_coefficient improved from 0.60023 to 0.60245, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 268ms/step - accuracy: 0.9498 - dice_coefficient: 0.6287 - iou_metric: 0.9069 - loss: 0.6691 - val_accuracy: 0.9539 - val_dice_coefficient: 0.6024 - val_iou_metric: 0.9129 - val_loss: 0.6769 - learning_rate: 1.0000e-04
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9476 - dice_coefficient: 0.6366 - iou_metric: 0.9036 - loss: 0.6638
# Epoch 41: val_dice_coefficient improved from 0.60245 to 0.60666, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 43s 402ms/step - accuracy: 0.9476 - dice_coefficient: 0.6366 - iou_metric: 0.9036 - loss: 0.6638 - val_accuracy: 0.9547 - val_dice_coefficient: 0.6067 - val_iou_metric: 0.9140 - val_loss: 0.6691 - learning_rate: 1.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9510 - dice_coefficient: 0.6481 - iou_metric: 0.9091 - loss: 0.6345
# Epoch 42: val_dice_coefficient improved from 0.60666 to 0.60938, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 78s 367ms/step - accuracy: 0.9510 - dice_coefficient: 0.6480 - iou_metric: 0.9091 - loss: 0.6346 - val_accuracy: 0.9508 - val_dice_coefficient: 0.6094 - val_iou_metric: 0.9076 - val_loss: 0.6621 - learning_rate: 1.0000e-04
# Epoch 43/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9505 - dice_coefficient: 0.6462 - iou_metric: 0.9083 - loss: 0.6489
# Epoch 43: val_dice_coefficient improved from 0.60938 to 0.61308, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 34s 314ms/step - accuracy: 0.9505 - dice_coefficient: 0.6462 - iou_metric: 0.9083 - loss: 0.6488 - val_accuracy: 0.9500 - val_dice_coefficient: 0.6131 - val_iou_metric: 0.9061 - val_loss: 0.6547 - learning_rate: 1.0000e-04
# Epoch 44/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9509 - dice_coefficient: 0.6553 - iou_metric: 0.9088 - loss: 0.6292
# Epoch 44: val_dice_coefficient improved from 0.61308 to 0.62174, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 47s 367ms/step - accuracy: 0.9510 - dice_coefficient: 0.6552 - iou_metric: 0.9089 - loss: 0.6292 - val_accuracy: 0.9564 - val_dice_coefficient: 0.6217 - val_iou_metric: 0.9170 - val_loss: 0.6483 - learning_rate: 1.0000e-04
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9506 - dice_coefficient: 0.6565 - iou_metric: 0.9085 - loss: 0.6279
# Epoch 45: val_dice_coefficient improved from 0.62174 to 0.62281, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 365ms/step - accuracy: 0.9506 - dice_coefficient: 0.6565 - iou_metric: 0.9085 - loss: 0.6278 - val_accuracy: 0.9546 - val_dice_coefficient: 0.6228 - val_iou_metric: 0.9135 - val_loss: 0.6414 - learning_rate: 1.0000e-04
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9513 - dice_coefficient: 0.6612 - iou_metric: 0.9100 - loss: 0.6176
# Epoch 46: val_dice_coefficient improved from 0.62281 to 0.62552, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 37s 345ms/step - accuracy: 0.9513 - dice_coefficient: 0.6612 - iou_metric: 0.9100 - loss: 0.6176 - val_accuracy: 0.9562 - val_dice_coefficient: 0.6255 - val_iou_metric: 0.9170 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 47/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9538 - dice_coefficient: 0.6592 - iou_metric: 0.9140 - loss: 0.6114
# Epoch 47: val_dice_coefficient improved from 0.62552 to 0.63383, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 374ms/step - accuracy: 0.9538 - dice_coefficient: 0.6592 - iou_metric: 0.9140 - loss: 0.6115 - val_accuracy: 0.9569 - val_dice_coefficient: 0.6338 - val_iou_metric: 0.9185 - val_loss: 0.6282 - learning_rate: 1.0000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9533 - dice_coefficient: 0.6666 - iou_metric: 0.9129 - loss: 0.6023
# Epoch 48: val_dice_coefficient did not improve from 0.63383
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 23s 198ms/step - accuracy: 0.9533 - dice_coefficient: 0.6667 - iou_metric: 0.9129 - loss: 0.6023 - val_accuracy: 0.9558 - val_dice_coefficient: 0.6241 - val_iou_metric: 0.9178 - val_loss: 0.6564 - learning_rate: 1.0000e-04
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9520 - dice_coefficient: 0.6698 - iou_metric: 0.9107 - loss: 0.6016
# Epoch 49: val_dice_coefficient improved from 0.63383 to 0.63863, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 60s 378ms/step - accuracy: 0.9521 - dice_coefficient: 0.6698 - iou_metric: 0.9107 - loss: 0.6015 - val_accuracy: 0.9571 - val_dice_coefficient: 0.6386 - val_iou_metric: 0.9184 - val_loss: 0.6149 - learning_rate: 1.0000e-04
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9548 - dice_coefficient: 0.6841 - iou_metric: 0.9156 - loss: 0.5762
# Epoch 50: val_dice_coefficient improved from 0.63863 to 0.64467, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 367ms/step - accuracy: 0.9548 - dice_coefficient: 0.6841 - iou_metric: 0.9156 - loss: 0.5763 - val_accuracy: 0.9596 - val_dice_coefficient: 0.6447 - val_iou_metric: 0.9233 - val_loss: 0.6135 - learning_rate: 1.0000e-04
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9537 - dice_coefficient: 0.6796 - iou_metric: 0.9140 - loss: 0.5918
# Epoch 51: val_dice_coefficient improved from 0.64467 to 0.64945, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 368ms/step - accuracy: 0.9537 - dice_coefficient: 0.6796 - iou_metric: 0.9140 - loss: 0.5918 - val_accuracy: 0.9569 - val_dice_coefficient: 0.6495 - val_iou_metric: 0.9188 - val_loss: 0.6051 - learning_rate: 1.0000e-04
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9524 - dice_coefficient: 0.6919 - iou_metric: 0.9117 - loss: 0.5679
# Epoch 52: val_dice_coefficient improved from 0.64945 to 0.65447, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 350ms/step - accuracy: 0.9524 - dice_coefficient: 0.6919 - iou_metric: 0.9117 - loss: 0.5678 - val_accuracy: 0.9549 - val_dice_coefficient: 0.6545 - val_iou_metric: 0.9150 - val_loss: 0.5961 - learning_rate: 1.0000e-04
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9537 - dice_coefficient: 0.6913 - iou_metric: 0.9138 - loss: 0.5718
# Epoch 53: val_dice_coefficient improved from 0.65447 to 0.66471, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 28s 263ms/step - accuracy: 0.9537 - dice_coefficient: 0.6913 - iou_metric: 0.9138 - loss: 0.5718 - val_accuracy: 0.9578 - val_dice_coefficient: 0.6647 - val_iou_metric: 0.9206 - val_loss: 0.5798 - learning_rate: 1.0000e-04
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9565 - dice_coefficient: 0.7013 - iou_metric: 0.9190 - loss: 0.5492
# Epoch 54: val_dice_coefficient improved from 0.66471 to 0.67621, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 52s 368ms/step - accuracy: 0.9565 - dice_coefficient: 0.7013 - iou_metric: 0.9190 - loss: 0.5491 - val_accuracy: 0.9574 - val_dice_coefficient: 0.6762 - val_iou_metric: 0.9201 - val_loss: 0.5630 - learning_rate: 1.0000e-04
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9557 - dice_coefficient: 0.7198 - iou_metric: 0.9171 - loss: 0.5252
# Epoch 55: val_dice_coefficient did not improve from 0.67621
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 23s 200ms/step - accuracy: 0.9556 - dice_coefficient: 0.7198 - iou_metric: 0.9171 - loss: 0.5253 - val_accuracy: 0.9560 - val_dice_coefficient: 0.6753 - val_iou_metric: 0.9172 - val_loss: 0.5606 - learning_rate: 1.0000e-04
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9547 - dice_coefficient: 0.7009 - iou_metric: 0.9155 - loss: 0.5524
# Epoch 56: val_dice_coefficient improved from 0.67621 to 0.68201, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 57s 358ms/step - accuracy: 0.9547 - dice_coefficient: 0.7009 - iou_metric: 0.9155 - loss: 0.5523 - val_accuracy: 0.9564 - val_dice_coefficient: 0.6820 - val_iou_metric: 0.9191 - val_loss: 0.5649 - learning_rate: 1.0000e-04
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9554 - dice_coefficient: 0.7198 - iou_metric: 0.9168 - loss: 0.5240
# Epoch 57: val_dice_coefficient improved from 0.68201 to 0.68328, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 36s 308ms/step - accuracy: 0.9554 - dice_coefficient: 0.7198 - iou_metric: 0.9169 - loss: 0.5240 - val_accuracy: 0.9549 - val_dice_coefficient: 0.6833 - val_iou_metric: 0.9189 - val_loss: 0.5656 - learning_rate: 1.0000e-04
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9562 - dice_coefficient: 0.7293 - iou_metric: 0.9181 - loss: 0.5100
# Epoch 58: val_dice_coefficient improved from 0.68328 to 0.68593, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 33s 309ms/step - accuracy: 0.9562 - dice_coefficient: 0.7293 - iou_metric: 0.9181 - loss: 0.5100 - val_accuracy: 0.9568 - val_dice_coefficient: 0.6859 - val_iou_metric: 0.9206 - val_loss: 0.5643 - learning_rate: 1.0000e-04
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9585 - dice_coefficient: 0.7373 - iou_metric: 0.9221 - loss: 0.4919
# Epoch 59: val_dice_coefficient did not improve from 0.68593
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 198ms/step - accuracy: 0.9585 - dice_coefficient: 0.7373 - iou_metric: 0.9221 - loss: 0.4920 - val_accuracy: 0.9562 - val_dice_coefficient: 0.6850 - val_iou_metric: 0.9194 - val_loss: 0.5705 - learning_rate: 1.0000e-04
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9576 - dice_coefficient: 0.7280 - iou_metric: 0.9206 - loss: 0.5093
# Epoch 60: val_dice_coefficient improved from 0.68593 to 0.69653, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 368ms/step - accuracy: 0.9576 - dice_coefficient: 0.7280 - iou_metric: 0.9206 - loss: 0.5093 - val_accuracy: 0.9590 - val_dice_coefficient: 0.6965 - val_iou_metric: 0.9234 - val_loss: 0.5487 - learning_rate: 1.0000e-04
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9585 - dice_coefficient: 0.7439 - iou_metric: 0.9223 - loss: 0.4903
# Epoch 61: val_dice_coefficient improved from 0.69653 to 0.69692, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 365ms/step - accuracy: 0.9585 - dice_coefficient: 0.7439 - iou_metric: 0.9223 - loss: 0.4903 - val_accuracy: 0.9580 - val_dice_coefficient: 0.6969 - val_iou_metric: 0.9209 - val_loss: 0.5442 - learning_rate: 1.0000e-04
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9574 - dice_coefficient: 0.7276 - iou_metric: 0.9201 - loss: 0.5165
# Epoch 62: val_dice_coefficient improved from 0.69692 to 0.70115, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 361ms/step - accuracy: 0.9574 - dice_coefficient: 0.7276 - iou_metric: 0.9201 - loss: 0.5164 - val_accuracy: 0.9591 - val_dice_coefficient: 0.7011 - val_iou_metric: 0.9233 - val_loss: 0.5454 - learning_rate: 1.0000e-04
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9587 - dice_coefficient: 0.7497 - iou_metric: 0.9225 - loss: 0.4686
# Epoch 63: val_dice_coefficient did not improve from 0.70115
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 197ms/step - accuracy: 0.9587 - dice_coefficient: 0.7497 - iou_metric: 0.9225 - loss: 0.4686 - val_accuracy: 0.9598 - val_dice_coefficient: 0.6962 - val_iou_metric: 0.9237 - val_loss: 0.5532 - learning_rate: 1.0000e-04
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9581 - dice_coefficient: 0.7491 - iou_metric: 0.9215 - loss: 0.4753
# Epoch 64: val_dice_coefficient improved from 0.70115 to 0.70340, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 52s 307ms/step - accuracy: 0.9581 - dice_coefficient: 0.7491 - iou_metric: 0.9216 - loss: 0.4753 - val_accuracy: 0.9579 - val_dice_coefficient: 0.7034 - val_iou_metric: 0.9223 - val_loss: 0.5467 - learning_rate: 1.0000e-04
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9581 - dice_coefficient: 0.7496 - iou_metric: 0.9215 - loss: 0.4818
# Epoch 65: val_dice_coefficient improved from 0.70340 to 0.70821, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 39s 370ms/step - accuracy: 0.9581 - dice_coefficient: 0.7496 - iou_metric: 0.9216 - loss: 0.4818 - val_accuracy: 0.9590 - val_dice_coefficient: 0.7082 - val_iou_metric: 0.9241 - val_loss: 0.5314 - learning_rate: 1.0000e-04
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9606 - dice_coefficient: 0.7583 - iou_metric: 0.9258 - loss: 0.4571
# Epoch 66: val_dice_coefficient did not improve from 0.70821
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 23s 196ms/step - accuracy: 0.9605 - dice_coefficient: 0.7583 - iou_metric: 0.9258 - loss: 0.4572 - val_accuracy: 0.9550 - val_dice_coefficient: 0.6883 - val_iou_metric: 0.9186 - val_loss: 0.6193 - learning_rate: 1.0000e-04
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9585 - dice_coefficient: 0.7461 - iou_metric: 0.9224 - loss: 0.4853
# Epoch 67: val_dice_coefficient did not improve from 0.70821
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.9585 - dice_coefficient: 0.7462 - iou_metric: 0.9224 - loss: 0.4851 - val_accuracy: 0.9575 - val_dice_coefficient: 0.7021 - val_iou_metric: 0.9228 - val_loss: 0.5505 - learning_rate: 1.0000e-04
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9604 - dice_coefficient: 0.7704 - iou_metric: 0.9255 - loss: 0.4424
# Epoch 68: val_dice_coefficient did not improve from 0.70821
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.9604 - dice_coefficient: 0.7704 - iou_metric: 0.9255 - loss: 0.4425 - val_accuracy: 0.9592 - val_dice_coefficient: 0.7064 - val_iou_metric: 0.9236 - val_loss: 0.5313 - learning_rate: 1.0000e-04
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9604 - dice_coefficient: 0.7784 - iou_metric: 0.9255 - loss: 0.4307
# Epoch 69: val_dice_coefficient did not improve from 0.70821
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.9604 - dice_coefficient: 0.7783 - iou_metric: 0.9255 - loss: 0.4309 - val_accuracy: 0.9574 - val_dice_coefficient: 0.7043 - val_iou_metric: 0.9208 - val_loss: 0.5401 - learning_rate: 1.0000e-04
# Epoch 70/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9586 - dice_coefficient: 0.7637 - iou_metric: 0.9223 - loss: 0.4547
# Epoch 70: val_dice_coefficient did not improve from 0.70821
# ...
# Epoch 118/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9650 - dice_coefficient: 0.8249 - iou_metric: 0.9338 - loss: 0.3351
# Epoch 118: val_dice_coefficient did not improve from 0.73293
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 197ms/step - accuracy: 0.9650 - dice_coefficient: 0.8248 - iou_metric: 0.9338 - loss: 0.3352 - val_accuracy: 0.9633 - val_dice_coefficient: 0.7294 - val_iou_metric: 0.9317 - val_loss: 0.5060 - learning_rate: 1.0000e-04
# Epoch 119/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9654 - dice_coefficient: 0.8143 - iou_metric: 0.9345 - loss: 0.3536
# Epoch 119: val_dice_coefficient did not improve from 0.73293
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9654 - dice_coefficient: 0.8143 - iou_metric: 0.9345 - loss: 0.3536 - val_accuracy: 0.9624 - val_dice_coefficient: 0.7279 - val_iou_metric: 0.9312 - val_loss: 0.5202 - learning_rate: 1.0000e-04
# Epoch 120/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9637 - dice_coefficient: 0.8078 - iou_metric: 0.9317 - loss: 0.3759
# Epoch 120: val_dice_coefficient did not improve from 0.73293
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.9637 - dice_coefficient: 0.8078 - iou_metric: 0.9317 - loss: 0.3759 - val_accuracy: 0.9614 - val_dice_coefficient: 0.7327 - val_iou_metric: 0.9297 - val_loss: 0.5048 - learning_rate: 1.0000e-04
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9639 - dice_coefficient: 0.8172 - iou_metric: 0.9319 - loss: 0.3551
# Epoch 121: val_dice_coefficient did not improve from 0.73293
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 196ms/step - accuracy: 0.9639 - dice_coefficient: 0.8171 - iou_metric: 0.9319 - loss: 0.3552 - val_accuracy: 0.9616 - val_dice_coefficient: 0.7328 - val_iou_metric: 0.9297 - val_loss: 0.5047 - learning_rate: 1.0000e-04
# Epoch 122/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9650 - dice_coefficient: 0.8264 - iou_metric: 0.9339 - loss: 0.3390
# Epoch 122: val_dice_coefficient did not improve from 0.73293
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 42s 203ms/step - accuracy: 0.9650 - dice_coefficient: 0.8264 - iou_metric: 0.9339 - loss: 0.3391 - val_accuracy: 0.9606 - val_dice_coefficient: 0.7300 - val_iou_metric: 0.9277 - val_loss: 0.5107 - learning_rate: 1.0000e-04
# Epoch 123/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9655 - dice_coefficient: 0.8165 - iou_metric: 0.9347 - loss: 0.3481
# Epoch 123: val_dice_coefficient improved from 0.73293 to 0.73503, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 61s 400ms/step - accuracy: 0.9655 - dice_coefficient: 0.8165 - iou_metric: 0.9347 - loss: 0.3481 - val_accuracy: 0.9622 - val_dice_coefficient: 0.7350 - val_iou_metric: 0.9305 - val_loss: 0.4999 - learning_rate: 1.0000e-04
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9652 - dice_coefficient: 0.8223 - iou_metric: 0.9342 - loss: 0.3395
# Epoch 124: val_dice_coefficient did not improve from 0.73503
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 201ms/step - accuracy: 0.9652 - dice_coefficient: 0.8223 - iou_metric: 0.9342 - loss: 0.3396 - val_accuracy: 0.9614 - val_dice_coefficient: 0.7283 - val_iou_metric: 0.9294 - val_loss: 0.5155 - learning_rate: 1.0000e-04
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9654 - dice_coefficient: 0.8266 - iou_metric: 0.9346 - loss: 0.3308
# Epoch 125: val_dice_coefficient improved from 0.73503 to 0.73559, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 59s 375ms/step - accuracy: 0.9654 - dice_coefficient: 0.8265 - iou_metric: 0.9346 - loss: 0.3309 - val_accuracy: 0.9624 - val_dice_coefficient: 0.7356 - val_iou_metric: 0.9310 - val_loss: 0.5025 - learning_rate: 1.0000e-04
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9642 - dice_coefficient: 0.8263 - iou_metric: 0.9326 - loss: 0.3346
# Epoch 126: val_dice_coefficient did not improve from 0.73559
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 200ms/step - accuracy: 0.9642 - dice_coefficient: 0.8263 - iou_metric: 0.9326 - loss: 0.3346 - val_accuracy: 0.9626 - val_dice_coefficient: 0.7336 - val_iou_metric: 0.9307 - val_loss: 0.4968 - learning_rate: 1.0000e-04
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9668 - dice_coefficient: 0.8272 - iou_metric: 0.9371 - loss: 0.3285
# Epoch 127: val_dice_coefficient did not improve from 0.73559
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 200ms/step - accuracy: 0.9668 - dice_coefficient: 0.8271 - iou_metric: 0.9371 - loss: 0.3286 - val_accuracy: 0.9626 - val_dice_coefficient: 0.7356 - val_iou_metric: 0.9314 - val_loss: 0.5020 - learning_rate: 1.0000e-04
# Epoch 128/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9641 - dice_coefficient: 0.8295 - iou_metric: 0.9324 - loss: 0.3343
# Epoch 128: val_dice_coefficient did not improve from 0.73559
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 201ms/step - accuracy: 0.9641 - dice_coefficient: 0.8294 - iou_metric: 0.9324 - loss: 0.3344 - val_accuracy: 0.9601 - val_dice_coefficient: 0.7209 - val_iou_metric: 0.9268 - val_loss: 0.5288 - learning_rate: 1.0000e-04
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9648 - dice_coefficient: 0.8228 - iou_metric: 0.9333 - loss: 0.3417
# Epoch 129: val_dice_coefficient did not improve from 0.73559
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 201ms/step - accuracy: 0.9648 - dice_coefficient: 0.8228 - iou_metric: 0.9333 - loss: 0.3418 - val_accuracy: 0.9617 - val_dice_coefficient: 0.7299 - val_iou_metric: 0.9304 - val_loss: 0.5143 - learning_rate: 1.0000e-04
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9644 - dice_coefficient: 0.8267 - iou_metric: 0.9328 - loss: 0.3345
# Epoch 130: val_dice_coefficient improved from 0.73559 to 0.73612, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 40s 373ms/step - accuracy: 0.9644 - dice_coefficient: 0.8267 - iou_metric: 0.9328 - loss: 0.3346 - val_accuracy: 0.9623 - val_dice_coefficient: 0.7361 - val_iou_metric: 0.9314 - val_loss: 0.5034 - learning_rate: 1.0000e-04
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9641 - dice_coefficient: 0.8273 - iou_metric: 0.9324 - loss: 0.3386
# Epoch 131: val_dice_coefficient did not improve from 0.73612
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 201ms/step - accuracy: 0.9641 - dice_coefficient: 0.8272 - iou_metric: 0.9324 - loss: 0.3387 - val_accuracy: 0.9611 - val_dice_coefficient: 0.7321 - val_iou_metric: 0.9291 - val_loss: 0.5109 - learning_rate: 1.0000e-04
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9658 - dice_coefficient: 0.8248 - iou_metric: 0.9351 - loss: 0.3359
# Epoch 132: val_dice_coefficient did not improve from 0.73612
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 200ms/step - accuracy: 0.9658 - dice_coefficient: 0.8248 - iou_metric: 0.9351 - loss: 0.3358 - val_accuracy: 0.9613 - val_dice_coefficient: 0.7312 - val_iou_metric: 0.9294 - val_loss: 0.5066 - learning_rate: 1.0000e-04
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9648 - dice_coefficient: 0.8176 - iou_metric: 0.9334 - loss: 0.3529
# Epoch 133: val_dice_coefficient improved from 0.73612 to 0.73625, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 58s 363ms/step - accuracy: 0.9648 - dice_coefficient: 0.8176 - iou_metric: 0.9335 - loss: 0.3527 - val_accuracy: 0.9615 - val_dice_coefficient: 0.7362 - val_iou_metric: 0.9298 - val_loss: 0.4966 - learning_rate: 1.0000e-04
# Epoch 134/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9670 - dice_coefficient: 0.8287 - iou_metric: 0.9374 - loss: 0.3258
# Epoch 134: val_dice_coefficient improved from 0.73625 to 0.73781, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 38s 354ms/step - accuracy: 0.9670 - dice_coefficient: 0.8287 - iou_metric: 0.9374 - loss: 0.3258 - val_accuracy: 0.9616 - val_dice_coefficient: 0.7378 - val_iou_metric: 0.9298 - val_loss: 0.5000 - learning_rate: 1.0000e-04
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9646 - dice_coefficient: 0.8232 - iou_metric: 0.9333 - loss: 0.3430
# Epoch 135: val_dice_coefficient improved from 0.73781 to 0.74233, saving model to efficient_weed_model_S.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 31s 267ms/step - accuracy: 0.9646 - dice_coefficient: 0.8231 - iou_metric: 0.9333 - loss: 0.3430 - val_accuracy: 0.9615 - val_dice_coefficient: 0.7423 - val_iou_metric: 0.9297 - val_loss: 0.4855 - learning_rate: 1.0000e-04
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9662 - dice_coefficient: 0.8169 - iou_metric: 0.9359 - loss: 0.3546
# Epoch 136: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.9662 - dice_coefficient: 0.8169 - iou_metric: 0.9359 - loss: 0.3546 - val_accuracy: 0.9612 - val_dice_coefficient: 0.7283 - val_iou_metric: 0.9292 - val_loss: 0.5229 - learning_rate: 1.0000e-04
# Epoch 137/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9654 - dice_coefficient: 0.8355 - iou_metric: 0.9347 - loss: 0.3220
# Epoch 137: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.9654 - dice_coefficient: 0.8354 - iou_metric: 0.9347 - loss: 0.3221 - val_accuracy: 0.9613 - val_dice_coefficient: 0.7304 - val_iou_metric: 0.9295 - val_loss: 0.5186 - learning_rate: 1.0000e-04
# Epoch 138/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9654 - dice_coefficient: 0.8313 - iou_metric: 0.9344 - loss: 0.3246
# Epoch 138: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 202ms/step - accuracy: 0.9654 - dice_coefficient: 0.8313 - iou_metric: 0.9344 - loss: 0.3246 - val_accuracy: 0.9617 - val_dice_coefficient: 0.7297 - val_iou_metric: 0.9304 - val_loss: 0.5191 - learning_rate: 1.0000e-04
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9672 - dice_coefficient: 0.8265 - iou_metric: 0.9377 - loss: 0.3317
# Epoch 139: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.9672 - dice_coefficient: 0.8265 - iou_metric: 0.9377 - loss: 0.3318 - val_accuracy: 0.9615 - val_dice_coefficient: 0.7297 - val_iou_metric: 0.9299 - val_loss: 0.5199 - learning_rate: 1.0000e-04
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9659 - dice_coefficient: 0.8270 - iou_metric: 0.9355 - loss: 0.3293
# Epoch 140: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9659 - dice_coefficient: 0.8270 - iou_metric: 0.9356 - loss: 0.3293 - val_accuracy: 0.9630 - val_dice_coefficient: 0.7264 - val_iou_metric: 0.9327 - val_loss: 0.5308 - learning_rate: 1.0000e-04
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9649 - dice_coefficient: 0.8194 - iou_metric: 0.9336 - loss: 0.3455
# Epoch 141: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.9649 - dice_coefficient: 0.8194 - iou_metric: 0.9336 - loss: 0.3454 - val_accuracy: 0.9628 - val_dice_coefficient: 0.7323 - val_iou_metric: 0.9323 - val_loss: 0.5161 - learning_rate: 1.0000e-04
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9666 - dice_coefficient: 0.8241 - iou_metric: 0.9367 - loss: 0.3326
# Epoch 142: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 202ms/step - accuracy: 0.9666 - dice_coefficient: 0.8241 - iou_metric: 0.9367 - loss: 0.3326 - val_accuracy: 0.9620 - val_dice_coefficient: 0.7348 - val_iou_metric: 0.9304 - val_loss: 0.5039 - learning_rate: 1.0000e-04
# Epoch 143/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9652 - dice_coefficient: 0.8218 - iou_metric: 0.9343 - loss: 0.3419
# Epoch 143: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 200ms/step - accuracy: 0.9652 - dice_coefficient: 0.8218 - iou_metric: 0.9343 - loss: 0.3418 - val_accuracy: 0.9622 - val_dice_coefficient: 0.7345 - val_iou_metric: 0.9310 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9665 - dice_coefficient: 0.8311 - iou_metric: 0.9364 - loss: 0.3223
# Epoch 144: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9665 - dice_coefficient: 0.8310 - iou_metric: 0.9364 - loss: 0.3224 - val_accuracy: 0.9629 - val_dice_coefficient: 0.7275 - val_iou_metric: 0.9322 - val_loss: 0.5195 - learning_rate: 1.0000e-04
# Epoch 145/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9644 - dice_coefficient: 0.8245 - iou_metric: 0.9329 - loss: 0.3358
# Epoch 145: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 200ms/step - accuracy: 0.9644 - dice_coefficient: 0.8245 - iou_metric: 0.9329 - loss: 0.3357 - val_accuracy: 0.9627 - val_dice_coefficient: 0.7319 - val_iou_metric: 0.9319 - val_loss: 0.5076 - learning_rate: 1.0000e-04
# Epoch 146/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9685 - dice_coefficient: 0.8373 - iou_metric: 0.9402 - loss: 0.3085
# Epoch 146: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 199ms/step - accuracy: 0.9685 - dice_coefficient: 0.8373 - iou_metric: 0.9402 - loss: 0.3086 - val_accuracy: 0.9627 - val_dice_coefficient: 0.7327 - val_iou_metric: 0.9317 - val_loss: 0.5110 - learning_rate: 1.0000e-04
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9670 - dice_coefficient: 0.8368 - iou_metric: 0.9374 - loss: 0.3117
# Epoch 147: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - accuracy: 0.9670 - dice_coefficient: 0.8367 - iou_metric: 0.9374 - loss: 0.3119 - val_accuracy: 0.9653 - val_dice_coefficient: 0.7357 - val_iou_metric: 0.9350 - val_loss: 0.4963 - learning_rate: 1.0000e-04
# Epoch 148/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9658 - dice_coefficient: 0.8193 - iou_metric: 0.9353 - loss: 0.3413
# Epoch 148: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.9658 - dice_coefficient: 0.8193 - iou_metric: 0.9353 - loss: 0.3413 - val_accuracy: 0.9631 - val_dice_coefficient: 0.7315 - val_iou_metric: 0.9318 - val_loss: 0.5145 - learning_rate: 1.0000e-04
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9673 - dice_coefficient: 0.8297 - iou_metric: 0.9379 - loss: 0.3255
# Epoch 149: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 41s 197ms/step - accuracy: 0.9673 - dice_coefficient: 0.8297 - iou_metric: 0.9379 - loss: 0.3255 - val_accuracy: 0.9655 - val_dice_coefficient: 0.7410 - val_iou_metric: 0.9347 - val_loss: 0.4839 - learning_rate: 1.0000e-04
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9659 - dice_coefficient: 0.8301 - iou_metric: 0.9354 - loss: 0.3285
# Epoch 150: val_dice_coefficient did not improve from 0.74233
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 202ms/step - accuracy: 0.9659 - dice_coefficient: 0.8301 - iou_metric: 0.9354 - loss: 0.3285 - val_accuracy: 0.9607 - val_dice_coefficient: 0.7265 - val_iou_metric: 0.9298 - val_loss: 0.5406 - learning_rate: 1.0000e-04
# Visualizando predicciones...
# Visualizando 4 muestras del conjunto de validación...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'efficient_weed_model_S.keras'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9627 - dice_coefficient: 0.7428 - iou_metric: 0.9305 - loss: 0.5221
# Pérdida en Validación: 0.4855
# Coeficiente de Dice en Validación: 0.7423
# IoU en Validación: 0.9297
# Accuracy en Validación: 0.9615
# Calculando IoU por clase...
# IoU for Background: 0.9491
# IoU for Cow-tongue: 0.9115
# IoU for Dandelion: 0.8997
# IoU for Kikuyo: 0.8953
# IoU for Other: 0.7178
# IoU for Potato: 0.8951
