# %% [markdown]
# <a href="https://colab.research.google.com/github/Masciel-Sevilla/modelos/blob/main/small_a100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6   # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 150
LEARNING_RATE = 1e-4

# --- Paths ---
# Asegúrate de que estas rutas coincidan con la estructura de tus carpetas
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')
# NUEVO: Paths para el conjunto de test, como lo pide tu tarea
TEST_IMAGES_PATH = os.path.join(BASE_PATH, 'test/images')
TEST_MASKS_PATH = os.path.join(BASE_PATH, 'test/masks')


# --- Módulos del modelo (ASPP, DeformableAttention) ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=192, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()
        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()
        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()
        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.2)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))
        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')
        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])
        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)
        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()
        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()
        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

# --- Backbone y Arquitectura del Modelo ---
def create_efficient_backbone(input_shape):
    """Crea el backbone usando EfficientNetV2S y extrae los mapas de características."""
    base_model = tf.keras.applications.EfficientNetV2S(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True
    layer_names = [
        'block1a_project_activation',
        'block2c_add',
        'block3c_add',
        'block6a_expand_activation',
        'top_activation'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2S_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)
    deep_features = feat5_out
    aspp_filters = 192
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)
    decoder_up1 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.2)(decoder_up1)
    feat4_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    decoder_conv_8x8 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.2)(decoder_conv_8x8)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.2)(decoder_up2)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)
    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.2)(decoder_conv_16x16)
    decoder_up3 = layers.Conv2DTranspose(48, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.2)(decoder_up3)
    feat2_processed = layers.Conv2D(48, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)
    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(48, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.2)(decoder_conv_32x32)
    decoder_up4 = layers.Conv2DTranspose(24, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.2)(decoder_up4)
    feat1_processed = layers.Conv2D(24, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)
    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(24, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.2)(decoder_conv_64x64)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    model = Model(inputs=inputs, outputs=outputs, name='EfficientWeedDetectionModel_S')
    return model

# --- Métricas y Funciones de Pérdida ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

# La métrica 'accuracy' es la global accuracy.
# Para mIoU, usaremos iou_metric que es un buen proxy (Mean IoU).
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos ---
def load_and_preprocess_data(image_paths, mask_paths, augment=False):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5: image, mask = tf.image.flip_left_right(image), tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5: image, mask = tf.image.flip_up_down(image), tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5: k = tf.random.uniform([], 1, 4, dtype=tf.int32); image, mask = tf.image.rot90(image, k), tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = tf.data.Dataset.zip((image_ds, mask_ds))

    if augment:
        dataset = dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_weed_model_S.keras'):
    model = create_weed_detection_model()
    model.summary()
    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-5)

    # Aquí ya estás pidiendo las métricas correctas
    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy'] # accuracy es global accuracy
    )
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor='val_iou_metric', save_best_only=True, mode='max', verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_iou_metric', patience=50, mode='max', restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=20, min_lr=1e-7, verbose=1),
    ]
    print(f"Iniciando entrenamiento por {EPOCHS} épocas...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history


# --- Bloque de Ejecución Principal ---
if __name__ == "__main__":
    # 1. Cargar datos de entrenamiento y validación
    train_image_paths = sorted(glob(os.path.join(TRAIN_IMAGES_PATH, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(TRAIN_MASKS_PATH, '*.png')))
    val_image_paths = sorted(glob(os.path.join(VAL_IMAGES_PATH, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(VAL_MASKS_PATH, '*.png')))

    print("Creando datasets de entrenamiento y validación...")
    train_ds = load_and_preprocess_data(train_image_paths, train_mask_paths, augment=True)
    val_ds = load_and_preprocess_data(val_image_paths, val_mask_paths, augment=False)

    # 2. Entrenar el modelo
    model_save_path = 'efficient_weed_model_S_best.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("\n--- Entrenamiento Finalizado ---")
    print(f"El mejor modelo se ha guardado en: {model_save_path}")

    # 3. Cargar el MEJOR modelo guardado para la evaluación final
    print("\nCargando el mejor modelo guardado para la evaluación en el conjunto de test...")
    best_model = tf.keras.models.load_model(
        model_save_path,
        custom_objects={
            'ASPPModule': ASPPModule,
            'DeformableAttention': DeformableAttention,
            'combined_loss': combined_loss,
            'dice_coefficient': dice_coefficient,
            'iou_metric': iou_metric,
            'dice_loss': dice_loss # Añadido por si acaso es necesario
        }
    )

    # 4. Cargar datos de test
    test_image_paths = sorted(glob(os.path.join(TEST_IMAGES_PATH, '*.jpg')))
    test_mask_paths = sorted(glob(os.path.join(TEST_MASKS_PATH, '*.png')))

    if not test_image_paths:
        print("\nADVERTENCIA: No se encontraron imágenes en el directorio de test. Saltando la evaluación de test.")
    else:
        print(f"Se encontraron {len(test_image_paths)} imágenes de test.")
        print("Creando dataset de test...")
        test_ds = load_and_preprocess_data(test_image_paths, test_mask_paths, augment=False)

        # 5. Evaluar en el conjunto de TEST
        print("\n--- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---")
        test_metrics = best_model.evaluate(test_ds)

        print("\n## MÉTRICAS DE TEST - MODELO 'SMALL' ##")
        print(f"Test Loss: {test_metrics[0]:.4f}")
        print(f"Test Dice Coefficient: {test_metrics[1]:.4f}")
        print(f"Test mIoU: {test_metrics[2]:.4f}")
        print(f"Test Global Accuracy: {test_metrics[3]:.4f}")

        # Calcular IoU por clase en el conjunto de test
        print("\nCalculando IoU por clase en el conjunto de test...")
        iou_per_class_values = []
        for images_batch, masks_batch in test_ds:
            predictions_batch = best_model.predict(images_batch, verbose=0)
            iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

        iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()
        class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
        print("\n## IoU por Clase (Test) ##")
        for i, iou in enumerate(iou_per_class_values):
            print(f"IoU for {class_names[i]}: {iou:.4f}")
        print(f"\nPromedio de IoU por clase: {np.mean(iou_per_class_values):.4f}")

        # Mostrar ejemplos de máscaras reales y predichas
        for images_batch, masks_batch in test_ds.take(1):
            predictions_batch = best_model.predict(images_batch)
            plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)

        # Gráficas de Dice Coefficient y Loss durante el entrenamiento
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['dice_coefficient'], label='Dice Coefficient (Train)')
        plt.plot(history.history['val_dice_coefficient'], label='Dice Coefficient (Validation)')
        plt.title('Dice Coefficient over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Dice Coefficient')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Loss (Train)')
        plt.plot(history.history['val_loss'], label='Loss (Validation)')
        plt.title('Loss over Epochs')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()
# Out:
# Creando datasets de entrenamiento y validación...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "EfficientWeedDetectionModel_S"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2S_Ba… │ [(None, 64, 64,   │ 20,331,360 │ input_layer[0][0] │
# │ (Functional)        │ 24), (None, 32,   │            │                   │
# │                     │ 32, 48), (None,   │            │                   │
# │                     │ 16, 16, 64),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 960), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 192) │  7,315,968 │ EfficientNetV2S_… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 192) │     76,992 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 96)  │     73,728 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 96)  │     92,160 │ EfficientNetV2S_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 192) │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 8, 8, 96)  │     20,160 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 96)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 96)  │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     36,864 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      6,144 │ EfficientNetV2S_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_10[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │     20,160 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_12[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     18,432 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      2,304 │ EfficientNetV2S_… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │ 96)               │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      5,472 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      4,608 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │        576 │ EfficientNetV2S_… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_16[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │ 48)               │            │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │      1,584 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_18[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        576 │ dropout_8[0][0]   │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 28,010,298 (106.85 MB)
#  Trainable params: 27,851,770 (106.25 MB)
#  Non-trainable params: 158,528 (619.25 KB)
# Iniciando entrenamiento por 150 épocas...
# Epoch 1/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1218 - dice_coefficient: 0.0831 - iou_metric: 0.0650 - loss: 2.3646
# Epoch 1: val_iou_metric improved from -inf to 0.09450, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 221s 292ms/step - accuracy: 0.1219 - dice_coefficient: 0.0832 - iou_metric: 0.0651 - loss: 2.3642 - val_accuracy: 0.1733 - val_dice_coefficient: 0.0866 - val_iou_metric: 0.0945 - val_loss: 2.2021 - learning_rate: 1.0000e-04
# Epoch 2/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2191 - dice_coefficient: 0.0969 - iou_metric: 0.1250 - loss: 2.1853
# Epoch 2: val_iou_metric improved from 0.09450 to 0.20476, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.2194 - dice_coefficient: 0.0969 - iou_metric: 0.1253 - loss: 2.1846 - val_accuracy: 0.3388 - val_dice_coefficient: 0.0937 - val_iou_metric: 0.2048 - val_loss: 2.0737 - learning_rate: 1.0000e-04
# Epoch 3/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4111 - dice_coefficient: 0.1213 - iou_metric: 0.2686 - loss: 1.9479
# Epoch 3: val_iou_metric improved from 0.20476 to 0.24496, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.4116 - dice_coefficient: 0.1213 - iou_metric: 0.2691 - loss: 1.9474 - val_accuracy: 0.3916 - val_dice_coefficient: 0.1056 - val_iou_metric: 0.2450 - val_loss: 1.9113 - learning_rate: 1.0000e-04
# Epoch 4/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6192 - dice_coefficient: 0.1496 - iou_metric: 0.4628 - loss: 1.7714
# Epoch 4: val_iou_metric improved from 0.24496 to 0.44371, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.6195 - dice_coefficient: 0.1497 - iou_metric: 0.4631 - loss: 1.7712 - val_accuracy: 0.6104 - val_dice_coefficient: 0.1272 - val_iou_metric: 0.4437 - val_loss: 1.7802 - learning_rate: 1.0000e-04
# Epoch 5/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7488 - dice_coefficient: 0.1748 - iou_metric: 0.6156 - loss: 1.6496
# Epoch 5: val_iou_metric improved from 0.44371 to 0.63055, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.7490 - dice_coefficient: 0.1748 - iou_metric: 0.6158 - loss: 1.6495 - val_accuracy: 0.7660 - val_dice_coefficient: 0.1606 - val_iou_metric: 0.6305 - val_loss: 1.6196 - learning_rate: 1.0000e-04
# Epoch 6/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8089 - dice_coefficient: 0.1932 - iou_metric: 0.6950 - loss: 1.5763
# Epoch 6: val_iou_metric improved from 0.63055 to 0.72497, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.8090 - dice_coefficient: 0.1932 - iou_metric: 0.6952 - loss: 1.5760 - val_accuracy: 0.8369 - val_dice_coefficient: 0.1989 - val_iou_metric: 0.7250 - val_loss: 1.4742 - learning_rate: 1.0000e-04
# Epoch 7/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8535 - dice_coefficient: 0.2216 - iou_metric: 0.7574 - loss: 1.4757
# Epoch 7: val_iou_metric improved from 0.72497 to 0.74072, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.8536 - dice_coefficient: 0.2216 - iou_metric: 0.7574 - loss: 1.4755 - val_accuracy: 0.8491 - val_dice_coefficient: 0.2231 - val_iou_metric: 0.7407 - val_loss: 1.3957 - learning_rate: 1.0000e-04
# Epoch 8/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8694 - dice_coefficient: 0.2395 - iou_metric: 0.7814 - loss: 1.4299
# Epoch 8: val_iou_metric improved from 0.74072 to 0.77682, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.8694 - dice_coefficient: 0.2396 - iou_metric: 0.7814 - loss: 1.4297 - val_accuracy: 0.8742 - val_dice_coefficient: 0.2610 - val_iou_metric: 0.7768 - val_loss: 1.2966 - learning_rate: 1.0000e-04
# Epoch 9/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8824 - dice_coefficient: 0.2617 - iou_metric: 0.7994 - loss: 1.3540
# Epoch 9: val_iou_metric improved from 0.77682 to 0.79584, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8824 - dice_coefficient: 0.2619 - iou_metric: 0.7994 - loss: 1.3538 - val_accuracy: 0.8857 - val_dice_coefficient: 0.2833 - val_iou_metric: 0.7958 - val_loss: 1.2462 - learning_rate: 1.0000e-04
# Epoch 10/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8884 - dice_coefficient: 0.2847 - iou_metric: 0.8092 - loss: 1.3033
# Epoch 10: val_iou_metric improved from 0.79584 to 0.80715, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8885 - dice_coefficient: 0.2848 - iou_metric: 0.8092 - loss: 1.3032 - val_accuracy: 0.8928 - val_dice_coefficient: 0.3064 - val_iou_metric: 0.8072 - val_loss: 1.1977 - learning_rate: 1.0000e-04
# Epoch 11/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8944 - dice_coefficient: 0.3025 - iou_metric: 0.8182 - loss: 1.2738
# Epoch 11: val_iou_metric improved from 0.80715 to 0.80811, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.8944 - dice_coefficient: 0.3026 - iou_metric: 0.8182 - loss: 1.2736 - val_accuracy: 0.8939 - val_dice_coefficient: 0.3220 - val_iou_metric: 0.8081 - val_loss: 1.1687 - learning_rate: 1.0000e-04
# Epoch 12/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9000 - dice_coefficient: 0.3221 - iou_metric: 0.8269 - loss: 1.2238
# Epoch 12: val_iou_metric improved from 0.80811 to 0.82159, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9000 - dice_coefficient: 0.3221 - iou_metric: 0.8269 - loss: 1.2237 - val_accuracy: 0.9017 - val_dice_coefficient: 0.3393 - val_iou_metric: 0.8216 - val_loss: 1.1330 - learning_rate: 1.0000e-04
# Epoch 13/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9075 - dice_coefficient: 0.3420 - iou_metric: 0.8386 - loss: 1.1877
# Epoch 13: val_iou_metric improved from 0.82159 to 0.82712, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9075 - dice_coefficient: 0.3419 - iou_metric: 0.8386 - loss: 1.1877 - val_accuracy: 0.9049 - val_dice_coefficient: 0.3518 - val_iou_metric: 0.8271 - val_loss: 1.1105 - learning_rate: 1.0000e-04
# Epoch 14/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9084 - dice_coefficient: 0.3617 - iou_metric: 0.8399 - loss: 1.1582
# Epoch 14: val_iou_metric improved from 0.82712 to 0.83567, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9084 - dice_coefficient: 0.3616 - iou_metric: 0.8399 - loss: 1.1582 - val_accuracy: 0.9102 - val_dice_coefficient: 0.3650 - val_iou_metric: 0.8357 - val_loss: 1.0833 - learning_rate: 1.0000e-04
# Epoch 15/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9120 - dice_coefficient: 0.3709 - iou_metric: 0.8459 - loss: 1.1360
# Epoch 15: val_iou_metric did not improve from 0.83567
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9120 - dice_coefficient: 0.3709 - iou_metric: 0.8459 - loss: 1.1359 - val_accuracy: 0.9097 - val_dice_coefficient: 0.3749 - val_iou_metric: 0.8349 - val_loss: 1.0648 - learning_rate: 1.0000e-04
# Epoch 16/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9111 - dice_coefficient: 0.3817 - iou_metric: 0.8441 - loss: 1.1110
# Epoch 16: val_iou_metric improved from 0.83567 to 0.84366, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9112 - dice_coefficient: 0.3818 - iou_metric: 0.8442 - loss: 1.1108 - val_accuracy: 0.9153 - val_dice_coefficient: 0.3898 - val_iou_metric: 0.8437 - val_loss: 1.0347 - learning_rate: 1.0000e-04
# Epoch 17/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9192 - dice_coefficient: 0.4090 - iou_metric: 0.8574 - loss: 1.0549
# Epoch 17: val_iou_metric improved from 0.84366 to 0.84554, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.9192 - dice_coefficient: 0.4090 - iou_metric: 0.8574 - loss: 1.0548 - val_accuracy: 0.9165 - val_dice_coefficient: 0.4053 - val_iou_metric: 0.8455 - val_loss: 1.0062 - learning_rate: 1.0000e-04
# Epoch 18/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9223 - dice_coefficient: 0.4268 - iou_metric: 0.8623 - loss: 1.0294
# Epoch 18: val_iou_metric improved from 0.84554 to 0.85577, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9223 - dice_coefficient: 0.4267 - iou_metric: 0.8623 - loss: 1.0293 - val_accuracy: 0.9229 - val_dice_coefficient: 0.4208 - val_iou_metric: 0.8558 - val_loss: 0.9736 - learning_rate: 1.0000e-04
# Epoch 19/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9266 - dice_coefficient: 0.4388 - iou_metric: 0.8692 - loss: 1.0046
# Epoch 19: val_iou_metric did not improve from 0.85577
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9266 - dice_coefficient: 0.4388 - iou_metric: 0.8692 - loss: 1.0046 - val_accuracy: 0.9185 - val_dice_coefficient: 0.4319 - val_iou_metric: 0.8497 - val_loss: 0.9683 - learning_rate: 1.0000e-04
# Epoch 20/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9274 - dice_coefficient: 0.4539 - iou_metric: 0.8711 - loss: 0.9673
# Epoch 20: val_iou_metric improved from 0.85577 to 0.85620, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9274 - dice_coefficient: 0.4539 - iou_metric: 0.8711 - loss: 0.9674 - val_accuracy: 0.9217 - val_dice_coefficient: 0.4428 - val_iou_metric: 0.8562 - val_loss: 0.9348 - learning_rate: 1.0000e-04
# Epoch 21/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9293 - dice_coefficient: 0.4701 - iou_metric: 0.8736 - loss: 0.9493
# Epoch 21: val_iou_metric improved from 0.85620 to 0.87120, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9293 - dice_coefficient: 0.4701 - iou_metric: 0.8735 - loss: 0.9493 - val_accuracy: 0.9313 - val_dice_coefficient: 0.4665 - val_iou_metric: 0.8712 - val_loss: 0.8937 - learning_rate: 1.0000e-04
# Epoch 22/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9301 - dice_coefficient: 0.4795 - iou_metric: 0.8754 - loss: 0.9300
# Epoch 22: val_iou_metric improved from 0.87120 to 0.88098, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9301 - dice_coefficient: 0.4795 - iou_metric: 0.8754 - loss: 0.9300 - val_accuracy: 0.9362 - val_dice_coefficient: 0.4775 - val_iou_metric: 0.8810 - val_loss: 0.8696 - learning_rate: 1.0000e-04
# Epoch 23/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9339 - dice_coefficient: 0.4922 - iou_metric: 0.8809 - loss: 0.9016
# Epoch 23: val_iou_metric improved from 0.88098 to 0.89452, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step - accuracy: 0.9339 - dice_coefficient: 0.4922 - iou_metric: 0.8809 - loss: 0.9016 - val_accuracy: 0.9436 - val_dice_coefficient: 0.4981 - val_iou_metric: 0.8945 - val_loss: 0.8362 - learning_rate: 1.0000e-04
# Epoch 24/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9377 - dice_coefficient: 0.5142 - iou_metric: 0.8871 - loss: 0.8625
# Epoch 24: val_iou_metric did not improve from 0.89452
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9377 - dice_coefficient: 0.5142 - iou_metric: 0.8871 - loss: 0.8625 - val_accuracy: 0.9421 - val_dice_coefficient: 0.5114 - val_iou_metric: 0.8922 - val_loss: 0.8145 - learning_rate: 1.0000e-04
# Epoch 25/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9397 - dice_coefficient: 0.5206 - iou_metric: 0.8900 - loss: 0.8566
# Epoch 25: val_iou_metric improved from 0.89452 to 0.89588, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9397 - dice_coefficient: 0.5206 - iou_metric: 0.8900 - loss: 0.8566 - val_accuracy: 0.9445 - val_dice_coefficient: 0.5293 - val_iou_metric: 0.8959 - val_loss: 0.7837 - learning_rate: 1.0000e-04
# Epoch 26/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9381 - dice_coefficient: 0.5324 - iou_metric: 0.8874 - loss: 0.8409
# Epoch 26: val_iou_metric improved from 0.89588 to 0.89780, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9381 - dice_coefficient: 0.5324 - iou_metric: 0.8875 - loss: 0.8408 - val_accuracy: 0.9456 - val_dice_coefficient: 0.5423 - val_iou_metric: 0.8978 - val_loss: 0.7622 - learning_rate: 1.0000e-04
# Epoch 27/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9396 - dice_coefficient: 0.5506 - iou_metric: 0.8896 - loss: 0.8207
# Epoch 27: val_iou_metric did not improve from 0.89780
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9396 - dice_coefficient: 0.5506 - iou_metric: 0.8896 - loss: 0.8205 - val_accuracy: 0.9429 - val_dice_coefficient: 0.5499 - val_iou_metric: 0.8934 - val_loss: 0.7524 - learning_rate: 1.0000e-04
# Epoch 28/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9395 - dice_coefficient: 0.5654 - iou_metric: 0.8898 - loss: 0.7931
# Epoch 28: val_iou_metric improved from 0.89780 to 0.89968, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9395 - dice_coefficient: 0.5654 - iou_metric: 0.8898 - loss: 0.7930 - val_accuracy: 0.9467 - val_dice_coefficient: 0.5622 - val_iou_metric: 0.8997 - val_loss: 0.7352 - learning_rate: 1.0000e-04
# Epoch 29/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9432 - dice_coefficient: 0.5676 - iou_metric: 0.8961 - loss: 0.7856
# Epoch 29: val_iou_metric did not improve from 0.89968
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9432 - dice_coefficient: 0.5677 - iou_metric: 0.8961 - loss: 0.7855 - val_accuracy: 0.9452 - val_dice_coefficient: 0.5696 - val_iou_metric: 0.8971 - val_loss: 0.7255 - learning_rate: 1.0000e-04
# Epoch 30/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9445 - dice_coefficient: 0.5823 - iou_metric: 0.8980 - loss: 0.7638
# Epoch 30: val_iou_metric improved from 0.89968 to 0.90003, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9445 - dice_coefficient: 0.5823 - iou_metric: 0.8980 - loss: 0.7637 - val_accuracy: 0.9471 - val_dice_coefficient: 0.5763 - val_iou_metric: 0.9000 - val_loss: 0.7137 - learning_rate: 1.0000e-04
# Epoch 31/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9480 - dice_coefficient: 0.5932 - iou_metric: 0.9040 - loss: 0.7274
# Epoch 31: val_iou_metric improved from 0.90003 to 0.90690, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9480 - dice_coefficient: 0.5932 - iou_metric: 0.9039 - loss: 0.7275 - val_accuracy: 0.9506 - val_dice_coefficient: 0.5816 - val_iou_metric: 0.9069 - val_loss: 0.7110 - learning_rate: 1.0000e-04
# Epoch 32/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9466 - dice_coefficient: 0.6033 - iou_metric: 0.9018 - loss: 0.7293
# Epoch 32: val_iou_metric did not improve from 0.90690
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9466 - dice_coefficient: 0.6033 - iou_metric: 0.9018 - loss: 0.7293 - val_accuracy: 0.9499 - val_dice_coefficient: 0.5888 - val_iou_metric: 0.9057 - val_loss: 0.6970 - learning_rate: 1.0000e-04
# Epoch 33/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9470 - dice_coefficient: 0.6121 - iou_metric: 0.9022 - loss: 0.7120
# Epoch 33: val_iou_metric did not improve from 0.90690
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9470 - dice_coefficient: 0.6120 - iou_metric: 0.9021 - loss: 0.7122 - val_accuracy: 0.9456 - val_dice_coefficient: 0.5859 - val_iou_metric: 0.8974 - val_loss: 0.7007 - learning_rate: 1.0000e-04
# Epoch 34/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9455 - dice_coefficient: 0.6088 - iou_metric: 0.9004 - loss: 0.7192
# Epoch 34: val_iou_metric did not improve from 0.90690
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9455 - dice_coefficient: 0.6088 - iou_metric: 0.9004 - loss: 0.7193 - val_accuracy: 0.9469 - val_dice_coefficient: 0.5903 - val_iou_metric: 0.9007 - val_loss: 0.6995 - learning_rate: 1.0000e-04
# Epoch 35/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9482 - dice_coefficient: 0.6266 - iou_metric: 0.9043 - loss: 0.6931
# Epoch 35: val_iou_metric did not improve from 0.90690
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9482 - dice_coefficient: 0.6266 - iou_metric: 0.9043 - loss: 0.6931 - val_accuracy: 0.9471 - val_dice_coefficient: 0.5929 - val_iou_metric: 0.9009 - val_loss: 0.6923 - learning_rate: 1.0000e-04
# Epoch 36/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9486 - dice_coefficient: 0.6293 - iou_metric: 0.9049 - loss: 0.6847
# Epoch 36: val_iou_metric improved from 0.90690 to 0.90875, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9486 - dice_coefficient: 0.6293 - iou_metric: 0.9049 - loss: 0.6847 - val_accuracy: 0.9516 - val_dice_coefficient: 0.6014 - val_iou_metric: 0.9087 - val_loss: 0.6808 - learning_rate: 1.0000e-04
# Epoch 37/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9485 - dice_coefficient: 0.6207 - iou_metric: 0.9050 - loss: 0.6939
# Epoch 37: val_iou_metric did not improve from 0.90875
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9485 - dice_coefficient: 0.6207 - iou_metric: 0.9050 - loss: 0.6939 - val_accuracy: 0.9502 - val_dice_coefficient: 0.5975 - val_iou_metric: 0.9062 - val_loss: 0.6896 - learning_rate: 1.0000e-04
# Epoch 38/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9488 - dice_coefficient: 0.6319 - iou_metric: 0.9055 - loss: 0.6819
# Epoch 38: val_iou_metric did not improve from 0.90875
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9488 - dice_coefficient: 0.6319 - iou_metric: 0.9055 - loss: 0.6820 - val_accuracy: 0.9488 - val_dice_coefficient: 0.5998 - val_iou_metric: 0.9036 - val_loss: 0.6819 - learning_rate: 1.0000e-04
# Epoch 39/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9510 - dice_coefficient: 0.6362 - iou_metric: 0.9093 - loss: 0.6657
# Epoch 39: val_iou_metric did not improve from 0.90875
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9510 - dice_coefficient: 0.6362 - iou_metric: 0.9092 - loss: 0.6658 - val_accuracy: 0.9488 - val_dice_coefficient: 0.6005 - val_iou_metric: 0.9029 - val_loss: 0.6790 - learning_rate: 1.0000e-04
# Epoch 40/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9512 - dice_coefficient: 0.6257 - iou_metric: 0.9094 - loss: 0.6805
# Epoch 40: val_iou_metric improved from 0.90875 to 0.90918, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9512 - dice_coefficient: 0.6257 - iou_metric: 0.9094 - loss: 0.6804 - val_accuracy: 0.9521 - val_dice_coefficient: 0.6066 - val_iou_metric: 0.9092 - val_loss: 0.6685 - learning_rate: 1.0000e-04
# Epoch 41/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9502 - dice_coefficient: 0.6472 - iou_metric: 0.9078 - loss: 0.6468
# Epoch 41: val_iou_metric did not improve from 0.90918
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9502 - dice_coefficient: 0.6471 - iou_metric: 0.9078 - loss: 0.6469 - val_accuracy: 0.9492 - val_dice_coefficient: 0.6052 - val_iou_metric: 0.9041 - val_loss: 0.6727 - learning_rate: 1.0000e-04
# Epoch 42/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9506 - dice_coefficient: 0.6448 - iou_metric: 0.9086 - loss: 0.6557
# Epoch 42: val_iou_metric did not improve from 0.90918
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9506 - dice_coefficient: 0.6448 - iou_metric: 0.9087 - loss: 0.6556 - val_accuracy: 0.9492 - val_dice_coefficient: 0.6107 - val_iou_metric: 0.9047 - val_loss: 0.6682 - learning_rate: 1.0000e-04
# Epoch 43/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9511 - dice_coefficient: 0.6515 - iou_metric: 0.9096 - loss: 0.6421
# Epoch 43: val_iou_metric improved from 0.90918 to 0.91207, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9511 - dice_coefficient: 0.6515 - iou_metric: 0.9096 - loss: 0.6420 - val_accuracy: 0.9535 - val_dice_coefficient: 0.6169 - val_iou_metric: 0.9121 - val_loss: 0.6593 - learning_rate: 1.0000e-04
# Epoch 44/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9524 - dice_coefficient: 0.6434 - iou_metric: 0.9120 - loss: 0.6615
# Epoch 44: val_iou_metric improved from 0.91207 to 0.91405, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9524 - dice_coefficient: 0.6434 - iou_metric: 0.9120 - loss: 0.6612 - val_accuracy: 0.9542 - val_dice_coefficient: 0.6167 - val_iou_metric: 0.9140 - val_loss: 0.6605 - learning_rate: 1.0000e-04
# Epoch 45/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9527 - dice_coefficient: 0.6513 - iou_metric: 0.9124 - loss: 0.6432
# Epoch 45: val_iou_metric did not improve from 0.91405
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9527 - dice_coefficient: 0.6513 - iou_metric: 0.9124 - loss: 0.6432 - val_accuracy: 0.9520 - val_dice_coefficient: 0.6122 - val_iou_metric: 0.9095 - val_loss: 0.6635 - learning_rate: 1.0000e-04
# Epoch 46/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9519 - dice_coefficient: 0.6524 - iou_metric: 0.9107 - loss: 0.6462
# Epoch 46: val_iou_metric did not improve from 0.91405
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9519 - dice_coefficient: 0.6524 - iou_metric: 0.9107 - loss: 0.6461 - val_accuracy: 0.9527 - val_dice_coefficient: 0.6161 - val_iou_metric: 0.9112 - val_loss: 0.6581 - learning_rate: 1.0000e-04
# Epoch 47/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9518 - dice_coefficient: 0.6508 - iou_metric: 0.9108 - loss: 0.6467
# Epoch 47: val_iou_metric improved from 0.91405 to 0.91517, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9518 - dice_coefficient: 0.6508 - iou_metric: 0.9108 - loss: 0.6467 - val_accuracy: 0.9547 - val_dice_coefficient: 0.6196 - val_iou_metric: 0.9152 - val_loss: 0.6532 - learning_rate: 1.0000e-04
# Epoch 48/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9565 - dice_coefficient: 0.6614 - iou_metric: 0.9186 - loss: 0.6150
# Epoch 48: val_iou_metric did not improve from 0.91517
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9565 - dice_coefficient: 0.6614 - iou_metric: 0.9186 - loss: 0.6150 - val_accuracy: 0.9536 - val_dice_coefficient: 0.6218 - val_iou_metric: 0.9133 - val_loss: 0.6433 - learning_rate: 1.0000e-04
# Epoch 49/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9558 - dice_coefficient: 0.6716 - iou_metric: 0.9178 - loss: 0.5970
# Epoch 49: val_iou_metric improved from 0.91517 to 0.91554, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9558 - dice_coefficient: 0.6716 - iou_metric: 0.9178 - loss: 0.5971 - val_accuracy: 0.9550 - val_dice_coefficient: 0.6247 - val_iou_metric: 0.9155 - val_loss: 0.6462 - learning_rate: 1.0000e-04
# Epoch 50/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9545 - dice_coefficient: 0.6593 - iou_metric: 0.9155 - loss: 0.6269
# Epoch 50: val_iou_metric did not improve from 0.91554
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9545 - dice_coefficient: 0.6593 - iou_metric: 0.9155 - loss: 0.6269 - val_accuracy: 0.9525 - val_dice_coefficient: 0.6190 - val_iou_metric: 0.9110 - val_loss: 0.6536 - learning_rate: 1.0000e-04
# Epoch 51/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9547 - dice_coefficient: 0.6702 - iou_metric: 0.9157 - loss: 0.6066
# Epoch 51: val_iou_metric did not improve from 0.91554
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9547 - dice_coefficient: 0.6702 - iou_metric: 0.9157 - loss: 0.6067 - val_accuracy: 0.9536 - val_dice_coefficient: 0.6246 - val_iou_metric: 0.9133 - val_loss: 0.6471 - learning_rate: 1.0000e-04
# Epoch 52/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9532 - dice_coefficient: 0.6709 - iou_metric: 0.9132 - loss: 0.6054
# Epoch 52: val_iou_metric did not improve from 0.91554
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9532 - dice_coefficient: 0.6709 - iou_metric: 0.9132 - loss: 0.6054 - val_accuracy: 0.9534 - val_dice_coefficient: 0.6269 - val_iou_metric: 0.9129 - val_loss: 0.6443 - learning_rate: 1.0000e-04
# Epoch 53/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9538 - dice_coefficient: 0.6757 - iou_metric: 0.9142 - loss: 0.6126
# Epoch 53: val_iou_metric did not improve from 0.91554
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9538 - dice_coefficient: 0.6757 - iou_metric: 0.9143 - loss: 0.6124 - val_accuracy: 0.9546 - val_dice_coefficient: 0.6282 - val_iou_metric: 0.9149 - val_loss: 0.6418 - learning_rate: 1.0000e-04
# Epoch 54/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9553 - dice_coefficient: 0.6815 - iou_metric: 0.9169 - loss: 0.5826
# Epoch 54: val_iou_metric improved from 0.91554 to 0.91892, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9553 - dice_coefficient: 0.6815 - iou_metric: 0.9169 - loss: 0.5826 - val_accuracy: 0.9569 - val_dice_coefficient: 0.6334 - val_iou_metric: 0.9189 - val_loss: 0.6359 - learning_rate: 1.0000e-04
# Epoch 55/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9551 - dice_coefficient: 0.6799 - iou_metric: 0.9165 - loss: 0.5936
# Epoch 55: val_iou_metric did not improve from 0.91892
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9551 - dice_coefficient: 0.6798 - iou_metric: 0.9165 - loss: 0.5936 - val_accuracy: 0.9555 - val_dice_coefficient: 0.6339 - val_iou_metric: 0.9173 - val_loss: 0.6352 - learning_rate: 1.0000e-04
# Epoch 56/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9554 - dice_coefficient: 0.6815 - iou_metric: 0.9174 - loss: 0.5853
# Epoch 56: val_iou_metric did not improve from 0.91892
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9554 - dice_coefficient: 0.6814 - iou_metric: 0.9174 - loss: 0.5854 - val_accuracy: 0.9541 - val_dice_coefficient: 0.6360 - val_iou_metric: 0.9146 - val_loss: 0.6255 - learning_rate: 1.0000e-04
# Epoch 57/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9566 - dice_coefficient: 0.6860 - iou_metric: 0.9193 - loss: 0.5740
# Epoch 57: val_iou_metric did not improve from 0.91892
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9566 - dice_coefficient: 0.6860 - iou_metric: 0.9193 - loss: 0.5741 - val_accuracy: 0.9548 - val_dice_coefficient: 0.6390 - val_iou_metric: 0.9158 - val_loss: 0.6217 - learning_rate: 1.0000e-04
# Epoch 58/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9561 - dice_coefficient: 0.6937 - iou_metric: 0.9185 - loss: 0.5615
# Epoch 58: val_iou_metric improved from 0.91892 to 0.92111, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step - accuracy: 0.9561 - dice_coefficient: 0.6937 - iou_metric: 0.9185 - loss: 0.5615 - val_accuracy: 0.9578 - val_dice_coefficient: 0.6522 - val_iou_metric: 0.9211 - val_loss: 0.6026 - learning_rate: 1.0000e-04
# Epoch 59/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9584 - dice_coefficient: 0.6953 - iou_metric: 0.9221 - loss: 0.5577
# Epoch 59: val_iou_metric improved from 0.92111 to 0.92126, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9584 - dice_coefficient: 0.6953 - iou_metric: 0.9221 - loss: 0.5577 - val_accuracy: 0.9578 - val_dice_coefficient: 0.6611 - val_iou_metric: 0.9213 - val_loss: 0.5932 - learning_rate: 1.0000e-04
# Epoch 60/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9571 - dice_coefficient: 0.6879 - iou_metric: 0.9197 - loss: 0.5718
# Epoch 60: val_iou_metric did not improve from 0.92126
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9571 - dice_coefficient: 0.6880 - iou_metric: 0.9197 - loss: 0.5716 - val_accuracy: 0.9562 - val_dice_coefficient: 0.6686 - val_iou_metric: 0.9186 - val_loss: 0.5868 - learning_rate: 1.0000e-04
# Epoch 61/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9579 - dice_coefficient: 0.7170 - iou_metric: 0.9212 - loss: 0.5289
# Epoch 61: val_iou_metric did not improve from 0.92126
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.9579 - dice_coefficient: 0.7170 - iou_metric: 0.9212 - loss: 0.5289 - val_accuracy: 0.9564 - val_dice_coefficient: 0.6796 - val_iou_metric: 0.9183 - val_loss: 0.5642 - learning_rate: 1.0000e-04
# Epoch 62/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9580 - dice_coefficient: 0.7165 - iou_metric: 0.9214 - loss: 0.5317
# Epoch 62: val_iou_metric did not improve from 0.92126
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9580 - dice_coefficient: 0.7165 - iou_metric: 0.9214 - loss: 0.5317 - val_accuracy: 0.9581 - val_dice_coefficient: 0.6849 - val_iou_metric: 0.9212 - val_loss: 0.5535 - learning_rate: 1.0000e-04
# Epoch 63/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9563 - dice_coefficient: 0.7245 - iou_metric: 0.9184 - loss: 0.5382
# Epoch 63: val_iou_metric improved from 0.92126 to 0.92436, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9563 - dice_coefficient: 0.7245 - iou_metric: 0.9185 - loss: 0.5381 - val_accuracy: 0.9597 - val_dice_coefficient: 0.6856 - val_iou_metric: 0.9244 - val_loss: 0.5706 - learning_rate: 1.0000e-04
# Epoch 64/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9581 - dice_coefficient: 0.7284 - iou_metric: 0.9214 - loss: 0.5086
# Epoch 64: val_iou_metric did not improve from 0.92436
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9581 - dice_coefficient: 0.7284 - iou_metric: 0.9214 - loss: 0.5087 - val_accuracy: 0.9556 - val_dice_coefficient: 0.6803 - val_iou_metric: 0.9171 - val_loss: 0.5808 - learning_rate: 1.0000e-04
# Epoch 65/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9567 - dice_coefficient: 0.7343 - iou_metric: 0.9191 - loss: 0.5125
# Epoch 65: val_iou_metric did not improve from 0.92436
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9567 - dice_coefficient: 0.7342 - iou_metric: 0.9191 - loss: 0.5125 - val_accuracy: 0.9576 - val_dice_coefficient: 0.6904 - val_iou_metric: 0.9208 - val_loss: 0.5585 - learning_rate: 1.0000e-04
# Epoch 66/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9595 - dice_coefficient: 0.7402 - iou_metric: 0.9239 - loss: 0.4961
# Epoch 66: val_iou_metric did not improve from 0.92436
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9595 - dice_coefficient: 0.7402 - iou_metric: 0.9239 - loss: 0.4962 - val_accuracy: 0.9577 - val_dice_coefficient: 0.6902 - val_iou_metric: 0.9202 - val_loss: 0.5527 - learning_rate: 1.0000e-04
# Epoch 67/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9585 - dice_coefficient: 0.7442 - iou_metric: 0.9221 - loss: 0.4884
# Epoch 67: val_iou_metric improved from 0.92436 to 0.92670, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.9585 - dice_coefficient: 0.7442 - iou_metric: 0.9221 - loss: 0.4884 - val_accuracy: 0.9607 - val_dice_coefficient: 0.6967 - val_iou_metric: 0.9267 - val_loss: 0.5421 - learning_rate: 1.0000e-04
# Epoch 68/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9590 - dice_coefficient: 0.7415 - iou_metric: 0.9230 - loss: 0.4922
# Epoch 68: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9590 - dice_coefficient: 0.7415 - iou_metric: 0.9230 - loss: 0.4922 - val_accuracy: 0.9570 - val_dice_coefficient: 0.6948 - val_iou_metric: 0.9197 - val_loss: 0.5440 - learning_rate: 1.0000e-04
# Epoch 69/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9574 - dice_coefficient: 0.7496 - iou_metric: 0.9204 - loss: 0.4805
# Epoch 69: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9574 - dice_coefficient: 0.7496 - iou_metric: 0.9204 - loss: 0.4805 - val_accuracy: 0.9598 - val_dice_coefficient: 0.6997 - val_iou_metric: 0.9248 - val_loss: 0.5361 - learning_rate: 1.0000e-04
# Epoch 70/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9584 - dice_coefficient: 0.7400 - iou_metric: 0.9220 - loss: 0.4959
# Epoch 70: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9584 - dice_coefficient: 0.7400 - iou_metric: 0.9220 - loss: 0.4958 - val_accuracy: 0.9572 - val_dice_coefficient: 0.6964 - val_iou_metric: 0.9196 - val_loss: 0.5422 - learning_rate: 1.0000e-04
# Epoch 71/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9563 - dice_coefficient: 0.7506 - iou_metric: 0.9185 - loss: 0.4792
# Epoch 71: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9563 - dice_coefficient: 0.7507 - iou_metric: 0.9185 - loss: 0.4792 - val_accuracy: 0.9578 - val_dice_coefficient: 0.6967 - val_iou_metric: 0.9215 - val_loss: 0.5492 - learning_rate: 1.0000e-04
# Epoch 72/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9604 - dice_coefficient: 0.7579 - iou_metric: 0.9256 - loss: 0.4610
# Epoch 72: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9604 - dice_coefficient: 0.7578 - iou_metric: 0.9256 - loss: 0.4611 - val_accuracy: 0.9595 - val_dice_coefficient: 0.6978 - val_iou_metric: 0.9241 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 73/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9597 - dice_coefficient: 0.7470 - iou_metric: 0.9243 - loss: 0.4796
# Epoch 73: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9597 - dice_coefficient: 0.7470 - iou_metric: 0.9243 - loss: 0.4796 - val_accuracy: 0.9582 - val_dice_coefficient: 0.6946 - val_iou_metric: 0.9217 - val_loss: 0.5544 - learning_rate: 1.0000e-04
# Epoch 74/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9586 - dice_coefficient: 0.7438 - iou_metric: 0.9223 - loss: 0.4905
# Epoch 74: val_iou_metric did not improve from 0.92670
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9586 - dice_coefficient: 0.7440 - iou_metric: 0.9223 - loss: 0.4901 - val_accuracy: 0.9580 - val_dice_coefficient: 0.6990 - val_iou_metric: 0.9205 - val_loss: 0.5339 - learning_rate: 1.0000e-04
# Epoch 75/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9603 - dice_coefficient: 0.7612 - iou_metric: 0.9253 - loss: 0.4539
# Epoch 75: val_iou_metric did not improve from 0.92670
# ...
# Epoch 120/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9648 - dice_coefficient: 0.8143 - iou_metric: 0.9335 - loss: 0.3579
# Epoch 120: val_iou_metric did not improve from 0.93010
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9648 - dice_coefficient: 0.8143 - iou_metric: 0.9335 - loss: 0.3579 - val_accuracy: 0.9626 - val_dice_coefficient: 0.7146 - val_iou_metric: 0.9298 - val_loss: 0.5273 - learning_rate: 1.0000e-04
# Epoch 121/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9657 - dice_coefficient: 0.8146 - iou_metric: 0.9350 - loss: 0.3565
# Epoch 121: val_iou_metric did not improve from 0.93010
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9657 - dice_coefficient: 0.8146 - iou_metric: 0.9350 - loss: 0.3565 - val_accuracy: 0.9613 - val_dice_coefficient: 0.7174 - val_iou_metric: 0.9280 - val_loss: 0.5204 - learning_rate: 1.0000e-04
# Epoch 122/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9624 - dice_coefficient: 0.8136 - iou_metric: 0.9293 - loss: 0.3592
# Epoch 122: val_iou_metric did not improve from 0.93010
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9624 - dice_coefficient: 0.8136 - iou_metric: 0.9294 - loss: 0.3593 - val_accuracy: 0.9614 - val_dice_coefficient: 0.7120 - val_iou_metric: 0.9282 - val_loss: 0.5340 - learning_rate: 1.0000e-04
# Epoch 123/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9651 - dice_coefficient: 0.8150 - iou_metric: 0.9340 - loss: 0.3572
# Epoch 123: val_iou_metric did not improve from 0.93010
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9651 - dice_coefficient: 0.8151 - iou_metric: 0.9340 - loss: 0.3572 - val_accuracy: 0.9619 - val_dice_coefficient: 0.7172 - val_iou_metric: 0.9288 - val_loss: 0.5250 - learning_rate: 1.0000e-04
# Epoch 124/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9657 - dice_coefficient: 0.8095 - iou_metric: 0.9351 - loss: 0.3653
# Epoch 124: val_iou_metric improved from 0.93010 to 0.93067, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9657 - dice_coefficient: 0.8095 - iou_metric: 0.9351 - loss: 0.3652 - val_accuracy: 0.9626 - val_dice_coefficient: 0.7200 - val_iou_metric: 0.9307 - val_loss: 0.5181 - learning_rate: 1.0000e-04
# Epoch 125/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9658 - dice_coefficient: 0.8101 - iou_metric: 0.9352 - loss: 0.3586
# Epoch 125: val_iou_metric improved from 0.93067 to 0.93099, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 91ms/step - accuracy: 0.9658 - dice_coefficient: 0.8102 - iou_metric: 0.9352 - loss: 0.3586 - val_accuracy: 0.9629 - val_dice_coefficient: 0.7218 - val_iou_metric: 0.9310 - val_loss: 0.5159 - learning_rate: 1.0000e-04
# Epoch 126/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9645 - dice_coefficient: 0.8172 - iou_metric: 0.9329 - loss: 0.3519
# Epoch 126: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9645 - dice_coefficient: 0.8172 - iou_metric: 0.9329 - loss: 0.3519 - val_accuracy: 0.9616 - val_dice_coefficient: 0.7185 - val_iou_metric: 0.9287 - val_loss: 0.5256 - learning_rate: 1.0000e-04
# Epoch 127/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9637 - dice_coefficient: 0.8082 - iou_metric: 0.9315 - loss: 0.3752
# Epoch 127: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9637 - dice_coefficient: 0.8082 - iou_metric: 0.9315 - loss: 0.3751 - val_accuracy: 0.9615 - val_dice_coefficient: 0.7173 - val_iou_metric: 0.9282 - val_loss: 0.5249 - learning_rate: 1.0000e-04
# Epoch 128/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9646 - dice_coefficient: 0.8057 - iou_metric: 0.9332 - loss: 0.3776
# Epoch 128: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9647 - dice_coefficient: 0.8058 - iou_metric: 0.9332 - loss: 0.3775 - val_accuracy: 0.9617 - val_dice_coefficient: 0.7187 - val_iou_metric: 0.9289 - val_loss: 0.5167 - learning_rate: 1.0000e-04
# Epoch 129/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9642 - dice_coefficient: 0.8117 - iou_metric: 0.9324 - loss: 0.3644
# Epoch 129: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9642 - dice_coefficient: 0.8117 - iou_metric: 0.9324 - loss: 0.3643 - val_accuracy: 0.9624 - val_dice_coefficient: 0.7186 - val_iou_metric: 0.9298 - val_loss: 0.5213 - learning_rate: 1.0000e-04
# Epoch 130/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9659 - dice_coefficient: 0.8194 - iou_metric: 0.9353 - loss: 0.3431
# Epoch 130: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9659 - dice_coefficient: 0.8194 - iou_metric: 0.9353 - loss: 0.3432 - val_accuracy: 0.9609 - val_dice_coefficient: 0.7149 - val_iou_metric: 0.9271 - val_loss: 0.5228 - learning_rate: 1.0000e-04
# Epoch 131/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9659 - dice_coefficient: 0.8177 - iou_metric: 0.9355 - loss: 0.3475
# Epoch 131: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9659 - dice_coefficient: 0.8177 - iou_metric: 0.9355 - loss: 0.3475 - val_accuracy: 0.9617 - val_dice_coefficient: 0.7180 - val_iou_metric: 0.9287 - val_loss: 0.5197 - learning_rate: 1.0000e-04
# Epoch 132/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9657 - dice_coefficient: 0.8156 - iou_metric: 0.9352 - loss: 0.3552
# Epoch 132: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9657 - dice_coefficient: 0.8156 - iou_metric: 0.9352 - loss: 0.3552 - val_accuracy: 0.9610 - val_dice_coefficient: 0.7157 - val_iou_metric: 0.9270 - val_loss: 0.5202 - learning_rate: 1.0000e-04
# Epoch 133/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9650 - dice_coefficient: 0.8155 - iou_metric: 0.9338 - loss: 0.3512
# Epoch 133: val_iou_metric did not improve from 0.93099
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9650 - dice_coefficient: 0.8155 - iou_metric: 0.9339 - loss: 0.3512 - val_accuracy: 0.9628 - val_dice_coefficient: 0.7220 - val_iou_metric: 0.9299 - val_loss: 0.5123 - learning_rate: 1.0000e-04
# Epoch 134/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9649 - dice_coefficient: 0.8057 - iou_metric: 0.9337 - loss: 0.3652
# Epoch 134: val_iou_metric improved from 0.93099 to 0.93203, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9649 - dice_coefficient: 0.8058 - iou_metric: 0.9337 - loss: 0.3650 - val_accuracy: 0.9636 - val_dice_coefficient: 0.7204 - val_iou_metric: 0.9320 - val_loss: 0.5231 - learning_rate: 1.0000e-04
# Epoch 135/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9650 - dice_coefficient: 0.8184 - iou_metric: 0.9337 - loss: 0.3445
# Epoch 135: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9650 - dice_coefficient: 0.8184 - iou_metric: 0.9338 - loss: 0.3445 - val_accuracy: 0.9620 - val_dice_coefficient: 0.7177 - val_iou_metric: 0.9295 - val_loss: 0.5210 - learning_rate: 1.0000e-04
# Epoch 136/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9667 - dice_coefficient: 0.8248 - iou_metric: 0.9369 - loss: 0.3370
# Epoch 136: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9667 - dice_coefficient: 0.8248 - iou_metric: 0.9369 - loss: 0.3370 - val_accuracy: 0.9626 - val_dice_coefficient: 0.7178 - val_iou_metric: 0.9300 - val_loss: 0.5200 - learning_rate: 1.0000e-04
# Epoch 137/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9647 - dice_coefficient: 0.8233 - iou_metric: 0.9334 - loss: 0.3365
# Epoch 137: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9647 - dice_coefficient: 0.8232 - iou_metric: 0.9334 - loss: 0.3366 - val_accuracy: 0.9622 - val_dice_coefficient: 0.7265 - val_iou_metric: 0.9290 - val_loss: 0.5005 - learning_rate: 1.0000e-04
# Epoch 138/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9663 - dice_coefficient: 0.8214 - iou_metric: 0.9362 - loss: 0.3402
# Epoch 138: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9663 - dice_coefficient: 0.8214 - iou_metric: 0.9362 - loss: 0.3402 - val_accuracy: 0.9630 - val_dice_coefficient: 0.7254 - val_iou_metric: 0.9307 - val_loss: 0.5034 - learning_rate: 1.0000e-04
# Epoch 139/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9654 - dice_coefficient: 0.8242 - iou_metric: 0.9346 - loss: 0.3347
# Epoch 139: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9655 - dice_coefficient: 0.8242 - iou_metric: 0.9346 - loss: 0.3347 - val_accuracy: 0.9628 - val_dice_coefficient: 0.7219 - val_iou_metric: 0.9306 - val_loss: 0.5142 - learning_rate: 1.0000e-04
# Epoch 140/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9656 - dice_coefficient: 0.8155 - iou_metric: 0.9351 - loss: 0.3482
# Epoch 140: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9656 - dice_coefficient: 0.8155 - iou_metric: 0.9351 - loss: 0.3482 - val_accuracy: 0.9628 - val_dice_coefficient: 0.7227 - val_iou_metric: 0.9302 - val_loss: 0.5102 - learning_rate: 1.0000e-04
# Epoch 141/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9634 - dice_coefficient: 0.8097 - iou_metric: 0.9311 - loss: 0.3641
# Epoch 141: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9634 - dice_coefficient: 0.8097 - iou_metric: 0.9311 - loss: 0.3641 - val_accuracy: 0.9632 - val_dice_coefficient: 0.7183 - val_iou_metric: 0.9316 - val_loss: 0.5260 - learning_rate: 1.0000e-04
# Epoch 142/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9663 - dice_coefficient: 0.8193 - iou_metric: 0.9361 - loss: 0.3459
# Epoch 142: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9663 - dice_coefficient: 0.8192 - iou_metric: 0.9361 - loss: 0.3460 - val_accuracy: 0.9627 - val_dice_coefficient: 0.7241 - val_iou_metric: 0.9305 - val_loss: 0.5145 - learning_rate: 1.0000e-04
# Epoch 143/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9664 - dice_coefficient: 0.8262 - iou_metric: 0.9364 - loss: 0.3280
# Epoch 143: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9664 - dice_coefficient: 0.8262 - iou_metric: 0.9364 - loss: 0.3281 - val_accuracy: 0.9629 - val_dice_coefficient: 0.7266 - val_iou_metric: 0.9305 - val_loss: 0.5106 - learning_rate: 1.0000e-04
# Epoch 144/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9649 - dice_coefficient: 0.8273 - iou_metric: 0.9336 - loss: 0.3345
# Epoch 144: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9649 - dice_coefficient: 0.8273 - iou_metric: 0.9337 - loss: 0.3344 - val_accuracy: 0.9616 - val_dice_coefficient: 0.7240 - val_iou_metric: 0.9285 - val_loss: 0.5103 - learning_rate: 1.0000e-04
# Epoch 145/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9650 - dice_coefficient: 0.8322 - iou_metric: 0.9339 - loss: 0.3267
# Epoch 145: val_iou_metric did not improve from 0.93203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9650 - dice_coefficient: 0.8321 - iou_metric: 0.9339 - loss: 0.3267 - val_accuracy: 0.9623 - val_dice_coefficient: 0.7222 - val_iou_metric: 0.9294 - val_loss: 0.5146 - learning_rate: 1.0000e-04
# Epoch 146/150
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9657 - dice_coefficient: 0.8359 - iou_metric: 0.9350 - loss: 0.3187
# Epoch 146: val_iou_metric improved from 0.93203 to 0.93210, saving model to efficient_weed_model_S_best.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9657 - dice_coefficient: 0.8358 - iou_metric: 0.9350 - loss: 0.3189 - val_accuracy: 0.9636 - val_dice_coefficient: 0.7272 - val_iou_metric: 0.9321 - val_loss: 0.5121 - learning_rate: 1.0000e-04
# Epoch 147/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9657 - dice_coefficient: 0.8220 - iou_metric: 0.9350 - loss: 0.3422
# Epoch 147: val_iou_metric did not improve from 0.93210
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9657 - dice_coefficient: 0.8221 - iou_metric: 0.9350 - loss: 0.3421 - val_accuracy: 0.9629 - val_dice_coefficient: 0.7253 - val_iou_metric: 0.9307 - val_loss: 0.5119 - learning_rate: 1.0000e-04
# Epoch 148/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9657 - dice_coefficient: 0.8193 - iou_metric: 0.9351 - loss: 0.3414
# Epoch 148: val_iou_metric did not improve from 0.93210
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9657 - dice_coefficient: 0.8193 - iou_metric: 0.9352 - loss: 0.3413 - val_accuracy: 0.9628 - val_dice_coefficient: 0.7199 - val_iou_metric: 0.9305 - val_loss: 0.5158 - learning_rate: 1.0000e-04
# Epoch 149/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9668 - dice_coefficient: 0.8333 - iou_metric: 0.9371 - loss: 0.3182
# Epoch 149: val_iou_metric did not improve from 0.93210
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9668 - dice_coefficient: 0.8333 - iou_metric: 0.9371 - loss: 0.3182 - val_accuracy: 0.9626 - val_dice_coefficient: 0.7185 - val_iou_metric: 0.9299 - val_loss: 0.5208 - learning_rate: 1.0000e-04
# Epoch 150/150
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9667 - dice_coefficient: 0.8280 - iou_metric: 0.9368 - loss: 0.3291
# Epoch 150: val_iou_metric did not improve from 0.93210
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9667 - dice_coefficient: 0.8280 - iou_metric: 0.9368 - loss: 0.3290 - val_accuracy: 0.9619 - val_dice_coefficient: 0.7197 - val_iou_metric: 0.9288 - val_loss: 0.5197 - learning_rate: 1.0000e-04
#
# --- Entrenamiento Finalizado ---
# El mejor modelo se ha guardado en: efficient_weed_model_S_best.keras
#
# Cargando el mejor modelo guardado para la evaluación en el conjunto de test...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'aspp_module', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Se encontraron 210 imágenes de test.
# Creando dataset de test...
#
# --- EVALUACIÓN FINAL EN EL CONJUNTO DE TEST ---
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 506ms/step - accuracy: 0.9648 - dice_coefficient: 0.6748 - iou_metric: 0.9337 - loss: 0.6475
#
# ## MÉTRICAS DE TEST - MODELO 'SMALL' ##
# Test Loss: 0.5321
# Test Dice Coefficient: 0.7066
# Test mIoU: 0.9404
# Test Global Accuracy: 0.9687
#
# Calculando IoU por clase en el conjunto de test...
#
# ## IoU por Clase (Test) ##
# IoU for Background: 0.9564
# IoU for Cow-tongue: 0.9040
# IoU for Dandelion: 0.9082
# IoU for Kikuyo: 0.9170
# IoU for Other: 0.7028
# IoU for Potato: 0.9052
#
# Promedio de IoU por clase: 0.8823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1078190267.py in <cell line: 0>()
#     354         for images_batch, masks_batch in test_ds.take(1):
#     355             predictions_batch = best_model.predict(images_batch)
# --> 356             plot_sample_masks(images_batch.numpy(), masks_batch.numpy(), predictions_batch)
#     357
#     358         # Gráficas de Dice Coefficient y Loss durante el entrenamiento
#
# NameError: name 'plot_sample_masks' is not defined
